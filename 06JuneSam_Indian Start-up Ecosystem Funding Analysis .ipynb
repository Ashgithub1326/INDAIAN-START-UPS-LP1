# %% [markdown]
# Indian Start-up Ecosystem Funding Analysis (2018-2021)

# %% [markdown]
# Business Understanding

# %% [markdown]
# Summary of the Task:
# This project involves analyzing the funding received by start-ups in India from 2018 to 2021. The goal is to investigate the Indian start-up ecosystem and propose strategic recommendations based on data-driven insights. The datasets are provided for each year, and the analysis will cover start-up details, funding amounts, and investors' information. Data is stored across various sources, and it is crucial to gather, clean, and analyze this data to derive meaningful insights

# %% [markdown]
# Project Name:
# Indian Start-up Funding Project (2018-2021)
#
# Summary of the Task:
# This project involves analyzing the funding received by start-ups in India from 2018 to 2021. The goal is to investigate the Indian start-up ecosystem and propose strategic recommendations based on data-driven insights. The datasets are provided for each year, and the analysis will cover start-up details, funding amounts, and investors' information. Data is stored across various sources, and it is crucial to gather, clean, and analyze this data to derive meaningful insights.
#
# Libraries and Packages:
# pandas for data manipulation and analysis
# numpy for numerical operations
# pyodbc for database connectivity
# sqlalchemy for database ORM (optional)
# matplotlib and seaborn for data visualization
# scikit-learn for machine learning (if applicable)
# python-dotenv for managing environment variables
# requests for handling HTTP requests (if needed)
# os and pathlib for handling file paths and directories

# %% [markdown]
# ## Business Questions
#
# 1.What sectors have shown the highest growth in terms of funding received over the past four years?
#
# 2.What geographical regions within India have emerged as the primary hubs for startup activity and investment, and what factors contribute to their prominence?
#
# 3.Are there any notable differences in funding patterns between early-stage startups and more established companies?
#
# 4.Which sectors recieve the lowest level of funding and which sectors recieve the highest levels of funding in India and what factors contribute to this?
#
# 5.Which investors have more impact on startups over the years?
#
# 6.What are the key characteristics of startups that successfully secure funding, and how do they differ from those that struggle to attract investment?

# %% [markdown]
# Null Hypothesis(Ho): There is no significant difference in the amount of funding between startups in Bangolore.
#
# Alternative Hypothesis(Ha): There is a significant difference in the amount of funding between startups in Bangalore.

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np
import re

import folium
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.subplots import go
from matplotlib.ticker import FuncFormatter
from scipy.stats import f_oneway, shapiro, levene

# Database connectivity
import pyodbc

# Database ORM (optional)
from sqlalchemy import create_engine

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors

# Machine learning (if applicable)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Managing environment variables
from dotenv import dotenv_values

# Handling HTTP requests (if needed)
import requests

# Handling file paths and directories
import os
from pathlib import Path
from geopy.geocoders import Nominatim

import warnings 

warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Data to Python VSO Environment:
#
# 1. Database Connection (2020 and 2021 Data):

# %%
# Load environment variables from .env file into a dictionary
environment_variables = dotenv_values('.env')

# Get the values for the credentials you set in the '.env' file
server = environment_variables.get("SERVER")
database = environment_variables.get("DATABASE")
username = environment_variables.get("UID")
password = environment_variables.get("PWD")

# %%
# Create a connection string
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
# Use the connect method of the pyodbc library and pass in the connection string.
# This will connect to the server and might take a few seconds to be complete. 

connection = pyodbc.connect(connection_string)

# %%
# Now the sql query to get the data is what what you see below. 

#query = "SELECT * FROM LP2_Telco_churn_first_3000"

# select data from 2020

query = "SELECT * FROM dbo.LP1_startup_funding2020"

data20 = pd.read_sql(query, connection)
data20.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10
# 0                      Angel investors  200000.0      None     None
# 1                      GSF Accelerator  100000.0  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital  400000.0      None     None
# 4  Siana Capital Management, Info Edge  340000.0      None     None

# %%
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.5+ KB

# %%
data20.shape
# Out:
# (1055, 10)

# %%
# creating a column to identify each dataset by addition of data year

data20['Funding_Year'] = 2020

#Change the funding year to integer type

data20['Funding_Year'] = data20['Funding_Year'].astype('int64').astype('int32')

data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
#  10  Funding_Year   1055 non-null   int32
# dtypes: float64(2), int32(1), object(8)
# memory usage: 86.7+ KB

# %%
data20.shape
# Out:
# (1055, 11)

# %%
#printing columns to compare if the column names are matching
print(data20.columns)
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'column10', 'Funding_Year'],
#       dtype='object')

# %%
# Renaming some columns

data20.rename(columns = {'Company_Brand' :'Company_Name'}, inplace =True)

data20.rename(columns = {'HeadQuarter': 'Location'}, inplace =True)

data20.head()
# Out:
#    Company_Name  Founded   Location              Sector  \
# 0    Aqgromalin   2019.0    Chennai            AgriTech
# 1      Krayonnz   2019.0  Bangalore              EdTech
# 2  PadCare Labs   2018.0       Pune  Hygiene management
# 3         NCOME   2020.0  New Delhi              Escrow
# 4    Gramophone   2016.0     Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10  \
# 0                      Angel investors  200000.0      None     None
# 1                      GSF Accelerator  100000.0  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital  400000.0      None     None
# 4  Siana Capital Management, Info Edge  340000.0      None     None
#
#    Funding_Year
# 0          2020
# 1          2020
# 2          2020
# 3          2020
# 4          2020

# %%
#select specific columns
data20 = data20[['Company_Name', 'Founded','Location','Sector','What_it_does','Founders','Investor','Amount','Stage','Funding_Year']]
                
data20.head()
# Out:
#    Company_Name  Founded   Location              Sector  \
# 0    Aqgromalin   2019.0    Chennai            AgriTech
# 1      Krayonnz   2019.0  Bangalore              EdTech
# 2  PadCare Labs   2018.0       Pune  Hygiene management
# 3         NCOME   2020.0  New Delhi              Escrow
# 4    Gramophone   2016.0     Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage  Funding_Year
# 0                      Angel investors  200000.0      None          2020
# 1                      GSF Accelerator  100000.0  Pre-seed          2020
# 2                       Venture Center       NaN  Pre-seed          2020
# 3  Venture Catalysts, PointOne Capital  400000.0      None          2020
# 4  Siana Capital Management, Info Edge  340000.0      None          2020

# %%
# Converting the funded column to numeric data
data20['Founded'] = pd.to_numeric(data20['Founded'], errors='coerce').convert_dtypes(int)

# %% [markdown]
# #### Exchange rates
#
# [Source: OFX](https://www.ofx.com/en-au/forex-news/historical-exchange-rates/yearly-average-rates/)
# ```bash
# exchange_rates = {
#     2018: 0.014649,
#     2019: 0.014209,
#     2020: 0.013501,
#     2021: 0.013527
# }

# %%
# Create a function to clean the Amount column of the 2018 DataFrame and convert Indian Rupees to US Dollars

def clean_amount_2020(Amount):
    try:
        Amount = str(Amount)
        # Remove commas
        Amount = Amount.replace(",", "")
        Amount = Amount.replace('—', "")
        # Check if the value is in Indian Rupees and convert US Dollars: Using USD = 68.4113 which was the average annual Indian Rupee to US Dollars in 2018
        if "₹" in Amount:
            Amount = Amount.replace("₹", "")
            return round(float(Amount) * 0.0146, 2)
        # Check if the value is in US Dollars
        elif "$" in Amount:
            Amount = Amount.replace("$", "")
            return round (float(Amount), 2)
        # check if no currency symbol is present, assume US Dollars
        else:
            return round(float(Amount), 2)
    except ValueError:
        # If the value is not a number, return NaN
        return np.nan
        
# Clean the Amount column of the 2018 DataFrame
data20["Amount"] = data20["Amount"].apply(clean_amount_2020)

# %%
# Converting the Amount column to a numeric, there the need to remove some symbols including commas and currency

data20['Amount'] = data20['Amount'].apply(lambda x:str(x).replace('$', ''))

data20['Amount'] = data20['Amount'].apply(lambda x:str(x).replace(',', ''))

data20['Amount'] = data20['Amount'].replace('—', np.nan)

# %%
#Find the number of rows with undisclosed amounts 

index1 = data20.index[data20['Amount']=='Undisclosed']

print('The total number of undisclosed records is', len(index1))
# Out:
# The total number of undisclosed records is 0

# %%
# convert undisclosed to NAN
data20['Amount'] = data20['Amount'].replace('Undisclosed', np.nan)

# %%
#print a summary information on the 2020 data 
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  1055 non-null   object
#  1   Founded       842 non-null    Int64
#  2   Location      961 non-null    object
#  3   Sector        1042 non-null   object
#  4   What_it_does  1055 non-null   object
#  5   Founders      1043 non-null   object
#  6   Investor      1017 non-null   object
#  7   Amount        1055 non-null   object
#  8   Stage         591 non-null    object
#  9   Funding_Year  1055 non-null   int32
# dtypes: Int64(1), int32(1), object(8)
# memory usage: 79.5+ KB

# %%
#Find the row with 887000 23000000 in the amount section
index1 = data20.index[data20['Amount']=='887000 23000000']
index1
# Out:
# Index([], dtype='int64')

# %%
#replace the values with the average 
avg = str((887000+23000000)/2)
data20.at[465, 'Amount'] = avg

# %%
#print the row record to confirm
print(data20.iloc[(465)])
# Out:
# Company_Name                                         True Balance
# Founded                                                      2014
# Location                                                 Gurugram
# Sector                                                    Finance
# What_it_does    Earn money by meeting financial needs of your ...
# Founders                                     Charlie, Jay, Martin
# Investor                                              Balancehero
# Amount                                                 11943500.0
# Stage                                                    Series C
# Funding_Year                                                 2020
# Name: 465, dtype: object

# %%
#Find the row with 800000000 to 850000000 in the amount section
index2 = data20.index[data20['Amount']=='800000000 to 850000000']

# %%
#replace the values with the average 
avg = str((800000000+850000000)/2)

data20.at[472, 'Amount'] = avg

# %%
#print the row record to confirm 
print(data20.iloc[(472)])
# Out:
# Company_Name                                             Eruditus
# Founded                                                      2010
# Location                                                   Mumbai
# Sector                                                  Education
# What_it_does    Bring world-class business and professional ed...
# Founders                     Chaitanya Kalipatnapu, Ashwin Damera
# Investor        Bertelsmann India Investments, Sequoia Capital...
# Amount                                                825000000.0
# Stage                                                        None
# Funding_Year                                                 2020
# Name: 472, dtype: object

# %%
#print a summary information on the 2020 data 
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  1055 non-null   object
#  1   Founded       842 non-null    Int64
#  2   Location      961 non-null    object
#  3   Sector        1042 non-null   object
#  4   What_it_does  1055 non-null   object
#  5   Founders      1043 non-null   object
#  6   Investor      1017 non-null   object
#  7   Amount        1055 non-null   object
#  8   Stage         591 non-null    object
#  9   Funding_Year  1055 non-null   int32
# dtypes: Int64(1), int32(1), object(8)
# memory usage: 79.5+ KB

# %%
duplicates = data20[data20.duplicated()]

duplicates
# Out:
#     Company_Name  Founded   Location                 Sector  \
# 145    Krimanshi     2015    Jodhpur  Biotechnology company
# 205        Nykaa     2012     Mumbai              Cosmetics
# 362       Byju’s     2011  Bangalore                 EdTech
#
#                                           What_it_does         Founders  \
# 145  Krimanshi aims to increase rural income by imp...     Nikhil Bohra
# 205  Nykaa is an online marketplace for different b...    Falguni Nayar
# 362  An Indian educational technology and online tu...  Byju Raveendran
#
#                                            Investor       Amount Stage  \
# 145  Rajasthan Venture Capital Fund, AIM Smart City     600000.0  Seed
# 205                        Alia Bhatt, Katrina Kaif          nan  None
# 362           Owl Ventures, Tiger Global Management  500000000.0  None
#
#      Funding_Year
# 145          2020
# 205          2020
# 362          2020

# %%
#drop all duplicates and leave only one record 

data20 = data20.drop_duplicates(keep='first')

# %%
#Check the 2020 datatset information to confirm the datatypes 
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1052 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  1052 non-null   object
#  1   Founded       839 non-null    Int64
#  2   Location      958 non-null    object
#  3   Sector        1039 non-null   object
#  4   What_it_does  1052 non-null   object
#  5   Founders      1040 non-null   object
#  6   Investor      1014 non-null   object
#  7   Amount        1052 non-null   object
#  8   Stage         590 non-null    object
#  9   Funding_Year  1052 non-null   int32
# dtypes: Int64(1), int32(1), object(8)
# memory usage: 87.3+ KB

# %%
#Check the first set of row 
data20.head()
# Out:
#    Company_Name  Founded   Location              Sector  \
# 0    Aqgromalin     2019    Chennai            AgriTech
# 1      Krayonnz     2019  Bangalore              EdTech
# 2  PadCare Labs     2018       Pune  Hygiene management
# 3         NCOME     2020  New Delhi              Escrow
# 4    Gramophone     2016     Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage  Funding_Year
# 0                      Angel investors  200000.0      None          2020
# 1                      GSF Accelerator  100000.0  Pre-seed          2020
# 2                       Venture Center       nan  Pre-seed          2020
# 3  Venture Catalysts, PointOne Capital  400000.0      None          2020
# 4  Siana Capital Management, Info Edge  340000.0      None          2020

# %%
# select data from 2021

query = "SELECT * FROM dbo.LP1_startup_funding2021"

data21 = pd.read_sql(query, connection)
data21.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
data21.shape
# Out:
# (1209, 9)

# %%
data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
# creating a column to identify each dataset by addition of data year

data21['Funding_Year'] = 2021

# change the Funding_Year to interger type

data21['Funding_Year'] = data21['Funding_Year'].astype('int64').astype('int32')

data21.info()

data21.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
#  9   Funding_Year   1209 non-null   int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 89.9+ KB
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage  \
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed
#
#    Funding_Year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %%
#printing columns to compare if the column names are matching

print(data21.columns)
# Out:
# Index(['Company_Brand', 'Founded', 'HeadQuarter', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Funding_Year'],
#       dtype='object')

# %%
# Renaming some columns

data21.rename(columns = {'Company_Brand' :'Company_Name'}, inplace =True)

data21.rename(columns = {'HeadQuarter': 'Location'}, inplace =True)

data21.head()
# Out:
#      Company_Name  Founded   Location          Sector  \
# 0  Unbox Robotics   2019.0  Bangalore      AI startup
# 1          upGrad   2015.0     Mumbai          EdTech
# 2     Lead School   2012.0     Mumbai          EdTech
# 3         Bizongo   2015.0     Mumbai  B2B E-commerce
# 4        FypMoney   2021.0   Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage  \
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed
#
#    Funding_Year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %%
#select specific columns
data21 = data21[['Company_Name', 'Founded','Location','Sector','What_it_does', 'Founders','Investor','Amount','Stage','Funding_Year']]
                
data21.head()
# Out:
#      Company_Name  Founded   Location          Sector  \
# 0  Unbox Robotics   2019.0  Bangalore      AI startup
# 1          upGrad   2015.0     Mumbai          EdTech
# 2     Lead School   2012.0     Mumbai          EdTech
# 3         Bizongo   2015.0     Mumbai  B2B E-commerce
# 4        FypMoney   2021.0   Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage  \
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed
#
#    Funding_Year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %%
# total undisclosed in the dataset
index5 = data21.index[data21['Amount']=='Undisclosed']

print(len(index5))
# Out:
# 43

# %%
#print the row records 
data21.loc[(index5)].tail()
# Out:
#     Company_Name  Founded   Location      Sector  \
# 824  Avalon Labs   2017.0  Bangalore     FinTech
# 827      Rezo.ai   2017.0      Noida  AI startup
# 833      Polygon   2017.0     Mumbai      Crypto
# 846     Ingenium   2018.0  New Delhi      EdTech
# 853      Celcius   2020.0     Mumbai   Logistics
#
#                                           What_it_does  \
# 824  Avalon Labs incubates, invests, partners with ...
# 827  Conversational AI platform - Innovate the way ...
# 833      Polygon is a blockchain scalability platform.
# 846  Ingenium Education has been pushing e-learning...
# 853  The “ONLINE” Cold Chain network for Reefer tru...
#
#                                           Founders  \
# 824                                    Varun Mayya
# 827                      Manish Gupta, Rashi Gupta
# 833   Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 846  Pramudit Somvanshi, Mohit Patel, Aakash Gupta
# 853       Swarup Bose, Rajneesh Raman, Arbind Jain
#
#                                               Investor       Amount  \
# 824  Tanglin Ventures, Better Capital, Whiteboard C...  Undisclosed
# 827                   Devesh Sachdev, Bhavesh Manglani  Undisclosed
# 833                           Mark Cuban, MiH Ventures  Undisclosed
# 846                                        Lead Angels  Undisclosed
# 853                                Eaglewings Ventures  Undisclosed
#
#             Stage  Funding_Year
# 824  Pre-series A          2021
# 827          Seed          2021
# 833          None          2021
# 846          Seed          2021
# 853          Seed          2021

# %%
# Replace the Undisclosed with NAN

data21['Amount'] = data21['Amount'].replace('Undisclosed', np.nan)

# %%
#print the last 5 row records 
data21.loc[(index5)].tail()
# Out:
#     Company_Name  Founded   Location      Sector  \
# 824  Avalon Labs   2017.0  Bangalore     FinTech
# 827      Rezo.ai   2017.0      Noida  AI startup
# 833      Polygon   2017.0     Mumbai      Crypto
# 846     Ingenium   2018.0  New Delhi      EdTech
# 853      Celcius   2020.0     Mumbai   Logistics
#
#                                           What_it_does  \
# 824  Avalon Labs incubates, invests, partners with ...
# 827  Conversational AI platform - Innovate the way ...
# 833      Polygon is a blockchain scalability platform.
# 846  Ingenium Education has been pushing e-learning...
# 853  The “ONLINE” Cold Chain network for Reefer tru...
#
#                                           Founders  \
# 824                                    Varun Mayya
# 827                      Manish Gupta, Rashi Gupta
# 833   Jaynti Kanani, Sandeep Nailwal, Anurag Arjun
# 846  Pramudit Somvanshi, Mohit Patel, Aakash Gupta
# 853       Swarup Bose, Rajneesh Raman, Arbind Jain
#
#                                               Investor Amount         Stage  \
# 824  Tanglin Ventures, Better Capital, Whiteboard C...    NaN  Pre-series A
# 827                   Devesh Sachdev, Bhavesh Manglani    NaN          Seed
# 833                           Mark Cuban, MiH Ventures    NaN          None
# 846                                        Lead Angels    NaN          Seed
# 853                                Eaglewings Ventures    NaN          Seed
#
#      Funding_Year
# 824          2021
# 827          2021
# 833          2021
# 846          2021
# 853          2021

# %%
# number of upspark in Amount column
index6 = data21.index[data21['Amount']=='Upsparks']

print(len(index6)), index6
# Out:
# 2
# (None, Index([98, 111], dtype='int64'))

# %%
# display them
data21.loc[index6]
# Out:
#     Company_Name  Founded        Location          Sector  \
# 98       FanPlay   2020.0  Computer Games  Computer Games
# 111      FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What_it_does Founders  \
# 98   A real money game app specializing in trivia g...   YC W21
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor    Amount     Stage  Funding_Year
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000          2021
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000          2021

# %%
#drop the duplicate

data21 = data21.drop(labels=index6[1], axis=0)

# %%
#Rearrange the record data correctly 

data21.loc[index6[0], ['Amount', 'Stage']] = ['$1200000', '']

# %%
# dispaly the changes 
data21.iloc[98]
# Out:
# Company_Name                                              FanPlay
# Founded                                                    2020.0
# Location                                           Computer Games
# Sector                                             Computer Games
# What_it_does    A real money game app specializing in trivia g...
# Founders                                                   YC W21
# Investor                              Pritesh Kumar, Bharat Gupta
# Amount                                                   $1200000
# Stage
# Funding_Year                                                 2021
# Name: 98, dtype: object

# %%
# Find element in amount with series C
index7 = data21.index[data21['Amount']=='Series C']

print(len(index7)), index7
# Out:
# 2
# (None, Index([242, 256], dtype='int64'))

# %%
# show the entry
data21.loc[index7]
# Out:
#            Company_Name  Founded                Location  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What_it_does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor    Amount Stage  \
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C  None
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C  None
#
#      Funding_Year
# 242          2021
# 256          2021

# %%
#since its duplicate  drop one 
data21 = data21.drop(labels=index7[1], axis=0)

# %%
#rearrange the columns entery 
data21.loc[index7[0], ['Sector', 'Location', 'Amount', 'Investor', 'Stage']] = ['Pharmaceuticals', '', '$22000000', '', 'Series C']

data21.loc[242]
# Out:
# Company_Name                    Fullife Healthcare
# Founded                                     2009.0
# Location
# Sector                             Pharmaceuticals
# What_it_does                          Varun Khanna
# Founders        Morgan Stanley Private Equity Asia
# Investor
# Amount                                   $22000000
# Stage                                     Series C
# Funding_Year                                  2021
# Name: 242, dtype: object

# %%
index8 = data21.index[data21['Amount']=='Seed']

print(index8)
# Out:
# Index([257, 1148], dtype='int64')

# %%
data21.loc[index8]
# Out:
#      Company_Name  Founded         Location  \
# 257       MoEVing   2021.0  Gurugram\t#REF!
# 1148    Godamwale   2016.0           Mumbai
#
#                                                  Sector  \
# 257   MoEVing is India's only Electric Mobility focu...
# 1148                           Logistics & Supply Chain
#
#                                            What_it_does  \
# 257                         Vikash Mishra, Mragank Jain
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                             Founders        Investor Amount  \
# 257   Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000   Seed
# 1148       Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!   Seed
#
#      Stage  Funding_Year
# 257   None          2021
# 1148  None          2021

# %%
data21.loc[index8[0], ['Sector', 'Location', 'Amount', 'Investor', 'Stage']] = ['Electric Mobility', 'Gurugram', '$5000000', '', 'Seed']
data21.loc[index8[1], ['Amount', 'Investor', 'Stage']] = ['1000000', '', 'Seed']

# %%
data21.loc[257]
# Out:
# Company_Name                                           MoEVing
# Founded                                                 2021.0
# Location                                              Gurugram
# Sector                                       Electric Mobility
# What_it_does                       Vikash Mishra, Mragank Jain
# Founders        Anshuman Maheshwary, Dr Srihari Raju Kalidindi
# Investor
# Amount                                                $5000000
# Stage                                                     Seed
# Funding_Year                                              2021
# Name: 257, dtype: object

# %%
index9 = data21.index[data21['Amount']=='ah! Ventures']

print(index9)
# Out:
# Index([538], dtype='int64')

# %%
data21.loc[index9]
# Out:
#     Company_Name  Founded   Location  Sector  \
# 538  Little Leap   2020.0  New Delhi  EdTech
#
#                             What_it_does  \
# 538  Soft Skills that make Smart Leaders
#
#                                               Founders      Investor  \
# 538  Holistic Development Programs for children in ...  Vishal Gupta
#
#            Amount    Stage  Funding_Year
# 538  ah! Ventures  $300000          2021

# %%
data21.loc[index9, ['Amount', 'Stage']] = ['$300000', '']

# %%
data21.loc[538]
# Out:
# Company_Name                                          Little Leap
# Founded                                                    2020.0
# Location                                                New Delhi
# Sector                                                     EdTech
# What_it_does                  Soft Skills that make Smart Leaders
# Founders        Holistic Development Programs for children in ...
# Investor                                             Vishal Gupta
# Amount                                                    $300000
# Stage
# Funding_Year                                                 2021
# Name: 538, dtype: object

# %%
# Pre-series A
index10 = data21.index[data21['Amount']=='Pre-series A']

index10
# Out:
# Index([545], dtype='int64')

# %%
data21.loc[index10]
# Out:
#     Company_Name  Founded Location  Sector  \
# 545    AdmitKard   2016.0    Noida  EdTech
#
#                                           What_it_does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders  Investor        Amount  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A
#
#     Stage  Funding_Year
# 545  None          2021

# %%
# ITO angel network, letsventure
index11 = data21.index[data21['Amount']=='ITO Angel Network, LetsVenture']

index11
# Out:
# Index([551], dtype='int64')

# %%
data21.loc[index11]
# Out:
#     Company_Name  Founded Location           Sector  \
# 551        BHyve   2020.0   Mumbai  Human Resources
#
#                                           What_it_does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor                          Amount    Stage  \
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture  $300000
#
#      Funding_Year
# 551          2021

# %%
# rearranging 
data21.at[551, 'Amount'] = '$300000'
data21.at[551, 'Investor'] = 'Omkar Pandharkame, Ketaki Ogale, JITO Angel Network, LetsVenture'
data21.at[551, 'Stage'] = ''

# %%
data21.loc[index11]
# Out:
#     Company_Name  Founded Location           Sector  \
# 551        BHyve   2020.0   Mumbai  Human Resources
#
#                                           What_it_does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                                               Investor   Amount Stage  \
# 551  Omkar Pandharkame, Ketaki Ogale, JITO Angel Ne...  $300000
#
#      Funding_Year
# 551          2021

# %%
# JITO Angel Network, LetsVenture
index12 = data21.index[data21['Amount']=='JITO Angel Network, LetsVenture']

index12
# Out:
# Index([677], dtype='int64')

# %%
data21.loc[index12]
# Out:
#          Company_Name  Founded   Location  Sector  \
# 677  Saarthi Pedagogy   2015.0  Ahmadabad  EdTech
#
#                                           What_it_does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor                           Amount     Stage  Funding_Year
# 677  Sushil Agarwal  JITO Angel Network, LetsVenture  $1000000          2021

# %%
# rearranging 
data21.at[677, 'Amount'] = '$1000000'
data21.at[677, 'Investor'] = 'Sushil Agarwal, JITO Angel Network, LetsVenture'
data21.at[677, 'Stage'] = ''

# %%
data21.loc[index12]
# Out:
#          Company_Name  Founded   Location  Sector  \
# 677  Saarthi Pedagogy   2015.0  Ahmadabad  EdTech
#
#                                           What_it_does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#                                             Investor    Amount Stage  \
# 677  Sushil Agarwal, JITO Angel Network, LetsVenture  $1000000
#
#      Funding_Year
# 677          2021

# %%
index13 = data21.index[data21['Amount']=='nan']

data21['Amount'] = data21['Amount'].replace('nan', np.nan)

# %%
index13 = data21.index[data21['Amount']=='nan']

data21['Amount'] = data21['Amount'].replace('nan', np.nan)

# %% [markdown]
# #### Exchange rates
#
# [Source: OFX](https://www.ofx.com/en-au/forex-news/historical-exchange-rates/yearly-average-rates/)
# ```bash
# exchange_rates = {
#     2018: 0.014649,
#     2019: 0.014209,
#     2020: 0.013501,
#     2021: 0.013527
# }

# %%
# Create a function to clean the Amount column of the 2018 DataFrame and convert Indian Rupees to US Dollars

def clean_amount_2021(Amount):
    try:
        Amount = str(Amount)
        # Remove commas
        Amount = Amount.replace(",", "")
        Amount = Amount.replace('—', "")
        # Check if the value is in Indian Rupees and convert US Dollars: Using USD = 68.4113 which was the average annual Indian Rupee to US Dollars in 2018
        if "₹" in Amount:
            Amount = Amount.replace("₹", "")
            return round(float(Amount) * 0.0146, 2)
        # Check if the value is in US Dollars
        elif "$" in Amount:
            Amount = Amount.replace("$", "")
            return round (float(Amount), 2)
        # check if no currency symbol is present, assume US Dollars
        else:
            return round(float(Amount), 2)
    except ValueError:
        # If the value is not a number, return NaN
        return np.nan
        
# Clean the Amount column of the 2018 DataFrame
data21["Amount"] = data21["Amount"].apply(clean_amount_2021)

# %%
# replace $ and , to empty space, - to NAN
data21['Amount'] = data21['Amount'].apply(lambda x:str(x).replace('$', ''))

data21['Amount'] = data21['Amount'].apply(lambda x:str(x).replace(',', ''))

data21['Amount'] = data21['Amount'].replace('—', np.nan)

# %%
data21
# Out:
#         Company_Name  Founded   Location                 Sector  \
# 0     Unbox Robotics   2019.0  Bangalore             AI startup
# 1             upGrad   2015.0     Mumbai                 EdTech
# 2        Lead School   2012.0     Mumbai                 EdTech
# 3            Bizongo   2015.0     Mumbai         B2B E-commerce
# 4           FypMoney   2021.0   Gurugram                FinTech
# ...              ...      ...        ...                    ...
# 1204        Gigforce   2019.0   Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0  New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0  Bangalore     Financial Services
# 1207    CollegeDekho   2015.0   Gurugram                 EdTech
# 1208          WeRize   2019.0  Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor       Amount  \
# 0                       BEENEXT, Entrepreneur First    1200000.0
# 1          Unilazer Ventures, IIFL Asset Management  120000000.0
# 2                  GSV Ventures, Westbridge Capital   30000000.0
# 3                            CDC Group, IDG Capital   51000000.0
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000.0
# ...                                             ...          ...
# 1204                                Endiya Partners    3000000.0
# 1205                                       IIFL AMC   20000000.0
# 1206                                   Owl Ventures   55000000.0
# 1207               Winter Capital, ETS, Man Capital   26000000.0
# 1208                 3one4 Capital, Kalaari Capital    8000000.0
#
#              Stage  Funding_Year
# 0     Pre-series A          2021
# 1             None          2021
# 2         Series D          2021
# 3         Series C          2021
# 4             Seed          2021
# ...            ...           ...
# 1204  Pre-series A          2021
# 1205      Series D          2021
# 1206      Series C          2021
# 1207      Series B          2021
# 1208      Series A          2021
#
# [1207 rows x 10 columns]

# %%
data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1207 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  1207 non-null   object
#  1   Founded       1206 non-null   float64
#  2   Location      1206 non-null   object
#  3   Sector        1207 non-null   object
#  4   What_it_does  1207 non-null   object
#  5   Founders      1203 non-null   object
#  6   Investor      1145 non-null   object
#  7   Amount        1207 non-null   object
#  8   Stage         783 non-null    object
#  9   Funding_Year  1207 non-null   int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 131.3+ KB

# %%
# Considering Location Column
data21.loc[98]
# Out:
# Company_Name                                              FanPlay
# Founded                                                    2020.0
# Location                                           Computer Games
# Sector                                             Computer Games
# What_it_does    A real money game app specializing in trivia g...
# Founders                                                   YC W21
# Investor                              Pritesh Kumar, Bharat Gupta
# Amount                                                  1200000.0
# Stage
# Funding_Year                                                 2021
# Name: 98, dtype: object

# %%
data21.loc[752]
# Out:
# Company_Name                                        NewLink Group
# Founded                                                    2016.0
# Location                                                  Beijing
# Sector                                               Tech Startup
# What_it_does    Developer of an energy management and transpor...
# Founders                                      Yang Wang, Zhen Dai
# Investor                                             Bain Capital
# Amount                                                200000000.0
# Stage                                                        None
# Funding_Year                                                 2021
# Name: 752, dtype: object

# %%
data21['Location'] = data21.Location.str.split(',').str[0]
data21.at[32, 'Location'] = 'Andhra Pradesh'
data21.at[98, 'Location'] = ''
data21.at[241, 'Location'] = ''
data21.at[255, 'Location'] = ''
data21.at[752, 'Location'] = ''
data21.at[1100, 'Location'] = ''
data21.at[1176, 'Location'] = ''

# %%
# Considering Sector Attribute

#data21['Sector'] = data21.Sector.str.split(',').str[0]
#data21.at[1100, 'Sector'] = 'Audio experience'

# %%
data21.head()
# Out:
#      Company_Name  Founded   Location          Sector  \
# 0  Unbox Robotics   2019.0  Bangalore      AI startup
# 1          upGrad   2015.0     Mumbai          EdTech
# 2     Lead School   2012.0     Mumbai          EdTech
# 3         Bizongo   2015.0     Mumbai  B2B E-commerce
# 4        FypMoney   2021.0   Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor       Amount         Stage  \
# 0                    BEENEXT, Entrepreneur First    1200000.0  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  120000000.0          None
# 2               GSV Ventures, Westbridge Capital   30000000.0      Series D
# 3                         CDC Group, IDG Capital   51000000.0      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000.0          Seed
#
#    Funding_Year
# 0          2021
# 1          2021
# 2          2021
# 3          2021
# 4          2021

# %% [markdown]
# Loading Data to Python VSO Environment:
#
# 2. Database Connection (2019 Data):

# %%
# Accessing the data for 2019 can be found in OneDrive. The file name startup_funding2019.csv

data19 = pd.read_csv('startup_funding2019.csv')
data19.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
data19.shape
# Out:
# (89, 9)

# %%
data19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
# Creating a column to identify each dataset by addition of data year
data19['Funding_Year'] = 2019

#Change the funding year to integer type

data19['Funding_Year'] = data19['Funding_Year'].astype('int64').astype('int32')


data19.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage  Funding_Year
# 0            NaN          2019
# 1       Series C          2019
# 2  Fresh funding          2019
# 3       Series D          2019
# 4            NaN          2019

# %%
# rename the columns for consistency 

data19.rename(columns = {'Company/Brand':'Company_Name'}, inplace = True)

data19.rename(columns = {'HeadQuarter':'Location'}, inplace = True)

data19.rename(columns = {'Amount($)':'Amount'}, inplace = True)

data19.rename(columns = {'What it does':'What_it_does'}, inplace = True)

data19.head()
# Out:
#      Company_Name  Founded   Location           Sector  \
# 0  Bombay Shaving      NaN        NaN        Ecommerce
# 1       Ruangguru   2014.0     Mumbai           Edtech
# 2        Eduisfun      NaN     Mumbai           Edtech
# 3        HomeLane   2014.0    Chennai  Interior design
# 4        Nu Genes   2004.0  Telangana         AgriTech
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor        Amount  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage  Funding_Year
# 0            NaN          2019
# 1       Series C          2019
# 2  Fresh funding          2019
# 3       Series D          2019
# 4            NaN          2019

# %%
#select specific columns
data19 = data19[['Company_Name', 'Founded','Location','Sector','What_it_does','Founders','Investor','Amount','Stage','Funding_Year']]
data19.head()
# Out:
#      Company_Name  Founded   Location           Sector  \
# 0  Bombay Shaving      NaN        NaN        Ecommerce
# 1       Ruangguru   2014.0     Mumbai           Edtech
# 2        Eduisfun      NaN     Mumbai           Edtech
# 3        HomeLane   2014.0    Chennai  Interior design
# 4        Nu Genes   2004.0  Telangana         AgriTech
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor        Amount  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage  Funding_Year
# 0            NaN          2019
# 1       Series C          2019
# 2  Fresh funding          2019
# 3       Series D          2019
# 4            NaN          2019

# %%
#check the summarized information on the 2019 dataset 
data19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  89 non-null     object
#  1   Founded       60 non-null     float64
#  2   Location      70 non-null     object
#  3   Sector        84 non-null     object
#  4   What_it_does  89 non-null     object
#  5   Founders      86 non-null     object
#  6   Investor      89 non-null     object
#  7   Amount        89 non-null     object
#  8   Stage         43 non-null     object
#  9   Funding_Year  89 non-null     int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 6.7+ KB

# %% [markdown]
# ##### Exchange rates
#
# [Source: OFX](https://www.ofx.com/en-au/forex-news/historical-exchange-rates/yearly-average-rates/)
# ```bash
# exchange_rates = {
#     2018: 0.014649,
#     2019: 0.014209,
#     2020: 0.013501,
#     2021: 0.013527
# }

# %%
# Create a function to clean the Amount column of the 2018 DataFrame and convert Indian Rupees to US Dollars

def clean_amount_2019(Amount):
    try:
        Amount = str(Amount)
        # Remove commas
        Amount = Amount.replace(",", "")
        Amount = Amount.replace('—', "")
        # Check if the value is in Indian Rupees and convert US Dollars: Using USD = 68.4113 which was the average annual Indian Rupee to US Dollars in 2018
        if "₹" in Amount:
            Amount = Amount.replace("₹", "")
            return round(float(Amount) * 0.0142, 2)
        # Check if the value is in US Dollars
        elif "$" in Amount:
            Amount = Amount.replace("$", "")
            return round (float(Amount), 2)
        # check if no currency symbol is present, assume US Dollars
        else:
            return round(float(Amount), 2)
    except ValueError:
        # If the value is not a number, return NaN
        return np.nan
        
# Clean the Amount column of the 2018 DataFrame
data19["Amount"] = data19["Amount"].apply(clean_amount_2019)

# %%
#To convert the column to a numerical one, there the need to remove some symbols including commas and currency

data19['Amount'] = data19['Amount'].apply(lambda x:str(x).replace('₹', ''))

data19['Amount'] = data19['Amount'].apply(lambda x:str(x).replace('$', ''))

data19['Amount'] = data19['Amount'].apply(lambda x:str(x).replace(',', ''))

data19['Amount'] = data19['Amount'].replace('—', np.nan)

# %%
#Some rows-values in the amount column are undisclosed 
# Extract the rows with undisclosed funding information 

index_new = data19.index[data19['Amount']=='Undisclosed']
#Print the number of rows with such undisclosed values
print('The number of values with undisclosed amount is ', len(index_new))
# Out:
# The number of values with undisclosed amount is  0

# %%
#check out these records 
data19.loc[(index_new)]
# Out:
# Empty DataFrame
# Columns: [Company_Name, Founded, Location, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year]
# Index: []

# %%
#Since undisclosed amounts does not provide any intelligenc, 
#we decided to drop rows with such characteristics 
# Replace the undisclosed amounts with an empty string

data19['Amount'] = data19['Amount'].replace('Undisclosed', np.nan)

# %%
#check out these records 
data19.loc[(index_new)]
# Out:
# Empty DataFrame
# Columns: [Company_Name, Founded, Location, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year]
# Index: []

# %%
#Convert the Amount column to float 

#data19['Amount'] = pd.to_numeric(data19['Amount'], errors='coerce')

# %%
#Check the first 5 rows of the dataset 
data19.head()
# Out:
#      Company_Name  Founded   Location           Sector  \
# 0  Bombay Shaving      NaN        NaN        Ecommerce
# 1       Ruangguru   2014.0     Mumbai           Edtech
# 2        Eduisfun      NaN     Mumbai           Edtech
# 3        HomeLane   2014.0    Chennai  Interior design
# 4        Nu Genes   2004.0  Telangana         AgriTech
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor       Amount  \
# 0                               Sixth Sense Ventures    6300000.0
# 1                                   General Atlantic  150000000.0
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000.0
# 4           Innovation in Food and Agriculture (IFA)    6000000.0
#
#            Stage  Funding_Year
# 0            NaN          2019
# 1       Series C          2019
# 2  Fresh funding          2019
# 3       Series D          2019
# 4            NaN          2019

# %%
#Check the summary information of the dataset 
data19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  89 non-null     object
#  1   Founded       60 non-null     float64
#  2   Location      70 non-null     object
#  3   Sector        84 non-null     object
#  4   What_it_does  89 non-null     object
#  5   Founders      86 non-null     object
#  6   Investor      89 non-null     object
#  7   Amount        89 non-null     object
#  8   Stage         43 non-null     object
#  9   Funding_Year  89 non-null     int32
# dtypes: float64(1), int32(1), object(8)
# memory usage: 6.7+ KB

# %%
#Check if there are any NULL VALUES 
data19.isna().any().sum()
# Out:
# 5

# %%
#find duplicates 

duplicate = data19[data19.duplicated()]

duplicate
# Out:
# Empty DataFrame
# Columns: [Company_Name, Founded, Location, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year]
# Index: []

# %%
data19['Amount'].unique()
# Out:
# array(['6300000.0', '150000000.0', '28000000.0', '30000000.0',
#        '6000000.0', 'nan', '1000000.0', '20000000.0', '275000000.0',
#        '22000000.0', '5000000.0', '140500.0', '540000000.0', '15000000.0',
#        '182700.0', '12000000.0', '11000000.0', '15500000.0', '1500000.0',
#        '5500000.0', '2500000.0', '140000.0', '230000000.0', '49400000.0',
#        '32000000.0', '26000000.0', '150000.0', '400000.0', '2000000.0',
#        '100000000.0', '8000000.0', '100000.0', '50000000.0',
#        '120000000.0', '4000000.0', '6800000.0', '36000000.0', '5700000.0',
#        '25000000.0', '600000.0', '70000000.0', '60000000.0', '220000.0',
#        '2800000.0', '2100000.0', '7000000.0', '311000000.0', '4800000.0',
#        '693000000.0', '33000000.0'], dtype=object)

# %% [markdown]
# Loading Data to Python VSO Environment:
#
# 2. Database Connection (2018 Data):

# %%
# The third data (data for 2018) is hosted on this GitHub Repository, in file called startup_funding2018.csv

data18 = pd.read_csv('startup_funding2018.csv')
data18.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
data18.shape
# Out:
# (526, 6)

# %%
data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
# rename the columns for consistency 

#industry --> sector 
#Round/Series --> stage 

data18.rename(columns = {'Company Name':'Company_Name'}, inplace = True)

data18.rename(columns = {'headquarter':'Location'}, inplace = True)

data18.rename(columns = {'Industry':'Sector'}, inplace = True)

data18.rename(columns = {'Round/Series':'Stage'}, inplace = True)

data18.rename(columns = {'About Company': 'What_it_does'}, inplace = True)

# Add founded, investor, What_it_does, Founders, funding year as a column 
data18['Founded'] = np.nan
data18['Investor'] = np.nan
data18['Founders'] = np.nan
data18
# Out:
#           Company_Name                                             Sector  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#         Stage       Amount                          Location  \
# 0        Seed       250000       Bangalore, Karnataka, India
# 1        Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2    Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3       Angel      2000000       Noida, Uttar Pradesh, India
# 4        Seed            —  Hyderabad, Andhra Pradesh, India
# ..        ...          ...                               ...
# 521  Series C    225000000       Bangalore, Karnataka, India
# 522  Series A            —           Haryana, Haryana, India
# 523      Seed         7500        Mumbai, Maharashtra, India
# 524      Seed  ₹35,000,000        Mumbai, Maharashtra, India
# 525  Series C     35000000        Chennai, Tamil Nadu, India
#
#                                           What_it_does  Founded  Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      NaN       NaN
# 1    A startup which aggregates milk from dairy far...      NaN       NaN
# 2            Leading Online Loans Marketplace in India      NaN       NaN
# 3    PayMe India is an innovative FinTech organizat...      NaN       NaN
# 4    Eunimart is a one stop solution for merchants ...      NaN       NaN
# ..                                                 ...      ...       ...
# 521  Udaan is a B2B trade platform, designed specif...      NaN       NaN
# 522            HappyEasyGo is an online travel domain.      NaN       NaN
# 523  Mombay is a unique opportunity for housewives ...      NaN       NaN
# 524  Droni Tech manufacture UAVs and develop softwa...      NaN       NaN
# 525       Welcome to India's most convenient pharmacy!      NaN       NaN
#
#      Founders
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 521       NaN
# 522       NaN
# 523       NaN
# 524       NaN
# 525       NaN
#
# [526 rows x 9 columns]

# %%
# Creating a column to identify each dataset by addition of data year

data18['Funding_Year'] = 2018

#Change the funding year to integer type 

data18['Funding_Year'] = data18['Funding_Year'].astype('int64').astype('int32')

data18.head()
# Out:
#       Company_Name                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage       Amount                          Location  \
# 0      Seed       250000       Bangalore, Karnataka, India
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What_it_does  Founded  Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN       NaN
# 1  A startup which aggregates milk from dairy far...      NaN       NaN
# 2          Leading Online Loans Marketplace in India      NaN       NaN
# 3  PayMe India is an innovative FinTech organizat...      NaN       NaN
# 4  Eunimart is a one stop solution for merchants ...      NaN       NaN
#
#    Founders  Funding_Year
# 0       NaN          2018
# 1       NaN          2018
# 2       NaN          2018
# 3       NaN          2018
# 4       NaN          2018

# %%
#select specific columns
data18 = data18[['Company_Name', 'Founded','Location','Sector', 'What_it_does', 'Founders','Investor','Amount','Stage','Funding_Year']]
                
data18.head()
# Out:
#       Company_Name  Founded                          Location  \
# 0  TheCollegeFever      NaN       Bangalore, Karnataka, India
# 1  Happy Cow Dairy      NaN        Mumbai, Maharashtra, India
# 2       MyLoanCare      NaN           Gurgaon, Haryana, India
# 3      PayMe India      NaN       Noida, Uttar Pradesh, India
# 4         Eunimart      NaN  Hyderabad, Andhra Pradesh, India
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does  Founders  Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...       NaN       NaN
# 1  A startup which aggregates milk from dairy far...       NaN       NaN
# 2          Leading Online Loans Marketplace in India       NaN       NaN
# 3  PayMe India is an innovative FinTech organizat...       NaN       NaN
# 4  Eunimart is a one stop solution for merchants ...       NaN       NaN
#
#         Amount     Stage  Funding_Year
# 0       250000      Seed          2018
# 1  ₹40,000,000      Seed          2018
# 2  ₹65,000,000  Series A          2018
# 3      2000000     Angel          2018
# 4            —      Seed          2018

# %%
#check the shape of the dataset 
data18.shape
# Out:
# (526, 10)

# %%
#check if there are any Null Values
data18.isna().any()
# Out:
# Company_Name    False
# Founded          True
# Location        False
# Sector          False
# What_it_does    False
# Founders         True
# Investor         True
# Amount          False
# Stage           False
# Funding_Year    False
# dtype: bool

# %%
#Strip the location column to only the city-area. 
data18['Location'] = data18.Location.str.split(',').str[0]
data18['Location'].head()
# Out:
# 0    Bangalore
# 1       Mumbai
# 2      Gurgaon
# 3        Noida
# 4    Hyderabad
# Name: Location, dtype: object

# %%
data18
# Out:
#           Company_Name  Founded   Location  \
# 0      TheCollegeFever      NaN  Bangalore
# 1      Happy Cow Dairy      NaN     Mumbai
# 2           MyLoanCare      NaN    Gurgaon
# 3          PayMe India      NaN      Noida
# 4             Eunimart      NaN  Hyderabad
# ..                 ...      ...        ...
# 521              Udaan      NaN  Bangalore
# 522  Happyeasygo Group      NaN    Haryana
# 523             Mombay      NaN     Mumbai
# 524         Droni Tech      NaN     Mumbai
# 525            Netmeds      NaN    Chennai
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does  Founders  Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...       NaN       NaN
# 1    A startup which aggregates milk from dairy far...       NaN       NaN
# 2            Leading Online Loans Marketplace in India       NaN       NaN
# 3    PayMe India is an innovative FinTech organizat...       NaN       NaN
# 4    Eunimart is a one stop solution for merchants ...       NaN       NaN
# ..                                                 ...       ...       ...
# 521  Udaan is a B2B trade platform, designed specif...       NaN       NaN
# 522            HappyEasyGo is an online travel domain.       NaN       NaN
# 523  Mombay is a unique opportunity for housewives ...       NaN       NaN
# 524  Droni Tech manufacture UAVs and develop softwa...       NaN       NaN
# 525       Welcome to India's most convenient pharmacy!       NaN       NaN
#
#           Amount     Stage  Funding_Year
# 0         250000      Seed          2018
# 1    ₹40,000,000      Seed          2018
# 2    ₹65,000,000  Series A          2018
# 3        2000000     Angel          2018
# 4              —      Seed          2018
# ..           ...       ...           ...
# 521    225000000  Series C          2018
# 522            —  Series A          2018
# 523         7500      Seed          2018
# 524  ₹35,000,000      Seed          2018
# 525     35000000  Series C          2018
#
# [526 rows x 10 columns]

# %% [markdown]
# ##### Exchange rates
#
# [Source: OFX](https://www.ofx.com/en-au/forex-news/historical-exchange-rates/yearly-average-rates/)
# ```bash
# exchange_rates = {
#     2018: 0.014649,
#     2019: 0.014209,
#     2020: 0.013501,
#     2021: 0.013527
# }

# %%
# Create a function to clean the Amount column of the 2018 DataFrame and convert Indian Rupees to US Dollars

def clean_amount_2018(Amount):
    try:
        Amount = str(Amount)
        # Remove commas
        Amount = Amount.replace(",", "")
        Amount = Amount.replace('—', "")
        # Check if the value is in Indian Rupees and convert US Dollars: Using USD = 68.4113 which was the average annual Indian Rupee to US Dollars in 2018
        if "₹" in Amount:
            Amount = Amount.replace("₹", "")
            return round(float(Amount) * 0.0146, 2)
        # Check if the value is in US Dollars
        elif "$" in Amount:
            Amount = Amount.replace("$", "")
            return round (float(Amount), 2)
        # check if no currency symbol is present, assume US Dollars
        else:
            return round(float(Amount), 2)
    except ValueError:
        # If the value is not a number, return NaN
        return np.nan
        
# Clean the Amount column of the 2018 DataFrame
data18["Amount"] = data18["Amount"].apply(clean_amount_2018)

# %%
#Check the summary information about the 2018 dataset 
data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  526 non-null    object
#  1   Founded       0 non-null      float64
#  2   Location      526 non-null    object
#  3   Sector        526 non-null    object
#  4   What_it_does  526 non-null    object
#  5   Founders      0 non-null      float64
#  6   Investor      0 non-null      float64
#  7   Amount        378 non-null    float64
#  8   Stage         526 non-null    object
#  9   Funding_Year  526 non-null    int32
# dtypes: float64(4), int32(1), object(5)
# memory usage: 39.2+ KB

# %%
data18.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does  Founders  Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...       NaN       NaN
# 1  A startup which aggregates milk from dairy far...       NaN       NaN
# 2          Leading Online Loans Marketplace in India       NaN       NaN
# 3  PayMe India is an innovative FinTech organizat...       NaN       NaN
# 4  Eunimart is a one stop solution for merchants ...       NaN       NaN
#
#       Amount     Stage  Funding_Year
# 0   250000.0      Seed          2018
# 1   584000.0      Seed          2018
# 2   949000.0  Series A          2018
# 3  2000000.0     Angel          2018
# 4        NaN      Seed          2018

# %%
data18['Amount'].unique()
# Out:
# array([2.500000e+05, 5.840000e+05, 9.490000e+05, 2.000000e+06,
#                 nan, 1.600000e+06, 2.336000e+05, 7.300000e+05,
#        1.460000e+06, 1.500000e+05, 1.100000e+06, 7.300000e+03,
#        6.000000e+06, 6.500000e+05, 5.110000e+05, 9.344000e+05,
#        2.920000e+05, 1.000000e+06, 5.000000e+06, 4.000000e+06,
#        4.380000e+05, 2.800000e+06, 1.700000e+06, 1.300000e+06,
#        7.300000e+04, 1.825000e+05, 2.190000e+05, 5.000000e+05,
#        1.518400e+06, 6.570000e+05, 1.340000e+07, 3.650000e+05,
#        3.854400e+05, 1.168000e+05, 8.760000e+02, 9.000000e+06,
#        1.000000e+05, 2.000000e+04, 1.200000e+05, 4.964000e+05,
#        4.993200e+06, 1.431450e+05, 8.760000e+06, 7.420000e+08,
#        1.460000e+07, 2.920000e+07, 3.980000e+06, 1.000000e+04,
#        1.460000e+03, 3.650000e+06, 1.000000e+09, 7.000000e+06,
#        3.500000e+07, 8.030000e+06, 2.850000e+07, 3.504000e+06,
#        1.752000e+06, 2.400000e+06, 3.000000e+07, 3.650000e+07,
#        2.300000e+07, 1.100000e+07, 6.424000e+05, 3.240000e+06,
#        8.760000e+05, 5.400000e+08, 9.490000e+06, 2.336000e+07,
#        9.000000e+05, 1.000000e+07, 1.500000e+06, 1.022000e+06,
#        1.400000e+07, 1.496500e+06, 1.000000e+08, 1.752000e+04,
#        7.592000e+07, 8.000000e+05, 1.041000e+06, 1.500000e+04,
#        1.400000e+06, 1.200000e+06, 2.200000e+06, 1.800000e+06,
#        3.600000e+06, 1.387000e+05, 3.000000e+05, 6.830000e+06,
#        2.000000e+05, 2.190000e+06, 4.300000e+06, 3.648460e+05,
#        4.000000e+05, 1.022000e+05, 2.044000e+04, 1.460000e+05,
#        3.285000e+05, 1.320000e+07, 5.000000e+04, 2.046920e+06,
#        3.000000e+06, 1.250000e+06, 1.800000e+05, 2.803200e+05,
#        1.503800e+06, 4.200000e+06, 1.750000e+05, 1.450000e+06,
#        2.920000e+03, 4.500000e+06, 6.000000e+05, 2.423600e+05,
#        1.752000e+05, 1.500000e+07, 4.818000e+05, 1.250000e+05,
#        1.300000e+05, 5.095400e+05, 1.051200e+06, 1.720000e+07,
#        4.672000e+05, 3.500000e+06, 1.971000e+06, 1.200000e+07,
#        4.000000e+07, 5.000000e+07, 2.248400e+07, 2.044000e+06,
#        4.190000e+07, 2.058600e+07, 3.530000e+06, 3.300000e+06,
#        8.468000e+06, 5.256000e+05, 4.964000e+06, 2.100000e+08,
#        3.768000e+07, 7.446000e+06, 3.212000e+07, 2.200000e+07,
#        7.000000e+04, 2.247232e+08, 2.920000e+08, 5.840000e+07,
#        1.850000e+08, 6.500000e+07, 2.409000e+06, 7.000000e+05,
#        3.066000e+06, 2.963216e+07, 7.500000e+07, 1.168000e+06,
#        1.760000e+06, 2.700000e+06, 4.088000e+06, 1.168000e+07,
#        7.500000e+05, 2.500000e+06, 8.000000e+07, 2.500000e+07,
#        1.065800e+07, 5.840000e+06, 3.700000e+06, 5.600000e+06,
#        3.796000e+06, 9.923000e+07, 7.000000e+07, 4.000000e+04,
#        5.500000e+05, 3.650000e+08, 1.277500e+05, 1.138800e+06,
#        2.800000e+07, 3.854400e+06, 1.649800e+07, 1.182600e+07,
#        2.044000e+07, 1.490000e+07, 2.250000e+08, 7.500000e+03])

# %%
data18.loc[(178)]
# Out:
# Company_Name                                       BuyForexOnline
# Founded                                                       NaN
# Location                                                Bangalore
# Sector                                                     Travel
# What_it_does    BuyForexOnline.com is India's first completely...
# Founders                                                      NaN
# Investor                                                      NaN
# Amount                                                  2000000.0
# Stage           https://docs.google.com/spreadsheets/d/1x9ziNe...
# Funding_Year                                                 2018
# Name: 178, dtype: object

# %%
data18.loc[178, ['Stage']] = ['']

data18['Stage'] = data18['Stage'].apply(lambda x:str(x).replace('Undisclosed', ''))

# %%
#drop duplicates 

data18 = data18.drop_duplicates(keep='first')

# %%
data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 525 entries, 0 to 525
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  525 non-null    object
#  1   Founded       0 non-null      float64
#  2   Location      525 non-null    object
#  3   Sector        525 non-null    object
#  4   What_it_does  525 non-null    object
#  5   Founders      0 non-null      float64
#  6   Investor      0 non-null      float64
#  7   Amount        377 non-null    float64
#  8   Stage         525 non-null    object
#  9   Funding_Year  525 non-null    int32
# dtypes: float64(4), int32(1), object(5)
# memory usage: 43.1+ KB

# %%
# Rename round_series to stage and location to headquarter
data18.rename(columns={
    'Company Name': 'company_brand', 
    'Industry': 'sector', 
    'Round/Series': 'stage', 
    'About Company': 'what_it_does', 
    
    },
    inplace=True
)

data18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 525 entries, 0 to 525
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  525 non-null    object
#  1   Founded       0 non-null      float64
#  2   Location      525 non-null    object
#  3   Sector        525 non-null    object
#  4   What_it_does  525 non-null    object
#  5   Founders      0 non-null      float64
#  6   Investor      0 non-null      float64
#  7   Amount        377 non-null    float64
#  8   Stage         525 non-null    object
#  9   Funding_Year  525 non-null    int32
# dtypes: float64(4), int32(1), object(5)
# memory usage: 43.1+ KB

# %% [markdown]
# #### Exploratory Data Analysis: EDA
#
# This is the segment dedicated to thoroughly examining the datasets, presenting them, formulating hypotheses, and strategizing the cleaning, processing, and creation of features.

# %%
print (data21.columns)
# Out:
# Index(['Company_Name', 'Founded', 'Location', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Funding_Year'],
#       dtype='object')

# %%
print (data20.columns)
# Out:
# Index(['Company_Name', 'Founded', 'Location', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Funding_Year'],
#       dtype='object')

# %%
print (data19.columns)
# Out:
# Index(['Company_Name', 'Founded', 'Location', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Funding_Year'],
#       dtype='object')

# %%
print (data18.columns)
# Out:
# Index(['Company_Name', 'Founded', 'Location', 'Sector', 'What_it_does',
#        'Founders', 'Investor', 'Amount', 'Stage', 'Funding_Year'],
#       dtype='object')

# %%
# concatenating all the dataframes together
df = pd.concat([data18, data19, data20, data21], axis=0)

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever     <NA>  Bangalore
# 1  Happy Cow Dairy     <NA>     Mumbai
# 2       MyLoanCare     <NA>    Gurgaon
# 3      PayMe India     <NA>      Noida
# 4         Eunimart     <NA>  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN      NaN
# 1  A startup which aggregates milk from dairy far...      NaN      NaN
# 2          Leading Online Loans Marketplace in India      NaN      NaN
# 3  PayMe India is an innovative FinTech organizat...      NaN      NaN
# 4  Eunimart is a one stop solution for merchants ...      NaN      NaN
#
#       Amount     Stage  Funding_Year
# 0   250000.0      Seed          2018
# 1   584000.0      Seed          2018
# 2   949000.0  Series A          2018
# 3  2000000.0     Angel          2018
# 4        NaN      Seed          2018

# %%
df.tail()
# Out:
#       Company_Name  Founded   Location                 Sector  \
# 1204      Gigforce   2019.0   Gurugram  Staffing & Recruiting
# 1205        Vahdam   2015.0  New Delhi       Food & Beverages
# 1206  Leap Finance   2019.0  Bangalore     Financial Services
# 1207  CollegeDekho   2015.0   Gurugram                 EdTech
# 1208        WeRize   2019.0  Bangalore     Financial Services
#
#                                            What_it_does  \
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                            Founders                          Investor  \
# 1204    Chirag Mittal, Anirudh Syal                   Endiya Partners
# 1205                     Bala Sarda                          IIFL AMC
# 1206     Arnav Kumar, Vaibhav Singh                      Owl Ventures
# 1207                   Ruchir Arora  Winter Capital, ETS, Man Capital
# 1208  Vishal Chopra, Himanshu Gupta    3one4 Capital, Kalaari Capital
#
#           Amount         Stage  Funding_Year
# 1204   3000000.0  Pre-series A          2021
# 1205  20000000.0      Series D          2021
# 1206  55000000.0      Series C          2021
# 1207  26000000.0      Series B          2021
# 1208   8000000.0      Series A          2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   Float64
#  2   Location      2759 non-null   object
#  3   Sector        2855 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2248 non-null   object
#  7   Amount        2725 non-null   object
#  8   Stage         1941 non-null   object
#  9   Funding_Year  2873 non-null   int32
# dtypes: Float64(1), int32(1), object(8)
# memory usage: 238.5+ KB

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# Founded       2105.0  2016.085986  4.367256  1963.0  2015.0  2017.0  2019.0
# Funding_Year  2873.0  2020.023669  1.087148  2018.0  2020.0  2020.0  2021.0
#
#                  max
# Founded       2021.0
# Funding_Year  2021.0

# %%
# Remove the undisclosed records from Data_df
df = df[df['Amount']!='Undisclosed']
df['Amount'].unique()
# Out:
# array([250000.0, 584000.0, 949000.0, 2000000.0, nan, 1600000.0, 233600.0,
#        730000.0, 1460000.0, 150000.0, 1100000.0, 7300.0, 6000000.0,
#        650000.0, 511000.0, 934400.0, 292000.0, 1000000.0, 5000000.0,
#        4000000.0, 438000.0, 2800000.0, 1700000.0, 1300000.0, 73000.0,
#        182500.0, 219000.0, 500000.0, 1518400.0, 657000.0, 13400000.0,
#        365000.0, 385440.0, 116800.0, 876.0, 9000000.0, 100000.0, 20000.0,
#        120000.0, 496400.0, 4993200.0, 143145.0, 8760000.0, 742000000.0,
#        14600000.0, 29200000.0, 3980000.0, 10000.0, 1460.0, 3650000.0,
#        1000000000.0, 7000000.0, 35000000.0, 8030000.0, 28500000.0,
#        3504000.0, 1752000.0, 2400000.0, 30000000.0, 36500000.0,
#        23000000.0, 11000000.0, 642400.0, 3240000.0, 876000.0, 540000000.0,
#        9490000.0, 23360000.0, 900000.0, 10000000.0, 1500000.0, 1022000.0,
#        14000000.0, 1496500.0, 100000000.0, 17520.0, 75920000.0, 800000.0,
#        1041000.0, 15000.0, 1400000.0, 1200000.0, 2200000.0, 1800000.0,
#        3600000.0, 138700.0, 300000.0, 6830000.0, 200000.0, 2190000.0,
#        4300000.0, 364846.0, 400000.0, 102200.0, 20440.0, 146000.0,
#        328500.0, 13200000.0, 50000.0, 2046920.0, 3000000.0, 1250000.0,
#        180000.0, 280320.0, 1503800.0, 4200000.0, 175000.0, 1450000.0,
#        2920.0, 4500000.0, 600000.0, 242360.0, 175200.0, 15000000.0,
#        481800.0, 125000.0, 130000.0, 509540.0, 1051200.0, 17200000.0,
#        467200.0, 3500000.0, 1971000.0, 12000000.0, 40000000.0, 50000000.0,
#        22484000.0, 2044000.0, 41900000.0, 20586000.0, 3530000.0,
#        3300000.0, 8468000.0, 525600.0, 4964000.0, 210000000.0, 37680000.0,
#        7446000.0, 32120000.0, 22000000.0, 70000.0, 224723200.0,
#        292000000.0, 58400000.0, 185000000.0, 65000000.0, 2409000.0,
#        700000.0, 3066000.0, 29632160.0, 75000000.0, 1168000.0, 1760000.0,
#        2700000.0, 4088000.0, 11680000.0, 750000.0, 2500000.0, 80000000.0,
#        25000000.0, 10658000.0, 5840000.0, 3700000.0, 5600000.0, 3796000.0,
#        99230000.0, 70000000.0, 40000.0, 550000.0, 365000000.0, 127750.0,
#        1138800.0, 28000000.0, 3854400.0, 16498000.0, 11826000.0,
#        20440000.0, 14900000.0, 225000000.0, 7500.0, '6300000.0',
#        '150000000.0', '28000000.0', '30000000.0', '6000000.0', 'nan',
#        '1000000.0', '20000000.0', '275000000.0', '22000000.0',
#        '5000000.0', '140500.0', '540000000.0', '15000000.0', '182700.0',
#        '12000000.0', '11000000.0', '15500000.0', '1500000.0', '5500000.0',
#        '2500000.0', '140000.0', '230000000.0', '49400000.0', '32000000.0',
#        '26000000.0', '150000.0', '400000.0', '2000000.0', '100000000.0',
#        '8000000.0', '100000.0', '50000000.0', '120000000.0', '4000000.0',
#        '6800000.0', '36000000.0', '5700000.0', '25000000.0', '600000.0',
#        '70000000.0', '60000000.0', '220000.0', '2800000.0', '2100000.0',
#        '7000000.0', '311000000.0', '4800000.0', '693000000.0',
#        '33000000.0', '200000.0', '340000.0', '45000000.0', '1200000.0',
#        '660000000.0', '120000.0', '7500000.0', '500000.0', '3000000.0',
#        '10000000.0', '145000000.0', '21000000.0', '560000.0', '275000.0',
#        '4500000.0', '390000000.0', '5100000.0', '700000000.0',
#        '2300000.0', '700000.0', '19000000.0', '9000000.0', '40000000.0',
#        '750000.0', '7800000.0', '80000000.0', '1700000.0', '40000.0',
#        '35000000.0', '300000.0', '3500000.0', '200000000.0', '1300000.0',
#        '4100000.0', '575000.0', '800000.0', '18000000.0', '3200000.0',
#        '900000.0', '250000.0', '4700000.0', '75000000.0', '121000000.0',
#        '55000000.0', '3300000.0', '16000000.0', '5400000.0', '4200000.0',
#        '52000000.0', '1100000.0', '118000000.0', '1600000.0',
#        '18500000.0', '70000000000.0', '800000000.0', '400000000.0',
#        '176000000.0', '470000.0', '240000.0', '3000000000.0',
#        '74000000.0', '62000000.0', '500000000.0', '12500000.0',
#        '2200000000.0', '5060000.0', '225000000.0', '24700000.0',
#        '7700000.0', '19067328.0', '51000000.0', '115000.0', '54000.0',
#        '20000.0', '803146.0', '238000.0', '10220000.0', '1020000.0',
#        '13400000.0', '170000000.0', '2900000.0', '543000.0', '90000000.0',
#        '3400000.0', '23000000.0', '8090000.0', '1030000.0', '5040000.0',
#        '360000.0', '1400000.0', '650000.0', '54000000.0', '42500000.0',
#        '11370000.0', '325000.0', '410000.0', '450000.0', '682000.0',
#        '4050000.0', '1050000.0', '1080000.0', '4300000.0', '2110000.0',
#        '11943500.0', '764000.0', '603000.0', '409000.0', '292000.0',
#        '286000.0', '136000.0', '825000000.0', '546000.0', '887000.0',
#        '43000.0', '40900.0', '2200000.0', '5660000.0', '350000.0',
#        '110000.0', '122000000.0', '11635000.0', '1065000.0', '669000.0',
#        '16076000.0', '649600.0', '6700000.0', '266500.0', '2879000.0',
#        '26500000.0', '351000.0', '46761000.0', '175000.0', '11241000.0',
#        '804000.0', '1340000.0', '467000.0', '133000.0', '3823000.0',
#        '934000.0', '293000.0', '198000.0', '927000.0', '971000.0',
#        '3060000.0', '1862000.0', '232000.0', '2888000.0', '1328000.0',
#        '56000000.0', '2250000.0', '16753000.0', '3700000.0', '1470000.0',
#        '530000.0', '267000.0', '3344000.0', '7200000.0', '2743000.0',
#        '6082000.0', '6609000.0', '27700000.0', '5940000.0', '3964000.0',
#        '197000.0', '4327000.0', '459000.0', '3937000.0', '1313500.0',
#        '229800.0', '5305000.0', '264000.0', '1750000.0', '5967000.0',
#        '2980000.0', '323000.0', '1326000.0', '27000000.0', '5200000.0',
#        '2530000.0', '792000.0', '11363000.0', '1715000.0', '329000.0',
#        '5271000.0', '8700000.0', '3226000.0', '5900000.0', '44000000.0',
#        '3879000.0', '13000000.0', '8800000.0', '9500000.0', '920000.0',
#        '35600000.0', '9400000.0', '790000.0', '480000.0', '160000.0',
#        '8200000.0', '4257000.0', '1410000.0', '349800.0', '786000.0',
#        '2004000.0', '123000000.0', '248000.0', '24000000.0', '14259000.0',
#        '24500000.0', '3800000.0', '18370000.0', '68525000.0', '1834000.0',
#        '23850000.0', '43000000.0', '21600000.0', '4598000.0',
#        '13137000.0', '115000000.0', '3900000.0', '670000.0', '8500000.0',
#        '3148000.0', '2600000.0', '4049500.0', '10500000.0', '6500000.0',
#        '43700000.0', '13800000.0', '306900.0', '420000.0', '627300.0',
#        '113000000.0', '110000000.0', '1397000.0', '448500.0', '7975700.0',
#        '330000.0', '5600000.0', '1402000.0', '21500000.0', '296000000.0',
#        '4900000.0', '1402400.0', '12618300.0', '9900000.0', '982530.0',
#        '70185200.0', '210000000.0', '84000000.0', '39000000.0',
#        '2700000.0', '1403400.0', '105000000.0', '103000000.0', '281300.0',
#        '12700.0', '25000.0', '97500000.0', '507000.0', '8400000.0',
#        '18300000.0', '125000000.0', '181000.0', '280000.0', '14700000.0',
#        '13200000.0', '8043000.0', '188000000.0', '49000000.0',
#        '160000000.0', '1800000.0', '850000.0', '53000000.0', '7400000.0',
#        '17000000.0', '215000000.0', '350000000.0', '83000000.0',
#        '65000000.0', '150000000000.0', '300000000.0', '140000000.0',
#        '17500000.0', '42000000.0', '450000000.0', '37000000.0',
#        '370000000.0', '770000.0', '6600000.0', '725000.0', '461000.0',
#        '96000000.0', '266000000.0', '325000000.0', '225000.0',
#        '85000000.0', '235000.0', '260000.0', '86000000.0', '130000.0',
#        '10000.0', '111000000.0', '265000.0', '76000000.0', '1000000000.0',
#        '95000000.0', '280000000.0', '14300000.0', '81000000.0',
#        '720000.0', '67000000.0', '10200000.0', '220000000.0',
#        '108000000.0', '370000.0', '48000000.0', '3600000.0',
#        '192000000.0', '1900000.0', '41000000.0', '144000000.0',
#        '270000000.0', '250000000.0', '320000.0', '38000000.0', '125000.0',
#        '64000000.0', '620000.0', '1250000.0', '234000000.0',
#        '460000000.0', '13500000.0', '195000000.0', '7300000.0',
#        '16500000.0', '92000000.0', '135000000.0', '155000.0',
#        '840000000.0', '248000000.0', '570000.0', '260000000.0',
#        '175000000.0', '810000.0', '600000000.0', '6750000.0',
#        '78000000.0', '255000000.0', '570000000.0', '550000.0',
#        '31000000.0', '540000.0', '14000000.0', '6200000.0'], dtype=object)

# %%
# index with undisclosed value at Investor column
index_ = df.index[df['Investor']=='Undisclosed']
index_
# Out:
# Index([5, 59, 70, 633, 675, 741, 798, 824, 902, 964, 1003, 1006, 1007], dtype='int64')

# %%
# replacing them with NAN
df['Investor'] = df['Investor'].replace('Undisclosed', np.nan)

# %% [markdown]
# ##### Cleaning the Sector Column

# %% [markdown]
# #### Standardize the sector names by converting them to title case

# %%
unique_sectors = df['Sector'].unique()
print(unique_sectors)
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing'
#  'Agriculture, Farming' 'Credit, Financial Services, Lending, Marketplace'
#  'Financial Services, FinTech' 'E-Commerce Platforms, Retail, SaaS'
#  'Cloud Infrastructure, PaaS, SaaS' 'Internet, Leisure, Marketplace'
#  'Market Research' 'Information Services, Information Technology'
#  'Mobile Payments' 'B2B, Shoes' 'Internet'
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat'
#  'Food Delivery' 'Industrial Automation'
#  'Automotive, Search Engine, Service Industry' 'Finance, Internet, Travel'
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS'
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software'
#  'Internet of Things, Waste Management'
#  'Air Transportation, Freight Service, Logistics, Marine Transportation'
#  'Financial Services' 'Food and Beverage' 'Autonomous Vehicles'
#  'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS'
#  'Agriculture, Analytics, Big Data, Farming'
#  'Logistics, Supply Chain Management' 'Financial Services, Lending'
#  'Automotive, Marketplace, Online Portals' 'Artificial Intelligence'
#  'Internet of Things, Telecommunications' 'Insurance'
#  'Information Technology, Logistics, Supply Chain Management'
#  'Blockchain, Developer Tools, Enterprise Software'
#  'Industrial Automation, Logistics, Supply Chain Management'
#  'Food and Beverage, Food Delivery, Snack Food' 'Education'
#  'E-Commerce, Fashion, Jewelry, Retail' 'Renewable Energy'
#  'E-Learning, Education'
#  'Clean Energy, CleanTech, Laundry and Dry-cleaning'
#  'E-Commerce, Fashion, Mobile'
#  'Apps, Messaging, Navigation, Public Safety' 'Transportation'
#  'Fitness, Health Care, Wellness'
#  'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant'
#  'Hospitality' 'Food and Beverage, Tea'
#  'Media and Entertainment, News, Outdoors'
#  'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming'
#  'B2B, Information Services, Information Technology'
#  'EdTech, Education, Enterprise Software, Peer to Peer'
#  'Health Care, Medical' 'E-Commerce' 'Health Care, Hospital, Wellness' '—'
#  'Sports' 'Big Data, Consumer Lending, FinTech'
#  'Cloud Computing, Computer, Semiconductor'
#  'Health Care, Medical, Pharmaceutical' 'Food Processing, Retail'
#  'Trading Platform' "Consumer Goods, Lifestyle, Men's" 'Wellness'
#  'Food and Beverage, Food Processing, Nutrition' 'Fashion'
#  'Automotive, Electric Vehicle, Energy Storage'
#  'Consulting, Retail, Social'
#  'Biotechnology, Life Science, Pharmaceutical, Product Research'
#  'Health Care' 'Credit, Financial Services, FinTech, Personal Finance'
#  'Communities, Coworking, Incubators'
#  'Consumer, Financial Services, FinTech'
#  'Consumer Applications, Information Services, Location Based Services, Virtual Assistant'
#  'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps'
#  'Education, Financial Services, FinTech'
#  'Advertising, Consulting, Digital Marketing'
#  'Marketplace, Real Estate, Rental Property'
#  'E-Learning, Internet, Video Games'
#  'Artificial Intelligence, Cloud Computing, Video'
#  'Health Care, Information Technology' 'Aerospace'
#  'E-Commerce, Fashion, Lifestyle'
#  'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning'
#  'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home'
#  'EdTech, Education, Information Services, SaaS' 'Energy, Solar'
#  'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security'
#  'Artificial Intelligence, Social' 'Logistics, Transportation, Travel'
#  'Digital Marketing, SEM, SEO, Web Development'
#  'Health Care, Hospital, Medical' 'Finance, Financial Services'
#  'Food Delivery, Food Processing, Internet'
#  'E-Commerce, Food and Beverage, Internet'
#  'Fitness, Food and Beverage, Health Care, Nutrition'
#  'EdTech, Education, Knowledge Management'
#  'Apps, Beauty, Consumer, Retail'
#  'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health'
#  'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management'
#  'E-Learning, Education, Higher Education' 'Health Diagnostics'
#  'EdTech, Education' 'Financial Services, SaaS, Security'
#  'Banking, Finance, Financial Services, Non Profit'
#  'B2B, E-Commerce, Mobile'
#  'Automotive, Electric Vehicle, Renewable Energy' 'E-Learning'
#  'Embedded Systems, Health Care, Medical, Product Research'
#  'Apps, E-Commerce, Internet' 'Advertising, Human Resources, Marketing'
#  'Beauty, Fitness, Home Services, Internet'
#  'Health Care, Medical Device, Public Safety'
#  'Food Delivery, Online Portals, Restaurants'
#  'AgTech, B2B, Supply Chain Management'
#  'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments'
#  'Software' 'EdTech, Education, Higher Education, Secondary Education'
#  'Manufacturing, Retail' 'Manufacturing'
#  'Information Services, Information Technology, InsurTech'
#  'Consumer Lending, FinTech' 'Internet, Social Network, TV'
#  'Beauty, Health Care' 'Hospital' 'Events'
#  '3D Printing, Manufacturing, Product Design' 'Automotive'
#  'Automotive, Retail' 'Apps, Audio' 'Automotive, E-Commerce'
#  'Digital Entertainment, Fantasy Sports, Sports'
#  'E-Learning, EdTech, Education'
#  'Funding Platform, Incubators, Non Profit'
#  'Hospitality, Hotel, Leisure, Travel'
#  'Classifieds, Internet, Marketplace, Rental Property'
#  'Banking, E-Learning, Trading Platform' 'E-Commerce, Mobile, Retail'
#  'Artificial Intelligence, Information Technology'
#  'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate'
#  'Banking, Finance, Financial Services' 'Audio, Mobile, Tourism, Travel'
#  'Energy, Energy Storage, Infrastructure'
#  'Government, Information Technology, Software' 'Information Technology'
#  'Education, Information Technology, Internet, Mobile, Software'
#  'Consumer Lending, Financial Services, Lending, Personal Finance'
#  'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media'
#  'Business Intelligence, Customer Service, Market Research, SaaS'
#  'Credit, Financial Services, FinTech, Lending'
#  'Children, Education, Parenting'
#  'Automotive, Battery, Energy, Energy Storage'
#  'E-Commerce, Mobile, Sharing Economy'
#  'Food Delivery, Organic, Organic Food' 'Mobile' 'Rental' 'Travel'
#  'Consumer' 'B2B, Farming, Marketplace' 'Wealth Management'
#  'Biotechnology' 'Education, Gaming, Training' 'Veterinary'
#  'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless'
#  'Health Care, Hospital, Supply Chain Management' 'Tourism, Travel'
#  'Hospitality, Real Estate' 'Finance'
#  'Digital Media, EBooks, Publishing, Reading Apps'
#  'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software'
#  'Food and Beverage, Food Processing' 'Internet, Marketplace, Shopping'
#  'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition'
#  'Facilities Support Services' 'Automotive, Electric Vehicle, Energy'
#  'Health Care, Health Diagnostics, Predictive Analytics'
#  'Cloud Computing, Computer, SaaS, Software' 'Fashion, Lifestyle, Retail'
#  'Medical' 'Music Streaming' 'Finance, Impact Investing, Internet'
#  'Internet, Social Entrepreneurship' 'Retail'
#  'Finance, Impact Investing, Mobile Apps'
#  'Cloud Computing, Computer, Software'
#  'Business Development, Market Research, Outsourcing'
#  'Health Care, Hospitality' 'Internet, Social News, Sports'
#  'Human Resources' 'Finance, Financial Services, FinTech'
#  'Customer Service, Software, Video, Video Streaming'
#  'E-Commerce, Food Processing' 'Training'
#  'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food'
#  'Manufacturing, Oil and Gas, Robotics'
#  'Artificial Intelligence, Computer, Machine Learning'
#  'Collaboration, Communities, Coworking, Sharing Economy'
#  'Big Data, EdTech, Machine Learning' 'Nanotechnology'
#  'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment'
#  'Financial Services, Lending, Peer to Peer'
#  'E-Commerce, Furniture, Home Decor, Interior Design, Internet'
#  'Digital Media' 'File Sharing, Personalization, Social Media'
#  'Home Decor, Interior Design' 'Health Care, Medical Device, Mobile Apps'
#  'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management'
#  'Crowdfunding, Finance, Financial Services'
#  'Finance, Financial Services, Insurance'
#  'Children, Education, Online Portals' 'Software, Virtual Reality'
#  'B2B, Food and Beverage, Food Delivery'
#  'Catering, Food and Beverage, Food Delivery, Food Processing'
#  'Food and Beverage, Snack Food' 'Automotive, E-Commerce, Mobile'
#  'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development'
#  'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development'
#  'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses'
#  'Delivery, Information Technology, Mobile Apps'
#  'Environmental Consulting, Renewable Energy'
#  'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance'
#  'Commercial Real Estate, Coworking, Office Administration, Real Estate'
#  'Food and Beverage, Food Processing, Organic Food, Snack Food'
#  'Apps, Health Care, Internet, Mobile Apps, Personal Health'
#  'Digital Media, Incubators, Social Entrepreneurship'
#  'Finance, Financial Services, Marketing'
#  'Biotechnology, Health Care, Life Science, Medical Device'
#  'Education, Human Resources' 'Consumer Electronics'
#  'Apps, Health Care, Hospital, Mobile Apps'
#  'Delivery Service, Logistics, Service Industry'
#  'Big Data, Data Visualization, Logistics, Software'
#  'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball'
#  'Media and Entertainment, News, Publishing' 'Consulting'
#  'Big Data, Financial Services, Machine Learning, Predictive Analytics'
#  'Agriculture, AgTech, Manufacturing' 'Digital Media, News, Publishing'
#  'Health Care, Hospital' 'B2B, E-Commerce, Enterprise'
#  'Fraud Detection, Information Services, Security'
#  'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning'
#  'Cryptocurrency, Trading Platform' 'Finance, FinTech, Mobile Payments'
#  'Wedding'
#  'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education'
#  'Consumer Goods' 'Digital Entertainment'
#  'Crowdsourcing, Financial Services, Funding Platform, Venture Capital'
#  'Delivery, Drones, Geospatial, Robotics'
#  'Health Care, Information Technology, Management Information Systems'
#  'Farming'
#  'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations'
#  'Career Planning, Education, Higher Education, Service Industry'
#  'Medical Device' 'Alternative Medicine, Health Care' 'Internet, Software'
#  'Dental, Elder Care, Health Care, Home Health Care, Personal Health'
#  'Financial Services, Insurance, Private Social Networking'
#  'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping'
#  'CleanTech' 'Advertising, Internet, Marketing'
#  'Human Resources, Security, Training'
#  'Consumer Lending, Finance, FinTech' 'Marketing, Social Media, Video'
#  'Banking' 'Food Processing' 'Apps' 'Marketing'
#  'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation'
#  'Digital Entertainment, Fantasy Sports, Gaming, Sports'
#  'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing'
#  'Commercial, E-Learning, Education'
#  'Continuing Education, EdTech, Education, Skill Assessment'
#  'Smart Cities, Telecommunications' 'Internet of Things, Robotics'
#  'Apps, Home Services, Information Services, Information Technology'
#  'Medical, Tourism' 'Career Planning, Education, Internet'
#  'Fashion, Graphic Design, Wearables'
#  'Communities, Leisure, Mobile Apps, Software'
#  'Automotive, Rental, Sharing Economy'
#  'Energy, Environmental Consulting, Renewable Energy, Solar'
#  'Information Technology, SaaS, Security'
#  'Crowdfunding, Financial Services, Internet'
#  'Customer Service, Information Technology, Internet, Sales Automation'
#  'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming'
#  'Credit Cards, Payments, Property Insurance, Property Management, Rental Property'
#  'Beauty, Cosmetics, Health Care, Service Industry'
#  'EdTech, Education, Mobile, Tutoring' 'Social Media, Sports' 'Biopharma'
#  'E-Commerce, E-Commerce Platforms, Retail'
#  'E-Commerce, Fashion, Shopping' 'Digital Entertainment, Mobile, PC Games'
#  'Finance, Financial Services, Small and Medium Businesses'
#  'Artificial Intelligence, Energy, Oil and Gas'
#  'Computer, FinTech, Risk Management, Software'
#  'Apps, Financial Services, FinTech'
#  "Child Care, Health Care, Hospital, Medical, Women's"
#  'Agriculture, Mobile'
#  'Finance, FinTech, Payments, Property Development, Rental'
#  'Information Services, Information Technology, Mobile, Software'
#  'Apps, Fitness, Health Care, mHealth' 'Food and Beverage, Food Delivery'
#  'Apps, Payments, Retail' 'Health Insurance, Insurance, Life Insurance'
#  'Rental, Taxi Service, Travel'
#  'E-Commerce, E-Commerce Platforms, Internet, Retail'
#  'Financial Services, Professional Services'
#  'Customer Service, Messaging, Mobile Apps, Personalization'
#  'Gaming, iOS, Sports'
#  'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media'
#  'Search Engine'
#  'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation'
#  'Agriculture, Farmers Market, Farming'
#  'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics'
#  'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation'
#  'Mobile, Software, Travel' 'Cosmetics'
#  'Consulting, Cyber Security, Network Security'
#  'eSports, Gaming, Video Games' 'Fashion, Jewelry' 'B2B, Medical Device'
#  'Consumer Goods, Manufacturing' 'Biotechnology, Health Care, Wellness'
#  'Health Care, Hospital, Medical, Robotics'
#  'E-Commerce, Fitness, Health Care' 'Financial Services, Venture Capital'
#  'Accounting, Apps, FinTech' 'Apps, Mobile, Transportation' 'Reading Apps'
#  'Energy, Renewable Energy, Solar' 'Banking, Financial Services, FinTech'
#  'Apps, Education, Retail' 'Electric Vehicle'
#  'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design'
#  'Automotive, E-Commerce, Marketplace' 'Agriculture'
#  'Apps, Information Services, Information Technology' 'B2B, Marketplace'
#  'Packaging Services' 'Computer, Furniture, Software'
#  'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine'
#  'Collaboration, Communities, Coworking, Real Estate'
#  'Accounting, Banking, Finance'
#  'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS'
#  'Information Services, Internet, Logistics, Supply Chain Management, Transportation'
#  'Automotive, E-Commerce, Information Services'
#  'Delivery, Logistics, Transportation'
#  'Automotive, E-Commerce Platforms, Marketplace'
#  'Last Mile Transportation, Railroad, Transportation, Travel'
#  'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals'
#  'FinTech, Mobile, Mobile Payments, Payments, Retail Technology'
#  'Online Games, Software' 'Online Portals, Property Management, Rental'
#  'E-Commerce, Food and Beverage, Tea' 'Music, Social Network, Video'
#  'Health Care, Pharmaceutical, Wellness'
#  'Delivery Service, Food and Beverage, Food Delivery'
#  'Hospitality, Information Technology, Travel Accommodations'
#  'Biotechnology, Diabetes, Health Care'
#  'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental'
#  'Finance, Financial Exchanges, Financial Services, Micro Lending'
#  'Analytics, Apps, Market Research'
#  'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet'
#  'Apps, Mobile, Mobile Apps, Software' 'News, Publishing, Social Media'
#  'Industrial, Industrial Automation'
#  'Internet, Mobile Apps, Social Network'
#  'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device'
#  'E-Commerce, Furniture, Interior Design' 'Apps, Events, News'
#  'Artificial Intelligence, Human Resources, Information Services, Information Technology'
#  'Logistics, Railroad, Transportation' 'Dating, Private Social Networking'
#  'Artificial Intelligence, Machine Learning, PaaS'
#  'Consumer, Furniture, Home Decor, Home Improvement'
#  'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation'
#  'Health Care, Health Insurance' 'Energy, Natural Resources'
#  'E-Commerce, Education, Health Care' 'Apps, Health Care, Pharmaceutical'
#  'Internet, Knowledge Management'
#  'Credit, Finance, FinTech, Lending, Sales Automation'
#  'Banking, Financial Services, Internet' 'E-Commerce, Health Care, Retail'
#  'Child Care, Information Technology' 'Financial Services, Micro Lending'
#  'E-Commerce, Retail, Shopping' 'Food and Beverage, Snack Food, Tea'
#  'Delivery Service, E-Commerce, Logistics' 'Fashion, Lifestyle, Rental'
#  'Fantasy Sports, Mobile, Sports' 'Beauty, Fashion, Wellness'
#  'Food and Beverage, Restaurants, Tea' 'Fitness, Sporting Goods, Sports'
#  'Food and Beverage, Food Processing, Manufacturing'
#  'E-Learning, Internet' 'Eyewear, Internet'
#  'Information Technology, Mobile, News, Operating Systems, Social Media, Social News'
#  'FinTech, Internet, Payments, Service Industry'
#  'B2B, Business Development, Internet, Marketplace'
#  'Food and Beverage, Food Delivery, Internet'
#  'Biotechnology, Health Care, Pharmaceutical' 'Ecommerce' 'Edtech'
#  'Interior design' 'AgriTech' 'Technology' 'SaaS' 'AI & Tech' 'E-commerce'
#  'E-commerce & AR' 'Fintech' 'HR tech' 'Food tech' 'Health' 'Healthcare'
#  'Safety tech' 'Pharmaceutical' 'Insurance technology' 'AI' 'Foodtech'
#  'Food' 'IoT' 'E-marketplace' 'Robotics & AI' 'Logistics'
#  'Food & Nutrition' 'Social Media' nan 'E-Sports' 'B2B' 'Jewellery'
#  'B2B Supply Chain' 'Games' 'Food & tech' 'Accomodation' 'Automotive tech'
#  'Legal tech' 'Mutual Funds' 'Cybersecurity' 'Automobile' 'Healthtech'
#  'Yoga & wellness' 'Virtual Banking' 'Transport & Rentals'
#  'Marketing & Customer loyalty' 'Infratech' 'Automobile & Technology'
#  'EdTech' 'Hygiene management' 'Escrow' 'Networking platform' 'FinTech'
#  'Crowdsourcing' 'Food & Bevarages' 'HealthTech' 'Fashion startup'
#  'Food Industry' 'Virtual auditing startup' 'Gaming' 'Work fulfillment'
#  'AI startup' 'Telecommunication' 'Tech Startup' 'Medtech'
#  'Tyre management' 'Cloud company' 'Software company' 'Venture capitalist'
#  'Renewable player' 'IoT startup' 'SaaS startup' 'Aero company'
#  'Marketing company' 'Retail startup' 'Co-working Startup'
#  'Finance company' 'Tech company' 'Solar Monitoring Company'
#  'Video sharing platform' 'Gaming startup' 'Video streaming platform'
#  'Consumer appliances' 'Blockchain startup' 'Conversational AI platform'
#  'Real Estate' 'SaaS platform' 'AI platform' 'Fusion beverages' 'HR Tech'
#  'Job portal' 'Dairy startup' 'Content management' 'Spacetech'
#  'Trading platform' 'AI Company' 'Photonics startup' 'Entertainment'
#  'Scanning app' 'Skincare startup' 'Food and Beverages'
#  'Biotechnology company' 'FoodTech' 'Proptech' 'Fitness startup'
#  'PaaS startup' 'Beverages' 'Automobiles' 'Deeptech' 'EV startup'
#  'AR/VR startup' 'Recruitment startup' 'QSR startup' 'Video platform'
#  'Fertility tech' 'Luxury car startup' 'FM' 'Nutrition sector'
#  'Tech platform' 'Video' 'Retail Tech' 'HeathTech' 'Sles and marketing'
#  'LegalTech' 'Car Service' 'Bike marketplace' 'Agri tech' 'Reatil startup'
#  'AR platform' 'Content marketplace' 'Interior Design' 'Rental space'
#  'Soil-Tech' 'Ayurveda tech' 'Packaging solution startup' 'Cleantech'
#  'Sanitation solutions' 'HealthCare' 'Home Design' 'InsureTech'
#  'AI Startup' 'Solar solution' 'Jewellery startup'
#  'Multinational conglomerate company' 'Deeptech startup' 'Social Network'
#  'Publication' 'Tech' 'Venture capital' 'Entreprenurship' 'Food devlivery'
#  'Warehouse' 'Online financial service' 'Eyeglasses' 'Battery design'
#  'Online credit management startup' 'Beverage' 'TravelTech'
#  'Startup laboratory' 'Personal care startup' 'Customer service company'
#  'SaaS\xa0\xa0startup' 'Marketing startup' 'Service industry'
#  'Social media' 'AR startup' 'HR Tech startup' 'Automotive Startup'
#  'Food Startup' 'EdTech Startup' 'Car Trade' 'EdtTech' 'AI Platform'
#  'Automation' 'Solar SaaS' 'WL & RAC protection' 'Social commerce'
#  'Home interior services' 'Agritech startup' 'API platform' 'Deep Tech'
#  'Electricity' 'Automotive company' 'FMCG' 'Insurance Tech'
#  'Video personalization' 'Software Company' 'Biomaterial startup' 'IT'
#  'Craft Beer' 'Investment' 'Linguistic Spiritual' 'Construction'
#  'Battery manufacturer' 'Nano Distribution Network' 'AI health'
#  'Dating app' 'Media' 'Healthcare/Edtech' 'Social Commerce'
#  'Agritech/Commerce' 'Mobility tech' 'Social e-commerce'
#  'Food & Logistics' 'SpaceTech' 'Nutrition Tech' 'HR' None 'Agritech'
#  'AR/VR' 'Appliance' 'Mental Health' 'Solar Solution' 'B2B marketplace'
#  'Fashion Tech' 'Nutrition tech' 'Health & Wellness' 'Cloud Kitchen'
#  'IoT/Automobile' 'Eye Wear' 'Digital tech' 'Data Intelligence'
#  'Co-living' 'Food & Beverages' 'Defense tech' 'Marketplace'
#  'Construction tech' 'Nutrition' 'Coworking' 'Micro-mobiity' 'Auto-tech'
#  'Beauty' 'Robotics' 'Logitech' 'Med Tech' 'Life sciences'
#  'Retail Aggregator' 'Deep Tech AI' 'Biotech' 'Blockchain' 'HrTech'
#  'Mobility/Transport' 'AI & Debt' 'SaaS/Edtech' 'Transport' 'Co-working'
#  'Insurtech' 'Cryptocurrency' 'Legal' 'Fitness' 'EV'
#  'Supply chain, Agritech' 'Pharma' 'Foodtech & Logistics' 'Housing'
#  'Data Analytics' 'Investment Tech' 'Dairy' 'Beauty & wellness'
#  'Travel & SaaS' 'Tourism & EV' 'Media Tech' 'Location Analytics'
#  'E store' 'Data Science' 'Health and Fitness' 'Interior & decor'
#  'eMobility' 'Automation tech' 'Media & Networking' 'E-market'
#  'AI & Data science' 'Travel tech' 'Automotive and Rentals' 'E-tail'
#  'AI & Media' 'Machine Learning' 'Content Marktplace' 'Visual Media'
#  'Hygiene' 'VR & SaaS' 'Sales & Services' 'AI & Deep learning'
#  'Housing & Rentals' 'Estore' 'E tailor' 'E-mobility' 'Ad-tech'
#  'Neo-banking' 'Transport Automation' 'Techonology' 'AI Robotics'
#  'Preschool Daycare' 'Food diet' 'B2B Agritech' 'E-connect' 'Tech hub'
#  'Consultancy' 'Pharmacy' 'Deisgning' 'Taxation' 'Automobile Technology'
#  'B2B E-commerce' 'Home services' 'B2B service' 'Helathcare' 'Electronics'
#  'IT startup' 'Aeorspace' 'Dating' 'Oil and Energy' 'Telecommuncation'
#  'Milk startup' 'AI Chatbot' 'Food delivery' 'Fantasy sports'
#  'Video communication' 'Skill development' 'Recruitment' 'Computer Games'
#  'Apparel & Fashion' 'Logistics & Supply Chain' 'SportsTech' 'HRTech'
#  'Wine & Spirits' 'Mechanical & Industrial Engineering' 'Spiritual'
#  'Lifestyle' 'Computer software' 'Tech startup' 'Digital mortgage'
#  'Information Technology & Services' 'Furniture' 'Healtcare' 'Tobacco'
#  'Insuretech' 'MLOps platform' 'Venture Capital' 'Pet care' 'Drone'
#  'Wholesale' 'E-learning' 'Consumer Services'
#  'Venture Capital & Private Equity' 'Health, Wellness & Fitness' 'OTT'
#  'Education Management' 'Computer Software' 'Software Startup'
#  'Computer & Network Security' 'Capital Markets' 'Social network'
#  'Hospital & Health Care' 'Music' 'Hauz Khas' 'Pharmaceuticals'
#  'Electric Mobility' 'Mobility' 'Digital platform' 'B2B Ecommerce'
#  'Online Media' 'Mobile Games' 'Food Production' 'Podcast' 'Battery'
#  'Content publishing' 'Water purification' 'Content commerce'
#  'Innovation Management' 'Celebrity Engagement' 'Personal Care'
#  'Cannabis startup' 'Blogging' 'BioTechnology' 'B2B Marketplace'
#  'Health care' 'Social audio' 'Fashion and lifestyle' 'Delivery service'
#  'B2B Manufacturing' 'Home Decor' 'Solar' 'TaaS startup'
#  'Manufacturing startup' 'Vehicle repair startup' 'Advisory firm'
#  'Legaltech' 'Pollution control equiptment' 'Fashion & Lifestyle' 'D2C'
#  'Environmental Services' 'Merchandise' 'Facilities Services'
#  'Marketing & Advertising' 'Eyewear' 'D2C Business' 'NFT Marketplace'
#  'Consumer software' 'Social community' 'Fishery'
#  'Renewables & Environment' 'Online storytelling' 'Aviation' 'IT company'
#  'Environmental service' 'Job discovery platform' 'D2C Fashion'
#  'Heathcare' 'CRM' 'D2C startup' 'Innovation management'
#  'Community platform' 'Networking' 'Commercial Real Estate'
#  'Consumer service' 'Consumer goods' 'MarTech' 'Advertisement'
#  'Content creation' 'Augmented reality' 'Bike Rental' 'Beauty products'
#  'Tourism' 'FemTech' 'Cultural' 'Supply chain platform' 'Social platform'
#  'Real estate' 'AI company' 'Sports startup' 'Matrimony' 'Crypto'
#  'Clothing' 'Analytics' 'IoT platform' 'Commerce' 'Defense & Space'
#  'Business Supplies & Equipment' 'NFT' 'Oil & Energy'
#  'Company-as-a-Service' 'Textiles' 'Professional Training & Coaching'
#  'Maritime' 'Housing Marketplace' 'Furniture Rental' 'Telecommunications'
#  'Equity Management' 'Cloud kitchen' 'Community' 'Higher Education'
#  'Mechanical Or Industrial Engineering' 'D2C jewellery'
#  'Sales and Distribution' 'Information Services'
#  'Translation & Localization' 'Investment Banking' 'Femtech' 'sports'
#  'Foootwear' 'Legal Services' 'Arts & Crafts' 'Investment Management'
#  'Management Consulting' 'B2B startup'
#  'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience'
#  'Design' 'B2B Travel' 'Manchester, Greater Manchester' 'Product studio'
#  'Aviation & Aerospace' 'Staffing & Recruiting']

# %%
print(df['Sector'].to_string(index=False))
# Out:
# Brand Marketing, Event Promotion, Marketing, Sp...
#                               Agriculture, Farming
#   Credit, Financial Services, Lending, Marketplace
#                        Financial Services, FinTech
#                 E-Commerce Platforms, Retail, SaaS
#                   Cloud Infrastructure, PaaS, SaaS
#                     Internet, Leisure, Marketplace
#                                    Market Research
#       Information Services, Information Technology
#                                    Mobile Payments
#                                         B2B, Shoes
#                                           Internet
# Apps, Collaboration, Developer Platform, Enterp...
#                                      Food Delivery
#                              Industrial Automation
#        Automotive, Search Engine, Service Industry
#                          Finance, Internet, Travel
# Accounting, Business Information Systems, Busin...
# Artificial Intelligence, Product Search, SaaS, ...
#               Internet of Things, Waste Management
# Air Transportation, Freight Service, Logistics,...
#                                 Financial Services
#                                  Food and Beverage
#                                Autonomous Vehicles
# Enterprise Software, Health Care, Hospital, Par...
#          Agriculture, Analytics, Big Data, Farming
#                 Logistics, Supply Chain Management
#                        Financial Services, Lending
#            Automotive, Marketplace, Online Portals
#                            Artificial Intelligence
#             Internet of Things, Telecommunications
#                                          Insurance
#                                 Financial Services
# Information Technology, Logistics, Supply Chain...
#   Blockchain, Developer Tools, Enterprise Software
# Industrial Automation, Logistics, Supply Chain ...
#       Food and Beverage, Food Delivery, Snack Food
#                                          Education
#               E-Commerce, Fashion, Jewelry, Retail
#                                 Financial Services
#                                   Renewable Energy
#                              E-Learning, Education
#  Clean Energy, CleanTech, Laundry and Dry-cleaning
#                        E-Commerce, Fashion, Mobile
#         Apps, Messaging, Navigation, Public Safety
#                                     Transportation
#                        Financial Services, Lending
#                     Fitness, Health Care, Wellness
# Artificial Intelligence, Machine Learning, SaaS...
#                                        Hospitality
#                             Food and Beverage, Tea
#            Media and Entertainment, News, Outdoors
# Broadcasting, Media and Entertainment, Music, M...
#  B2B, Information Services, Information Technology
# EdTech, Education, Enterprise Software, Peer to...
#                               Health Care, Medical
#                                         E-Commerce
#                    Health Care, Hospital, Wellness
#                                                  —
#                                             Sports
#                Big Data, Consumer Lending, FinTech
#           Cloud Computing, Computer, Semiconductor
#               Health Care, Medical, Pharmaceutical
#                            Food Processing, Retail
#                                   Trading Platform
#                   Consumer Goods, Lifestyle, Men's
#                                           Wellness
#                                          Education
#      Food and Beverage, Food Processing, Nutrition
#                                            Fashion
#       Automotive, Electric Vehicle, Energy Storage
#                         Consulting, Retail, Social
# Biotechnology, Life Science, Pharmaceutical, Pr...
#                                        Health Care
# Credit, Financial Services, FinTech, Personal F...
#                                           Internet
#                 Communities, Coworking, Incubators
#              Consumer, Financial Services, FinTech
# Consumer Applications, Information Services, Lo...
# Mobile, Mobile Apps, Personalization, Test and ...
#             Education, Financial Services, FinTech
#         Advertising, Consulting, Digital Marketing
#          Marketplace, Real Estate, Rental Property
#                                        Health Care
#                  E-Learning, Internet, Video Games
#    Artificial Intelligence, Cloud Computing, Video
#                Health Care, Information Technology
#                                          Aerospace
#                     E-Commerce, Fashion, Lifestyle
# Artificial Intelligence, Business Intelligence,...
#                                          Insurance
#                                         E-Commerce
# Home Decor, Home Improvement, Home Renovation, ...
#      EdTech, Education, Information Services, SaaS
#                                      Energy, Solar
# B2B, Biometrics, Cyber Security, Fraud Detectio...
#                    Artificial Intelligence, Social
#                  Logistics, Transportation, Travel
#       Digital Marketing, SEM, SEO, Web Development
#                     Health Care, Hospital, Medical
#                        Finance, Financial Services
#           Food Delivery, Food Processing, Internet
#            E-Commerce, Food and Beverage, Internet
# Fitness, Food and Beverage, Health Care, Nutrition
#            EdTech, Education, Knowledge Management
#                                                  —
#                                 Financial Services
#                     Apps, Beauty, Consumer, Retail
# Creative Agency, Crowdfunding, EdTech, Health C...
# Consumer Lending, Financial Services, FinTech, ...
#            E-Learning, Education, Higher Education
#               Health Care, Medical, Pharmaceutical
#                                 Health Diagnostics
#                                  EdTech, Education
#                 Financial Services, SaaS, Security
#   Banking, Finance, Financial Services, Non Profit
#                        Finance, Financial Services
#                            B2B, E-Commerce, Mobile
#     Automotive, Electric Vehicle, Renewable Energy
#                                         E-Learning
# Embedded Systems, Health Care, Medical, Product...
#                                                  —
#                         Apps, E-Commerce, Internet
#            Advertising, Human Resources, Marketing
#           Beauty, Fitness, Home Services, Internet
#         Health Care, Medical Device, Public Safety
#         Food Delivery, Online Portals, Restaurants
#               AgTech, B2B, Supply Chain Management
# Credit Cards, Finance, Mobile Apps, Mobile Paym...
#                                           Software
# EdTech, Education, Higher Education, Secondary ...
#                              Manufacturing, Retail
#                                      Manufacturing
# Information Services, Information Technology, I...
#                          Consumer Lending, FinTech
#                       Internet, Social Network, TV
#                                Beauty, Health Care
#                                           Hospital
#                                             Events
#         3D Printing, Manufacturing, Product Design
#                                         Automotive
#                                 Automotive, Retail
#                                        Apps, Audio
#                             Automotive, E-Commerce
#      Digital Entertainment, Fantasy Sports, Sports
#                      E-Learning, EdTech, Education
#                                                  —
#           Funding Platform, Incubators, Non Profit
#                Hospitality, Hotel, Leisure, Travel
# Classifieds, Internet, Marketplace, Rental Prop...
#                                             Sports
#              Banking, E-Learning, Trading Platform
#                         E-Commerce, Mobile, Retail
#                                                  —
#    Artificial Intelligence, Information Technology
# Enterprise Resource Planning (ERP), Information...
#               Banking, Finance, Financial Services
#                                           Software
#       Information Services, Information Technology
#                     Audio, Mobile, Tourism, Travel
#             Energy, Energy Storage, Infrastructure
#                            Artificial Intelligence
#       Government, Information Technology, Software
#                             Information Technology
# Education, Information Technology, Internet, Mo...
# Consumer Lending, Financial Services, Lending, ...
# Digital Media, Internet, Media and Entertainmen...
# Business Intelligence, Customer Service, Market...
#       Credit, Financial Services, FinTech, Lending
#                                         E-Learning
#                                           Software
#                     Children, Education, Parenting
#        Automotive, Battery, Energy, Energy Storage
#                E-Commerce, Mobile, Sharing Economy
#                                                  —
#               Food Delivery, Organic, Organic Food
#                                             Mobile
#                                             Rental
#                                             Travel
#                                           Consumer
#                          B2B, Farming, Marketplace
#                                                  —
#                                  Wealth Management
#                                      Biotechnology
#                        Education, Gaming, Training
#                                         Veterinary
# Internet, Mobile, Social Entrepreneurship, Tele...
#     Health Care, Hospital, Supply Chain Management
#                        Finance, Financial Services
#                        Financial Services, Lending
#                                    Tourism, Travel
#                                          Education
#                           Hospitality, Real Estate
#                                            Finance
#                                    Market Research
#                                    Tourism, Travel
#    Digital Media, EBooks, Publishing, Reading Apps
# Consumer Electronics, Embedded Systems, Hardwar...
#                 Food and Beverage, Food Processing
#                    Internet, Marketplace, Shopping
# Analytics, Computer Vision, Enterprise Software...
#                        Facilities Support Services
#               Automotive, Electric Vehicle, Energy
# Health Care, Health Diagnostics, Predictive Ana...
#          Cloud Computing, Computer, SaaS, Software
#                         Fashion, Lifestyle, Retail
#                                          Education
#                                            Medical
#                                    Music Streaming
#                Finance, Impact Investing, Internet
#                                                  —
#                  Internet, Social Entrepreneurship
#                                             Retail
#             Finance, Impact Investing, Mobile Apps
#                Cloud Computing, Computer, Software
# Business Development, Market Research, Outsourcing
#                                          Education
#                           Health Care, Hospitality
#                      Internet, Social News, Sports
#                             Information Technology
#                                    Human Resources
#                                 Financial Services
#                                 Financial Services
#               Finance, Financial Services, FinTech
# Customer Service, Software, Video, Video Streaming
#                        E-Commerce, Food Processing
#                                        Health Care
#                                           Training
#                                             Travel
#                                  Food and Beverage
#                                                  —
# Dietary Supplements, Food and Beverage, Health ...
#                                 Financial Services
#               Manufacturing, Oil and Gas, Robotics
#                     Fitness, Health Care, Wellness
#                                                  —
# Artificial Intelligence, Computer, Machine Lear...
# Collaboration, Communities, Coworking, Sharing ...
#                                                  —
#                 Big Data, EdTech, Machine Learning
#                                     Nanotechnology
# Analytics, Audio, Digital Media, Innovation Man...
#                                                  —
#                                                  —
#          Financial Services, Lending, Peer to Peer
# E-Commerce, Furniture, Home Decor, Interior Des...
#                                      Digital Media
#                                                  —
#        File Sharing, Personalization, Social Media
#                        Home Decor, Interior Design
#           Health Care, Medical Device, Mobile Apps
#                                                  —
# E-Commerce, Facilities Support Services, Procur...
#          Crowdfunding, Finance, Financial Services
#             Finance, Financial Services, Insurance
#                Children, Education, Online Portals
#                          Software, Virtual Reality
#                                                  —
#                                                  —
#                                                  —
#              B2B, Food and Beverage, Food Delivery
# Catering, Food and Beverage, Food Delivery, Foo...
#                      Food and Beverage, Snack Food
#                     Automotive, E-Commerce, Mobile
# Computer, Digital Marketing, Facilities Support...
# Android, Big Data, Blockchain, Cloud Computing,...
# Analytics, CRM, Loyalty Programs, Machine Learn...
#      Delivery, Information Technology, Mobile Apps
#         Environmental Consulting, Renewable Energy
#                 Food and Beverage, Food Processing
# Big Data, Business Intelligence, Financial Serv...
#               Finance, Financial Services, FinTech
# Commercial Real Estate, Coworking, Office Admin...
# Food and Beverage, Food Processing, Organic Foo...
# Apps, Health Care, Internet, Mobile Apps, Perso...
# Digital Media, Incubators, Social Entrepreneurship
#             Finance, Financial Services, Marketing
# Biotechnology, Health Care, Life Science, Medic...
#                                             Travel
#                         Education, Human Resources
#                                           Internet
#                               Consumer Electronics
#           Apps, Health Care, Hospital, Mobile Apps
#      Delivery Service, Logistics, Service Industry
#       Information Services, Information Technology
#  Big Data, Data Visualization, Logistics, Software
# Basketball, Cricket, Cycling, eSports, Fitness,...
#          Media and Entertainment, News, Publishing
#                                           Internet
#                                         Consulting
#                                    Human Resources
#                                            Finance
# Big Data, Financial Services, Machine Learning,...
#                 Agriculture, AgTech, Manufacturing
#                                                  —
#                    Digital Media, News, Publishing
#                                 Financial Services
#                                           Software
#                              Health Care, Hospital
#          Crowdfunding, Finance, Financial Services
#                        B2B, E-Commerce, Enterprise
#    Fraud Detection, Information Services, Security
# Agriculture, AgTech, Artificial Intelligence, I...
#                   Cryptocurrency, Trading Platform
#                  Finance, FinTech, Mobile Payments
#                             Information Technology
#                                            Wedding
#                                      Digital Media
# E-Learning, EdTech, Education, Image Recognitio...
#                                     Consumer Goods
#                             Information Technology
#                     Fitness, Health Care, Wellness
#                              Digital Entertainment
# Crowdsourcing, Financial Services, Funding Plat...
#             Delivery, Drones, Geospatial, Robotics
#                              Health Care, Hospital
#                                     Consumer Goods
#                                 Financial Services
# Health Care, Information Technology, Management...
#                                            Farming
# Business Travel, Hospitality, Hotel, Marketplac...
# Career Planning, Education, Higher Education, S...
#                                     Medical Device
#                  Alternative Medicine, Health Care
#                                 Internet, Software
#                                                  —
#                                                  —
# Dental, Elder Care, Health Care, Home Health Ca...
# Financial Services, Insurance, Private Social N...
# Consumer Electronics, E-Commerce, E-Commerce Pl...
#                                          CleanTech
#                            Artificial Intelligence
#                                          Education
#                   Advertising, Internet, Marketing
#                                 Financial Services
#                Human Resources, Security, Training
#                 Consumer Lending, Finance, FinTech
#                     Marketing, Social Media, Video
#                                     Transportation
#                                            Banking
#                              Health Care, Hospital
#                 Food and Beverage, Food Processing
#                                    Food Processing
#                                               Apps
#                                          Marketing
# Apps, B2B, Freight Service, Logistics, SaaS, Sh...
#                                                  —
# Digital Entertainment, Fantasy Sports, Gaming, ...
# Automotive, Last Mile Transportation, Peer to P...
#                  Commercial, E-Learning, Education
# Continuing Education, EdTech, Education, Skill ...
#                   Smart Cities, Telecommunications
#                       Internet of Things, Robotics
# Apps, Home Services, Information Services, Info...
#                                   Medical, Tourism
#                                 Financial Services
#               Career Planning, Education, Internet
#                 Fashion, Graphic Design, Wearables
#        Communities, Leisure, Mobile Apps, Software
#                Automotive, Rental, Sharing Economy
# Energy, Environmental Consulting, Renewable Ene...
#                              Health Care, Hospital
#             Information Technology, SaaS, Security
#         Crowdfunding, Financial Services, Internet
# Customer Service, Information Technology, Inter...
# Advertising, Artificial Intelligence, Digital M...
# Credit Cards, Payments, Property Insurance, Pro...
#   Beauty, Cosmetics, Health Care, Service Industry
#               Banking, Finance, Financial Services
#                EdTech, Education, Mobile, Tutoring
#                               Social Media, Sports
#                                          Biopharma
#           E-Commerce, E-Commerce Platforms, Retail
#                      E-Commerce, Fashion, Shopping
#            Digital Entertainment, Mobile, PC Games
# Finance, Financial Services, Small and Medium B...
#                                    Mobile Payments
#       Artificial Intelligence, Energy, Oil and Gas
#       Computer, FinTech, Risk Management, Software
#                  Apps, Financial Services, FinTech
# Child Care, Health Care, Hospital, Medical, Wom...
#                                Agriculture, Mobile
# Finance, FinTech, Payments, Property Developmen...
# Information Services, Information Technology, M...
#                                          Education
#                Apps, Fitness, Health Care, mHealth
#                   Food and Beverage, Food Delivery
#                             Apps, Payments, Retail
#        Health Insurance, Insurance, Life Insurance
#                                         Automotive
#                       Rental, Taxi Service, Travel
# E-Commerce, E-Commerce Platforms, Internet, Retail
#          Financial Services, Professional Services
#                                 Health Diagnostics
# Customer Service, Messaging, Mobile Apps, Perso...
#                                Gaming, iOS, Sports
#                                             Retail
#                                                  —
# E-Commerce, E-Commerce Platforms, Internet, Mob...
#                                      Search Engine
# Battery, Electric Vehicle, Energy, Renewable En...
#               Agriculture, Farmers Market, Farming
# Artificial Intelligence, Drones, Navigation, Pa...
#                                            Fashion
# Fitness, GreenTech, Internet of Things, Mobile ...
#                           Mobile, Software, Travel
#                                          Cosmetics
#       Consulting, Cyber Security, Network Security
#                      E-Learning, EdTech, Education
#                       eSports, Gaming, Video Games
#                                   Fashion, Jewelry
#                                 Financial Services
#                                B2B, Medical Device
#       Credit, Financial Services, FinTech, Lending
#                      Consumer Goods, Manufacturing
#               Biotechnology, Health Care, Wellness
#           Health Care, Hospital, Medical, Robotics
#                                        Health Care
#                   E-Commerce, Fitness, Health Care
#                Financial Services, Venture Capital
#                                          Aerospace
#                          Accounting, Apps, FinTech
#                       Apps, Mobile, Transportation
#                                       Reading Apps
#                    Energy, Renewable Energy, Solar
#               Banking, Financial Services, FinTech
#                              Health Care, Hospital
#                                      Biotechnology
#                                 Financial Services
#                            Apps, Education, Retail
#                                   Electric Vehicle
#                               Agriculture, Farming
#                     Fitness, Health Care, Wellness
# Automotive, Battery, Electric Vehicle, Manufact...
#                Automotive, E-Commerce, Marketplace
#                                        Agriculture
#                             Information Technology
# Apps, Information Services, Information Technology
#                            Artificial Intelligence
#                                   B2B, Marketplace
#                                 Financial Services
#                                 Packaging Services
#                      Computer, Furniture, Software
# Food Delivery, Hospitality, Reservations, Resta...
# Collaboration, Communities, Coworking, Real Estate
#                       Accounting, Banking, Finance
# Cloud Computing, Enterprise Software, Network H...
# Information Services, Internet, Logistics, Supp...
#       Automotive, E-Commerce, Information Services
#                Delivery, Logistics, Transportation
#      Automotive, E-Commerce Platforms, Marketplace
# Last Mile Transportation, Railroad, Transportat...
# Cooking, E-Commerce, Food and Beverage, Food De...
# FinTech, Mobile, Mobile Payments, Payments, Ret...
#                              E-Learning, Education
#                             Online Games, Software
#                                                  —
#        Online Portals, Property Management, Rental
#                 E-Commerce, Food and Beverage, Tea
#                       Music, Social Network, Video
#                                         Automotive
#              Health Care, Pharmaceutical, Wellness
# Delivery Service, Food and Beverage, Food Delivery
# Hospitality, Information Technology, Travel Acc...
#               Biotechnology, Diabetes, Health Care
# Autonomous Vehicles, Last Mile Transportation, ...
#                             Information Technology
#                                 Financial Services
# Finance, Financial Exchanges, Financial Service...
#                        Finance, Financial Services
#                   Analytics, Apps, Market Research
#                                                  —
#                                                  —
#                        Finance, Financial Services
# E-Commerce, E-Commerce Platforms, Furniture, Ho...
#                                                  —
#                Apps, Mobile, Mobile Apps, Software
#                                                  —
#                     News, Publishing, Social Media
#                                                  —
#                  Industrial, Industrial Automation
#              Internet, Mobile Apps, Social Network
# Health Care, Health Diagnostics, Internet of Th...
#             E-Commerce, Furniture, Interior Design
#                                 Apps, Events, News
# Artificial Intelligence, Human Resources, Infor...
#     Health Care, Hospital, Supply Chain Management
#                Logistics, Railroad, Transportation
#                  Dating, Private Social Networking
#    Artificial Intelligence, Machine Learning, PaaS
#  Consumer, Furniture, Home Decor, Home Improvement
# Apps, E-Commerce, Internet, Mobile, Ride Sharin...
#                      Health Care, Health Insurance
#                          Energy, Natural Resources
#                 E-Commerce, Education, Health Care
#                  Apps, Health Care, Pharmaceutical
#                     Internet, Knowledge Management
# Credit, Finance, FinTech, Lending, Sales Automa...
#              Banking, Financial Services, Internet
#                        Financial Services, FinTech
#                    E-Commerce, Health Care, Retail
#                 Child Care, Information Technology
#                  Financial Services, Micro Lending
#                       E-Commerce, Retail, Shopping
#                                  Food and Beverage
#                                         E-Learning
#                 Food and Beverage, Snack Food, Tea
#            Delivery Service, E-Commerce, Logistics
#                         Fashion, Lifestyle, Rental
#                                                  —
#                     Fantasy Sports, Mobile, Sports
#                                          Education
#                          Beauty, Fashion, Wellness
#                Food and Beverage, Restaurants, Tea
#                    Fitness, Sporting Goods, Sports
#  Food and Beverage, Food Processing, Manufacturing
#                               E-Learning, Internet
#                                  Eyewear, Internet
# Information Technology, Mobile, News, Operating...
#      FinTech, Internet, Payments, Service Industry
#   B2B, Business Development, Internet, Marketplace
#                                    Tourism, Travel
#         Food and Beverage, Food Delivery, Internet
#                             Information Technology
#         Biotechnology, Health Care, Pharmaceutical
#                                          Ecommerce
#                                             Edtech
#                                             Edtech
#                                    Interior design
#                                           AgriTech
#                                         Technology
#                                               SaaS
#                                         Technology
#                                          AI & Tech
#                                         E-commerce
#                                    E-commerce & AR
#                                               SaaS
#                                            Fintech
#                                            HR tech
#                                          Food tech
#                                            Fintech
#                                             Edtech
#                                            Fintech
#                                             Edtech
#                                             Health
#                                            Fintech
#                                         Healthcare
#                                             Edtech
#                                        Safety tech
#                                     Pharmaceutical
#                                               SaaS
#                               Insurance technology
#                                                 AI
#                                           Foodtech
#                                           AgriTech
#                                               Food
#                                                IoT
#                                      E-marketplace
#                                      Robotics & AI
#                                          Logistics
#                                             Travel
#                                      Manufacturing
#                                                 AI
#                                      E-marketplace
#                                   Food & Nutrition
#                                       Social Media
#                                                NaN
#                                         E-commerce
#                                               SaaS
#                                           E-Sports
#                                            Fintech
#                                         Technology
#                                           AgriTech
#                                           Foodtech
#                                                NaN
#                                          Cosmetics
#                                                B2B
#                                                NaN
#                                          Jewellery
#                                   B2B Supply Chain
#                                              Games
#                                                NaN
#                                                NaN
#                                           AgriTech
#                                        Food & tech
#                                          Logistics
#                                       Accomodation
#                                    Automotive tech
#                                    Automotive tech
#                                         E-commerce
#                                                IoT
#                                         Legal tech
#                                             Edtech
#                                               Food
#                                       Mutual Funds
#                                      Cybersecurity
#                                             Edtech
#                                         Automobile
#                                          Logistics
#                                         Automobile
#                                             Sports
#                                         Healthtech
#                                    Yoga & wellness
#                                    Virtual Banking
#                                       Accomodation
#                                     Transportation
#                                Transport & Rentals
#                                         Technology
#                       Marketing & Customer loyalty
#                                          Infratech
#                                        Hospitality
#                            Automobile & Technology
#                                         Automobile
#                                            Banking
#                                           AgriTech
#                                             EdTech
#                                 Hygiene management
#                                             Escrow
#                                           AgriTech
#                                           AgriTech
#                                             EdTech
#                                Networking platform
#                                            FinTech
#                                      Crowdsourcing
#                                   Food & Bevarages
#                                         HealthTech
#                                    Fashion startup
#                                   Food & Bevarages
#                                      Food Industry
#                                      Food Delivery
#                           Virtual auditing startup
#                                         E-commerce
#                                            FinTech
#                                            FinTech
#                                             Gaming
#                                            FinTech
#                                            FinTech
#                                   Work fulfillment
#                                            FinTech
#                                            FinTech
#                                         AI startup
#                                  Telecommunication
#                                      Food Industry
#                                         E-commerce
#                                           AgriTech
#                                          Logistics
#                                            FinTech
#                                             EdTech
#                                       Tech Startup
#                                             Sports
#                                         E-commerce
#                                         E-commerce
#                                             Retail
#                                            Medtech
#                                    Tyre management
#                                            FinTech
#                                      Cloud company
#                                   Software company
#                                 Venture capitalist
#                                   Renewable player
#                                            FinTech
#                                             EdTech
#                                        IoT startup
#                                       SaaS startup
#                                            FinTech
#                                         HealthTech
#                                         HealthTech
#                                       Aero company
#                                  Marketing company
#                                     Retail startup
#                                            FinTech
#                                             EdTech
#                                 Co-working Startup
#                                          Logistics
#                                    Finance company
#                                            FinTech
#                                           AgriTech
#                                       Tech company
#                           Solar Monitoring Company
#                                       SaaS startup
#                             Video sharing platform
#                                     Gaming startup
#                                         E-commerce
#                           Video streaming platform
#                                Consumer appliances
#                                         E-commerce
#                                            FinTech
#                                             EdTech
#                                     Gaming startup
#                                         HealthTech
#                                 Blockchain startup
#                         Conversational AI platform
#                                         E-commerce
#                                           AgriTech
#                                        Real Estate
#                                 Venture capitalist
#                                         E-commerce
#                                             EdTech
#                                    Finance company
#                                    Finance company
#                                      SaaS platform
#                                             EdTech
#                                      SaaS platform
#                                        AI platform
#                                             EdTech
#                                             EdTech
#                                   Fusion beverages
#                                            HR Tech
#                                             Gaming
#                                         Job portal
#                                        Hospitality
#                                         Job portal
#                                      Digital Media
#                                            FinTech
#                                            FinTech
#                                         AI startup
#                                      Dairy startup
#                                 Content management
#                                             Retail
#                                          Spacetech
#                                         HealthTech
#                                     Transportation
#                                   Trading platform
#                                            FinTech
#                                       Tech company
#                                            FinTech
#                                         AI Company
#                                       Tech company
#                                  Photonics startup
#                                            FinTech
#                                             EdTech
#                                             EdTech
#                                         HealthTech
#                                      Entertainment
#                                          Cosmetics
#                                       Scanning app
#                                            FinTech
#                                   Skincare startup
#                                             EdTech
#                                         E-commerce
#                                 Food and Beverages
#                                         AI startup
#                                             EdTech
#                              Biotechnology company
#                                         AI startup
#                                     Gaming startup
#                                            FinTech
#                                         HealthTech
#                                         E-commerce
#                                     Gaming startup
#                                            FinTech
#                                           FoodTech
#                                           Proptech
#                                         HealthTech
#                                          CleanTech
#                                       SaaS startup
#                                         HealthTech
#                                       Tech Startup
#                                      SaaS platform
#                                            FinTech
#                                         E-commerce
#                                    Fitness startup
#                                          Cosmetics
#                                 Venture capitalist
#                                            FinTech
#                                         Healthcare
#                                       SaaS startup
#                                         E-commerce
#                                            FinTech
#                                         HealthTech
#                                           AgriTech
#                                       PaaS startup
#                                      Entertainment
#                                             EdTech
#                                             Retail
#                                          Beverages
#                                         HealthTech
#                                             EdTech
#                                         E-commerce
#                                       Social Media
#                                        Automobiles
#                                       SaaS startup
#                                            FinTech
#                                    Fashion startup
#                                             EdTech
#                                   Food & Bevarages
#                                           Deeptech
#                                         EV startup
#                                             EdTech
#                                             EdTech
#                                      AR/VR startup
#                                         E-commerce
#                                Recruitment startup
#                                         HealthTech
#                                        QSR startup
#                                     Video platform
#                                   Food & Bevarages
#                                             EdTech
#                                             EdTech
#                                         AI startup
#                                          Logistics
#                                             Gaming
#                                         AI startup
#                                        Hospitality
#                                           AgriTech
#                                            FinTech
#                                           AgriTech
#                                           AgriTech
#                                         E-commerce
#                                            FinTech
#                                     Transportation
#                                            FinTech
#                                             Edtech
#                                         E-commerce
#                                     Fertility tech
#                                            FinTech
#                                 Luxury car startup
#                                         Healthcare
#                                         E-commerce
#                                     Gaming startup
#                                          Cosmetics
#                                                 FM
#                                         Healthcare
#                                         E-commerce
#                                             Retail
#                                         E-commerce
#                                               Food
#                                             Edtech
#                                   Nutrition sector
#                                           AgriTech
#                                            FinTech
#                                      Tech platform
#                                         Healthcare
#                                              Video
#                                        Retail Tech
#                                       Tech company
#                                            FinTech
#                                         AI startup
#                                          Cosmetics
#                                            FinTech
#                                             Edtech
#                                         AI startup
#                                             Edtech
#                                            Medtech
#                                          HeathTech
#                                             Edtech
#                                        Automobiles
#                                       Social Media
#                                     Retail startup
#                                             Gaming
#                                            Medtech
#                                             Retail
#                                 Sles and marketing
#                                          LegalTech
#                                             Edtech
#                                       SaaS startup
#                                        Car Service
#                                         E-commerce
#                                       Tech Startup
#                                           FoodTech
#                                       Tech Startup
#                                   Bike marketplace
#                                          Agri tech
#                                        Automobiles
#                                    Fitness startup
#                                           FoodTech
#                                   Food & Bevarages
#                                       Tech Startup
#                                        Real Estate
#                                       SaaS startup
#                                     Reatil startup
#                                        AR platform
#                                         EV startup
#                                            FinTech
#                                           Deeptech
#                                          LegalTech
#                                            FinTech
#                                     Consumer Goods
#                                         AI startup
#                                            FinTech
#                                      Food Industry
#                                      Food Industry
#                                Content marketplace
#                                    Interior Design
#                                         Healthcare
#                                         Healthcare
#                                       Tech company
#                                           AgriTech
#                                             Edtech
#                                            FinTech
#                                            FinTech
#                                       SaaS startup
#                                             Retail
#                                             Edtech
#                                         AI startup
#                                       Rental space
#                                           AgriTech
#                                          Soil-Tech
#                                Recruitment startup
#                                         AI startup
#                                            FinTech
#                                             Edtech
#                                      Ayurveda tech
#                         Packaging solution startup
#                                       SaaS startup
#                                             Gaming
#                                        Hospitality
#                                          Cleantech
#                                       Social Media
#                                          LegalTech
#                                             Gaming
#                               Sanitation solutions
#                                       SaaS startup
#                                       Tech company
#                                         E-commerce
#                                             Edtech
#                                           AgriTech
#                                       Tech company
#                                         HealthCare
#                                            FinTech
#                                         E-commerce
#                                         E-commerce
#                                         HealthCare
#                                        Home Design
#                                         InsureTech
#                                           AgriTech
#                                         AI Startup
#                                       Tech Startup
#                                      Entertainment
#                                       Tech company
#                                       Tech company
#                                             EdTech
#                                      Entertainment
#                                     Solar solution
#                                         E-commerce
#                                            FinTech
#                                            FinTech
#                                         HealthCare
#                                             EdTech
#                                  Jewellery startup
#                 Multinational conglomerate company
# ...
#                                 Financial Services
#                                         E-learning
#                                       Online Media
#                  Information Technology & Services
#                                   Food & Beverages
#                               Company-as-a-Service
#                                            Eyewear
#                                           Textiles
#                  Information Technology & Services
#                  Information Technology & Services
#                             Hospital & Health Care
#                                  Computer Software
#                                                D2C
#                   Professional Training & Coaching
#                                           Maritime
#                                     Consumer Goods
#                  Information Technology & Services
#                                 Financial Services
#                                 Financial Services
#                                          Furniture
#                   Venture Capital & Private Equity
#                                 Financial Services
#                                 Financial Services
#                                         E-learning
#                                  Computer Software
#                                         E-learning
#                                 Financial Services
#                         Health, Wellness & Fitness
#                                Housing Marketplace
#                               Education Management
#                                        Real Estate
#                              Industrial Automation
#                                 Financial Services
#                                 Financial Services
#                                     Consumer Goods
#                                 Financial Services
#                                        Real Estate
#                                       Tech startup
#                                         Automotive
#                                             Sports
#                                         Automotive
#                                   Furniture Rental
#                                 Financial Services
#                                         E-learning
#                                         E-learning
#                             Hospital & Health Care
#                                 Financial Services
#                                          Cosmetics
#                                     Consumer Goods
#                                            FinTech
#                                        Recruitment
#                                           Textiles
#                                         E-commerce
#                  Information Technology & Services
#                                          Insurance
#                                             EdTech
#                  Information Technology & Services
#                                   Food & Beverages
#                                           Mobility
#                  Information Technology & Services
#                                            Farming
#                                             EdTech
#                                 Telecommunications
#                                             Crypto
#                                          Insurance
#                                         Automotive
#                  Information Technology & Services
#                                  Computer Software
#                           Renewables & Environment
#                         Health, Wellness & Fitness
#                                  Equity Management
#                         Health, Wellness & Fitness
#                                      Cloud kitchen
#                            Marketing & Advertising
#                                     Nanotechnology
#                                      Entertainment
#                                  Computer Software
#                                         Automotive
#                                          Community
#                                             Retail
#                                   Higher Education
#                                 Financial Services
#                                 Financial Services
#                         Health, Wellness & Fitness
#                                              Media
#                                                NFT
#                                                B2B
#               Mechanical Or Industrial Engineering
#                                   Software Startup
#                                 Financial Services
#                                 Financial Services
#                                 Financial Services
#                                         E-learning
#                                         Automotive
#                                      D2C jewellery
#                             Sales and Distribution
#                                               SaaS
#                                         E-learning
#                                   Food & Beverages
#                  Information Technology & Services
#                               Information Services
#                                  Apparel & Fashion
#                                             Crypto
#                  Information Technology & Services
#                         Health, Wellness & Fitness
#                                          Furniture
#                                 Financial Services
#                                  Computer Software
#                                      Biotechnology
#                                               SaaS
#                         Translation & Localization
#                                            Finance
#                               Education Management
#                                      Entertainment
#                                 Financial Services
#                                 Financial Services
#                            Marketing & Advertising
#                                         Automotive
#                                      Entertainment
#                                 Financial Services
#                                   Food & Beverages
#                                 Investment Banking
#                                            Farming
#                                             EdTech
#                  Information Technology & Services
#                                             Retail
#                                        Hospitality
#                  Information Technology & Services
#               Mechanical Or Industrial Engineering
#                                         E-learning
#                                    Social commerce
#                                   Food & Beverages
#                                  Computer Software
#                                            Finance
#                                     Consumer Goods
#                                 Financial Services
#                                         E-learning
#                           Logistics & Supply Chain
#                  Information Technology & Services
#                                          Marketing
#                                 Financial Services
#                                 Financial Services
#                                 Financial Services
#                                           AgriTech
#                                            Femtech
#                                  Computer Software
#                                    Human Resources
#                  Information Technology & Services
#                                             Retail
#                                 Financial Services
#                                  Computer Software
#                                             sports
#                                       Tech startup
#                                          Foootwear
#                                  Computer Software
#                                     Consumer Goods
#                                          Insurance
#                                             Retail
#                                   Food & Beverages
#                                     Legal Services
#                             Hospital & Health Care
#                                         Veterinary
#                                 Financial Services
#                                     Consumer Goods
#                                         E-commerce
#                                      Arts & Crafts
#                             Hospital & Health Care
#                                   Food & Beverages
#                                         E-learning
#                             Hospital & Health Care
#                                            FinTech
#                                         E-learning
#                                 Telecommunications
#                                             sports
#                                    Social commerce
#                                         Automotive
#                                  Computer Software
#                  Information Technology & Services
#                                         Blockchain
#                                 Financial Services
#                                         Automotive
#                                       Construction
#                                            FinTech
#                                      Arts & Crafts
#                  Information Technology & Services
#                                 Financial Services
#                                 Financial Services
#                                            FinTech
#                                   Food & Beverages
#                                 Financial Services
#                         Health, Wellness & Fitness
#                                         Healthtech
#                                            Farming
#                           Logistics & Supply Chain
#                                 Financial Services
#                              Investment Management
#                                          Education
#                                             sports
#                         Health, Wellness & Fitness
#                              Management Consulting
#                             Hospital & Health Care
#                                        B2B startup
#                                 Financial Services
#                  Information Technology & Services
# Sochcast is an Audio experiences company that g...
#                             Hospital & Health Care
#                                            FinTech
#                                 Financial Services
#                                             Retail
#                           Logistics & Supply Chain
#                   Professional Training & Coaching
#                                        Hospitality
#                                         E-learning
#                                  Computer Software
#                                         Automotive
#                                 Financial Services
#                                       Online Media
#                  Information Technology & Services
#                                           Mobility
#                                             Design
#                                 Financial Services
#                                  Computer Software
#                                         E-learning
#                                         E-learning
#                                   Food & Beverages
#                                  Consumer Services
#                                      Biotechnology
#                                 Financial Services
#                                         E-learning
#                                            FinTech
#                                          Healtcare
#                                       Online Media
#                                   Higher Education
#                                         Automotive
#                                  Computer Software
#                                         B2B Travel
#                                   Food & Beverages
#                  Information Technology & Services
#                  Information Technology & Services
#                             Hospital & Health Care
#                                 Financial Services
#                                             EdTech
#                                  Computer Software
#                                             Retail
#                                         Healthtech
#                                         E-learning
#                                            FinTech
#                  Information Technology & Services
#                                  Consumer Services
#                  Information Technology & Services
#                                             sports
#                                             EdTech
#                           Logistics & Supply Chain
#                                              Music
#                                             Gaming
#                         Health, Wellness & Fitness
#                                        Recruitment
#                                           AgriTech
#                                  Apparel & Fashion
#                                     Wine & Spirits
#                                       SaaS startup
#                  Information Technology & Services
#                                 Financial Services
#                                 Financial Services
#                               Consumer Electronics
#                                             EdTech
#                                      Biotechnology
#                                     Computer Games
#                                           AgriTech
#                                    Food Production
#                                             EdTech
#                                  Consumer Services
#                         Health, Wellness & Fitness
#                                    Interior Design
#                                         E-learning
#                                            FinTech
#                              Industrial Automation
#                                 Financial Services
#                                             EdTech
#                                         AI startup
#                     Manchester, Greater Manchester
#                                         Automotive
#                              Investment Management
#                                     Product studio
#                                             EdTech
#                                         E-commerce
#                                             Health
#                                             Retail
#                                             EdTech
#                                   Food & Beverages
#                                       SaaS startup
#                                           Deeptech
#                  Information Technology & Services
#                                         Blockchain
#                                      Biotechnology
#                         Health, Wellness & Fitness
#                                                B2B
#                                  Computer Software
#                                            FinTech
#                           Logistics & Supply Chain
#                                             Design
#                                           Internet
#                  Information Technology & Services
#                                    Food Production
#                                           AgriTech
#                               Aviation & Aerospace
#                                           Deeptech
#                           Logistics & Supply Chain
#                              Staffing & Recruiting
#                                   Food & Beverages
#                                 Financial Services
#                                             EdTech
#                                 Financial Services

# %%
# Get unique values in the Company_Brand column
unique_sectors = df['Sector'].unique()

# Convert the unique values array to a list
unique_sectors_list = unique_sectors.tolist()

# Print the list of unique company brands
unique_sectors_list
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#  'Agriculture, Farming',
#  'Credit, Financial Services, Lending, Marketplace',
#  'Financial Services, FinTech',
#  'E-Commerce Platforms, Retail, SaaS',
#  'Cloud Infrastructure, PaaS, SaaS',
#  'Internet, Leisure, Marketplace',
#  'Market Research',
#  'Information Services, Information Technology',
#  'Mobile Payments',
#  'B2B, Shoes',
#  'Internet',
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#  'Food Delivery',
#  'Industrial Automation',
#  'Automotive, Search Engine, Service Industry',
#  'Finance, Internet, Travel',
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#  'Internet of Things, Waste Management',
#  'Air Transportation, Freight Service, Logistics, Marine Transportation',
#  'Financial Services',
#  'Food and Beverage',
#  'Autonomous Vehicles',
#  'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS',
#  'Agriculture, Analytics, Big Data, Farming',
#  'Logistics, Supply Chain Management',
#  'Financial Services, Lending',
#  'Automotive, Marketplace, Online Portals',
#  'Artificial Intelligence',
#  'Internet of Things, Telecommunications',
#  'Insurance',
#  'Information Technology, Logistics, Supply Chain Management',
#  'Blockchain, Developer Tools, Enterprise Software',
#  'Industrial Automation, Logistics, Supply Chain Management',
#  'Food and Beverage, Food Delivery, Snack Food',
#  'Education',
#  'E-Commerce, Fashion, Jewelry, Retail',
#  'Renewable Energy',
#  'E-Learning, Education',
#  'Clean Energy, CleanTech, Laundry and Dry-cleaning',
#  'E-Commerce, Fashion, Mobile',
#  'Apps, Messaging, Navigation, Public Safety',
#  'Transportation',
#  'Fitness, Health Care, Wellness',
#  'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant',
#  'Hospitality',
#  'Food and Beverage, Tea',
#  'Media and Entertainment, News, Outdoors',
#  'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming',
#  'B2B, Information Services, Information Technology',
#  'EdTech, Education, Enterprise Software, Peer to Peer',
#  'Health Care, Medical',
#  'E-Commerce',
#  'Health Care, Hospital, Wellness',
#  '—',
#  'Sports',
#  'Big Data, Consumer Lending, FinTech',
#  'Cloud Computing, Computer, Semiconductor',
#  'Health Care, Medical, Pharmaceutical',
#  'Food Processing, Retail',
#  'Trading Platform',
#  "Consumer Goods, Lifestyle, Men's",
#  'Wellness',
#  'Food and Beverage, Food Processing, Nutrition',
#  'Fashion',
#  'Automotive, Electric Vehicle, Energy Storage',
#  'Consulting, Retail, Social',
#  'Biotechnology, Life Science, Pharmaceutical, Product Research',
#  'Health Care',
#  'Credit, Financial Services, FinTech, Personal Finance',
#  'Communities, Coworking, Incubators',
#  'Consumer, Financial Services, FinTech',
#  'Consumer Applications, Information Services, Location Based Services, Virtual Assistant',
#  'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps',
#  'Education, Financial Services, FinTech',
#  'Advertising, Consulting, Digital Marketing',
#  'Marketplace, Real Estate, Rental Property',
#  'E-Learning, Internet, Video Games',
#  'Artificial Intelligence, Cloud Computing, Video',
#  'Health Care, Information Technology',
#  'Aerospace',
#  'E-Commerce, Fashion, Lifestyle',
#  'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning',
#  'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home',
#  'EdTech, Education, Information Services, SaaS',
#  'Energy, Solar',
#  'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security',
#  'Artificial Intelligence, Social',
#  'Logistics, Transportation, Travel',
#  'Digital Marketing, SEM, SEO, Web Development',
#  'Health Care, Hospital, Medical',
#  'Finance, Financial Services',
#  'Food Delivery, Food Processing, Internet',
#  'E-Commerce, Food and Beverage, Internet',
#  'Fitness, Food and Beverage, Health Care, Nutrition',
#  'EdTech, Education, Knowledge Management',
#  'Apps, Beauty, Consumer, Retail',
#  'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health',
#  'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management',
#  'E-Learning, Education, Higher Education',
#  'Health Diagnostics',
#  'EdTech, Education',
#  'Financial Services, SaaS, Security',
#  'Banking, Finance, Financial Services, Non Profit',
#  'B2B, E-Commerce, Mobile',
#  'Automotive, Electric Vehicle, Renewable Energy',
#  'E-Learning',
#  'Embedded Systems, Health Care, Medical, Product Research',
#  'Apps, E-Commerce, Internet',
#  'Advertising, Human Resources, Marketing',
#  'Beauty, Fitness, Home Services, Internet',
#  'Health Care, Medical Device, Public Safety',
#  'Food Delivery, Online Portals, Restaurants',
#  'AgTech, B2B, Supply Chain Management',
#  'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments',
#  'Software',
#  'EdTech, Education, Higher Education, Secondary Education',
#  'Manufacturing, Retail',
#  'Manufacturing',
#  'Information Services, Information Technology, InsurTech',
#  'Consumer Lending, FinTech',
#  'Internet, Social Network, TV',
#  'Beauty, Health Care',
#  'Hospital',
#  'Events',
#  '3D Printing, Manufacturing, Product Design',
#  'Automotive',
#  'Automotive, Retail',
#  'Apps, Audio',
#  'Automotive, E-Commerce',
#  'Digital Entertainment, Fantasy Sports, Sports',
#  'E-Learning, EdTech, Education',
#  'Funding Platform, Incubators, Non Profit',
#  'Hospitality, Hotel, Leisure, Travel',
#  'Classifieds, Internet, Marketplace, Rental Property',
#  'Banking, E-Learning, Trading Platform',
#  'E-Commerce, Mobile, Retail',
#  'Artificial Intelligence, Information Technology',
#  'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate',
#  'Banking, Finance, Financial Services',
#  'Audio, Mobile, Tourism, Travel',
#  'Energy, Energy Storage, Infrastructure',
#  'Government, Information Technology, Software',
#  'Information Technology',
#  'Education, Information Technology, Internet, Mobile, Software',
#  'Consumer Lending, Financial Services, Lending, Personal Finance',
#  'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media',
#  'Business Intelligence, Customer Service, Market Research, SaaS',
#  'Credit, Financial Services, FinTech, Lending',
#  'Children, Education, Parenting',
#  'Automotive, Battery, Energy, Energy Storage',
#  'E-Commerce, Mobile, Sharing Economy',
#  'Food Delivery, Organic, Organic Food',
#  'Mobile',
#  'Rental',
#  'Travel',
#  'Consumer',
#  'B2B, Farming, Marketplace',
#  'Wealth Management',
#  'Biotechnology',
#  'Education, Gaming, Training',
#  'Veterinary',
#  'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless',
#  'Health Care, Hospital, Supply Chain Management',
#  'Tourism, Travel',
#  'Hospitality, Real Estate',
#  'Finance',
#  'Digital Media, EBooks, Publishing, Reading Apps',
#  'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software',
#  'Food and Beverage, Food Processing',
#  'Internet, Marketplace, Shopping',
#  'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition',
#  'Facilities Support Services',
#  'Automotive, Electric Vehicle, Energy',
#  'Health Care, Health Diagnostics, Predictive Analytics',
#  'Cloud Computing, Computer, SaaS, Software',
#  'Fashion, Lifestyle, Retail',
#  'Medical',
#  'Music Streaming',
#  'Finance, Impact Investing, Internet',
#  'Internet, Social Entrepreneurship',
#  'Retail',
#  'Finance, Impact Investing, Mobile Apps',
#  'Cloud Computing, Computer, Software',
#  'Business Development, Market Research, Outsourcing',
#  'Health Care, Hospitality',
#  'Internet, Social News, Sports',
#  'Human Resources',
#  'Finance, Financial Services, FinTech',
#  'Customer Service, Software, Video, Video Streaming',
#  'E-Commerce, Food Processing',
#  'Training',
#  'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food',
#  'Manufacturing, Oil and Gas, Robotics',
#  'Artificial Intelligence, Computer, Machine Learning',
#  'Collaboration, Communities, Coworking, Sharing Economy',
#  'Big Data, EdTech, Machine Learning',
#  'Nanotechnology',
#  'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment',
#  'Financial Services, Lending, Peer to Peer',
#  'E-Commerce, Furniture, Home Decor, Interior Design, Internet',
#  'Digital Media',
#  'File Sharing, Personalization, Social Media',
#  'Home Decor, Interior Design',
#  'Health Care, Medical Device, Mobile Apps',
#  'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management',
#  'Crowdfunding, Finance, Financial Services',
#  'Finance, Financial Services, Insurance',
#  'Children, Education, Online Portals',
#  'Software, Virtual Reality',
#  'B2B, Food and Beverage, Food Delivery',
#  'Catering, Food and Beverage, Food Delivery, Food Processing',
#  'Food and Beverage, Snack Food',
#  'Automotive, E-Commerce, Mobile',
#  'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development',
#  'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development',
#  'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses',
#  'Delivery, Information Technology, Mobile Apps',
#  'Environmental Consulting, Renewable Energy',
#  'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance',
#  'Commercial Real Estate, Coworking, Office Administration, Real Estate',
#  'Food and Beverage, Food Processing, Organic Food, Snack Food',
#  'Apps, Health Care, Internet, Mobile Apps, Personal Health',
#  'Digital Media, Incubators, Social Entrepreneurship',
#  'Finance, Financial Services, Marketing',
#  'Biotechnology, Health Care, Life Science, Medical Device',
#  'Education, Human Resources',
#  'Consumer Electronics',
#  'Apps, Health Care, Hospital, Mobile Apps',
#  'Delivery Service, Logistics, Service Industry',
#  'Big Data, Data Visualization, Logistics, Software',
#  'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball',
#  'Media and Entertainment, News, Publishing',
#  'Consulting',
#  'Big Data, Financial Services, Machine Learning, Predictive Analytics',
#  'Agriculture, AgTech, Manufacturing',
#  'Digital Media, News, Publishing',
#  'Health Care, Hospital',
#  'B2B, E-Commerce, Enterprise',
#  'Fraud Detection, Information Services, Security',
#  'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning',
#  'Cryptocurrency, Trading Platform',
#  'Finance, FinTech, Mobile Payments',
#  'Wedding',
#  'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education',
#  'Consumer Goods',
#  'Digital Entertainment',
#  'Crowdsourcing, Financial Services, Funding Platform, Venture Capital',
#  'Delivery, Drones, Geospatial, Robotics',
#  'Health Care, Information Technology, Management Information Systems',
#  'Farming',
#  'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations',
#  'Career Planning, Education, Higher Education, Service Industry',
#  'Medical Device',
#  'Alternative Medicine, Health Care',
#  'Internet, Software',
#  'Dental, Elder Care, Health Care, Home Health Care, Personal Health',
#  'Financial Services, Insurance, Private Social Networking',
#  'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping',
#  'CleanTech',
#  'Advertising, Internet, Marketing',
#  'Human Resources, Security, Training',
#  'Consumer Lending, Finance, FinTech',
#  'Marketing, Social Media, Video',
#  'Banking',
#  'Food Processing',
#  'Apps',
#  'Marketing',
#  'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation',
#  'Digital Entertainment, Fantasy Sports, Gaming, Sports',
#  'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing',
#  'Commercial, E-Learning, Education',
#  'Continuing Education, EdTech, Education, Skill Assessment',
#  'Smart Cities, Telecommunications',
#  'Internet of Things, Robotics',
#  'Apps, Home Services, Information Services, Information Technology',
#  'Medical, Tourism',
#  'Career Planning, Education, Internet',
#  'Fashion, Graphic Design, Wearables',
#  'Communities, Leisure, Mobile Apps, Software',
#  'Automotive, Rental, Sharing Economy',
#  'Energy, Environmental Consulting, Renewable Energy, Solar',
#  'Information Technology, SaaS, Security',
#  'Crowdfunding, Financial Services, Internet',
#  'Customer Service, Information Technology, Internet, Sales Automation',
#  'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming',
#  'Credit Cards, Payments, Property Insurance, Property Management, Rental Property',
#  'Beauty, Cosmetics, Health Care, Service Industry',
#  'EdTech, Education, Mobile, Tutoring',
#  'Social Media, Sports',
#  'Biopharma',
#  'E-Commerce, E-Commerce Platforms, Retail',
#  'E-Commerce, Fashion, Shopping',
#  'Digital Entertainment, Mobile, PC Games',
#  'Finance, Financial Services, Small and Medium Businesses',
#  'Artificial Intelligence, Energy, Oil and Gas',
#  'Computer, FinTech, Risk Management, Software',
#  'Apps, Financial Services, FinTech',
#  "Child Care, Health Care, Hospital, Medical, Women's",
#  'Agriculture, Mobile',
#  'Finance, FinTech, Payments, Property Development, Rental',
#  'Information Services, Information Technology, Mobile, Software',
#  'Apps, Fitness, Health Care, mHealth',
#  'Food and Beverage, Food Delivery',
#  'Apps, Payments, Retail',
#  'Health Insurance, Insurance, Life Insurance',
#  'Rental, Taxi Service, Travel',
#  'E-Commerce, E-Commerce Platforms, Internet, Retail',
#  'Financial Services, Professional Services',
#  'Customer Service, Messaging, Mobile Apps, Personalization',
#  'Gaming, iOS, Sports',
#  'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media',
#  'Search Engine',
#  'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation',
#  'Agriculture, Farmers Market, Farming',
#  'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics',
#  'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation',
#  'Mobile, Software, Travel',
#  'Cosmetics',
#  'Consulting, Cyber Security, Network Security',
#  'eSports, Gaming, Video Games',
#  'Fashion, Jewelry',
#  'B2B, Medical Device',
#  'Consumer Goods, Manufacturing',
#  'Biotechnology, Health Care, Wellness',
#  'Health Care, Hospital, Medical, Robotics',
#  'E-Commerce, Fitness, Health Care',
#  'Financial Services, Venture Capital',
#  'Accounting, Apps, FinTech',
#  'Apps, Mobile, Transportation',
#  'Reading Apps',
#  'Energy, Renewable Energy, Solar',
#  'Banking, Financial Services, FinTech',
#  'Apps, Education, Retail',
#  'Electric Vehicle',
#  'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design',
#  'Automotive, E-Commerce, Marketplace',
#  'Agriculture',
#  'Apps, Information Services, Information Technology',
#  'B2B, Marketplace',
#  'Packaging Services',
#  'Computer, Furniture, Software',
#  'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine',
#  'Collaboration, Communities, Coworking, Real Estate',
#  'Accounting, Banking, Finance',
#  'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS',
#  'Information Services, Internet, Logistics, Supply Chain Management, Transportation',
#  'Automotive, E-Commerce, Information Services',
#  'Delivery, Logistics, Transportation',
#  'Automotive, E-Commerce Platforms, Marketplace',
#  'Last Mile Transportation, Railroad, Transportation, Travel',
#  'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals',
#  'FinTech, Mobile, Mobile Payments, Payments, Retail Technology',
#  'Online Games, Software',
#  'Online Portals, Property Management, Rental',
#  'E-Commerce, Food and Beverage, Tea',
#  'Music, Social Network, Video',
#  'Health Care, Pharmaceutical, Wellness',
#  'Delivery Service, Food and Beverage, Food Delivery',
#  'Hospitality, Information Technology, Travel Accommodations',
#  'Biotechnology, Diabetes, Health Care',
#  'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental',
#  'Finance, Financial Exchanges, Financial Services, Micro Lending',
#  'Analytics, Apps, Market Research',
#  'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet',
#  'Apps, Mobile, Mobile Apps, Software',
#  'News, Publishing, Social Media',
#  'Industrial, Industrial Automation',
#  'Internet, Mobile Apps, Social Network',
#  'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device',
#  'E-Commerce, Furniture, Interior Design',
#  'Apps, Events, News',
#  'Artificial Intelligence, Human Resources, Information Services, Information Technology',
#  'Logistics, Railroad, Transportation',
#  'Dating, Private Social Networking',
#  'Artificial Intelligence, Machine Learning, PaaS',
#  'Consumer, Furniture, Home Decor, Home Improvement',
#  'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation',
#  'Health Care, Health Insurance',
#  'Energy, Natural Resources',
#  'E-Commerce, Education, Health Care',
#  'Apps, Health Care, Pharmaceutical',
#  'Internet, Knowledge Management',
#  'Credit, Finance, FinTech, Lending, Sales Automation',
#  'Banking, Financial Services, Internet',
#  'E-Commerce, Health Care, Retail',
#  'Child Care, Information Technology',
#  'Financial Services, Micro Lending',
#  'E-Commerce, Retail, Shopping',
#  'Food and Beverage, Snack Food, Tea',
#  'Delivery Service, E-Commerce, Logistics',
#  'Fashion, Lifestyle, Rental',
#  'Fantasy Sports, Mobile, Sports',
#  'Beauty, Fashion, Wellness',
#  'Food and Beverage, Restaurants, Tea',
#  'Fitness, Sporting Goods, Sports',
#  'Food and Beverage, Food Processing, Manufacturing',
#  'E-Learning, Internet',
#  'Eyewear, Internet',
#  'Information Technology, Mobile, News, Operating Systems, Social Media, Social News',
#  'FinTech, Internet, Payments, Service Industry',
#  'B2B, Business Development, Internet, Marketplace',
#  'Food and Beverage, Food Delivery, Internet',
#  'Biotechnology, Health Care, Pharmaceutical',
#  'Ecommerce',
#  'Edtech',
#  'Interior design',
#  'AgriTech',
#  'Technology',
#  'SaaS',
#  'AI & Tech',
#  'E-commerce',
#  'E-commerce & AR',
#  'Fintech',
#  'HR tech',
#  'Food tech',
#  'Health',
#  'Healthcare',
#  'Safety tech',
#  'Pharmaceutical',
#  'Insurance technology',
#  'AI',
#  'Foodtech',
#  'Food',
#  'IoT',
#  'E-marketplace',
#  'Robotics & AI',
#  'Logistics',
#  'Food & Nutrition',
#  'Social Media',
#  nan,
#  'E-Sports',
#  'B2B',
#  'Jewellery',
#  'B2B Supply Chain',
#  'Games',
#  'Food & tech',
#  'Accomodation',
#  'Automotive tech',
#  'Legal tech',
#  'Mutual Funds',
#  'Cybersecurity',
#  'Automobile',
#  'Healthtech',
#  'Yoga & wellness',
#  'Virtual Banking',
#  'Transport & Rentals',
#  'Marketing & Customer loyalty',
#  'Infratech',
#  'Automobile & Technology',
#  'EdTech',
#  'Hygiene management',
#  'Escrow',
#  'Networking platform',
#  'FinTech',
#  'Crowdsourcing',
#  'Food & Bevarages',
#  'HealthTech',
#  'Fashion startup',
#  'Food Industry',
#  'Virtual auditing startup',
#  'Gaming',
#  'Work fulfillment',
#  'AI startup',
#  'Telecommunication',
#  'Tech Startup',
#  'Medtech',
#  'Tyre management',
#  'Cloud company',
#  'Software company',
#  'Venture capitalist',
#  'Renewable player',
#  'IoT startup',
#  'SaaS startup',
#  'Aero company',
#  'Marketing company',
#  'Retail startup',
#  'Co-working Startup',
#  'Finance company',
#  'Tech company',
#  'Solar Monitoring Company',
#  'Video sharing platform',
#  'Gaming startup',
#  'Video streaming platform',
#  'Consumer appliances',
#  'Blockchain startup',
#  'Conversational AI platform',
#  'Real Estate',
#  'SaaS platform',
#  'AI platform',
#  'Fusion beverages',
#  'HR Tech',
#  'Job portal',
#  'Dairy startup',
#  'Content management',
#  'Spacetech',
#  'Trading platform',
#  'AI Company',
#  'Photonics startup',
#  'Entertainment',
#  'Scanning app',
#  'Skincare startup',
#  'Food and Beverages',
#  'Biotechnology company',
#  'FoodTech',
#  'Proptech',
#  'Fitness startup',
#  'PaaS startup',
#  'Beverages',
#  'Automobiles',
#  'Deeptech',
#  'EV startup',
#  'AR/VR startup',
#  'Recruitment startup',
#  'QSR startup',
#  'Video platform',
#  'Fertility tech',
#  'Luxury car startup',
#  'FM',
#  'Nutrition sector',
#  'Tech platform',
#  'Video',
#  'Retail Tech',
#  'HeathTech',
#  'Sles and marketing',
#  'LegalTech',
#  'Car Service',
#  'Bike marketplace',
#  'Agri tech',
#  'Reatil startup',
#  'AR platform',
#  'Content marketplace',
#  'Interior Design',
#  'Rental space',
#  'Soil-Tech',
#  'Ayurveda tech',
#  'Packaging solution startup',
#  'Cleantech',
#  'Sanitation solutions',
#  'HealthCare',
#  'Home Design',
#  'InsureTech',
#  'AI Startup',
#  'Solar solution',
#  'Jewellery startup',
#  'Multinational conglomerate company',
#  'Deeptech startup',
#  'Social Network',
#  'Publication',
#  'Tech',
#  'Venture capital',
#  'Entreprenurship',
#  'Food devlivery',
#  'Warehouse',
#  'Online financial service',
#  'Eyeglasses',
#  'Battery design',
#  'Online credit management startup',
#  'Beverage',
#  'TravelTech',
#  'Startup laboratory',
#  'Personal care startup',
#  'Customer service company',
#  'SaaS\xa0\xa0startup',
#  'Marketing startup',
#  'Service industry',
#  'Social media',
#  'AR startup',
#  'HR Tech startup',
#  'Automotive Startup',
#  'Food Startup',
#  'EdTech Startup',
#  'Car Trade',
#  'EdtTech',
#  'AI Platform',
#  'Automation',
#  'Solar SaaS',
#  'WL & RAC protection',
#  'Social commerce',
#  'Home interior services',
#  'Agritech startup',
#  'API platform',
#  'Deep Tech',
#  'Electricity',
#  'Automotive company',
#  'FMCG',
#  'Insurance Tech',
#  'Video personalization',
#  'Software Company',
#  'Biomaterial startup',
#  'IT',
#  'Craft Beer',
#  'Investment',
#  'Linguistic Spiritual',
#  'Construction',
#  'Battery manufacturer',
#  'Nano Distribution Network',
#  'AI health',
#  'Dating app',
#  'Media',
#  'Healthcare/Edtech',
#  'Social Commerce',
#  'Agritech/Commerce',
#  'Mobility tech',
#  'Social e-commerce',
#  'Food & Logistics',
#  'SpaceTech',
#  'Nutrition Tech',
#  'HR',
#  None,
#  'Agritech',
#  'AR/VR',
#  'Appliance',
#  'Mental Health',
#  'Solar Solution',
#  'B2B marketplace',
#  'Fashion Tech',
#  'Nutrition tech',
#  'Health & Wellness',
#  'Cloud Kitchen',
#  'IoT/Automobile',
#  'Eye Wear',
#  'Digital tech',
#  'Data Intelligence',
#  'Co-living',
#  'Food & Beverages',
#  'Defense tech',
#  'Marketplace',
#  'Construction tech',
#  'Nutrition',
#  'Coworking',
#  'Micro-mobiity',
#  'Auto-tech',
#  'Beauty',
#  'Robotics',
#  'Logitech',
#  'Med Tech',
#  'Life sciences',
#  'Retail Aggregator',
#  'Deep Tech AI',
#  'Biotech',
#  'Blockchain',
#  'HrTech',
#  'Mobility/Transport',
#  'AI & Debt',
#  'SaaS/Edtech',
#  'Transport',
#  'Co-working',
#  'Insurtech',
#  'Cryptocurrency',
#  'Legal',
#  'Fitness',
#  'EV',
#  'Supply chain, Agritech',
#  'Pharma',
#  'Foodtech & Logistics',
#  'Housing',
#  'Data Analytics',
#  'Investment Tech',
#  'Dairy',
#  'Beauty & wellness',
#  'Travel & SaaS',
#  'Tourism & EV',
#  'Media Tech',
#  'Location Analytics',
#  'E store',
#  'Data Science',
#  'Health and Fitness',
#  'Interior & decor',
#  'eMobility',
#  'Automation tech',
#  'Media & Networking',
#  'E-market',
#  'AI & Data science',
#  'Travel tech',
#  'Automotive and Rentals',
#  'E-tail',
#  'AI & Media',
#  'Machine Learning',
#  'Content Marktplace',
#  'Visual Media',
#  'Hygiene',
#  'VR & SaaS',
#  'Sales & Services',
#  'AI & Deep learning',
#  'Housing & Rentals',
#  'Estore',
#  'E tailor',
#  'E-mobility',
#  'Ad-tech',
#  'Neo-banking',
#  'Transport Automation',
#  'Techonology',
#  'AI Robotics',
#  'Preschool Daycare',
#  'Food diet',
#  'B2B Agritech',
#  'E-connect',
#  'Tech hub',
#  'Consultancy',
#  'Pharmacy',
#  'Deisgning',
#  'Taxation',
#  'Automobile Technology',
#  'B2B E-commerce',
#  'Home services',
#  'B2B service',
#  'Helathcare',
#  'Electronics',
#  'IT startup',
#  'Aeorspace',
#  'Dating',
#  'Oil and Energy',
#  'Telecommuncation',
#  'Milk startup',
#  'AI Chatbot',
#  'Food delivery',
#  'Fantasy sports',
#  'Video communication',
#  'Skill development',
#  'Recruitment',
#  'Computer Games',
#  'Apparel & Fashion',
#  'Logistics & Supply Chain',
#  'SportsTech',
#  'HRTech',
#  'Wine & Spirits',
#  'Mechanical & Industrial Engineering',
#  'Spiritual',
#  'Lifestyle',
#  'Computer software',
#  'Tech startup',
#  'Digital mortgage',
#  'Information Technology & Services',
#  'Furniture',
#  'Healtcare',
#  'Tobacco',
#  'Insuretech',
#  'MLOps platform',
#  'Venture Capital',
#  'Pet care',
#  'Drone',
#  'Wholesale',
#  'E-learning',
#  'Consumer Services',
#  'Venture Capital & Private Equity',
#  'Health, Wellness & Fitness',
#  'OTT',
#  'Education Management',
#  'Computer Software',
#  'Software Startup',
#  'Computer & Network Security',
#  'Capital Markets',
#  'Social network',
#  'Hospital & Health Care',
#  'Music',
#  'Hauz Khas',
#  'Pharmaceuticals',
#  'Electric Mobility',
#  'Mobility',
#  'Digital platform',
#  'B2B Ecommerce',
#  'Online Media',
#  'Mobile Games',
#  'Food Production',
#  'Podcast',
#  'Battery',
#  'Content publishing',
#  'Water purification',
#  'Content commerce',
#  'Innovation Management',
#  'Celebrity Engagement',
#  'Personal Care',
#  'Cannabis startup',
#  'Blogging',
#  'BioTechnology',
#  'B2B Marketplace',
#  'Health care',
#  'Social audio',
#  'Fashion and lifestyle',
#  'Delivery service',
#  'B2B Manufacturing',
#  'Home Decor',
#  'Solar',
#  'TaaS startup',
#  'Manufacturing startup',
#  'Vehicle repair startup',
#  'Advisory firm',
#  'Legaltech',
#  'Pollution control equiptment',
#  'Fashion & Lifestyle',
#  'D2C',
#  'Environmental Services',
#  'Merchandise',
#  'Facilities Services',
#  'Marketing & Advertising',
#  'Eyewear',
#  'D2C Business',
#  'NFT Marketplace',
#  'Consumer software',
#  'Social community',
#  'Fishery',
#  'Renewables & Environment',
#  'Online storytelling',
#  'Aviation',
#  'IT company',
#  'Environmental service',
#  'Job discovery platform',
#  'D2C Fashion',
#  'Heathcare',
#  'CRM',
#  'D2C startup',
#  'Innovation management',
#  'Community platform',
#  'Networking',
#  'Commercial Real Estate',
#  'Consumer service',
#  'Consumer goods',
#  'MarTech',
#  'Advertisement',
#  'Content creation',
#  'Augmented reality',
#  'Bike Rental',
#  'Beauty products',
#  'Tourism',
#  'FemTech',
#  'Cultural',
#  'Supply chain platform',
#  'Social platform',
#  'Real estate',
#  'AI company',
#  'Sports startup',
#  'Matrimony',
#  'Crypto',
#  'Clothing',
#  'Analytics',
#  'IoT platform',
#  'Commerce',
#  'Defense & Space',
#  'Business Supplies & Equipment',
#  'NFT',
#  'Oil & Energy',
#  'Company-as-a-Service',
#  'Textiles',
#  'Professional Training & Coaching',
#  'Maritime',
#  'Housing Marketplace',
#  'Furniture Rental',
#  'Telecommunications',
#  'Equity Management',
#  'Cloud kitchen',
#  'Community',
#  'Higher Education',
#  'Mechanical Or Industrial Engineering',
#  'D2C jewellery',
#  'Sales and Distribution',
#  'Information Services',
#  'Translation & Localization',
#  'Investment Banking',
#  'Femtech',
#  'sports',
#  'Foootwear',
#  'Legal Services',
#  'Arts & Crafts',
#  'Investment Management',
#  'Management Consulting',
#  'B2B startup',
#  'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#  'Design',
#  'B2B Travel',
#  'Manchester, Greater Manchester',
#  'Product studio',
#  'Aviation & Aerospace',
#  'Staffing & Recruiting']

# %%
# Filter the data where the "Sector" column is equal to "Manchester, Greater Manchester"
df[df['Sector'] == "Manchester, Greater Manchester"]
# Out:
#      Company_Name  Founded Location                          Sector  \
# 1176         Peak   2014.0           Manchester, Greater Manchester
#
#                                            What_it_does     Founders  \
# 1176  Peak helps the world's smartest companies put ...  Atul Sharma
#
#                     Investor      Amount     Stage  Funding_Year
# 1176  SoftBank Vision Fund 2  75000000.0  Series C          2021

# %%
# Swap values between 'Sector' and 'Location' columns for the row where 'Company_Name' is 'Peak'
df.loc[df['Company_Name'] == 'Peak', ['Sector', 'Location']] = df.loc[df['Company_Name'] == 'Peak', ['Location', 'Sector']].values

# Filter the data where the "Company_Anme" column is equal to Peak
df[df['Company_Name'] == "Peak"]
# Out:
#      Company_Name  Founded                        Location Sector  \
# 1176         Peak   2014.0  Manchester, Greater Manchester
#
#                                            What_it_does     Founders  \
# 1176  Peak helps the world's smartest companies put ...  Atul Sharma
#
#                     Investor      Amount     Stage  Funding_Year
# 1176  SoftBank Vision Fund 2  75000000.0  Series C          2021

# %%
# Get unique values in the Company_Brand column
unique_sectors = df['Sector'].unique()

# Convert the unique values array to a list
unique_sectors_list = unique_sectors.tolist()

# Print the list of unique company brands
unique_sectors_list
# Out:
# ['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#  'Agriculture, Farming',
#  'Credit, Financial Services, Lending, Marketplace',
#  'Financial Services, FinTech',
#  'E-Commerce Platforms, Retail, SaaS',
#  'Cloud Infrastructure, PaaS, SaaS',
#  'Internet, Leisure, Marketplace',
#  'Market Research',
#  'Information Services, Information Technology',
#  'Mobile Payments',
#  'B2B, Shoes',
#  'Internet',
#  'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#  'Food Delivery',
#  'Industrial Automation',
#  'Automotive, Search Engine, Service Industry',
#  'Finance, Internet, Travel',
#  'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#  'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#  'Internet of Things, Waste Management',
#  'Air Transportation, Freight Service, Logistics, Marine Transportation',
#  'Financial Services',
#  'Food and Beverage',
#  'Autonomous Vehicles',
#  'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS',
#  'Agriculture, Analytics, Big Data, Farming',
#  'Logistics, Supply Chain Management',
#  'Financial Services, Lending',
#  'Automotive, Marketplace, Online Portals',
#  'Artificial Intelligence',
#  'Internet of Things, Telecommunications',
#  'Insurance',
#  'Information Technology, Logistics, Supply Chain Management',
#  'Blockchain, Developer Tools, Enterprise Software',
#  'Industrial Automation, Logistics, Supply Chain Management',
#  'Food and Beverage, Food Delivery, Snack Food',
#  'Education',
#  'E-Commerce, Fashion, Jewelry, Retail',
#  'Renewable Energy',
#  'E-Learning, Education',
#  'Clean Energy, CleanTech, Laundry and Dry-cleaning',
#  'E-Commerce, Fashion, Mobile',
#  'Apps, Messaging, Navigation, Public Safety',
#  'Transportation',
#  'Fitness, Health Care, Wellness',
#  'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant',
#  'Hospitality',
#  'Food and Beverage, Tea',
#  'Media and Entertainment, News, Outdoors',
#  'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming',
#  'B2B, Information Services, Information Technology',
#  'EdTech, Education, Enterprise Software, Peer to Peer',
#  'Health Care, Medical',
#  'E-Commerce',
#  'Health Care, Hospital, Wellness',
#  '—',
#  'Sports',
#  'Big Data, Consumer Lending, FinTech',
#  'Cloud Computing, Computer, Semiconductor',
#  'Health Care, Medical, Pharmaceutical',
#  'Food Processing, Retail',
#  'Trading Platform',
#  "Consumer Goods, Lifestyle, Men's",
#  'Wellness',
#  'Food and Beverage, Food Processing, Nutrition',
#  'Fashion',
#  'Automotive, Electric Vehicle, Energy Storage',
#  'Consulting, Retail, Social',
#  'Biotechnology, Life Science, Pharmaceutical, Product Research',
#  'Health Care',
#  'Credit, Financial Services, FinTech, Personal Finance',
#  'Communities, Coworking, Incubators',
#  'Consumer, Financial Services, FinTech',
#  'Consumer Applications, Information Services, Location Based Services, Virtual Assistant',
#  'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps',
#  'Education, Financial Services, FinTech',
#  'Advertising, Consulting, Digital Marketing',
#  'Marketplace, Real Estate, Rental Property',
#  'E-Learning, Internet, Video Games',
#  'Artificial Intelligence, Cloud Computing, Video',
#  'Health Care, Information Technology',
#  'Aerospace',
#  'E-Commerce, Fashion, Lifestyle',
#  'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning',
#  'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home',
#  'EdTech, Education, Information Services, SaaS',
#  'Energy, Solar',
#  'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security',
#  'Artificial Intelligence, Social',
#  'Logistics, Transportation, Travel',
#  'Digital Marketing, SEM, SEO, Web Development',
#  'Health Care, Hospital, Medical',
#  'Finance, Financial Services',
#  'Food Delivery, Food Processing, Internet',
#  'E-Commerce, Food and Beverage, Internet',
#  'Fitness, Food and Beverage, Health Care, Nutrition',
#  'EdTech, Education, Knowledge Management',
#  'Apps, Beauty, Consumer, Retail',
#  'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health',
#  'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management',
#  'E-Learning, Education, Higher Education',
#  'Health Diagnostics',
#  'EdTech, Education',
#  'Financial Services, SaaS, Security',
#  'Banking, Finance, Financial Services, Non Profit',
#  'B2B, E-Commerce, Mobile',
#  'Automotive, Electric Vehicle, Renewable Energy',
#  'E-Learning',
#  'Embedded Systems, Health Care, Medical, Product Research',
#  'Apps, E-Commerce, Internet',
#  'Advertising, Human Resources, Marketing',
#  'Beauty, Fitness, Home Services, Internet',
#  'Health Care, Medical Device, Public Safety',
#  'Food Delivery, Online Portals, Restaurants',
#  'AgTech, B2B, Supply Chain Management',
#  'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments',
#  'Software',
#  'EdTech, Education, Higher Education, Secondary Education',
#  'Manufacturing, Retail',
#  'Manufacturing',
#  'Information Services, Information Technology, InsurTech',
#  'Consumer Lending, FinTech',
#  'Internet, Social Network, TV',
#  'Beauty, Health Care',
#  'Hospital',
#  'Events',
#  '3D Printing, Manufacturing, Product Design',
#  'Automotive',
#  'Automotive, Retail',
#  'Apps, Audio',
#  'Automotive, E-Commerce',
#  'Digital Entertainment, Fantasy Sports, Sports',
#  'E-Learning, EdTech, Education',
#  'Funding Platform, Incubators, Non Profit',
#  'Hospitality, Hotel, Leisure, Travel',
#  'Classifieds, Internet, Marketplace, Rental Property',
#  'Banking, E-Learning, Trading Platform',
#  'E-Commerce, Mobile, Retail',
#  'Artificial Intelligence, Information Technology',
#  'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate',
#  'Banking, Finance, Financial Services',
#  'Audio, Mobile, Tourism, Travel',
#  'Energy, Energy Storage, Infrastructure',
#  'Government, Information Technology, Software',
#  'Information Technology',
#  'Education, Information Technology, Internet, Mobile, Software',
#  'Consumer Lending, Financial Services, Lending, Personal Finance',
#  'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media',
#  'Business Intelligence, Customer Service, Market Research, SaaS',
#  'Credit, Financial Services, FinTech, Lending',
#  'Children, Education, Parenting',
#  'Automotive, Battery, Energy, Energy Storage',
#  'E-Commerce, Mobile, Sharing Economy',
#  'Food Delivery, Organic, Organic Food',
#  'Mobile',
#  'Rental',
#  'Travel',
#  'Consumer',
#  'B2B, Farming, Marketplace',
#  'Wealth Management',
#  'Biotechnology',
#  'Education, Gaming, Training',
#  'Veterinary',
#  'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless',
#  'Health Care, Hospital, Supply Chain Management',
#  'Tourism, Travel',
#  'Hospitality, Real Estate',
#  'Finance',
#  'Digital Media, EBooks, Publishing, Reading Apps',
#  'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software',
#  'Food and Beverage, Food Processing',
#  'Internet, Marketplace, Shopping',
#  'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition',
#  'Facilities Support Services',
#  'Automotive, Electric Vehicle, Energy',
#  'Health Care, Health Diagnostics, Predictive Analytics',
#  'Cloud Computing, Computer, SaaS, Software',
#  'Fashion, Lifestyle, Retail',
#  'Medical',
#  'Music Streaming',
#  'Finance, Impact Investing, Internet',
#  'Internet, Social Entrepreneurship',
#  'Retail',
#  'Finance, Impact Investing, Mobile Apps',
#  'Cloud Computing, Computer, Software',
#  'Business Development, Market Research, Outsourcing',
#  'Health Care, Hospitality',
#  'Internet, Social News, Sports',
#  'Human Resources',
#  'Finance, Financial Services, FinTech',
#  'Customer Service, Software, Video, Video Streaming',
#  'E-Commerce, Food Processing',
#  'Training',
#  'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food',
#  'Manufacturing, Oil and Gas, Robotics',
#  'Artificial Intelligence, Computer, Machine Learning',
#  'Collaboration, Communities, Coworking, Sharing Economy',
#  'Big Data, EdTech, Machine Learning',
#  'Nanotechnology',
#  'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment',
#  'Financial Services, Lending, Peer to Peer',
#  'E-Commerce, Furniture, Home Decor, Interior Design, Internet',
#  'Digital Media',
#  'File Sharing, Personalization, Social Media',
#  'Home Decor, Interior Design',
#  'Health Care, Medical Device, Mobile Apps',
#  'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management',
#  'Crowdfunding, Finance, Financial Services',
#  'Finance, Financial Services, Insurance',
#  'Children, Education, Online Portals',
#  'Software, Virtual Reality',
#  'B2B, Food and Beverage, Food Delivery',
#  'Catering, Food and Beverage, Food Delivery, Food Processing',
#  'Food and Beverage, Snack Food',
#  'Automotive, E-Commerce, Mobile',
#  'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development',
#  'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development',
#  'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses',
#  'Delivery, Information Technology, Mobile Apps',
#  'Environmental Consulting, Renewable Energy',
#  'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance',
#  'Commercial Real Estate, Coworking, Office Administration, Real Estate',
#  'Food and Beverage, Food Processing, Organic Food, Snack Food',
#  'Apps, Health Care, Internet, Mobile Apps, Personal Health',
#  'Digital Media, Incubators, Social Entrepreneurship',
#  'Finance, Financial Services, Marketing',
#  'Biotechnology, Health Care, Life Science, Medical Device',
#  'Education, Human Resources',
#  'Consumer Electronics',
#  'Apps, Health Care, Hospital, Mobile Apps',
#  'Delivery Service, Logistics, Service Industry',
#  'Big Data, Data Visualization, Logistics, Software',
#  'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball',
#  'Media and Entertainment, News, Publishing',
#  'Consulting',
#  'Big Data, Financial Services, Machine Learning, Predictive Analytics',
#  'Agriculture, AgTech, Manufacturing',
#  'Digital Media, News, Publishing',
#  'Health Care, Hospital',
#  'B2B, E-Commerce, Enterprise',
#  'Fraud Detection, Information Services, Security',
#  'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning',
#  'Cryptocurrency, Trading Platform',
#  'Finance, FinTech, Mobile Payments',
#  'Wedding',
#  'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education',
#  'Consumer Goods',
#  'Digital Entertainment',
#  'Crowdsourcing, Financial Services, Funding Platform, Venture Capital',
#  'Delivery, Drones, Geospatial, Robotics',
#  'Health Care, Information Technology, Management Information Systems',
#  'Farming',
#  'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations',
#  'Career Planning, Education, Higher Education, Service Industry',
#  'Medical Device',
#  'Alternative Medicine, Health Care',
#  'Internet, Software',
#  'Dental, Elder Care, Health Care, Home Health Care, Personal Health',
#  'Financial Services, Insurance, Private Social Networking',
#  'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping',
#  'CleanTech',
#  'Advertising, Internet, Marketing',
#  'Human Resources, Security, Training',
#  'Consumer Lending, Finance, FinTech',
#  'Marketing, Social Media, Video',
#  'Banking',
#  'Food Processing',
#  'Apps',
#  'Marketing',
#  'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation',
#  'Digital Entertainment, Fantasy Sports, Gaming, Sports',
#  'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing',
#  'Commercial, E-Learning, Education',
#  'Continuing Education, EdTech, Education, Skill Assessment',
#  'Smart Cities, Telecommunications',
#  'Internet of Things, Robotics',
#  'Apps, Home Services, Information Services, Information Technology',
#  'Medical, Tourism',
#  'Career Planning, Education, Internet',
#  'Fashion, Graphic Design, Wearables',
#  'Communities, Leisure, Mobile Apps, Software',
#  'Automotive, Rental, Sharing Economy',
#  'Energy, Environmental Consulting, Renewable Energy, Solar',
#  'Information Technology, SaaS, Security',
#  'Crowdfunding, Financial Services, Internet',
#  'Customer Service, Information Technology, Internet, Sales Automation',
#  'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming',
#  'Credit Cards, Payments, Property Insurance, Property Management, Rental Property',
#  'Beauty, Cosmetics, Health Care, Service Industry',
#  'EdTech, Education, Mobile, Tutoring',
#  'Social Media, Sports',
#  'Biopharma',
#  'E-Commerce, E-Commerce Platforms, Retail',
#  'E-Commerce, Fashion, Shopping',
#  'Digital Entertainment, Mobile, PC Games',
#  'Finance, Financial Services, Small and Medium Businesses',
#  'Artificial Intelligence, Energy, Oil and Gas',
#  'Computer, FinTech, Risk Management, Software',
#  'Apps, Financial Services, FinTech',
#  "Child Care, Health Care, Hospital, Medical, Women's",
#  'Agriculture, Mobile',
#  'Finance, FinTech, Payments, Property Development, Rental',
#  'Information Services, Information Technology, Mobile, Software',
#  'Apps, Fitness, Health Care, mHealth',
#  'Food and Beverage, Food Delivery',
#  'Apps, Payments, Retail',
#  'Health Insurance, Insurance, Life Insurance',
#  'Rental, Taxi Service, Travel',
#  'E-Commerce, E-Commerce Platforms, Internet, Retail',
#  'Financial Services, Professional Services',
#  'Customer Service, Messaging, Mobile Apps, Personalization',
#  'Gaming, iOS, Sports',
#  'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media',
#  'Search Engine',
#  'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation',
#  'Agriculture, Farmers Market, Farming',
#  'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics',
#  'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation',
#  'Mobile, Software, Travel',
#  'Cosmetics',
#  'Consulting, Cyber Security, Network Security',
#  'eSports, Gaming, Video Games',
#  'Fashion, Jewelry',
#  'B2B, Medical Device',
#  'Consumer Goods, Manufacturing',
#  'Biotechnology, Health Care, Wellness',
#  'Health Care, Hospital, Medical, Robotics',
#  'E-Commerce, Fitness, Health Care',
#  'Financial Services, Venture Capital',
#  'Accounting, Apps, FinTech',
#  'Apps, Mobile, Transportation',
#  'Reading Apps',
#  'Energy, Renewable Energy, Solar',
#  'Banking, Financial Services, FinTech',
#  'Apps, Education, Retail',
#  'Electric Vehicle',
#  'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design',
#  'Automotive, E-Commerce, Marketplace',
#  'Agriculture',
#  'Apps, Information Services, Information Technology',
#  'B2B, Marketplace',
#  'Packaging Services',
#  'Computer, Furniture, Software',
#  'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine',
#  'Collaboration, Communities, Coworking, Real Estate',
#  'Accounting, Banking, Finance',
#  'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS',
#  'Information Services, Internet, Logistics, Supply Chain Management, Transportation',
#  'Automotive, E-Commerce, Information Services',
#  'Delivery, Logistics, Transportation',
#  'Automotive, E-Commerce Platforms, Marketplace',
#  'Last Mile Transportation, Railroad, Transportation, Travel',
#  'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals',
#  'FinTech, Mobile, Mobile Payments, Payments, Retail Technology',
#  'Online Games, Software',
#  'Online Portals, Property Management, Rental',
#  'E-Commerce, Food and Beverage, Tea',
#  'Music, Social Network, Video',
#  'Health Care, Pharmaceutical, Wellness',
#  'Delivery Service, Food and Beverage, Food Delivery',
#  'Hospitality, Information Technology, Travel Accommodations',
#  'Biotechnology, Diabetes, Health Care',
#  'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental',
#  'Finance, Financial Exchanges, Financial Services, Micro Lending',
#  'Analytics, Apps, Market Research',
#  'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet',
#  'Apps, Mobile, Mobile Apps, Software',
#  'News, Publishing, Social Media',
#  'Industrial, Industrial Automation',
#  'Internet, Mobile Apps, Social Network',
#  'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device',
#  'E-Commerce, Furniture, Interior Design',
#  'Apps, Events, News',
#  'Artificial Intelligence, Human Resources, Information Services, Information Technology',
#  'Logistics, Railroad, Transportation',
#  'Dating, Private Social Networking',
#  'Artificial Intelligence, Machine Learning, PaaS',
#  'Consumer, Furniture, Home Decor, Home Improvement',
#  'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation',
#  'Health Care, Health Insurance',
#  'Energy, Natural Resources',
#  'E-Commerce, Education, Health Care',
#  'Apps, Health Care, Pharmaceutical',
#  'Internet, Knowledge Management',
#  'Credit, Finance, FinTech, Lending, Sales Automation',
#  'Banking, Financial Services, Internet',
#  'E-Commerce, Health Care, Retail',
#  'Child Care, Information Technology',
#  'Financial Services, Micro Lending',
#  'E-Commerce, Retail, Shopping',
#  'Food and Beverage, Snack Food, Tea',
#  'Delivery Service, E-Commerce, Logistics',
#  'Fashion, Lifestyle, Rental',
#  'Fantasy Sports, Mobile, Sports',
#  'Beauty, Fashion, Wellness',
#  'Food and Beverage, Restaurants, Tea',
#  'Fitness, Sporting Goods, Sports',
#  'Food and Beverage, Food Processing, Manufacturing',
#  'E-Learning, Internet',
#  'Eyewear, Internet',
#  'Information Technology, Mobile, News, Operating Systems, Social Media, Social News',
#  'FinTech, Internet, Payments, Service Industry',
#  'B2B, Business Development, Internet, Marketplace',
#  'Food and Beverage, Food Delivery, Internet',
#  'Biotechnology, Health Care, Pharmaceutical',
#  'Ecommerce',
#  'Edtech',
#  'Interior design',
#  'AgriTech',
#  'Technology',
#  'SaaS',
#  'AI & Tech',
#  'E-commerce',
#  'E-commerce & AR',
#  'Fintech',
#  'HR tech',
#  'Food tech',
#  'Health',
#  'Healthcare',
#  'Safety tech',
#  'Pharmaceutical',
#  'Insurance technology',
#  'AI',
#  'Foodtech',
#  'Food',
#  'IoT',
#  'E-marketplace',
#  'Robotics & AI',
#  'Logistics',
#  'Food & Nutrition',
#  'Social Media',
#  nan,
#  'E-Sports',
#  'B2B',
#  'Jewellery',
#  'B2B Supply Chain',
#  'Games',
#  'Food & tech',
#  'Accomodation',
#  'Automotive tech',
#  'Legal tech',
#  'Mutual Funds',
#  'Cybersecurity',
#  'Automobile',
#  'Healthtech',
#  'Yoga & wellness',
#  'Virtual Banking',
#  'Transport & Rentals',
#  'Marketing & Customer loyalty',
#  'Infratech',
#  'Automobile & Technology',
#  'EdTech',
#  'Hygiene management',
#  'Escrow',
#  'Networking platform',
#  'FinTech',
#  'Crowdsourcing',
#  'Food & Bevarages',
#  'HealthTech',
#  'Fashion startup',
#  'Food Industry',
#  'Virtual auditing startup',
#  'Gaming',
#  'Work fulfillment',
#  'AI startup',
#  'Telecommunication',
#  'Tech Startup',
#  'Medtech',
#  'Tyre management',
#  'Cloud company',
#  'Software company',
#  'Venture capitalist',
#  'Renewable player',
#  'IoT startup',
#  'SaaS startup',
#  'Aero company',
#  'Marketing company',
#  'Retail startup',
#  'Co-working Startup',
#  'Finance company',
#  'Tech company',
#  'Solar Monitoring Company',
#  'Video sharing platform',
#  'Gaming startup',
#  'Video streaming platform',
#  'Consumer appliances',
#  'Blockchain startup',
#  'Conversational AI platform',
#  'Real Estate',
#  'SaaS platform',
#  'AI platform',
#  'Fusion beverages',
#  'HR Tech',
#  'Job portal',
#  'Dairy startup',
#  'Content management',
#  'Spacetech',
#  'Trading platform',
#  'AI Company',
#  'Photonics startup',
#  'Entertainment',
#  'Scanning app',
#  'Skincare startup',
#  'Food and Beverages',
#  'Biotechnology company',
#  'FoodTech',
#  'Proptech',
#  'Fitness startup',
#  'PaaS startup',
#  'Beverages',
#  'Automobiles',
#  'Deeptech',
#  'EV startup',
#  'AR/VR startup',
#  'Recruitment startup',
#  'QSR startup',
#  'Video platform',
#  'Fertility tech',
#  'Luxury car startup',
#  'FM',
#  'Nutrition sector',
#  'Tech platform',
#  'Video',
#  'Retail Tech',
#  'HeathTech',
#  'Sles and marketing',
#  'LegalTech',
#  'Car Service',
#  'Bike marketplace',
#  'Agri tech',
#  'Reatil startup',
#  'AR platform',
#  'Content marketplace',
#  'Interior Design',
#  'Rental space',
#  'Soil-Tech',
#  'Ayurveda tech',
#  'Packaging solution startup',
#  'Cleantech',
#  'Sanitation solutions',
#  'HealthCare',
#  'Home Design',
#  'InsureTech',
#  'AI Startup',
#  'Solar solution',
#  'Jewellery startup',
#  'Multinational conglomerate company',
#  'Deeptech startup',
#  'Social Network',
#  'Publication',
#  'Tech',
#  'Venture capital',
#  'Entreprenurship',
#  'Food devlivery',
#  'Warehouse',
#  'Online financial service',
#  'Eyeglasses',
#  'Battery design',
#  'Online credit management startup',
#  'Beverage',
#  'TravelTech',
#  'Startup laboratory',
#  'Personal care startup',
#  'Customer service company',
#  'SaaS\xa0\xa0startup',
#  'Marketing startup',
#  'Service industry',
#  'Social media',
#  'AR startup',
#  'HR Tech startup',
#  'Automotive Startup',
#  'Food Startup',
#  'EdTech Startup',
#  'Car Trade',
#  'EdtTech',
#  'AI Platform',
#  'Automation',
#  'Solar SaaS',
#  'WL & RAC protection',
#  'Social commerce',
#  'Home interior services',
#  'Agritech startup',
#  'API platform',
#  'Deep Tech',
#  'Electricity',
#  'Automotive company',
#  'FMCG',
#  'Insurance Tech',
#  'Video personalization',
#  'Software Company',
#  'Biomaterial startup',
#  'IT',
#  'Craft Beer',
#  'Investment',
#  'Linguistic Spiritual',
#  'Construction',
#  'Battery manufacturer',
#  'Nano Distribution Network',
#  'AI health',
#  'Dating app',
#  'Media',
#  'Healthcare/Edtech',
#  'Social Commerce',
#  'Agritech/Commerce',
#  'Mobility tech',
#  'Social e-commerce',
#  'Food & Logistics',
#  'SpaceTech',
#  'Nutrition Tech',
#  'HR',
#  None,
#  'Agritech',
#  'AR/VR',
#  'Appliance',
#  'Mental Health',
#  'Solar Solution',
#  'B2B marketplace',
#  'Fashion Tech',
#  'Nutrition tech',
#  'Health & Wellness',
#  'Cloud Kitchen',
#  'IoT/Automobile',
#  'Eye Wear',
#  'Digital tech',
#  'Data Intelligence',
#  'Co-living',
#  'Food & Beverages',
#  'Defense tech',
#  'Marketplace',
#  'Construction tech',
#  'Nutrition',
#  'Coworking',
#  'Micro-mobiity',
#  'Auto-tech',
#  'Beauty',
#  'Robotics',
#  'Logitech',
#  'Med Tech',
#  'Life sciences',
#  'Retail Aggregator',
#  'Deep Tech AI',
#  'Biotech',
#  'Blockchain',
#  'HrTech',
#  'Mobility/Transport',
#  'AI & Debt',
#  'SaaS/Edtech',
#  'Transport',
#  'Co-working',
#  'Insurtech',
#  'Cryptocurrency',
#  'Legal',
#  'Fitness',
#  'EV',
#  'Supply chain, Agritech',
#  'Pharma',
#  'Foodtech & Logistics',
#  'Housing',
#  'Data Analytics',
#  'Investment Tech',
#  'Dairy',
#  'Beauty & wellness',
#  'Travel & SaaS',
#  'Tourism & EV',
#  'Media Tech',
#  'Location Analytics',
#  'E store',
#  'Data Science',
#  'Health and Fitness',
#  'Interior & decor',
#  'eMobility',
#  'Automation tech',
#  'Media & Networking',
#  'E-market',
#  'AI & Data science',
#  'Travel tech',
#  'Automotive and Rentals',
#  'E-tail',
#  'AI & Media',
#  'Machine Learning',
#  'Content Marktplace',
#  'Visual Media',
#  'Hygiene',
#  'VR & SaaS',
#  'Sales & Services',
#  'AI & Deep learning',
#  'Housing & Rentals',
#  'Estore',
#  'E tailor',
#  'E-mobility',
#  'Ad-tech',
#  'Neo-banking',
#  'Transport Automation',
#  'Techonology',
#  'AI Robotics',
#  'Preschool Daycare',
#  'Food diet',
#  'B2B Agritech',
#  'E-connect',
#  'Tech hub',
#  'Consultancy',
#  'Pharmacy',
#  'Deisgning',
#  'Taxation',
#  'Automobile Technology',
#  'B2B E-commerce',
#  'Home services',
#  'B2B service',
#  'Helathcare',
#  'Electronics',
#  'IT startup',
#  'Aeorspace',
#  'Dating',
#  'Oil and Energy',
#  'Telecommuncation',
#  'Milk startup',
#  'AI Chatbot',
#  'Food delivery',
#  'Fantasy sports',
#  'Video communication',
#  'Skill development',
#  'Recruitment',
#  'Computer Games',
#  'Apparel & Fashion',
#  'Logistics & Supply Chain',
#  'SportsTech',
#  'HRTech',
#  'Wine & Spirits',
#  'Mechanical & Industrial Engineering',
#  'Spiritual',
#  'Lifestyle',
#  'Computer software',
#  'Tech startup',
#  'Digital mortgage',
#  'Information Technology & Services',
#  'Furniture',
#  'Healtcare',
#  'Tobacco',
#  'Insuretech',
#  'MLOps platform',
#  'Venture Capital',
#  'Pet care',
#  'Drone',
#  'Wholesale',
#  'E-learning',
#  'Consumer Services',
#  'Venture Capital & Private Equity',
#  'Health, Wellness & Fitness',
#  'OTT',
#  'Education Management',
#  'Computer Software',
#  'Software Startup',
#  'Computer & Network Security',
#  'Capital Markets',
#  'Social network',
#  'Hospital & Health Care',
#  'Music',
#  'Hauz Khas',
#  'Pharmaceuticals',
#  'Electric Mobility',
#  'Mobility',
#  'Digital platform',
#  'B2B Ecommerce',
#  'Online Media',
#  'Mobile Games',
#  'Food Production',
#  'Podcast',
#  'Battery',
#  'Content publishing',
#  'Water purification',
#  'Content commerce',
#  'Innovation Management',
#  'Celebrity Engagement',
#  'Personal Care',
#  'Cannabis startup',
#  'Blogging',
#  'BioTechnology',
#  'B2B Marketplace',
#  'Health care',
#  'Social audio',
#  'Fashion and lifestyle',
#  'Delivery service',
#  'B2B Manufacturing',
#  'Home Decor',
#  'Solar',
#  'TaaS startup',
#  'Manufacturing startup',
#  'Vehicle repair startup',
#  'Advisory firm',
#  'Legaltech',
#  'Pollution control equiptment',
#  'Fashion & Lifestyle',
#  'D2C',
#  'Environmental Services',
#  'Merchandise',
#  'Facilities Services',
#  'Marketing & Advertising',
#  'Eyewear',
#  'D2C Business',
#  'NFT Marketplace',
#  'Consumer software',
#  'Social community',
#  'Fishery',
#  'Renewables & Environment',
#  'Online storytelling',
#  'Aviation',
#  'IT company',
#  'Environmental service',
#  'Job discovery platform',
#  'D2C Fashion',
#  'Heathcare',
#  'CRM',
#  'D2C startup',
#  'Innovation management',
#  'Community platform',
#  'Networking',
#  'Commercial Real Estate',
#  'Consumer service',
#  'Consumer goods',
#  'MarTech',
#  'Advertisement',
#  'Content creation',
#  'Augmented reality',
#  'Bike Rental',
#  'Beauty products',
#  'Tourism',
#  'FemTech',
#  'Cultural',
#  'Supply chain platform',
#  'Social platform',
#  'Real estate',
#  'AI company',
#  'Sports startup',
#  'Matrimony',
#  'Crypto',
#  'Clothing',
#  'Analytics',
#  'IoT platform',
#  'Commerce',
#  'Defense & Space',
#  'Business Supplies & Equipment',
#  'NFT',
#  'Oil & Energy',
#  'Company-as-a-Service',
#  'Textiles',
#  'Professional Training & Coaching',
#  'Maritime',
#  'Housing Marketplace',
#  'Furniture Rental',
#  'Telecommunications',
#  'Equity Management',
#  'Cloud kitchen',
#  'Community',
#  'Higher Education',
#  'Mechanical Or Industrial Engineering',
#  'D2C jewellery',
#  'Sales and Distribution',
#  'Information Services',
#  'Translation & Localization',
#  'Investment Banking',
#  'Femtech',
#  'sports',
#  'Foootwear',
#  'Legal Services',
#  'Arts & Crafts',
#  'Investment Management',
#  'Management Consulting',
#  'B2B startup',
#  'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#  'Design',
#  'B2B Travel',
#  '',
#  'Product studio',
#  'Aviation & Aerospace',
#  'Staffing & Recruiting']

# %% [markdown]
# ##### Mapping Sector

# %%
import re

# Define the sector redistribution function
def sector_redistribution(Sector):
    if re.search(r'Credit Cards|Taxation|Banking|Insuretech|Infratech|Saas\xa0\xa0Startup|Equity Management|Wealth Management|Saas  Startup|Insurtech|  Venture Capitalist| Crowdsourcing|Cryptocurrency|Online Financial Service|Neo-Banking|Capital Markets|Mutual Funds|Bank|Finance|Crypto|Account|Credit|Venture|Crowd|Blockchain|Fund|Lending|Trading|Wealth|Insurance|Remittance|Money|Equity|Investment|Mortgage|Financial Services|  Fintech |  fintech|  finTech| Mutual Funds|  FinTech |Nft|Payments |Venture Capital', Sector):
        return 'Financial Services'
    elif re.search(r'Agritech|Agriculture|Soil-Tech|Fishery|Agri|Biotechnology|Industrial|Farming|Fish|Milk|Diary|Dairy Startup | Agriculture|Farming|AgTech|Supply Chain Management|Farmers Market', Sector):
        return 'Agriculture'
    elif re.search(r'Machine Learning|Hrtech|Ar/Vr|Technology|Ai|E-Connect|E-Market|Traveltech|Biotech|Medtech|Ad-Tech|Healthtech|Games|Computer & Network Security|Saas Startup|Scanning App|Cloud Company|Cybersecurity|Aero Company|Cloud Computing|Techonology|E-Learning|Content Management|Recruitment|Consultancy|Ecommerce|Ev|Designing|Networking|Product Studio|Legaltech| Proptech|Techonology|Milk Startup|Craft Beer|Online Credit Management Startup|Foodtech|Spacetech|Deisgning|Clothing|Logitech|Femtech|D2C|Skill Development|Martech|Luxury Car Startup|Emobility|It|Healthcare|Qsr Startup|Sportstech|E-Marketplace|Cleantech|Heathtech|Digital Mortgage|Innovation Management|Photonics Startup| Photonics Startup|Life Sciences|Cloud Kitchen|Content Marktplace|Vehicle Repair Startup|Photonics Startup| Deeptech|Martech|  Nano Distribution Network', Sector):
        return 'Software & Technology'
    elif re.search(r'Food & Beverage|Beverages|Foodtech|Craft Beer|Milk Startup|Beverage|Catering|Cook|Food|Restaurants', Sector):
        return 'Food & Beverage'
    elif re.search(r'Auto-Tech|Tyre Management|Automobiles|Automobile|E-Mobility|Autonomous Vehicles|Vehicle Repair Startup|Automotive|Air Transport|Transport|Logistics|Vehicle|Transportation|Aviation|Vehicles|Tyre|Fleet|Wheels|Aero|Mobility|Aeorspace|Wl & Rac Protection|Micro-Mobiity|Delivery Service', Sector):
        return 'Transport'
    elif re.search(r'Business Intelligence|Data Science|Analytics|Consulting|Human|Career|Erp|Advertising|Advertisement|Market Research|Entrepre|Recruit|Hr|Working|Sultancy|Advisory|Work|Job|Management|Skill|Legal|Crm|Specific Domain To Individuals| Data Intelligence    |Business  | Information ServicesMarketing |Staffing & Recruiting|Human Resources    |Multinational Conglomerate Company', Sector):
        return 'Business Services'
    elif re.search(r'Renewables & Environment|Renewable Player|Electric Vehicle|Pollution Control Equiptment|Cleantech|Clean Energy|Energy|Boil &|Boil|Sanitation Solutions|Solar|Electricity|Environment|Environmental Services|Biomaterial Startup|Environmental Service|Job Portal', Sector):
        return 'Energy & Renewable Resources'
    elif re.search(r'Hospitality|Customer Service|Home Services|E Store|Customer Service Company|Co-Working|Accomodation|Cloud Kitchen|Customer|Hospital|Tourism|Events|Wedding|Travel|Hosts|Booking|Wedding|Qsr', Sector):
        return 'Hospitality'
    elif re.search(r'Trading  &  Platform|Consumer|Supply Chain Platform|B2B|Business Supplies & Equipment|Fmcg|E-Tail|Entreprenurship|Car Trade|Reatil Startup|E-Mobility|Estore|Capital Markets|E-Commerce|Sales & Services|Sales And Distribution|Estore|Retail Startup|Packaging Services|E-Marketplace|2|Trade|Enterprise|Commerce|Commercial|Consumer Goods|Marketplace|Business Consumer|Marketing|Retail|Market|Store|Furniture|Wholesale|Wine & Spirits|Multinational|E-|Packaging|Sales|Tplace|Warehouse|Fm|Product|Merchandise|Reatil|Conglomerates|Invoice Discounting|Supply Chain|Car Service|Service Industry|Company-As-A-Service|Consumer Service|Facilities Support Services|Facilities Services', Sector):
        return 'Commerce & Retail'
    elif re.search(r'Mechanical & Industrial Engineering|Packaging Solution Startup|Manufaation Manufacturing|Industrial Automation|Engineering|Robotics|Mechanical Design|Appliances|Automation|Product Design|Manufacturing', Sector):
        return 'Manufacturing'
    elif re.search(r'Healthtech|Healthcare|Pharmaceuticals|Pharmaceuticals|Healtcare|Pharmaceutical|Pharmacy|Helathcare|Medical|Healthtech|Dental|Health|Health Insurance|Medic|Supplement|Biopharma|Veterinary|Pharma|Heathcare|Nutrition|Hygiene|Care|Sanitation|Bio|Cannabis|Tobacco|Sciences', Sector):
        return 'Health & Life Sciences'
    elif re.search(r'Sports & Fitness|Sportstech|Sports|Esports|Game|Ball|Player|ManchesterGaming|Virtual Reality|Augmented Reality|Gaming Industry | Sports | Sports betting| Betting |Bet |Fantasy Sports|Sports |Fantasy Sports|Sports|Games', Sector):
        return 'Sports & Fitness'
    elif re.search(r'Beauty And Fashion|Skincare Startup|Foootwear|Eye Wear|Personal Care Startup|Beauty And Fashion|Clothing|Beauty|Cosmetic|Skincare|Fashion|Wear|Cosmetics|Textiles|Eyewear|Jewellery|Cloth|Eyeglasses', Sector):
        return 'Beauty and Fashion'
    elif re.search(r'Defense & Space|Government|Advisory Firm|Smart Cities|Government|Classifieds|Water|Defense|Pollution|Translation & Localization|Maritime', Sector):
        return 'Government '
    elif re.search(r'E-Learning|EduTech|Edttech|E-Learning|Skill Development|E-Learning|Job Discovery Platform|E-Learning|Preschool Daycare|E-Learning|E-Learning|Edutech|Education|Learn|Edtech | EdTech', Sector):
        return 'Education'
    elif re.search(r'Real Estate|Commercial Real Estate|Residential Real Estate|Co-Working|Hospitality|Accommodation|Estate Planning', Sector):
        return 'Real Estate and Property'
    elif re.search(r'Social Network|Social Platform|Community|Communication | Community |Networking|Collaboration|Social Entrepreneurship | Social Impact|Non-Profit|Charity|Philanthropy|Community Development|Social Audio|Social Network|Communities', Sector):
        return 'Social and Community'
    elif re.search(r'Entertainment|Video Streaming|Digital Media|Online Portals|Music|Podcast|Broadcasting|Creative Content | Media and Entertainment|Social Media|Mobile|Video Streaming|Digital Media|Online Portals|Music|Podcast|Broadcasting|Creative Content|Tourism', Sector):
        return 'Media and Entertainment'
    elif re.search(r'Water Purification|Others|Cannabis Startup|Hauz KhasCoworking|Content Publishing|Work Fulfillment|Pet Care|— |NaN|-|nan|NaN |  None', Sector):
        return 'Others'
    else: 
        return 
        
    
    # Convert "Sector" column to string type
df['Sector'] = df['Sector'].astype(str)

# Apply the function to create the new column
df['Main_Sector'] = df['Sector'].apply(sector_redistribution)

# %%
# Finding unique values from Main_Sector column

df['Main_Sector'].unique()
# Out:
# array(['Software & Technology', 'Agriculture', 'Financial Services',
#        'Commerce & Retail', None, 'Business Services',
#        'Media and Entertainment', 'Food & Beverage', 'Transport',
#        'Hospitality', 'Education', 'Energy & Renewable Resources',
#        'Health & Life Sciences', 'Sports & Fitness', 'Beauty and Fashion',
#        'Social and Community', 'Manufacturing', 'Government ',
#        'Real Estate and Property', 'Others'], dtype=object)

# %%
df.head(28)
# Out:
#                         Company_Name  Founded   Location  \
# 0                    TheCollegeFever     <NA>  Bangalore
# 1                    Happy Cow Dairy     <NA>     Mumbai
# 2                         MyLoanCare     <NA>    Gurgaon
# 3                        PayMe India     <NA>      Noida
# 4                           Eunimart     <NA>  Hyderabad
# 5                             Hasura     <NA>  Bengaluru
# 6                          Tripshelf     <NA>    Kalkaji
# 7                       Hyperdata.IO     <NA>  Hyderabad
# 8                       Freightwalla     <NA>     Mumbai
# 9                 Microchip Payments     <NA>  Bangalore
# 10        BizCrum Infotech Pvt. Ltd.     <NA>      Delhi
# 11                           Emojifi     <NA>  Bengaluru
# 12                             Flock     <NA>      India
# 13                         Freshboxx     <NA>      Hubli
# 14        Wide Mobility Mechatronics     <NA>  Bangalore
# 15                           Pitstop     <NA>  Bengaluru
# 16                            Mihuru     <NA>     Mumbai
# 17                              Fyle     <NA>  Bengaluru
# 18                          AppWharf     <NA>  New Delhi
# 19  Antariksh Waste Ventures Pvt ltd     <NA>    Chennai
# 20                          Cogoport     <NA>     Mumbai
# 21                        PaisaDukan     <NA>     Mumbai
# 22                 Sleepy Owl Coffee     <NA>  New Delhi
# 23                          BlueJack     <NA>      Delhi
# 24                         PregBuddy     <NA>  Bengaluru
# 25               AgNext Technologies     <NA>     Mohali
# 26                             Pando     <NA>    Chennai
# 27                           Mintifi     <NA>     Mumbai
#
#                                                Sector  \
# 0   Brand Marketing, Event Promotion, Marketing, S...
# 1                                Agriculture, Farming
# 2    Credit, Financial Services, Lending, Marketplace
# 3                         Financial Services, FinTech
# 4                  E-Commerce Platforms, Retail, SaaS
# 5                    Cloud Infrastructure, PaaS, SaaS
# 6                      Internet, Leisure, Marketplace
# 7                                     Market Research
# 8        Information Services, Information Technology
# 9                                     Mobile Payments
# 10                                         B2B, Shoes
# 11                                           Internet
# 12  Apps, Collaboration, Developer Platform, Enter...
# 13                                      Food Delivery
# 14                              Industrial Automation
# 15        Automotive, Search Engine, Service Industry
# 16                          Finance, Internet, Travel
# 17  Accounting, Business Information Systems, Busi...
# 18  Artificial Intelligence, Product Search, SaaS,...
# 19               Internet of Things, Waste Management
# 20  Air Transportation, Freight Service, Logistics...
# 21                                 Financial Services
# 22                                  Food and Beverage
# 23                                Autonomous Vehicles
# 24  Enterprise Software, Health Care, Hospital, Pa...
# 25          Agriculture, Analytics, Big Data, Farming
# 26                 Logistics, Supply Chain Management
# 27                        Financial Services, Lending
#
#                                          What_it_does Founders Investor  \
# 0   TheCollegeFever is a hub for fun, fiesta and f...      NaN      NaN
# 1   A startup which aggregates milk from dairy far...      NaN      NaN
# 2           Leading Online Loans Marketplace in India      NaN      NaN
# 3   PayMe India is an innovative FinTech organizat...      NaN      NaN
# 4   Eunimart is a one stop solution for merchants ...      NaN      NaN
# 5   Hasura is a platform that allows developers to...      NaN      NaN
# 6   Tripshelf is an online market place for holida...      NaN      NaN
# 7   Hyperdata combines advanced machine learning w...      NaN      NaN
# 8   Freightwalla is an international forwarder tha...      NaN      NaN
# 9   Microchip payments is a mobile-based payment a...      NaN      NaN
# 10           Building Transactionary B2B Marketplaces      NaN      NaN
# 11  Emojifi is an app that provides live emoji, st...      NaN      NaN
# 12  Flock is a real-time messaging and collaborati...      NaN      NaN
# 13  Freshboxx is incubated at Sandbox Startups, a ...      NaN      NaN
# 14  Wide Mobility Mechatronics is a Private Compan...      NaN      NaN
# 15  Pitstop offers general repair and maintenance ...      NaN      NaN
# 16  Mihuru is an online platform which gives micro...      NaN      NaN
# 17  Fyle is an intelligent expense management plat...      NaN      NaN
# 18  Appwharf is an intelligent assistant that help...      NaN      NaN
# 19                  Waste Management for Smart Cities      NaN      NaN
# 20  Cogoport is a platform that provides freight b...      NaN      NaN
# 21                 A P2P lending marketplace platform      NaN      NaN
# 22  Makers of a signature coffee that's exceptiona...      NaN      NaN
# 23      Delhi-based online used vehicles marketplace.      NaN      NaN
# 24  PregBuddy is a smart connected care platform f...      NaN      NaN
# 25  AgNext is an agricultural sensing and solution...      NaN      NaN
# 26  A startup which digitizes logistics operations...      NaN      NaN
# 27            Online lending startup based in Mumbai.      NaN      NaN
#
#        Amount     Stage  Funding_Year              Main_Sector
# 0    250000.0      Seed          2018    Software & Technology
# 1    584000.0      Seed          2018              Agriculture
# 2    949000.0  Series A          2018       Financial Services
# 3   2000000.0     Angel          2018       Financial Services
# 4         NaN      Seed          2018        Commerce & Retail
# 5   1600000.0      Seed          2018                     None
# 6    233600.0      Seed          2018        Commerce & Retail
# 7    730000.0     Angel          2018        Business Services
# 8         NaN      Seed          2018    Software & Technology
# 9         NaN      Seed          2018  Media and Entertainment
# 10        NaN      Seed          2018        Commerce & Retail
# 11        NaN      Seed          2018                     None
# 12        NaN      Seed          2018        Commerce & Retail
# 13        NaN      Seed          2018          Food & Beverage
# 14        NaN      Seed          2018              Agriculture
# 15  1460000.0      Seed          2018                Transport
# 16   150000.0      Seed          2018       Financial Services
# 17  1100000.0      Seed          2018       Financial Services
# 18        NaN      Seed          2018        Commerce & Retail
# 19     7300.0      Seed          2018        Business Services
# 20  6000000.0  Series A          2018    Software & Technology
# 21   650000.0      Seed          2018       Financial Services
# 22   511000.0      Seed          2018          Food & Beverage
# 23   934400.0      Seed          2018                Transport
# 24        NaN      Seed          2018              Hospitality
# 25        NaN  Series A          2018              Agriculture
# 26  2000000.0      Seed          2018              Agriculture
# 27  2000000.0      Seed          2018       Financial Services

# %%
df.tail(50)
# Out:
#                Company_Name  Founded                        Location  \
# 1159                   4Fin   2021.0                            Pune
# 1160  Atomberg Technologies   2012.0                          Mumbai
# 1161        Genext Students   2013.0                          Mumbai
# 1162             immunitoAI   2020.0                       Bangalore
# 1163        GameEon Studios   2013.0                          Mumbai
# 1164     Farmers Fresh Zone   2015.0                           Kochi
# 1165               Anveshan   2019.0                       Bangalore
# 1166              OckyPocky   2015.0                        Gurugram
# 1167               Coutloot   2016.0                          Mumbai
# 1168          Nova Benefits   2020.0                       Bangalore
# 1169               HomeLane   2014.0                       Bangalore
# 1170          Lido Learning   2019.0                          Mumbai
# 1171                    Jar   2021.0                       Bangalore
# 1172             Peppermint   2019.0                            Pune
# 1173               moneyHOP   2018.0                          London
# 1174               Codingal   2020.0                       Bangalore
# 1175                   Skit   2016.0                       Bangalore
# 1176                   Peak   2014.0  Manchester, Greater Manchester
# 1177                  REVOS   2017.0                       Bangalore
# 1178                Dezerv.   2021.0                          Mumbai
# 1179          AppsForBharat   2020.0                       Bangalore
# 1180                 Habbit   2020.0                       Bangalore
# 1181                 Bikayi   2019.0                       Hyderabad
# 1182              Sugar.fit   2021.0                       Bangalore
# 1183                 Dukaan   2020.0                       Bangalore
# 1184               Vidyakul   2017.0                        Gurugram
# 1185               Goodmylk   2015.0                       Bangalore
# 1186             Fieldproxy   2016.0                         Chennai
# 1187          NeuroPixel.AI   2020.0                       Bangalore
# 1188  Elixia Tech Solutions   2011.0                          Mumbai
# 1189             bitsCrunch   2020.0                         Chennai
# 1190                Prolgae   2016.0                    The Nilgiris
# 1191                Biddano   2016.0                            Pune
# 1192              Geniemode   2021.0                        Gurugram
# 1193        Sapio Analytics   2019.0                          Mumbai
# 1194                Neokred   2019.0                       Bangalore
# 1195              Delhivery   2011.0                        Gurugram
# 1196             Flipspaces   2011.0                          Mumbai
# 1197                  Fleek   2021.0                       Bangalore
# 1198                 GoKwik   2020.0                       New Delhi
# 1199                 Proeon   2018.0                            Pune
# 1200             InfyU Labs   2019.0                     Gandhinagar
# 1201              TechEagle   2015.0                        Gurugram
# 1202             Voxelgrids   2017.0                       Bangalore
# 1203     Cogos Technologies   2016.0                       Bangalore
# 1204               Gigforce   2019.0                        Gurugram
# 1205                 Vahdam   2015.0                       New Delhi
# 1206           Leap Finance   2019.0                       Bangalore
# 1207           CollegeDekho   2015.0                        Gurugram
# 1208                 WeRize   2019.0                       Bangalore
#
#                                  Sector  \
# 1159                 Financial Services
# 1160               Consumer Electronics
# 1161                             EdTech
# 1162                      Biotechnology
# 1163                     Computer Games
# 1164                           AgriTech
# 1165                    Food Production
# 1166                             EdTech
# 1167                  Consumer Services
# 1168         Health, Wellness & Fitness
# 1169                    Interior Design
# 1170                         E-learning
# 1171                            FinTech
# 1172              Industrial Automation
# 1173                 Financial Services
# 1174                             EdTech
# 1175                         AI startup
# 1176
# 1177                         Automotive
# 1178              Investment Management
# 1179                     Product studio
# 1180                             EdTech
# 1181                         E-commerce
# 1182                             Health
# 1183                             Retail
# 1184                             EdTech
# 1185                   Food & Beverages
# 1186                       SaaS startup
# 1187                           Deeptech
# 1188  Information Technology & Services
# 1189                         Blockchain
# 1190                      Biotechnology
# 1191         Health, Wellness & Fitness
# 1192                                B2B
# 1193                  Computer Software
# 1194                            FinTech
# 1195           Logistics & Supply Chain
# 1196                             Design
# 1197                           Internet
# 1198  Information Technology & Services
# 1199                    Food Production
# 1200                           AgriTech
# 1201               Aviation & Aerospace
# 1202                           Deeptech
# 1203           Logistics & Supply Chain
# 1204              Staffing & Recruiting
# 1205                   Food & Beverages
# 1206                 Financial Services
# 1207                             EdTech
# 1208                 Financial Services
#
#                                            What_it_does  \
# 1159  4Fin is a Fintech Platform catering to needs o...
# 1160             A maker of energy-efficient smart fans
# 1161  LIVE online classes with expert tutors for K-1...
# 1162  Perform Antibody Discovery using Artificial In...
# 1163  GameEon is based in the sleepless city of Mumb...
# 1164  D2C Health and Wellness Brand for Fresh and Sa...
# 1165  Revolutionizing the food industry through tech...
# 1166  OckyPocky is India's 1st interactive English l...
# 1167  Empowering local markets to sell online social...
# 1168  Nova Benefits is the one stop tech platform fo...
# 1169  Tech-empowered teams have delivered over 20,00...
# 1170  LIDO is an  ed-tech company revolutionizing fo...
# 1171  A daily gold-savings app that saves spare chan...
# 1172  Intelligent Housekeeping Robots for public and...
# 1173   moneyHOP is India’s first cross-border neo bank.
# 1174  Codingal is on a mission to inspire school kid...
# 1175  Enabling enterprises to automate their contact...
# 1176  Peak helps the world's smartest companies put ...
# 1177  REVOS is a smart mobility platform that empowe...
# 1178  Integrated Portfolios designed by experts with...
# 1179  A mission to assist a billion Indians in their...
# 1180  Habbit is online learning community for anyone...
# 1181                           Empowering SMBs in India
# 1182  Innovative technology, compassionate diabetes ...
# 1183  Help forward thinking entrepreneurs by providi...
# 1184           Vidyakul is a group of academic experts.
# 1185  Make plant-based food affordable and accessibl...
# 1186  Fieldproxy is a no-code platform that helps fi...
# 1187  NeuroPixel.AI Labs is a deep tech start-up tha...
# 1188             End to End Logistics Automation Expert
# 1189  A consulting firm focused mainly on Data Analy...
# 1190  Prolgae Spirulina Supplies Pvt. Ltd. is a Nord...
# 1191  India's first tech-enabled healthcare logistic...
# 1192  Transforming global sourcing for retailers & s...
# 1193  Sapio helps government create policies driven ...
# 1194                         Democratizing Open Banking
# 1195  Delhivery is a leading logistics and supply ch...
# 1196  Flipspaces is a global tech-enabled venture to...
# 1197  Fleek helps track & manage subscriptions in on...
# 1198  GoKwik is a platform for solving shopping expe...
# 1199  Innovating plant protein ingredients with supe...
# 1200  InfyU Labs is a team of dedicated professional...
# 1201  Safe, secure & reliable On-Demand Drone delive...
# 1202  Voxelgrids is an Magnetic Resonance Imaging te...
# 1203  A smart-tech-enabled platform offering a one-s...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 1159                            Amit Tewary, Ajit Sinha
# 1160                         Manoj Meena, Sibabrata Das
# 1161                    Ali Asgar Kagzi, Piyush Dhanuka
# 1162                     Aridni Shah, Trisha Chatterjee
# 1163                                    Nikhil Malankar
# 1164                                         Pradeep PS
# 1165   Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa
# 1166                                       Amit Agrawal
# 1167                         Mahima Kaul, Jasmeet Thind
# 1168                           Saransh Garg, Yash Gupta
# 1169                                      Srikanth Iyer
# 1170                                        Sahil Sheth
# 1171                         Nishchay AG, Misbah Ashraf
# 1172                       Runal Dahiwade, Miraj C Vora
# 1173                                       Mayank Goyal
# 1174                     Vivek Prakash, Satyam Baranwal
# 1175                      Sourabh Gupta, Akshay Deshraj
# 1176                                        Atul Sharma
# 1177             Mohit Yadav, Jyotrian Jan Harichandran
# 1178  Sandeep Jethwani, Vaibhav Porwal, Sahil Contra...
# 1179                                    Prashant Sachan
# 1180                      Somnath Sandeep, Raghav Goyal
# 1181                  Sonakshi Nathani, Ashutosh Singla
# 1182                 Shivtosh Kumar, Madan Somasundaram
# 1183                     Suumit Shah, Subhash Choudhary
# 1184                        Tarun Saini, Gaurav Singhvi
# 1185                                       Abhay Rangan
# 1186                 Swaroop Vijayakumar, Balakrishna B
# 1187                                               None
# 1188                                       Sanket Sheth
# 1189                             Saravanan Jaichandaran
# 1190                                    Aakas Sadasivam
# 1191                          Talha Shaikh, Ashok Yadav
# 1192                        Amit Sharma, Tanuj Gangwani
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
# 1194                          Tarun Nazare, Rohith Reji
# 1195                                        Sahil Barua
# 1196                                       Kunal Sharma
# 1197                 Aditya Uttaravalli, Arvind Eashwar
# 1198         Ankush Talwar, Chirag Taneja, Vivek Bajpai
# 1199                         Ashish Korde, Kevin Parekh
# 1200                     Amit Srivastava, Ankit Chauhan
# 1201                                 Vikram Singh Meena
# 1202                                  Arjun Arunachalam
# 1203                                     Prasad Sreeram
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                                Investor      Amount  \
# 1159                             Curesense Therapeutics   1100000.0
# 1160                                     Ka Enterprises         nan
# 1161                                  Navneet Education         nan
# 1162                                        pi Ventures   1000000.0
# 1163                              Mumbai Angels Network    320000.0
# 1164  IAN Fund, Malabar Angel Network, Native Angel ...    800000.0
# 1165               DSG Consumer Partners, Titan Capital    500000.0
# 1166              Sujeet Kumar, SucSEED Indovation Fund         nan
# 1167                           Ameba Capital, 9Unicorns   8000000.0
# 1168  Susquehanna International Group, Bessemer Vent...  10000000.0
# 1169         IIFL AMC, Oman India Joint Investment Fund  50000000.0
# 1170                                  Unilazer Ventures  10000000.0
# 1171     Tribe Capital, Arkam Ventures, WEH, Kunal Shah   4500000.0
# 1172            Venture Catalysts, Indian Angel Network    600000.0
# 1173                                               None   1200000.0
# 1174                                               None   1200000.0
# 1175                                 Westbridge Capital  23000000.0
# 1176                             SoftBank Vision Fund 2  75000000.0
# 1177                                               None   4000000.0
# 1178           Elevation Capital, Matrix Partners India   7000000.0
# 1179                                  Elevation Capital  10000000.0
# 1180                                        Ashok Goyal    320000.0
# 1181                              Sequoia Capital India  10000000.0
# 1182         Cure.fit, Endiya Partners, Tanglin Venture  10000000.0
# 1183  HOF Capital, Old Well Ventures, LetsVenture, 9...  11000000.0
# 1184                                  We Founder Circle    500000.0
# 1185  Jinisha Sharma, Aditya Agarwal, Victoria, Abhi...   1000000.0
# 1186                    LetsVenture, 2am VC, magic.fund    200000.0
# 1187         Arvind Venugopal Nair, Amritendu Mukherjee    800000.0
# 1188                     Rajasthan Venture Capital Fund   1000000.0
# 1189  Covalent, Double Peak, GenBlock Capital, Ledge...    700000.0
# 1190                                            Vijayan    200000.0
# 1191  Gokul Rajaram, JPIN, Venture Catalysts UK, Ang...   2000000.0
# 1192                                 Info Edge Ventures   2000000.0
# 1193                        Rachit Poddar, Rajesh Gupta         nan
# 1194         Virenxia Group, Rajesh Jain, Nitin Agarwal    500000.0
# 1195                                           Addition  76000000.0
# 1196                                     Prashasta Seth   2000000.0
# 1197                                             Axilor   1000000.0
# 1198  Matrix Partners India, Jitendra Gupta, RTP Global   5000000.0
# 1199                  Shaival Desai, Flowstate Ventures   2000000.0
# 1200                                                IAN    200000.0
# 1201                                  India Accelerator    500000.0
# 1202                                               Zoho   5000000.0
# 1203                                   Transworld Group   2000000.0
# 1204                                    Endiya Partners   3000000.0
# 1205                                           IIFL AMC  20000000.0
# 1206                                       Owl Ventures  55000000.0
# 1207                   Winter Capital, ETS, Man Capital  26000000.0
# 1208                     3one4 Capital, Kalaari Capital   8000000.0
#
#               Stage  Funding_Year             Main_Sector
# 1159       Pre-seed          2021      Financial Services
# 1160           None          2021       Commerce & Retail
# 1161           None          2021                    None
# 1162           Seed          2021             Agriculture
# 1163           None          2021   Software & Technology
# 1164   Pre-series A          2021             Agriculture
# 1165           Seed          2021         Food & Beverage
# 1166           Seed          2021                    None
# 1167     Pre-series          2021       Commerce & Retail
# 1168       Series A          2021  Health & Life Sciences
# 1169       Series E          2021                    None
# 1170           None          2021       Commerce & Retail
# 1171   Pre-series A          2021                    None
# 1172           None          2021             Agriculture
# 1173           Seed          2021      Financial Services
# 1174           Seed          2021                    None
# 1175       Series B          2021                    None
# 1176       Series C          2021                    None
# 1177       Series A          2021               Transport
# 1178           Seed          2021      Financial Services
# 1179       Series A          2021       Commerce & Retail
# 1180       Pre-seed          2021                    None
# 1181       Series A          2021       Commerce & Retail
# 1182           None          2021  Health & Life Sciences
# 1183       Series A          2021       Commerce & Retail
# 1184         Bridge          2021                    None
# 1185           Seed          2021         Food & Beverage
# 1186           Seed          2021                    None
# 1187           Seed          2021                    None
# 1188   Pre-series A          2021   Software & Technology
# 1189           Seed          2021      Financial Services
# 1190           Seed          2021             Agriculture
# 1191  Pre-series A1          2021  Health & Life Sciences
# 1192           None          2021       Commerce & Retail
# 1193           None          2021                    None
# 1194           Seed          2021                    None
# 1195       Series I          2021               Transport
# 1196   Pre-series B          2021                    None
# 1197           Seed          2021                    None
# 1198   Pre-series A          2021   Software & Technology
# 1199           Seed          2021         Food & Beverage
# 1200           Seed          2021             Agriculture
# 1201           Seed          2021               Transport
# 1202           None          2021                    None
# 1203   Pre-series A          2021               Transport
# 1204   Pre-series A          2021       Business Services
# 1205       Series D          2021         Food & Beverage
# 1206       Series C          2021      Financial Services
# 1207       Series B          2021                    None
# 1208       Series A          2021      Financial Services

# %% [markdown]
# ##### Filter rows where either 'Main Sector' or 'industry' has missing values

# %% [markdown]
# Cleaning Columns
# Location / Sector columns

# %%
# Function to remove '#REF!' in a series
def remove_ref(value):
    if isinstance(value, str):
        value = value.replace('#REF!', '').strip()
            
    return value

# Columns of Interest 
columns = ['Location', 'Investor']
for column in columns:    
    # Identify rows where column value contains '#REF!
    mask = df[column].str.contains('#REF!')
    
    # Fill missing values in mask with False
    mask.fillna(False, inplace=True)
    
    # Update the column by applying the remove_ref function to the column
    df.loc[mask, column] = df.loc[mask, column].apply(remove_ref)
    
    # Shift values in selected rows excluding the last column 'year'
df.loc[mask, column:'Stage'] = df.loc[mask, column:'Stage'].shift(1, axis=1)


# Sanitisizing the sector column after shifting
mask = df['Sector'].apply(lambda x: x in df['Location'].unique())

# Update 'headquarter' value with 'sector' value
df.loc[mask, 'Location'] = df.loc[mask, 'Sector']

# Set the 'sector' value to NaN
df.loc[mask, 'Sector'] = np.nan

# %% [markdown]
# To ensure consistent representation of missing values by replacing 'None' string values with NaN

# %%
# Function replace None with NaN
def replace_none(value):
    return np.nan if isinstance(value, str) and value.strip().lower() in ['none', 'nan'] else value

# Apply the function to all columns
df = df.applymap(replace_none) # element-wise

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2759 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2235 non-null   object
#  7   Amount        2318 non-null   object
#  8   Stage         1941 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 269.3+ KB

# %% [markdown]
# ##### If a value in the 'Stage' column is a website link, its correct value is NaN

# %%
# Function to remove website link from stage column
def remove_website_link(value):
    # Regular expression pattern to match website URLs
    pattern = r'https?://\S+'
    
    # Check if the value is a string and matches the pattern
    if isinstance(value, str) and re.match(pattern, value):
        return np.nan
    return value

# %%
# Function to clean amount values
def floater(string):
    try:
        string = float(string)
    except ValueError:
        string = np.nan
    
    return string
    
def clean_amount(row): 
    Amount = row[0]    
    Funding_Year   = row['Funding_Year'] 
    
    # Source: https://www.ofx.com/en-au/forex-news/historical-exchange-rates/yearly-average-rates/
    exchange_rates = {
        2018: 0.014649,
        2019: 0.014209,
        2020: 0.013501,
        2021: 0.013527
    }
    
    exchange_rate = exchange_rates[year]   
    
    # Convert to string
    Amount = str(Amount)   
    
    if isinstance(Amount, str):        
        # Set of elements to replace
        to_replace = {' ', ','}

        # Replace each element in the set with an empty string
        for r in to_replace:
            Amount = Amount.replace(r, '')        
                        
        if Amount == '' or Amount == '—': 
            Amount = np.nan
        # If the amount is in INR (Indian Rupees), convert it to USD using the conversion rate of the year
        elif '₹' in Amount:
            Amount = Amount.replace('₹', '')
            Amount = floater(Amount) * exchange_rate
        
        # If the amount is in USD, remove the '$' symbol and convert it to a float
        elif '$' in Amount:
            Amount = Amount.replace('$', '')
            Amount = floater(Amount)
        else:
            Amount = floater(Amount)

    
    return Amount

# %%
# Function to clean Amount field
def clean_amount(Amount, Funding_Year):
    # Define exchange rates
    exchange_rates = {
        2018: 0.014649,
        2019: 0.014209,
        2020: 0.013501,
        2021: 0.013527
    }
    
    # Handle missing values
    if pd.isnull(Amount) or Amount == '—' or Amount == '':
        return np.nan
    
    # Convert INR to USD using exchange rate
    if '₹' in Amount:
        Amount = float(Amount.replace('₹', '')) * exchange_rates[Funding_Year]
    
    # Remove $ symbol and convert to float for USD amounts
    elif '$' in Amount:
        Amount = float(Amount.replace('$', ''))
    
    # Convert other numeric strings to float
    else:
        try:
            Amount = float(Amount)
        except ValueError:
            return np.nan
    
    return Amount

# %%
df.isna().sum()
# Out:
# Company_Name       0
# Founded          768
# Location         114
# Sector            19
# What_it_does       0
# Founders         544
# Investor         638
# Amount           555
# Stage            932
# Funding_Year       0
# Main_Sector     1095
# dtype: int64

# %% [markdown]
# ##### Handling Investor and Amount Values:
# - If the investor value is numeric or contains '$':
#   - Missing amount values should be replaced with the investor value.
#   - The stage value should revert to the original amount value.
#   - The investor value is set to NaN or missing.

# %%
# Identify rows where 'Stage' value is numeric using clean amount function
mask = df[['Stage', 'Funding_Year']].apply(lambda row: pd.notna(clean_amount(row['Stage'], row['Funding_Year'])), axis=1)

# Update the 'What_it_does' column to its concatenation with 'Founder' value
old_What_it_does = df.loc[mask, 'What_it_does']
old_Founder = df.loc[mask, 'Founders']
df.loc[mask, 'What_it_does'] = old_What_it_does.fillna('') + ' ' + old_Founder.fillna('')

# Update 'Founder' column using the old 'Investor' value
df.loc[mask, 'Founders'] = df.loc[mask, 'Investor']

# Update 'Investor' column using the old 'Amount' value
df.loc[mask, 'Investor'] = df.loc[mask, 'Amount']

# Update 'Amount' column using the old 'Stage' value
df.loc[mask, 'Amount'] = df.loc[mask, 'Stage']

# Set 'Stage' to NaN
df.loc[mask, 'Stage'] = np.nan

# %%
# Split the 'investor' column by commas and expand into separate columns
investor_split = df['Investor'].str.split(',', expand=True)

# Iterate over each column of the split DataFrame
for col in investor_split.columns:
    # Only replace non-null values in the original DataFrame
    mask = ~investor_split[col].isnull()
    df.loc[mask, 'Investor'] = investor_split.loc[mask, col]

# Display the updated DataFrame
print(df['Investor'])
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#               ...
# 1204     Endiya Partners
# 1205            IIFL AMC
# 1206        Owl Ventures
# 1207         Man Capital
# 1208     Kalaari Capital
# Name: Investor, Length: 2873, dtype: object

# %%
# Calculate the mode for each sector in the 'Investor' column
mode_per_Main_Sector = df.groupby('Sector')['Investor'].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else "Unknown")

# Fill missing values in the 'investor' column with the calculated mode per sector
df['Investor'].fillna(mode_per_Main_Sector, inplace=True)

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector
# 0   250000.0      Seed          2018  Software & Technology
# 1   584000.0      Seed          2018            Agriculture
# 2   949000.0  Series A          2018     Financial Services
# 3  2000000.0     Angel          2018     Financial Services
# 4        NaN      Seed          2018      Commerce & Retail

# %% [markdown]
# #### Clean and convert amounts to USD and rename colume from amount to amount($)

# %%
# Clean and convert amounts to USD considering the average exchange rate per year
def clean_and_convert_amount(row):
    Amount = row['Amount']
    Funding_Year = row['Funding_Year']
    
    Converted_Amount = Amount
    
    return Converted_Amount

# Clean and convert amounts to USD considering the average exchange rate per year
df['Amount'] = df[['Amount', 'Funding_Year']].apply(clean_and_convert_amount, axis=1)

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector
# 0   250000.0      Seed          2018  Software & Technology
# 1   584000.0      Seed          2018            Agriculture
# 2   949000.0  Series A          2018     Financial Services
# 3  2000000.0     Angel          2018     Financial Services
# 4        NaN      Seed          2018      Commerce & Retail

# %% [markdown]
# #### Data Cleaning by Column
# ##### Cleaning Amount Column

# %%
df['Amount'].unique()
# Out:
# array([250000.0, 584000.0, 949000.0, 2000000.0, nan, 1600000.0, 233600.0,
#        730000.0, 1460000.0, 150000.0, 1100000.0, 7300.0, 6000000.0,
#        650000.0, 511000.0, 934400.0, 292000.0, 1000000.0, 5000000.0,
#        4000000.0, 438000.0, 2800000.0, 1700000.0, 1300000.0, 73000.0,
#        182500.0, 219000.0, 500000.0, 1518400.0, 657000.0, 13400000.0,
#        365000.0, 385440.0, 116800.0, 876.0, 9000000.0, 100000.0, 20000.0,
#        120000.0, 496400.0, 4993200.0, 143145.0, 8760000.0, 742000000.0,
#        14600000.0, 29200000.0, 3980000.0, 10000.0, 1460.0, 3650000.0,
#        1000000000.0, 7000000.0, 35000000.0, 8030000.0, 28500000.0,
#        3504000.0, 1752000.0, 2400000.0, 30000000.0, 36500000.0,
#        23000000.0, 11000000.0, 642400.0, 3240000.0, 876000.0, 540000000.0,
#        9490000.0, 23360000.0, 900000.0, 10000000.0, 1500000.0, 1022000.0,
#        14000000.0, 1496500.0, 100000000.0, 17520.0, 75920000.0, 800000.0,
#        1041000.0, 15000.0, 1400000.0, 1200000.0, 2200000.0, 1800000.0,
#        3600000.0, 138700.0, 300000.0, 6830000.0, 200000.0, 2190000.0,
#        4300000.0, 364846.0, 400000.0, 102200.0, 20440.0, 146000.0,
#        328500.0, 13200000.0, 50000.0, 2046920.0, 3000000.0, 1250000.0,
#        180000.0, 280320.0, 1503800.0, 4200000.0, 175000.0, 1450000.0,
#        2920.0, 4500000.0, 600000.0, 242360.0, 175200.0, 15000000.0,
#        481800.0, 125000.0, 130000.0, 509540.0, 1051200.0, 17200000.0,
#        467200.0, 3500000.0, 1971000.0, 12000000.0, 40000000.0, 50000000.0,
#        22484000.0, 2044000.0, 41900000.0, 20586000.0, 3530000.0,
#        3300000.0, 8468000.0, 525600.0, 4964000.0, 210000000.0, 37680000.0,
#        7446000.0, 32120000.0, 22000000.0, 70000.0, 224723200.0,
#        292000000.0, 58400000.0, 185000000.0, 65000000.0, 2409000.0,
#        700000.0, 3066000.0, 29632160.0, 75000000.0, 1168000.0, 1760000.0,
#        2700000.0, 4088000.0, 11680000.0, 750000.0, 2500000.0, 80000000.0,
#        25000000.0, 10658000.0, 5840000.0, 3700000.0, 5600000.0, 3796000.0,
#        99230000.0, 70000000.0, 40000.0, 550000.0, 365000000.0, 127750.0,
#        1138800.0, 28000000.0, 3854400.0, 16498000.0, 11826000.0,
#        20440000.0, 14900000.0, 225000000.0, 7500.0, '6300000.0',
#        '150000000.0', '28000000.0', '30000000.0', '6000000.0',
#        '1000000.0', '20000000.0', '275000000.0', '22000000.0',
#        '5000000.0', '140500.0', '540000000.0', '15000000.0', '182700.0',
#        '12000000.0', '11000000.0', '15500000.0', '1500000.0', '5500000.0',
#        '2500000.0', '140000.0', '230000000.0', '49400000.0', '32000000.0',
#        '26000000.0', '150000.0', '400000.0', '2000000.0', '100000000.0',
#        '8000000.0', '100000.0', '50000000.0', '120000000.0', '4000000.0',
#        '6800000.0', '36000000.0', '5700000.0', '25000000.0', '600000.0',
#        '70000000.0', '60000000.0', '220000.0', '2800000.0', '2100000.0',
#        '7000000.0', '311000000.0', '4800000.0', '693000000.0',
#        '33000000.0', '200000.0', '340000.0', '45000000.0', '1200000.0',
#        '660000000.0', '120000.0', '7500000.0', '500000.0', '3000000.0',
#        '10000000.0', '145000000.0', '21000000.0', '560000.0', '275000.0',
#        '4500000.0', '390000000.0', '5100000.0', '700000000.0',
#        '2300000.0', '700000.0', '19000000.0', '9000000.0', '40000000.0',
#        '750000.0', '7800000.0', '80000000.0', '1700000.0', '40000.0',
#        '35000000.0', '300000.0', '3500000.0', '200000000.0', '1300000.0',
#        '4100000.0', '575000.0', '800000.0', '18000000.0', '3200000.0',
#        '900000.0', '250000.0', '4700000.0', '75000000.0', '121000000.0',
#        '55000000.0', '3300000.0', '16000000.0', '5400000.0', '4200000.0',
#        '52000000.0', '1100000.0', '118000000.0', '1600000.0',
#        '18500000.0', '70000000000.0', '800000000.0', '400000000.0',
#        '176000000.0', '470000.0', '240000.0', '3000000000.0',
#        '74000000.0', '62000000.0', '500000000.0', '12500000.0',
#        '2200000000.0', '5060000.0', '225000000.0', '24700000.0',
#        '7700000.0', '19067328.0', '51000000.0', '115000.0', '54000.0',
#        '20000.0', '803146.0', '238000.0', '10220000.0', '1020000.0',
#        '13400000.0', '170000000.0', '2900000.0', '543000.0', '90000000.0',
#        '3400000.0', '23000000.0', '8090000.0', '1030000.0', '5040000.0',
#        '360000.0', '1400000.0', '650000.0', '54000000.0', '42500000.0',
#        '11370000.0', '325000.0', '410000.0', '450000.0', '682000.0',
#        '4050000.0', '1050000.0', '1080000.0', '4300000.0', '2110000.0',
#        '11943500.0', '764000.0', '603000.0', '409000.0', '292000.0',
#        '286000.0', '136000.0', '825000000.0', '546000.0', '887000.0',
#        '43000.0', '40900.0', '2200000.0', '5660000.0', '350000.0',
#        '110000.0', '122000000.0', '11635000.0', '1065000.0', '669000.0',
#        '16076000.0', '649600.0', '6700000.0', '266500.0', '2879000.0',
#        '26500000.0', '351000.0', '46761000.0', '175000.0', '11241000.0',
#        '804000.0', '1340000.0', '467000.0', '133000.0', '3823000.0',
#        '934000.0', '293000.0', '198000.0', '927000.0', '971000.0',
#        '3060000.0', '1862000.0', '232000.0', '2888000.0', '1328000.0',
#        '56000000.0', '2250000.0', '16753000.0', '3700000.0', '1470000.0',
#        '530000.0', '267000.0', '3344000.0', '7200000.0', '2743000.0',
#        '6082000.0', '6609000.0', '27700000.0', '5940000.0', '3964000.0',
#        '197000.0', '4327000.0', '459000.0', '3937000.0', '1313500.0',
#        '229800.0', '5305000.0', '264000.0', '1750000.0', '5967000.0',
#        '2980000.0', '323000.0', '1326000.0', '27000000.0', '5200000.0',
#        '2530000.0', '792000.0', '11363000.0', '1715000.0', '329000.0',
#        '5271000.0', '8700000.0', '3226000.0', '5900000.0', '44000000.0',
#        '3879000.0', '13000000.0', '8800000.0', '9500000.0', '920000.0',
#        '35600000.0', '9400000.0', '790000.0', '480000.0', '160000.0',
#        '8200000.0', '4257000.0', '1410000.0', '349800.0', '786000.0',
#        '2004000.0', '123000000.0', '248000.0', '24000000.0', '14259000.0',
#        '24500000.0', '3800000.0', '18370000.0', '68525000.0', '1834000.0',
#        '23850000.0', '43000000.0', '21600000.0', '4598000.0',
#        '13137000.0', '115000000.0', '3900000.0', '670000.0', '8500000.0',
#        '3148000.0', '2600000.0', '4049500.0', '10500000.0', '6500000.0',
#        '43700000.0', '13800000.0', '306900.0', '420000.0', '627300.0',
#        '113000000.0', '110000000.0', '1397000.0', '448500.0', '7975700.0',
#        '330000.0', '5600000.0', '1402000.0', '21500000.0', '296000000.0',
#        '4900000.0', '1402400.0', '12618300.0', '9900000.0', '982530.0',
#        '70185200.0', '210000000.0', '84000000.0', '39000000.0',
#        '2700000.0', '1403400.0', '105000000.0', '103000000.0', '281300.0',
#        '12700.0', '25000.0', '97500000.0', '507000.0', '8400000.0',
#        '18300000.0', '125000000.0', '181000.0', '280000.0', '14700000.0',
#        '13200000.0', '8043000.0', '188000000.0', '49000000.0',
#        '160000000.0', '1800000.0', '850000.0', '53000000.0', '7400000.0',
#        '17000000.0', '215000000.0', '350000000.0', '83000000.0',
#        '65000000.0', '150000000000.0', '300000000.0', '140000000.0',
#        '17500000.0', '42000000.0', '450000000.0', '37000000.0',
#        '370000000.0', '770000.0', '6600000.0', '725000.0', '461000.0',
#        '96000000.0', '266000000.0', '325000000.0', '225000.0',
#        '85000000.0', '235000.0', '260000.0', '86000000.0', '130000.0',
#        '10000.0', '111000000.0', '265000.0', '76000000.0', '1000000000.0',
#        '95000000.0', '280000000.0', '14300000.0', '81000000.0',
#        '720000.0', '67000000.0', '10200000.0', '220000000.0',
#        '108000000.0', '370000.0', '48000000.0', '3600000.0',
#        '192000000.0', '1900000.0', '41000000.0', '144000000.0',
#        '270000000.0', '250000000.0', '320000.0', '38000000.0', '125000.0',
#        '64000000.0', '620000.0', '$6000000', '1250000.0', '234000000.0',
#        '460000000.0', '13500000.0', '195000000.0', '7300000.0',
#        '16500000.0', '92000000.0', '135000000.0', '155000.0',
#        '840000000.0', '248000000.0', '570000.0', '260000000.0',
#        '175000000.0', '810000.0', '600000000.0', '6750000.0',
#        '78000000.0', '255000000.0', '570000000.0', '550000.0',
#        '31000000.0', '540000.0', '14000000.0', '6200000.0'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2759 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2873 non-null   object
#  7   Amount        2319 non-null   object
#  8   Stage         1940 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 269.3+ KB

# %%
# Remove non-numeric characters and the dollar sign ('$')
df['Amount'] = df['Amount'].apply(lambda x: str(x).replace('$', '') if pd.notna(x) else x)

# %%
# Convert 'Amount' column to float 
df['Amount'] = df['Amount'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2759 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2873 non-null   object
#  7   Amount        2319 non-null   float64
#  8   Stage         1940 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 269.3+ KB

# %%
df['Amount'].unique()
# Out:
# array([2.5000000e+05, 5.8400000e+05, 9.4900000e+05, 2.0000000e+06,
#                  nan, 1.6000000e+06, 2.3360000e+05, 7.3000000e+05,
#        1.4600000e+06, 1.5000000e+05, 1.1000000e+06, 7.3000000e+03,
#        6.0000000e+06, 6.5000000e+05, 5.1100000e+05, 9.3440000e+05,
#        2.9200000e+05, 1.0000000e+06, 5.0000000e+06, 4.0000000e+06,
#        4.3800000e+05, 2.8000000e+06, 1.7000000e+06, 1.3000000e+06,
#        7.3000000e+04, 1.8250000e+05, 2.1900000e+05, 5.0000000e+05,
#        1.5184000e+06, 6.5700000e+05, 1.3400000e+07, 3.6500000e+05,
#        3.8544000e+05, 1.1680000e+05, 8.7600000e+02, 9.0000000e+06,
#        1.0000000e+05, 2.0000000e+04, 1.2000000e+05, 4.9640000e+05,
#        4.9932000e+06, 1.4314500e+05, 8.7600000e+06, 7.4200000e+08,
#        1.4600000e+07, 2.9200000e+07, 3.9800000e+06, 1.0000000e+04,
#        1.4600000e+03, 3.6500000e+06, 1.0000000e+09, 7.0000000e+06,
#        3.5000000e+07, 8.0300000e+06, 2.8500000e+07, 3.5040000e+06,
#        1.7520000e+06, 2.4000000e+06, 3.0000000e+07, 3.6500000e+07,
#        2.3000000e+07, 1.1000000e+07, 6.4240000e+05, 3.2400000e+06,
#        8.7600000e+05, 5.4000000e+08, 9.4900000e+06, 2.3360000e+07,
#        9.0000000e+05, 1.0000000e+07, 1.5000000e+06, 1.0220000e+06,
#        1.4000000e+07, 1.4965000e+06, 1.0000000e+08, 1.7520000e+04,
#        7.5920000e+07, 8.0000000e+05, 1.0410000e+06, 1.5000000e+04,
#        1.4000000e+06, 1.2000000e+06, 2.2000000e+06, 1.8000000e+06,
#        3.6000000e+06, 1.3870000e+05, 3.0000000e+05, 6.8300000e+06,
#        2.0000000e+05, 2.1900000e+06, 4.3000000e+06, 3.6484600e+05,
#        4.0000000e+05, 1.0220000e+05, 2.0440000e+04, 1.4600000e+05,
#        3.2850000e+05, 1.3200000e+07, 5.0000000e+04, 2.0469200e+06,
#        3.0000000e+06, 1.2500000e+06, 1.8000000e+05, 2.8032000e+05,
#        1.5038000e+06, 4.2000000e+06, 1.7500000e+05, 1.4500000e+06,
#        2.9200000e+03, 4.5000000e+06, 6.0000000e+05, 2.4236000e+05,
#        1.7520000e+05, 1.5000000e+07, 4.8180000e+05, 1.2500000e+05,
#        1.3000000e+05, 5.0954000e+05, 1.0512000e+06, 1.7200000e+07,
#        4.6720000e+05, 3.5000000e+06, 1.9710000e+06, 1.2000000e+07,
#        4.0000000e+07, 5.0000000e+07, 2.2484000e+07, 2.0440000e+06,
#        4.1900000e+07, 2.0586000e+07, 3.5300000e+06, 3.3000000e+06,
#        8.4680000e+06, 5.2560000e+05, 4.9640000e+06, 2.1000000e+08,
#        3.7680000e+07, 7.4460000e+06, 3.2120000e+07, 2.2000000e+07,
#        7.0000000e+04, 2.2472320e+08, 2.9200000e+08, 5.8400000e+07,
#        1.8500000e+08, 6.5000000e+07, 2.4090000e+06, 7.0000000e+05,
#        3.0660000e+06, 2.9632160e+07, 7.5000000e+07, 1.1680000e+06,
#        1.7600000e+06, 2.7000000e+06, 4.0880000e+06, 1.1680000e+07,
#        7.5000000e+05, 2.5000000e+06, 8.0000000e+07, 2.5000000e+07,
#        1.0658000e+07, 5.8400000e+06, 3.7000000e+06, 5.6000000e+06,
#        3.7960000e+06, 9.9230000e+07, 7.0000000e+07, 4.0000000e+04,
#        5.5000000e+05, 3.6500000e+08, 1.2775000e+05, 1.1388000e+06,
#        2.8000000e+07, 3.8544000e+06, 1.6498000e+07, 1.1826000e+07,
#        2.0440000e+07, 1.4900000e+07, 2.2500000e+08, 7.5000000e+03,
#        6.3000000e+06, 1.5000000e+08, 2.0000000e+07, 2.7500000e+08,
#        1.4050000e+05, 1.8270000e+05, 1.5500000e+07, 5.5000000e+06,
#        1.4000000e+05, 2.3000000e+08, 4.9400000e+07, 3.2000000e+07,
#        2.6000000e+07, 8.0000000e+06, 1.2000000e+08, 6.8000000e+06,
#        3.6000000e+07, 5.7000000e+06, 6.0000000e+07, 2.2000000e+05,
#        2.1000000e+06, 3.1100000e+08, 4.8000000e+06, 6.9300000e+08,
#        3.3000000e+07, 3.4000000e+05, 4.5000000e+07, 6.6000000e+08,
#        7.5000000e+06, 1.4500000e+08, 2.1000000e+07, 5.6000000e+05,
#        2.7500000e+05, 3.9000000e+08, 5.1000000e+06, 7.0000000e+08,
#        2.3000000e+06, 1.9000000e+07, 7.8000000e+06, 2.0000000e+08,
#        4.1000000e+06, 5.7500000e+05, 1.8000000e+07, 3.2000000e+06,
#        4.7000000e+06, 1.2100000e+08, 5.5000000e+07, 1.6000000e+07,
#        5.4000000e+06, 5.2000000e+07, 1.1800000e+08, 1.8500000e+07,
#        7.0000000e+10, 8.0000000e+08, 4.0000000e+08, 1.7600000e+08,
#        4.7000000e+05, 2.4000000e+05, 3.0000000e+09, 7.4000000e+07,
#        6.2000000e+07, 5.0000000e+08, 1.2500000e+07, 2.2000000e+09,
#        5.0600000e+06, 2.4700000e+07, 7.7000000e+06, 1.9067328e+07,
#        5.1000000e+07, 1.1500000e+05, 5.4000000e+04, 8.0314600e+05,
#        2.3800000e+05, 1.0220000e+07, 1.0200000e+06, 1.7000000e+08,
#        2.9000000e+06, 5.4300000e+05, 9.0000000e+07, 3.4000000e+06,
#        8.0900000e+06, 1.0300000e+06, 5.0400000e+06, 3.6000000e+05,
#        5.4000000e+07, 4.2500000e+07, 1.1370000e+07, 3.2500000e+05,
#        4.1000000e+05, 4.5000000e+05, 6.8200000e+05, 4.0500000e+06,
#        1.0500000e+06, 1.0800000e+06, 2.1100000e+06, 1.1943500e+07,
#        7.6400000e+05, 6.0300000e+05, 4.0900000e+05, 2.8600000e+05,
#        1.3600000e+05, 8.2500000e+08, 5.4600000e+05, 8.8700000e+05,
#        4.3000000e+04, 4.0900000e+04, 5.6600000e+06, 3.5000000e+05,
#        1.1000000e+05, 1.2200000e+08, 1.1635000e+07, 1.0650000e+06,
#        6.6900000e+05, 1.6076000e+07, 6.4960000e+05, 6.7000000e+06,
#        2.6650000e+05, 2.8790000e+06, 2.6500000e+07, 3.5100000e+05,
#        4.6761000e+07, 1.1241000e+07, 8.0400000e+05, 1.3400000e+06,
#        4.6700000e+05, 1.3300000e+05, 3.8230000e+06, 9.3400000e+05,
#        2.9300000e+05, 1.9800000e+05, 9.2700000e+05, 9.7100000e+05,
#        3.0600000e+06, 1.8620000e+06, 2.3200000e+05, 2.8880000e+06,
#        1.3280000e+06, 5.6000000e+07, 2.2500000e+06, 1.6753000e+07,
#        1.4700000e+06, 5.3000000e+05, 2.6700000e+05, 3.3440000e+06,
#        7.2000000e+06, 2.7430000e+06, 6.0820000e+06, 6.6090000e+06,
#        2.7700000e+07, 5.9400000e+06, 3.9640000e+06, 1.9700000e+05,
#        4.3270000e+06, 4.5900000e+05, 3.9370000e+06, 1.3135000e+06,
#        2.2980000e+05, 5.3050000e+06, 2.6400000e+05, 1.7500000e+06,
#        5.9670000e+06, 2.9800000e+06, 3.2300000e+05, 1.3260000e+06,
#        2.7000000e+07, 5.2000000e+06, 2.5300000e+06, 7.9200000e+05,
#        1.1363000e+07, 1.7150000e+06, 3.2900000e+05, 5.2710000e+06,
#        8.7000000e+06, 3.2260000e+06, 5.9000000e+06, 4.4000000e+07,
#        3.8790000e+06, 1.3000000e+07, 8.8000000e+06, 9.5000000e+06,
#        9.2000000e+05, 3.5600000e+07, 9.4000000e+06, 7.9000000e+05,
#        4.8000000e+05, 1.6000000e+05, 8.2000000e+06, 4.2570000e+06,
#        1.4100000e+06, 3.4980000e+05, 7.8600000e+05, 2.0040000e+06,
#        1.2300000e+08, 2.4800000e+05, 2.4000000e+07, 1.4259000e+07,
#        2.4500000e+07, 3.8000000e+06, 1.8370000e+07, 6.8525000e+07,
#        1.8340000e+06, 2.3850000e+07, 4.3000000e+07, 2.1600000e+07,
#        4.5980000e+06, 1.3137000e+07, 1.1500000e+08, 3.9000000e+06,
#        6.7000000e+05, 8.5000000e+06, 3.1480000e+06, 2.6000000e+06,
#        4.0495000e+06, 1.0500000e+07, 6.5000000e+06, 4.3700000e+07,
#        1.3800000e+07, 3.0690000e+05, 4.2000000e+05, 6.2730000e+05,
#        1.1300000e+08, 1.1000000e+08, 1.3970000e+06, 4.4850000e+05,
#        7.9757000e+06, 3.3000000e+05, 1.4020000e+06, 2.1500000e+07,
#        2.9600000e+08, 4.9000000e+06, 1.4024000e+06, 1.2618300e+07,
#        9.9000000e+06, 9.8253000e+05, 7.0185200e+07, 8.4000000e+07,
#        3.9000000e+07, 1.4034000e+06, 1.0500000e+08, 1.0300000e+08,
#        2.8130000e+05, 1.2700000e+04, 2.5000000e+04, 9.7500000e+07,
#        5.0700000e+05, 8.4000000e+06, 1.8300000e+07, 1.2500000e+08,
#        1.8100000e+05, 2.8000000e+05, 1.4700000e+07, 8.0430000e+06,
#        1.8800000e+08, 4.9000000e+07, 1.6000000e+08, 8.5000000e+05,
#        5.3000000e+07, 7.4000000e+06, 1.7000000e+07, 2.1500000e+08,
#        3.5000000e+08, 8.3000000e+07, 1.5000000e+11, 3.0000000e+08,
#        1.4000000e+08, 1.7500000e+07, 4.2000000e+07, 4.5000000e+08,
#        3.7000000e+07, 3.7000000e+08, 7.7000000e+05, 6.6000000e+06,
#        7.2500000e+05, 4.6100000e+05, 9.6000000e+07, 2.6600000e+08,
#        3.2500000e+08, 2.2500000e+05, 8.5000000e+07, 2.3500000e+05,
#        2.6000000e+05, 8.6000000e+07, 1.1100000e+08, 2.6500000e+05,
#        7.6000000e+07, 9.5000000e+07, 2.8000000e+08, 1.4300000e+07,
#        8.1000000e+07, 7.2000000e+05, 6.7000000e+07, 1.0200000e+07,
#        2.2000000e+08, 1.0800000e+08, 3.7000000e+05, 4.8000000e+07,
#        1.9200000e+08, 1.9000000e+06, 4.1000000e+07, 1.4400000e+08,
#        2.7000000e+08, 2.5000000e+08, 3.2000000e+05, 3.8000000e+07,
#        6.4000000e+07, 6.2000000e+05, 2.3400000e+08, 4.6000000e+08,
#        1.3500000e+07, 1.9500000e+08, 7.3000000e+06, 1.6500000e+07,
#        9.2000000e+07, 1.3500000e+08, 1.5500000e+05, 8.4000000e+08,
#        2.4800000e+08, 5.7000000e+05, 2.6000000e+08, 1.7500000e+08,
#        8.1000000e+05, 6.0000000e+08, 6.7500000e+06, 7.8000000e+07,
#        2.5500000e+08, 5.7000000e+08, 3.1000000e+07, 5.4000000e+05,
#        6.2000000e+06])

# %% [markdown]
# ##### Cleaning Stage Column

# %%
# Get unique values in the Stage column
unique_stages = df['Stage'].unique()

# Convert the unique values array to a list``
unique_stages_list = unique_stages.tolist()

# Print the list of unique stages
unique_stages_list
# Out:
# ['Seed',
#  'Series A',
#  'Angel',
#  'Series B',
#  'Pre-Seed',
#  'Private Equity',
#  'Venture - Series Unknown',
#  'Grant',
#  'Debt Financing',
#  'Post-IPO Debt',
#  'Series H',
#  'Series C',
#  'Series E',
#  'Corporate Round',
#  '',
#  'Series D',
#  'Secondary Market',
#  'Post-IPO Equity',
#  'Non-equity Assistance',
#  'Funding Round',
#  nan,
#  'Fresh funding',
#  'Pre series A',
#  'Series G',
#  'Post series A',
#  'Seed funding',
#  'Seed fund',
#  'Series F',
#  'Series B+',
#  'Seed round',
#  'Pre-series A',
#  None,
#  'Pre-seed',
#  'Pre-series',
#  'Debt',
#  'Pre-series C',
#  'Pre-series B',
#  'Bridge',
#  'Series B2',
#  'Pre- series A',
#  'Edge',
#  'Pre-Series B',
#  'Seed A',
#  'Series A-1',
#  'Seed Funding',
#  'Pre-seed Round',
#  'Seed Round & Series A',
#  'Pre Series A',
#  'Pre seed Round',
#  'Angel Round',
#  'Pre series A1',
#  'Series E2',
#  'Seed Round',
#  'Bridge Round',
#  'Pre seed round',
#  'Pre series B',
#  'Pre series C',
#  'Seed Investment',
#  'Series D1',
#  'Mid series',
#  'Series C, D',
#  'Seed+',
#  'Series F2',
#  'Series A+',
#  'Series B3',
#  'PE',
#  'Series F1',
#  'Pre-series A1',
#  'Early seed',
#  'Seies A',
#  'Series A2',
#  'Series I']

# %%
# Select rows where the 'Stage' column contains NaN values
df[pd.isna(df['Stage'])]
# Out:
#          Company_Name  Founded   Location                 Sector  \
# 0      Bombay Shaving      NaN        NaN              Ecommerce
# 4            Nu Genes   2004.0  Telangana               AgriTech
# 5            FlytBase      NaN       Pune             Technology
# 6               Finly      NaN  Bangalore                   SaaS
# 10         Cub McPaws   2010.0     Mumbai        E-commerce & AR
# ...               ...      ...        ...                    ...
# 1172       Peppermint   2019.0       Pune  Industrial Automation
# 1182        Sugar.fit   2021.0  Bangalore                 Health
# 1192        Geniemode   2021.0   Gurugram                    B2B
# 1193  Sapio Analytics   2019.0     Mumbai      Computer Software
# 1202       Voxelgrids   2017.0  Bangalore               Deeptech
#
#                                            What_it_does  \
# 0            Provides a range of male grooming products
# 4     It is a seed company engaged in production, pr...
# 5                           A drone automation platform
# 6     It builds software products that makes work si...
# 10    A B2C  brand that focusses on premium and comf...
# ...                                                 ...
# 1172  Intelligent Housekeeping Robots for public and...
# 1182  Innovative technology, compassionate diabetes ...
# 1192  Transforming global sourcing for retailers & s...
# 1193  Sapio helps government create policies driven ...
# 1202  Voxelgrids is an Magnetic Resonance Imaging te...
#
#                                                Founders  \
# 0                                    Shantanu Deshpande
# 4                                Narayana Reddy Punyala
# 5                                           Nitin Gupta
# 6                             Vivek AG, Veekshith C Rai
# 10                              Abhay Bhat, Kinnar Shah
# ...                                                 ...
# 1172                       Runal Dahiwade, Miraj C Vora
# 1182                 Shivtosh Kumar, Madan Somasundaram
# 1192                        Amit Sharma, Tanuj Gangwani
# 1193  Hardik Somani, Ashwin Srivastava, Shripal Jain...
# 1202                                  Arjun Arunachalam
#
#                                       Investor      Amount Stage  \
# 0                         Sixth Sense Ventures   6300000.0   NaN
# 4     Innovation in Food and Agriculture (IFA)   6000000.0   NaN
# 5                  Lightspeed Venture Partners         NaN   NaN
# 6                                  Niti Aayog.         NaN   NaN
# 10                           Venture Catalysts         NaN   NaN
# ...                                        ...         ...   ...
# 1172                      Indian Angel Network    600000.0  None
# 1182                           Tanglin Venture  10000000.0  None
# 1192                        Info Edge Ventures   2000000.0  None
# 1193                              Rajesh Gupta         NaN  None
# 1202                                      Zoho   5000000.0  None
#
#       Funding_Year             Main_Sector
# 0             2019   Software & Technology
# 4             2019             Agriculture
# 5             2019   Software & Technology
# 6             2019                    None
# 10            2019       Commerce & Retail
# ...            ...                     ...
# 1172          2021             Agriculture
# 1182          2021  Health & Life Sciences
# 1192          2021       Commerce & Retail
# 1193          2021                    None
# 1202          2021                    None
#
# [933 rows x 11 columns]

# %%
# Convert NaN values in the 'Stage' column to an empty string ('')
df.loc[pd.isna(df['Stage']), 'Stage'] = ''

# %%
# Get unique values in the Stage column
unique_stages = df['Stage'].unique()

# Convert the unique values array to a list``
unique_stages_list = unique_stages.tolist()

# Print the list of unique stages
unique_stages_list
# Out:
# ['Seed',
#  'Series A',
#  'Angel',
#  'Series B',
#  'Pre-Seed',
#  'Private Equity',
#  'Venture - Series Unknown',
#  'Grant',
#  'Debt Financing',
#  'Post-IPO Debt',
#  'Series H',
#  'Series C',
#  'Series E',
#  'Corporate Round',
#  '',
#  'Series D',
#  'Secondary Market',
#  'Post-IPO Equity',
#  'Non-equity Assistance',
#  'Funding Round',
#  'Fresh funding',
#  'Pre series A',
#  'Series G',
#  'Post series A',
#  'Seed funding',
#  'Seed fund',
#  'Series F',
#  'Series B+',
#  'Seed round',
#  'Pre-series A',
#  'Pre-seed',
#  'Pre-series',
#  'Debt',
#  'Pre-series C',
#  'Pre-series B',
#  'Bridge',
#  'Series B2',
#  'Pre- series A',
#  'Edge',
#  'Pre-Series B',
#  'Seed A',
#  'Series A-1',
#  'Seed Funding',
#  'Pre-seed Round',
#  'Seed Round & Series A',
#  'Pre Series A',
#  'Pre seed Round',
#  'Angel Round',
#  'Pre series A1',
#  'Series E2',
#  'Seed Round',
#  'Bridge Round',
#  'Pre seed round',
#  'Pre series B',
#  'Pre series C',
#  'Seed Investment',
#  'Series D1',
#  'Mid series',
#  'Series C, D',
#  'Seed+',
#  'Series F2',
#  'Series A+',
#  'Series B3',
#  'PE',
#  'Series F1',
#  'Pre-series A1',
#  'Early seed',
#  'Seies A',
#  'Series A2',
#  'Series I']

# %%
# Fill missing values in 'stage' column with 'Venture - Series Unknown
df['Stage'].fillna('Venture - Series Unknown', inplace=True)

# Replace Undisclosed values in 'stage' column with 'Venture - Series Unknown
df['Stage'].replace(to_replace='Undisclosed', value='Venture - Series Unknown', inplace=True)

df['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', '', 'Series D', 'Secondary Market',
#        'Post-IPO Equity', 'Non-equity Assistance', 'Funding Round',
#        'Fresh funding', 'Pre series A', 'Series G', 'Post series A',
#        'Seed funding', 'Seed fund', 'Series F', 'Series B+', 'Seed round',
#        'Pre-series A', 'Pre-seed', 'Pre-series', 'Debt', 'Pre-series C',
#        'Pre-series B', 'Bridge', 'Series B2', 'Pre- series A', 'Edge',
#        'Pre-Series B', 'Seed A', 'Series A-1', 'Seed Funding',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Seed Round', 'Bridge Round', 'Pre seed round', 'Pre series B',
#        'Pre series C', 'Seed Investment', 'Series D1', 'Mid series',
#        'Series C, D', 'Seed+', 'Series F2', 'Series A+', 'Series B3',
#        'PE', 'Series F1', 'Pre-series A1', 'Early seed', 'Seies A',
#        'Series A2', 'Series I'], dtype=object)

# %%
def Stage_redistribution(Stage):
    # Define the categorization based on regex patterns
    if re.search(r'Pre-Seed|Pre seed|Pre-seed', Stage):
        return 'Ideation'
    elif re.search(r'Seed|Seed funding|Seed fund|Seed round|Seed A|Seed Funding|Seed Round|Seed Round & Series A|Early seed|Seed\+|Seed Investment|Angel|Angel Round|Pre series A|Pre-Series A|Pre-series A|Pre series A1|Pre-series A1|Pre series|Pre- series A', Stage):
        return 'Validation'
    elif re.search(r'Series A|Series A-1|Series A1|Series A2|Series A\+|Pre series A|Pre Series A|Pre-Series A|Seies A |Pre-Series B|Pre-series B|Pre series B|Pre series C|Pre-series C|Pre-Series C |Pre-Series B', Stage, ):
        return 'Early Traction'
    elif re.search(r'Series B|Series B\+|Series B2|Series B3|Series C|Series C, D|Series D|Series D1|Series E|Series E2|Series F|Series F1|Series F2|Series G|Series H|Series Unknown|Private Equity|Corporate Round|Debt Financing|Bridge|Bridge Round|Funding Round|Fresh funding|Non-equity Assistance|PE|Post-IPO Debt|Post-IPO Equity|Mid series', Stage):
        return 'Scaling'
    elif re.search(r'PE|Post-IPO Debt|Post-IPO Equity|Grant|Post series A|Post-Series A|Post series B|Post-Series B|Post series C|Post-Series C|Post series D|Post-Series D|Exit Option |Secondary Market', Stage):
        return 'Exit Option'
    else:
        return 'Unknown'



# Convert "Stage" column to string type to handle None and NaN values
df['Stage'] = df['Stage'].astype(str)

# Apply the function to create the new column
df['Stages'] = df['Stage'].apply(Stage_redistribution)

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector          Stages
# 0   250000.0      Seed          2018  Software & Technology      Validation
# 1   584000.0      Seed          2018            Agriculture      Validation
# 2   949000.0  Series A          2018     Financial Services  Early Traction
# 3  2000000.0     Angel          2018     Financial Services      Validation
# 4        NaN      Seed          2018      Commerce & Retail      Validation

# %%
df['Stages'].unique()
# Out:
# array(['Validation', 'Early Traction', 'Scaling', 'Ideation',
#        'Exit Option', 'Unknown'], dtype=object)

# %%
df.isna().sum()
# Out:
# Company_Name       0
# Founded          768
# Location         114
# Sector            19
# What_it_does       0
# Founders         544
# Investor           0
# Amount           554
# Stage              0
# Funding_Year       0
# Main_Sector     1095
# Stages             0
# dtype: int64

# %% [markdown]
# ##### Cleaning Location Column

# %%
# Get unique values in the HeadQuarter column
unique_Location = df['Location'].unique()

# Convert the unique values array to a list``
unique_Location_list = unique_Location.tolist()

# Print the list of unique HeadQuarter
unique_Location_list
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurgaon',
#  'Noida',
#  'Hyderabad',
#  'Bengaluru',
#  'Kalkaji',
#  'Delhi',
#  'India',
#  'Hubli',
#  'New Delhi',
#  'Chennai',
#  'Mohali',
#  'Kolkata',
#  'Pune',
#  'Jodhpur',
#  'Kanpur',
#  'Ahmedabad',
#  'Azadpur',
#  'Haryana',
#  'Cochin',
#  'Faridabad',
#  'Jaipur',
#  'Kota',
#  'Anand',
#  'Bangalore City',
#  'Belgaum',
#  'Thane',
#  'Margão',
#  'Indore',
#  'Alwar',
#  'Kannur',
#  'Trivandrum',
#  'Ernakulam',
#  'Kormangala',
#  'Uttar Pradesh',
#  'Andheri',
#  'Mylapore',
#  'Ghaziabad',
#  'Kochi',
#  'Powai',
#  'Guntur',
#  'Kalpakkam',
#  'Bhopal',
#  'Coimbatore',
#  'Worli',
#  'Alleppey',
#  'Chandigarh',
#  'Guindy',
#  'Lucknow',
#  nan,
#  'Telangana',
#  'Gurugram',
#  'Surat',
#  'Uttar pradesh',
#  'Rajasthan',
#  'Tirunelveli, Tamilnadu',
#  None,
#  'Singapore',
#  'Gujarat',
#  'Kerala',
#  'Jaipur, Rajastan',
#  'Frisco, Texas, United States',
#  'California',
#  'Dhingsara, Haryana',
#  'New York, United States',
#  'Patna',
#  'San Francisco, California, United States',
#  'San Francisco, United States',
#  'San Ramon, California',
#  'Paris, Ile-de-France, France',
#  'Plano, Texas, United States',
#  'Sydney',
#  'San Francisco Bay Area, Silicon Valley, West Coast',
#  'Bangaldesh',
#  'London, England, United Kingdom',
#  'Sydney, New South Wales, Australia',
#  'Milano, Lombardia, Italy',
#  'Palmwoods, Queensland, Australia',
#  'France',
#  'San Francisco Bay Area, West Coast, Western US',
#  'Trivandrum, Kerala, India',
#  'Samastipur, Bihar',
#  'Irvine, California, United States',
#  'Tumkur, Karnataka',
#  'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#  'Shanghai, China',
#  'Jiaxing, Zhejiang, China',
#  'Rajastan',
#  'Ludhiana',
#  'Dehradun',
#  'San Franciscao',
#  'San Francisco',
#  'Tangerang, Jawa Barat, Indonesia',
#  'Berlin',
#  'Seattle',
#  'Riyadh',
#  'Seoul',
#  'New York',
#  'Bangkok',
#  'Warangal',
#  'Hyderebad',
#  'Odisha',
#  'Bihar',
#  'Goa',
#  'Tamil Nadu',
#  'Banglore',
#  'Ahmadabad',
#  'Andhra Pradesh',
#  'Rajsamand',
#  'Ranchi',
#  '',
#  'Vadodara',
#  'Nagpur',
#  'West Bengal',
#  'Samsitpur',
#  'Silvassa',
#  'Thiruvananthapuram',
#  'Roorkee',
#  'Ambernath',
#  'Panchkula',
#  'Mangalore',
#  'Telugana',
#  'Bhubaneswar',
#  'Kottayam',
#  'Panaji',
#  'Satara',
#  'Orissia',
#  'Santra',
#  'Mountain View',
#  'Jharkhand',
#  'Bhilwara',
#  'Guwahati',
#  'London',
#  'The Nilgiris',
#  'Gandhinagar']

# %%
# Replace 'Online Media\t#REF!' with 'Online Media'
df ['Location'].replace('Online Media\t#REF!', 'Online Media', inplace=True)

# Replace 'Manchester, Greater Manchester' with 'Manchester'
df['Location'].replace('Manchester, Greater Manchester', 'Manchester', inplace=True)

# %%
# Get unique values in the Location column
unique_Location = df['Location'].unique()

# Convert the unique values array to a list``
unique_Location_list = unique_Location.tolist()

# Print the list of unique Location
unique_Location_list
# Out:
# ['Bangalore',
#  'Mumbai',
#  'Gurgaon',
#  'Noida',
#  'Hyderabad',
#  'Bengaluru',
#  'Kalkaji',
#  'Delhi',
#  'India',
#  'Hubli',
#  'New Delhi',
#  'Chennai',
#  'Mohali',
#  'Kolkata',
#  'Pune',
#  'Jodhpur',
#  'Kanpur',
#  'Ahmedabad',
#  'Azadpur',
#  'Haryana',
#  'Cochin',
#  'Faridabad',
#  'Jaipur',
#  'Kota',
#  'Anand',
#  'Bangalore City',
#  'Belgaum',
#  'Thane',
#  'Margão',
#  'Indore',
#  'Alwar',
#  'Kannur',
#  'Trivandrum',
#  'Ernakulam',
#  'Kormangala',
#  'Uttar Pradesh',
#  'Andheri',
#  'Mylapore',
#  'Ghaziabad',
#  'Kochi',
#  'Powai',
#  'Guntur',
#  'Kalpakkam',
#  'Bhopal',
#  'Coimbatore',
#  'Worli',
#  'Alleppey',
#  'Chandigarh',
#  'Guindy',
#  'Lucknow',
#  nan,
#  'Telangana',
#  'Gurugram',
#  'Surat',
#  'Uttar pradesh',
#  'Rajasthan',
#  'Tirunelveli, Tamilnadu',
#  None,
#  'Singapore',
#  'Gujarat',
#  'Kerala',
#  'Jaipur, Rajastan',
#  'Frisco, Texas, United States',
#  'California',
#  'Dhingsara, Haryana',
#  'New York, United States',
#  'Patna',
#  'San Francisco, California, United States',
#  'San Francisco, United States',
#  'San Ramon, California',
#  'Paris, Ile-de-France, France',
#  'Plano, Texas, United States',
#  'Sydney',
#  'San Francisco Bay Area, Silicon Valley, West Coast',
#  'Bangaldesh',
#  'London, England, United Kingdom',
#  'Sydney, New South Wales, Australia',
#  'Milano, Lombardia, Italy',
#  'Palmwoods, Queensland, Australia',
#  'France',
#  'San Francisco Bay Area, West Coast, Western US',
#  'Trivandrum, Kerala, India',
#  'Samastipur, Bihar',
#  'Irvine, California, United States',
#  'Tumkur, Karnataka',
#  'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#  'Shanghai, China',
#  'Jiaxing, Zhejiang, China',
#  'Rajastan',
#  'Ludhiana',
#  'Dehradun',
#  'San Franciscao',
#  'San Francisco',
#  'Tangerang, Jawa Barat, Indonesia',
#  'Berlin',
#  'Seattle',
#  'Riyadh',
#  'Seoul',
#  'New York',
#  'Bangkok',
#  'Warangal',
#  'Hyderebad',
#  'Odisha',
#  'Bihar',
#  'Goa',
#  'Tamil Nadu',
#  'Banglore',
#  'Ahmadabad',
#  'Andhra Pradesh',
#  'Rajsamand',
#  'Ranchi',
#  '',
#  'Vadodara',
#  'Nagpur',
#  'West Bengal',
#  'Samsitpur',
#  'Silvassa',
#  'Thiruvananthapuram',
#  'Roorkee',
#  'Ambernath',
#  'Panchkula',
#  'Mangalore',
#  'Telugana',
#  'Bhubaneswar',
#  'Kottayam',
#  'Panaji',
#  'Satara',
#  'Orissia',
#  'Santra',
#  'Mountain View',
#  'Jharkhand',
#  'Bhilwara',
#  'Guwahati',
#  'London',
#  'The Nilgiris',
#  'Gandhinagar']

# %%
# Filter the data where the "HeadQuarter" column is equal to "The Nilgiris"
df[df['Location'] == "The Nilgiris"]
# Out:
#      Company_Name  Founded      Location         Sector  \
# 1190      Prolgae   2016.0  The Nilgiris  Biotechnology
#
#                                            What_it_does         Founders  \
# 1190  Prolgae Spirulina Supplies Pvt. Ltd. is a Nord...  Aakas Sadasivam
#
#      Investor    Amount Stage  Funding_Year  Main_Sector      Stages
# 1190  Vijayan  200000.0  Seed          2021  Agriculture  Validation

# %%
df['Location'] .unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow', nan,
#        'Telangana', 'Gurugram', 'Surat', 'Uttar pradesh', 'Rajasthan',
#        'Tirunelveli, Tamilnadu', None, 'Singapore', 'Gujarat', 'Kerala',
#        'Jaipur, Rajastan', 'Frisco, Texas, United States', 'California',
#        'Dhingsara, Haryana', 'New York, United States', 'Patna',
#        'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Warangal', 'Hyderebad', 'Odisha',
#        'Bihar', 'Goa', 'Tamil Nadu', 'Banglore', 'Ahmadabad',
#        'Andhra Pradesh', 'Rajsamand', 'Ranchi', '', 'Vadodara', 'Nagpur',
#        'West Bengal', 'Samsitpur', 'Silvassa', 'Thiruvananthapuram',
#        'Roorkee', 'Ambernath', 'Panchkula', 'Mangalore', 'Telugana',
#        'Bhubaneswar', 'Kottayam', 'Panaji', 'Satara', 'Orissia', 'Santra',
#        'Mountain View', 'Jharkhand', 'Bhilwara', 'Guwahati', 'London',
#        'The Nilgiris', 'Gandhinagar'], dtype=object)

# %%
# Renaming some values in the hLocation column
# Define the mapping for name changes
name_changes = {
    'Bangalore': 'Bangalore',
    'Bangalore city': 'Bangalore',
    'Banglore' : 'Bangalore',
    'Jaipur, Rajastan' : ' Jaipur',
    'Rajasthan' : 'Jaipur',
    'Rajastan' : 'Jaipur',
    'Hyderebad' : 'Hyderabad',
    'Bangalore City': 'Bangalore',
    'Bengaluru': 'Bangalore',
    'Dheli': 'Delhi',
    'India' : 'New Delhi',
    'New dheli': 'New Delhi',
    'New Delhi': 'New Delhi',
    'Haryana' : 'Chandigarh',
    'Dhingsara, Haryana' : 'Dhingsara',
    'Kerala ' : 'Thiruvananthapuram',
    'Orissia': 'Odisha',
    'Ahmadabad' : 'Ahmedabad',
    'Uttar Pradesh' : 'Nolda',
    'Bihar ' : 'Patna',
    'Tamil Nadur ': 'Chennai',
    'Andhra Pradesh ' :'Amaravati',
    'West Bengal ' : ' Kolkata',
    'Telangana' : 'Hyderabad',
    'Orissia' : 'Bhubaneswar',
    'Jharkhand' : 'Ranchi',
    'The nilgiris' : ' Chennai',
    'Nilgiris' :'Ootacamund'

}
# Replace the names in the 'Location' column
df['Location'] = df['Location'].replace(name_changes)

# %%
df.isna().sum()
# Out:
# Company_Name       0
# Founded          768
# Location         114
# Sector            19
# What_it_does       0
# Founders         544
# Investor           0
# Amount           554
# Stage              0
# Funding_Year       0
# Main_Sector     1095
# Stages             0
# dtype: int64

# %%
# Set seed for reproducibility

# Identify the rows with missing 'Location' values
missing_location = df['Location'].isna()

# Get non-missing values for 'Location'
non_missing_locations = df.loc[~missing_location, 'Location']

# Fill missing values with randomly sampled non-missing 'Location' values
df.loc[missing_location, 'Location'] = non_missing_locations.sample(n=missing_location.sum(), replace=True).values

# %%
df.isna().sum()
# Out:
# Company_Name       0
# Founded          768
# Location           0
# Sector            19
# What_it_does       0
# Founders         544
# Investor           0
# Amount           554
# Stage              0
# Funding_Year       0
# Main_Sector     1095
# Stages             0
# dtype: int64

# %% [markdown]
# ##### Cleaning What_it_does Column

# %%
# Get unique values in the HeadQuarter column
unique_WiD = df['What_it_does'].unique()

# Convert the unique values array to a list``
unique_WiD_list = unique_WiD.tolist()

# Print the list of uniqueLocation
unique_WiD_list
# Out:
# ['TheCollegeFever is a hub for fun, fiesta and frolic of Colleges.',
#  'A startup which aggregates milk from dairy farmers in rural Maharashtra.',
#  'Leading Online Loans Marketplace in India',
#  'PayMe India is an innovative FinTech organization which offers short term financial suport to corporate employees.',
#  'Eunimart is a one stop solution for merchants to create a difference by selling globally.',
#  'Hasura is a platform that allows developers to build, deploy, and host cloud-native applications quickly.',
#  'Tripshelf is an online market place for holiday packages.',
#  'Hyperdata combines advanced machine learning with human intelligence.',
#  'Freightwalla is an international forwarder thats helps you manage supply chain by providing online tools including instant quotations.',
#  'Microchip payments is a mobile-based payment application and point-of-sale device',
#  'Building Transactionary B2B Marketplaces',
#  'Emojifi is an app that provides live emoji, stickers & GIFs suggestions based on the typed words across chat platforms.',
#  'Flock is a real-time messaging and collaboration app for teams that speeds up and simplifies communication and boosts productivity.',
#  'Freshboxx is incubated at Sandbox Startups, a unit of the Deshpande Foundation.',
#  'Wide Mobility Mechatronics is a Private Company limited by Shares',
#  'Pitstop offers general repair and maintenance services for cars through its doorstep service vehicles.',
#  'Mihuru is an online platform which gives micro loans for air travel .',
#  'Fyle is an intelligent expense management platform for enterprises.',
#  'Appwharf is an intelligent assistant that helps find you the best-fit SaaS for your business.',
#  'Waste Management for Smart Cities',
#  'Cogoport is a platform that provides freight buying industry with spot rates and bidding process for freight buyers.',
#  'A P2P lending marketplace platform',
#  "Makers of a signature coffee that's exceptional in taste. It's super easy to brew, requires no equipment & ships to your door.",
#  'Delhi-based online used vehicles marketplace.',
#  'PregBuddy is a smart connected care platform for expecting mothers.',
#  'AgNext is an agricultural sensing and solutions company focused on building data-driven solutions for agricultural stakeholders',
#  'A startup which digitizes logistics operations for Fortune 500 companies.',
#  'Online lending startup based in Mumbai.',
#  "India's Online Auto Repair Marketplace",
#  'Early stage Artificial Intelligence (AI) start up.',
#  'Chariot Tech is an Internet of Things (IoT) startup based in New Delhi.',
#  'Ideal Insurance Broking is one of the leaders in insurance broking domain.',
#  'Loanzen helps small businesses get unsecured working capital loans against their their pending invoices.',
#  "Mojro envisions to be the world's largest technology-enabled logistics platform.",
#  'Blockchain Development Platform To Design, Run & Scale Blockchain Networks.',
#  'LoadShare is India’s fastest growing logistics company',
#  'Food startup Yumlane operated by QwikPik Technology',
#  'A Education Start Up.',
#  'Pipa+Bella is an online store aimed at selling fashionable and affordable costume jewelry at par with international standards and trends',
#  'A fintech platform.',
#  'Chakr has developed the world’s first retro-fit emission control device for diesel generators.',
#  "India's the premier education destination catering to the needs of aspiring students of the CA community.",
#  'UClean is a tech enabled laundry service provider.',
#  'The Fashion Re-commerce platform.',
#  'Letstrack GPS tracking devices to track your kids, bike, car and other vehicles. GPS trackers for Vehicle Tracking System in India.',
#  'Pooltoo offers a premium ride sharing platform.',
#  'finzy is the premier peer to peer lending solution in India.',
#  "India's largest online fitness platform that provides an integrated eco-system to help users start & sustain their fitness journey",
#  'Building an Intelligent Digital Assistant.',
#  'Reserve your Room, Hostel or Paying Guest, while relocating for higher education.',
#  'Chai Kings is a tea retail chain',
#  'Dainik Jagran is a media and communications group.',
#  'Playtoome is a live entertainment destination',
#  'ONGO Framework is a B2B IT and digital solution provider.',
#  'A Global Peer-to-Peer and Peer-to-Group Learning Platform that helps students supplement their academic & competitive exam prep.',
#  'Arogya MedTech is a Research & Development organization in Bio-Medical industry.',
#  "Propshop24, a one-stop shop for a handpicked selection of 'fun'tastic products from around the world.",
#  'To bring health issues to people in their language.',
#  'MissMalini Entertainment is a multi-platform new media network dedicated to Entertaining, Connecting & Empowering young Indians.',
#  'Rooter is a mobile-based platform',
#  "Zest is India's first completely automated consumer digital lending platform.",
#  'Advancing AI compute',
#  'MyDentistChoice is a direct sales and distribution of dental equipment and accessories from top name manufacturers',
#  'Sattviko fosters wellness and shares Indianness through the Sattvik way of cooking that is wholesome and tasty!',
#  'Investment Management Platform',
#  "Bombay Shaving Company is a Men's grooming startup",
#  'Medcords is India’s first holistic healthcare ecosystem on a cloud platform that makes health management easier',
#  'University Living is an online global student housing marketplace.',
#  'Food and Beverage startup focussing on developing products using ayurveda with modern science for women empowerment and fitness.',
#  'Enakshi is an online apparel brand for women.',
#  'Ultraviolette is a startup working on electric two-wheelers and energy infrastructure.',
#  'Inthree Access is an impact venture that connects the most inaccessible rural markets with products that can transform lives in Rural India.',
#  'BUGWORKS is a drug discovery company.',
#  "GNC is a leading global specialty retailer of health and wellness products that takes pride to be the world's largest company",
#  'PrestLoans New age tech driven RBI regd NBFC helping businesses by providing easy, quick n hassle free loans.',
#  'Data Intelligence Publishing Platform, We bring the best resources to learn valuable technologies which will shape tomorrow.',
#  'India Accelerator runs mentorship-driven incubation and acceleration programs for start ups.',
#  'HappyEMI is a point of sale digital lending platform that helps consumers finance their purchases in-store and online',
#  'Premium Personal Assistance service',
#  'Hansel, a mobile app management platform, provides the infrastructure that companies need, in order to personalize product experiences.',
#  'Propelld is a student education financing platform.',
#  'Digital Marketing powered by Data & Technology; fueled by Design thinking',
#  'ZiffyHomes is a technology driven marketplace to find out home on rent.',
#  'Carmesi is a brand of high-end menstrual-hygiene products in India.',
#  'OckyPocky is a interactive and personalised language learning app for preschool kids.',
#  'Racetrack is a sales and support-focused AI-driven platform designed for education, real estate, and e-commerce sectors.',
#  'WHR is to make affordable healthcare a reality for all. Our vision is to make healthcare services easier, better and more accessible.',
#  'Asteria Aerospace is a robotics and artificial intelligence company.',
#  'FabAlley is the ultimate Indian fashion destination for fashion-forward, indie-chic girls. Founded in 2012, Tanvi Malik and Shivani Poddar',
#  'Tranzmeo Connect : is A Complete Comprehensive Anomaly forensic Solution with Actionable Insights.',
#  'SBI Life is one of the life insurance company that offers a range of life insurance plans and policies to protect you and your family.',
#  'Studds Accessories is a scooter accessories service provider in India',
#  'Design + Execution Organization that delivers beautiful & innovative designs for Home Interiors, in any budget.',
#  'NoPaperForms is a marketing automation, lead nurture and enrolment management platform for educational institutions',
#  'Rays Power Infra is a leading integrated Solar Power Company.',
#  'SaaS, B2B, Security, Stop account sharing, Fraud Detection',
#  'Vernacular Social Network Focused on Town Level Content and Interactions',
#  'Lets transport is a logistics solution provider.',
#  'Next Digital Solutions is website design & Digital Marketing development company.',
#  'Portea Medical is the largest and fastest growing provider of in-home medical care in India today with a 24-city network.',
#  'Aavas Financiers is engaged in the business of providing housing loans, primarily in the un-served, unreached and under-served market.',
#  'Swiggy is a food ordering and delivery company that provides food service solutions for restaurants.',
#  'Milkbasket delivers milk, bread, eggs, butter, juices and other daily need items, every morning, right at your doorstep, free of charge.',
#  'Nutrisattva is a protein innovation compan',
#  'Toppr.com is an online preparation platform for entrance exams in India.',
#  'Jagaran Microfin is a Microfinance institution which achieves a healthy amalgamation of social and financial',
#  'Vivriti Capital is an online platform for institutional debt in India.',
#  "Be U is India's first subscription based Salon Chain.",
#  "We're a Harvard incubated crowdfunding platform for nonprofits, social enterprises, startups and individuals.",
#  'MobiKwik is a payments backed fintech platform in India. MobiKwik App offers instant loans & investment products to the 500M masses of India',
#  'Stones2milestones is a Gurgaon Based Learning Company.',
#  'Generico is the fastest growing specialized pharmacy retail chain of Generic medicines.',
#  'Adiuvo Diagnostics is a medical diagnostic device company based in India.',
#  'DataTrained is a educational platform, which operates an ed-tech startup on data science',
#  'OneAssist is a protection & assistance services platform.',
#  'Satin is a non-banking finance company providing individual loans to urban shopkeepers.',
#  'APAC Financial Services is a financial services platform.',
#  'Moglix is a supplier of industrial tools like hand tools, power tools, electrical, and safety equipment.',
#  'SEDEMAC Mechatronics is technology company that distributes control-intensive products for automobiles.',
#  'MadGuy Labs is a Online Test-prep Platform.',
#  'Dee Dee Labs is design and development lab with a primary focus on the development of next generation of bionic prostheses.',
#  'FLEECA is a Tyre Care Provider company.',
#  '#1 Online Selling App. India’s leading social commerce platform. Setup free online store in 2 min. Sell own goods or resell Shop101 Supply.',
#  'On Demand Staffing Platform',
#  'Housejoy is a web-based platform that allows individuals to browse and book service providers for their homes.',
#  'Ambee is an Environment analytics startup.',
#  'FoodBuddy is a online food delivery portal, providing boundary breaking delivery.',
#  'Ninjacart is a B2B agri-marketing platform that connects vegetables and fruits farmers directly with businesses.',
#  "Olly is a digital credit card for India's working masses and young people.",
#  'No-Code Workflow Automation. Build enterprise applications in days with AI, Cognitive Automation, Collaboration and more built in.',
#  'BYJU’s is an edtech company that is reinventing how students learn through its learning app.',
#  'Wakefitkart is a mattress manufacturing company. We manufacture the best quality mattresses at affordable prices.',
#  'Hero Electric, a 100% subsidiary of the Hero Group, is a pioneer in the Indian Electric Vehicle Industry.',
#  'Pentation as an Insurtech enables insurers and intermediaries with our Insurance Analytics Suite- an Insurance specific AI/ML Software Suite',
#  'PerkFinance partners with employers to provide affordable loans to their employees at no cost to the company',
#  'Roposo - TV by the People is a unique social media platform where people express visually with homemade videos and photos.',
#  'Plum Haircare Is Silicone-Free & Sulphate-Free. Designed For Damaged & Dandruff-Free Hair',
#  'Drstore is a exclusive e- commerce platform.',
#  'Wow Venue is an online platform.',
#  'Chizel is a worlds most advanced cloud platform for on-demand manufacturing in 3D Printing and CNC Machining',
#  'OTO Capital is a platform that allows you to own a car faster than ever.',
#  'boodmo.com - large online marketplace for auto parts in India.',
#  'Khabri is a digital audio platform for content in vernacular.',
#  'MyNewCar.in offers new cars at best price with great deals. Book a new car online or request a doorstep test drive',
#  'A daily fantasy sports platform.',
#  'PlanetSpark is an after-school Maths and English learning program for pre teen kids between Grades 2nd to 7th.',
#  'WheelsEMI is the brand name of NBFC, WheelsEMI Pvt. Ltd.',
#  'FiiRE, a technology business incubator helps the startup process to move from the garage to the lab.',
#  'OYO is an Indian hospitality startup that operates a network of budget hotels.',
#  'Quikr is a free classifieds and online marketplace that helps users sell, buy, rent, or discover anything across India.',
#  'Tabono is a one stop environment for all your fitness solution.',
#  'Learnapp.co - Video courses & live classes in investing, trading, banking and finance.',
#  'Shopkirana connects brands and traditional retailers with the help of technology and supply chain innovation.',
#  'Fric Bergen is a leader in the specialty food industry.',
#  'Articbot is a conversational AI platform for automated customer support and lead generation',
#  'India’s most advanced ERP system for the real estate',
#  'Fusion Microfinance Pvt. Ltd. is an NBFC registered with RBI',
#  'Anytime Doctor is a Software company.',
#  'Go Payments was founded with the mission of assisting consumers with performing a whole host of financial services at their doorstep.',
#  'We build In-Destination Experiences!',
#  'A stealth startup building a layer of infrastructure for highly efficient energy storage systems.',
#  'SaaS to verify counterfeit',
#  'Gov-Tech',
#  'Smarter analytics to understand how each customer uses your product. Drive growth in conversion, retention and engagement.',
#  'Saas, Web App, Mobile App, School Education',
#  'Snapmint facilitates simplified, fairly-priced and hassle-free EMI options without a Credit Card.',
#  'Ai platform for Art and Creative Community',
#  'Stethoscope for customer feedback !',
#  'Credy is a fintech platform that connects borrowers seeking capital with lenders seeking market beating returns.',
#  'iChamp is an e education innovation product from RNM E-Services Pvt Ltd.',
#  'A cloud-based HR management and employee engagement platform.',
#  'Avishkaar Box is just not another box full of material rather it is a well researched, thought through solution',
#  'A Mumbai-based startup Electric Vehicle (EV) & Energy Storage company.',
#  "hyperXchange is India's fastest growing O2O marketplace for premium refurb gadgets",
#  'Deftouch is a mobile game development company that currently focuses on winning the Cricket gaming market with a social multiplayer game.',
#  "Doodhwala is an online milk delivery startup that offers over 70 varieties of milk along with a plan based on clients' requirement.",
#  'DronaHQ is an enterprise mobile engagement platform.',
#  'FastFox: Market Network for Home Rentals (India)',
#  "BuyForexOnline.com is India's first completely online provider for buying Foreign Exchange.",
#  'A technology powered network of Branded Serviced Homes conveniently located near educational institutions & workplaces.',
#  'Online marketplace where farmers and traders can sell their produce to B2B buyers',
#  'Corefactors is a leading campaign management, business communication and analytics company.',
#  'A startup in the personal finance space in India .',
#  'Bengaluru based biotech startup.',
#  'Shirsa Labs is a cognitive skill assessment and training portal that provides children with fun educational games.',
#  'Gurugram-based Online petcare platform.',
#  'Awwaz.De develops inclusive mobile solutions that enable organizations to achieve last-mile connectivity for social impact.',
#  'PinkBlue.in - Super-efficient supply-chain for clinical supplies',
#  'Eduvanz is new, innovative finance company, which is completely revolutionizing the student loan market.',
#  'Rupeek is an asset backed online lending platform currently operating in the space of Gold loans.',
#  'Backpacker Panda is creating an ecosystem for youth accommodation and travel.',
#  'Physical education start up',
#  'Placio is a student housing and a complete broker-free platform.',
#  'Delhi based housing finance company.',
#  'A Robotic Company.',
#  'HeyHolidays, a global player in online vacation rentals.',
#  "Amazon's Kindle Direct Publishing for Indian Languages",
#  'SectorQube develops smart kitchen devices that make food automatically.',
#  'Iconic Indian Delicacies from the most renowned vendors of India Delivered Globally.',
#  'Zamroo is a growing mobile marketplace that allows users to buy and sell locally.',
#  'Silversparro is a deep learning technology solution provider.',
#  'A coworking space provider.',
#  'Emflux Motors is committed to bring clean and sustainable energy into a state of universal acceptance through technological innovation.',
#  'Predictive Healthcare Analytics Company',
#  'Virtual/Augmented Reality Start Up .',
#  'A fashion enterprise that provides a launchpad to fashion talent and brands using a tech enabled platform',
#  'Chrysalis (EZ Vidya) is India’s leading educational research and innovation organization',
#  'EKincare empowers you to take charge of your health by enabling you to monitor critical medical info and make it available anywhere.',
#  'Live stream music from nightclubs, bars & festivals!',
#  'Groww offers a new way of investing money.',
#  'Cell Propulsion is an electric mobility startup that designs autonomous electric vehicles.',
#  'Chezuba is a web-based platform enabling skilled professionals to volunteer online with Non-profits worldwide',
#  'Ontrack provides affordable independent transport to those dependent on cabs and autos for commute by renting bikes on a monthly basis.',
#  'Wealthtrust offers a wealth manager application that enables its users to invest and manage their investments online.',
#  'Faclon is an IoT and data analytics based tech startup building products to make cities and villages smart.',
#  'Operations and manpower outsourcing startup',
#  'World-class Enterprise System for Education.',
#  'Zyla is transforming the way healthcare is delivered in India with specific focus on high-risk chronic patients.',
#  'Get your daily dose of interest as summaries from news and magazine stories .',
#  'Rubix Total App makes it effortless for Institutes to send home important information and updates about the day’s learning experiences.',
#  'Be Smart, Work on Contract,Be Smart, Hire on Contract',
#  'Algorithmic trading platform.',
#  'NiYO is a fintech company that helps salaried employees access company benefits and other financial services.',
#  'A video recording and sharing software.',
#  'Satvacart is a Gurgaon’s largest online supermarket',
#  'Sports Nutrition startup',
#  'A Delhi-based Augmented Reality and Virtual Reality technology development company.',
#  'MY CHIRAAG CAB SERVICES PVT LTD',
#  'It operates a business-to-business e-commerce portal for food and beverages.',
#  'FInd your Customized Home here.',
#  'True elements offers a range of high-quality snacks and supplements that are inspired by natural foods consumed by our ancestors.',
#  'Trendlyne Technologies is a stock market analytics platform and marketplace for retail investors.',
#  'Planys Technologies is India’s first and only manufacturer of compact ROVs providing underwater robotic inspection and survey solutions.',
#  'HealthPlix is a healthtech startup',
#  "dishq leverages food science and machine learning (AI) to understand and predict people's tastes.",
#  'The boundaries between Human and Machines are shrinking fast.',
#  'myHQ turns your everyday coffee space into a perfect work zone. Get an amazing work environment without paying any rent.',
#  'Trell is a location based network which helps you in exploring amazing experiences and annotating places around you.',
#  'Building future human capital through 21st Century Skills programs for K-12',
#  'Log 9 Materials is a nano-materials manufacturing and RnD startup',
#  'VTION is a media technology innovation firm aiming to solve key problems in the media based ecosystem.',
#  'New Apartments, Flats for Sale in Bangalore',
#  'It is a fabless semiconductor company focused on CMOS millimeter wave products for Radar.',
#  'RupeeCircle is a new age finance company.',
#  'Woodenstreet.com ensures to fulfill customer’s unique furniture requirements by crafting one-of-a-kind furniture pieces.',
#  'The Ken is India’s first subscriptions-only business news site',
#  "SaffronStays connects travellers to India's Incredible hosts.",
#  'A personal network for close people',
#  "Foyr.com is India's first online, automated interior designer",
#  'MEngage is a mass consumer engagement application for doctors on both android and IOS platforms.',
#  'Inner Being Wellness manufactures beauty, wellness, and nutrition products.',
#  'Kobster is a pioneer of B2B eProcurement and an eMarketplace providing Corporates an end-to-end solution for their procure-to-pay cycle.',
#  'Wishberry is a rewards-based crowdfunding platform that enables users to raise funds for their creative and innovative ideas.',
#  'McXtra is a digital insurance broking startup.',
#  'Magic Crate is a theme based stimulating, fun and learning activity box for 4-8 year olds that is mailed to your doorstep every month.',
#  'It is a Virtual Reality Solutions StartUp',
#  'SEO, PPC, Search Engine Marketing, Social Media Optimization, Content Marketing, Brand Reputation Management',
#  'Digital Marketing Agency',
#  'Scale Labs is a cross border e-commerce solutions provider that drives global trade for brands.',
#  'HungerBox is a full stack B2B F&B technology company delivering food solutions for the corporates in India.',
#  'BBK delivers both authentic taste of Hyderabadi and Lucknowi Biryani prepared in individual earthen Handis with the freshest ingredients.',
#  'Wholesome Habits (EAT Anytime) is a healthy snacks Company.',
#  'Car Service and Bike Service Mobile App',
#  'Fixpocket is a internet-based startup.',
#  'Edureka is the fastest growing online learning platform that offers live, instructor-led courses for professionals from various industries.',
#  'Hashtag Loyalty is a customer engagement and marketing automation tool for local businesses.',
#  'WOW, as customers react to his studiously taught, trained, polite and courteous nature.',
#  'ZunRoof is a rooftop focused solar startup.',
#  'Eggoz is a full-stack layer poultry business operator & service provider .',
#  'Personal Finance',
#  'GalaxyCard is a mobile based Instant credit card.',
#  'IndiQube is a provider of co-working spaces based in Bengaluru.',
#  'A food processing enterprise registered with StartUp India .',
#  'NirogStreet is an Ayurvedic doctor discovery and appointment booking platform where patients can easily find doctors and fix consultation.',
#  'Pixr8 is a global media platform dedicated to Start-ups and business organisations for promoting entrepreneurship work.',
#  'Nivesh.com is a mass market mutual funds investment platform.',
#  'A fully functioning cell culture facility and molecular biology setup.',
#  'Poshmiles aims to help point travellers to long weekend trips at popular and undiscovered destinations based on budget & interest.',
#  'A campus recruitment solution provider.',
#  'Orbo is a computer vision and deep facial technology company.',
#  'Inntot Technologies, is a technology driven company.',
#  'Zoctr Health Network is a first-of-its kind pan-India Home & Telehealth Company',
#  'Hey Deedee is a Mumbai-based company that provides solutions to parcel delivery problems.',
#  'A technology company focused on introducing products that will accelerate and enhance sales productivity and effectiveness .',
#  'Locus is an intelligent logistics automation platform.',
#  'Sports Flashes operates a sports content app that provides sports news, live scores, fantasy gaming, expert views, trivia, and more.',
#  'Inc42 is one of the leading tech media publications of India.',
#  'A stock photo startup based in Amravati, Andhra Pradesh.',
#  'A coworking incubator Company.',
#  'HR Technology start-up.',
#  'Cash Suvidha is an Digital Lending Platform that provide working capital finance to SMEs and MSMEs in India.',
#  'Providing financial access to the millions of mobile users in India using alternative credit assessment',
#  'Carmel Organics is an India-based herb company engaged in sourcing, processing, and distributing herbal tea ingredients.',
#  'Transforming the way businesses deliver. Work-force & fleet mobility tools.',
#  'A digital news platform.',
#  'Creditas was set-up in 2015 with an aim to help Financial Institutions find better ways to reach and interact with their customers.',
#  'UrbanPiper offers restaurants and chains with a suite of products to manage and analyze their online presence.',
#  'Doxper is Health tech startup which has created a digital pen and coded paper system for doctors to record patient information',
#  'i2ifunding is an online marketplace that connects borrowers looking for personal loans with investors looking for alternative investments.',
#  'Home of B2B Commerce',
#  'HelloVerify is an online background check platform.',
#  'Climate Smart Precision Agriculture Platform',
#  'CoinGeto is one of India’s most advanced digital assets exchange.',
#  'Avail is a mobile-first platform aiming to financially include the urban mass of India.',
#  'Radical Travel Automation - Cloud Based Corporate Travel & Expense Management Software',
#  'Wedeterna is a new-age, personalised and fresh approach to arranged marriages, DIY matrimonial community with only self created profiles.',
#  'Stumagz is about connecting with Stories Stumagz is about collaborating with people Stumagz is about creating a Cult.',
#  'Gurgaon based E-learning platform.',
#  "MCaffeine is India's First Caffeine Infuse Personal Care Brand. It's an extension to the hyperactive lifestyle and individualistic identity.",
#  'A Bengaluru-based fraud analytics solution provider .',
#  'HealthAssure provides access to Discounted & High Quality primary care medical network.',
#  'Operator of low-cost mobile cinema theatres in rural areas.',
#  'Equity crowd funding platform focused on connecting investors with a host of extremely promising Indian start-ups and early stage ventures',
#  'Professional Drones for Enterprise Applications',
#  'Wellthy is a digital therapeutics company focused on improving patient health through the intersection of technology, and clinical outcomes.',
#  'Nua is an e-commerce and feminine care brand platform focused on creating women care products.',
#  'An online platform for mutual fund investments.',
#  'Livehealth is an end-to-end collaborative report management solution. We help you get your medical reports instantly from various health',
#  'An agricultural inputs startup Company.',
#  'Ora is an online marketplace of unique accommodations. Awarded as among top 3000 startups in India by IIM Kolkata.',
#  'Buddy4Study is the best scholarship search engine for Indian students. It also helps organizations to set up their own scholarship schemes.',
#  'Healthcare devices for cancer detection',
#  'Syncremedies is an Integrated Medicine service that brings together Allopathy, Ayurveda and Homeopathy to treat chronic ailments.',
#  'Bluleaf Cyberspace is Cloud Based Software Company.',
#  'Toffee is a bite size, micro-event & contextual insurtech startup which aims to de-jargonise the insurance buying experience.',
#  'Online wealth management platform',
#  "HealWell24 is India's emerging technology-empowered healthcare company, aiming to bring world-class quality healthcare services anywhere.",
#  'Acko General Insurance is a digital insurance company in India that redefines insurance for the consumers.',
#  'E-commerce website promising the best price on any product a consumer buys anywhere on the internet.',
#  'A clean tech product Company',
#  'DheeYantra is building a cognitive conversational chatbot platform by name "dhee.ai" for vernacular languages',
#  'Edyoo.com is a technology platform that offers the most intuitive design, flexibility, and ease of use.',
#  'Chtrbox connects social media influencers with brands .',
#  'Provide housing finance to those in the informal sector enabling the hither to un-served to own a home of their own.',
#  'BetterPlace provides businesses with contractor workforce management, including onboarding, training, and background checks.',
#  'A P2P Lending Platform connecting millions of financially under-served & new to credit borrowers with investment savvy lenders in India',
#  'Easy video creation for social media.',
#  'FreightBazaar.com is an online platform that connects Truck suppliers with Truck users.',
#  'Open up to a new world of Banking',
#  'Hospital & Health Care Start up',
#  'Earth Food is a healthy Food Start Up.',
#  'Charcoal Eats aims to bring Dominos style standardisation.',
#  'A platform for people to express their opinions in form of short videos around any topic.',
#  'Fast growing Influencer Marketing platform in India.',
#  'Software for the new-age freight',
#  'Finwego partners with Small and Medium Businesses in India to offer convenient and responsible credit to their employees',
#  'Cricnwin is a Gurugram - based Fan Engagement Platform',
#  'Peer-to-Peer motor vehicles sharing',
#  "India's Go to Career Commerce Portal",
#  'Eruditus, promoted by Alumni of INSEAD and other top business schools, delivers high quality executive education programmes',
#  'Gaia Smart Cities is an early leader in the rapidly-emerging Internet of Things (IoT) marketplace.',
#  'Delivering Imagination',
#  "UrbanClap is India's leading managed marketplace for home services.",
#  'Hospals is a medical tourism company.',
#  'Kogta Financial (India) Ltd is a retail-focused non banking financial company .',
#  'An Education Management startup.',
#  'The Souled Store bring to you awesome t-shirts, framed prints, badges, notebooks, coasters.',
#  'Enabling diversity of opinions in organizations',
#  "Drivezy is India's largest vehicle sharing platform which helps people turn their vehicles into earning members of their family.",
#  'Freyr Energy is a company that provides full service solar provider based in Hyderabad, India.',
#  'NIRAMAI has developed a novel breast cancer screening solution that uses Thermalytix.',
#  'Cloudsek is an Infosec Risk assessment company which provides intelligence needed to tackle online threats.',
#  "Lendbox is India's leading peer-to-peer lending online lending platform.",
#  'Verloop is an automated customer support and engagement platform.',
#  'Flickstree is a smart video content aggregator, powered by Artificial Intelligence.',
#  "India's Leading Property Rent management platform",
#  'Idha skin clinic jayanagar is dedicated to restore health and natural beauty to your skin.',
#  'InCred Finance is a mumbai-based non-banking financial company',
#  'Vedantu provides personalized LIVE Online Tutoring. Vedantu aims to democratize teaching by creating a marketplace of Teachers',
#  'Sportido is a sports discovery app that helps you find people and places to play 700+ sports around you.',
#  'Stelis Biopharma is a vertically integrated biopharmaceutical company',
#  'Magicpin is a platform where users and merchants in a locality discover, interact, and transact.',
#  'Try & Buy',
#  'Mech Mocha is a mobile gaming startup based in Bangalore working towards ‘Making India Play’ .',
#  'Aye Finance provides financial services to micro and small businesses in Northern India.',
#  'Mobile Wallet Focusing on hassle free checkout via Finger Print & OTP.',
#  'Completely automated remote control system.',
#  "Signzy are creating 'building blocks for a Digital Trust system.",
#  'A Mumbai-based fin-tech startup',
#  'Cloudnine is an Indian chain of women and child care hospitals.',
#  'To discover, develop and deliver innovative solution in Agtech Space',
#  'BillDesk, a property of IndiaIdeas.com Ltd. was conceived in early 2000 to solve the frustrations of most of us when it comes to paying',
#  'Yaantra, India’s leading mobile phone repair, refurbished & Unboxed centre In India',
#  'Techbooze[1] "AN OPEN FORUM" is an educational enterprise, headquartered in India working across the country.',
#  'HealthifyMe is an application that allows its users to achieve their fitness and weight loss goals from their computers and smartphones.',
#  "India's first hotel dedicated food brand which promises great in room dining experience in budget hotels",
#  'Perpule is a self-checkout product for retail outlets to enhance the shopping experience of the customers.',
#  'Royal Sundaram provides comprehensive insurance plans and innovative insurance solutions to individuals, families and businesses.',
#  'CleanseCar is a company provides Washing and Repair Services.',
#  'DriveU is a convenient and a quick way of getting on demand drivers for consumers and businesses',
#  'Used cars marketplace in India. Ushering new era of transparency and convenience.',
#  'Asset Reconstruction Company (India) Ltd. operates as a asset reconstruction company.',
#  'Wellness, Specialised Testing, Healthcare at Home',
#  'Dunzo is an app that connects you with the nearest available delivery partner to pickup or deliver items for you.',
#  'Mobile Premier League(MPL) is a skill based E-Sports platform where you can play your favourite mobile games and win real cash always.',
#  'Wal-Mart India Private Limited is a wholly owned subsidiary of Walmart Stores Inc.,',
#  'Cred is a platform to celebrate and reward the most creditworthy people of India.',
#  'Meesho is an online reseller network of housewives and SMBs, who sell products within their network on social channels.',
#  'Bhaskarguru.com is your local search Engine',
#  "Gugu designs & Sells all Electric Connected Two-wheeler's with Network of Open & Free Fast charging Stations across India.",
#  'Farm Taaza provides expert advice to the farmers on improving the yield and improving the field operations of the farmer.',
#  'Autonomous Drone Solutions for last mile delivery as well as search and rescue',
#  "BIGPHI technologies is the India's first technologically advanced apparel and wearable company.",
#  "India's 1st Dockless Bicycle Sharing App",
#  'AI based Business Travel & Expense management',
#  'Em Personal Care is a Cosmetic products manufacturing Company.',
#  'Lucideus is a cybersecurity company that offers its customers with consultancy, training, and solutions to counteract cyber-attacks.',
#  'Eupheus Learning offers a seamless integrated learning solution for the K-12 market in India.',
#  'GamingMonk is an eSports gaming company based out of New Delhi, India.',
#  'Sukkhi Jewellery is a Contemporary fashion jewellery brand.',
#  'INDwealth is an Artificial Intelligence (AI) powered wealth management company',
#  "India's largest medical and surgical supplies marketplace",
#  'NIRA promotes financial inclusion by creating simple, transparent products that empower individuals to live a life of choice and freedom.',
#  'Duroflex Pvt. Ltd. operates as a dominant mattress player.',
#  'A biotechnology start-up was incorporated to improve the National Hygiene condition whilst addressing the aspect of water conservation.',
#  'Jetbrain Robotics is Hong Kong / Gurgaon based company, building advanced robotic transportation solutions for multi speciality hospitals.',
#  'MediMetry is an online platform where patients can consult specialists doctors online - from anywhere, at anytime.',
#  'The one stop shop for health, fitness & beauty.',
#  'Indiabulls Ventures Limited is one of India’s leading capital market companies providing securities and derivative broking services.',
#  'Vistara is a joint venture of Tata Sons Limited and Singapore Airlines Limited (SIA)',
#  'ClearTax India helps individuals prepare and e-file their Income Tax Return online.',
#  'Shuttl provides an app-based office shuttle service to make daily commute safe, reliable, affordable and dignified for everyone.',
#  'A one of its kind digital integrated platform connecting tutors and students.',
#  'Azure Power produces and distributes solar power to commercial, government, and utility customers in India.',
#  'Cube is consumer banking focused fintech company.',
#  'RAHI Care is a Health Care company.',
#  'Mynvax is a biotech Company.',
#  'Loans4SME is an alternative lending platform.',
#  'UpCyclersLab is a startup that makes sustainability-based learning tools for children above the age of five.',
#  'Cellerite Systems is a charging solutions provider for electric vehicles.',
#  'Taru Naturals is a network that connects farmer communities with clean technology and renewable energy.',
#  'LetsMD.com is a marketplace for elective surgeries',
#  'Twenty Two Motors aim of making cutting edge EV technology affordable for the current generation.',
#  'Truebil is a team of young, highly motivated professionals who strive to help you buy and sell used cars in the simplest way possible.',
#  'FarmersFZ is an online venture for fresh and safe vegetables and agri products.',
#  'worxogo’s is a pioneering persuasive technology products align employee behaviours .',
#  "India's leading mobile based security management solution .",
#  'Singularity Dynamics is a Chip-design testing startup.',
#  'Virtual MetalStreet(Metalstreet) is a B2B marketplace for steel trading in India',
#  'Veritas Finance has been promoted with a primary purpose of meeting the working capital and business credit requirements of the small bus.',
#  'Manjushree Technopack is a Rigid plastics packaging convertor in India and South Asia.',
#  'Startup working on a white space in the eCommerce industry.',
#  'Zomato is a search app offering detailed information for restaurants as well as online food delivery.',
#  'Innov8 is a Y- Combinator backed company that offers coworking and shared office spaces.',
#  'RevFin is a digital lending company.',
#  'Lavelle Networks provides Software Defined WAN (SD-WAN) Solutions to build end to end Enterprise Networking Platforms for tomorrow',
#  'Blackbuck is a logistics startup based in India.',
#  'Cardekho is a car search venture that helps users buy cars that are right for them.',
#  'ElasticRun develops an online system that improves the reception of orders from customers and the dispatch of delivery drivers in India.',
#  'Droom is a marketplace for automobiles and automobile services.',
#  'Vogo is a dockless scooter rental company in India which lets customers rent scooters for short one way trips.',
#  'InnerChef is an online food discovery and delivery experience that will make the foodie in you come alive.',
#  'LivQuik was incorporated with the vision to simplify payments for merchants and consumers in an increasingly digital world',
#  'Disprz is a one-of-its-kind “knowledge-tech” start-up that strives to make people knowledgeable, productive and smarter at what they do.',
#  'Online gaming startup.',
#  'Origo Commodities, a complete post-harvest management services for agricultural commodities, is the fastest growing company in its sector.',
#  'Good quality, strategically located homes closer to work for millennials',
#  'Vahdam Teas is a vertically integrated online-first tea brand that sources premium garden fresh teas direct from over 150+ tea plantations.',
#  'A social networking app that lets you create and view Spoofs of your favourite videos.',
#  'Strom Motors is a smart urban mobility Company.',
#  'PharmEasy - Indias largest healthcare delivery platform',
#  'Licious is an online meat and fish ordering startup that solves existing problem of finding safe, delectable, trustworthy fresh meat.',
#  'Stanza Living is a co-living platform created for students moving to a new place.',
#  'Docturnal, an online platform, enables individuals to find information and diagnostic services related to diabetes, cancer, and more.',
#  'Bounce (formerly Metro Bikes) is an urban mobility solution that makes daily commute stress-free, time-saving, reliable, and convenient.',
#  'Technology 9 Labs is an Information Technology and Services company.',
#  'Goals101 is a one of the fastest growing big-data platforms.',
#  'New Delhi-based non-banking financial company.',
#  'Ummeed Housing Finance Private Limited',
#  'StockEdge is a unique platform, which is 100% focused on research and analytics',
#  'Sequretek is a cyber security start-up.',
#  'Avenues Payments is an IT solutions provider for the remittance\\money transfer and forex industries.',
#  'Qbera is a managed marketplace for unsecured personal loans.',
#  'Urban Ladder is a Bangalore-based online furniture company.',
#  'Planet11 is backed by SK Planet, which is a part of the SK Group – one of the largest conglomerates in South Korea.',
#  'Daily Ninja, a mobile app that delivers daily needs on a subscription model',
#  'Iba Halal Care is a cosmetics brand company.',
#  'Knocksense is a fast growing lifestyle website.',
#  'Togedr is an activity discovery & booking platform.',
#  'Parkwheels aims at solving the big, bad & unsexy parking problems of India.',
#  'ShareChat is a social networking and regional content platform for the fast growing Internet users in India.',
#  'Medtech startup working on clinical and wearable diagnostic and rehab products for neuro vestibular disorders using eye tracking technology.',
#  'Livspace is the new online shopping destination where you can design, decorate and furnish your dream home.',
#  'NewsBytes provides your everyday news in a contextual timeline to reduce information overload.',
#  'Leena is smart AI powered HR companion dedicated towards engaging employees.',
#  'Max Healthcare is one of the leading chain of hospitals in India.',
#  'Delhi-based logistics technology.',
#  'GoGaga is a new age dating app that has removed the mindless swiping on strangers and connects users through their network and find matches.',
#  'Mate Labs is a machine learning solutions platform for beginners.',
#  'Furlenco is a Bangalore-based company that offers a home furniture subscription program.',
#  'Ola is a mobile app that brings together cab drivers and customers using technology to make transportation hassle-free in India.',
#  "DocPrime offers a one-stop healthcare solution right at the comfort of patients' homes.",
#  'CLP India Pvt. Ltd. is a foreign investor in the Indian power sector.',
#  'Xplorabox is as an educational activity box subscription startup aiming to revolutionize the early education industry.',
#  'Myra is a unique solution of technology and operations that makes buying medicines fast and efficient.',
#  "India's Largest Peer-to-Peer Knowledge Sharing Platform in Indian Languages.",
#  'Kissht is a financial technology platform that enables instant, seamless credit for consumers to make purchases at digital points of sales',
#  'Upwards Fintech financial company.',
#  'Bon, a Pune-based FinTech firm was created to bring financial services to the gig-economy workforce.',
#  'Mamaearth is an online retailer specializing in baby and toddler products.',
#  "BabyChakra is India's largest & most loved platform to discover the right maternity and childcare.",
#  'Belstar Investment and Finance Private Limited is a provider of scalable microfinance services to entrepreneurs.',
#  'Koku Gamer is an online platform that offers gaming related news, editorials, reviews, previews, and other content.',
#  'Moonshine Meadery is a first craft meadery.',
#  'Verzeo is anAI-focussed edtech startup.',
#  'Haazri is a tea and snack quick service restaurant startup',
#  'To create pervasive network where connections are simpler, more powerful, more affordable, more global and more available to all.',
#  'Flyrobe is an on-demand apparel rental platform that provides premium designer wear.',
#  'Edutech',
#  'Dream11 is India’s Biggest Sports Game with 30 million+ users playing Fantasy Cricket, Football, Kabaddi and NBA.',
#  'SRJNA is a brand of Elation Edtech Pvt. Ltd., which helps schools to integrate hands on, affordable and turnkey STEM.',
#  'Nykaa.com is a premier online beauty and wellness destination',
#  'Chaayos was born in November 2012 out of this premise - a contemporary interpretation of the chai adda.',
#  'Heelium is an athletic footwear and wearable startup with primary focus on sports safety and sustainability.',
#  'LT Foods believe that nature will continue to nurture us until we as a species continue to breathe and live.',
#  'Free language learning platform.',
#  'Uttar Pradesh based online eyewear marketplace.',
#  'NewsHunt is a Bangalore based eBooks company.',
#  'SlicePay is an AI based instant credit app for youngsters in India.',
#  'Udaan is a B2B trade platform, designed specifically for small and medium businesses in India.',
#  'HappyEasyGo is an online travel domain.',
#  'Mombay is a unique opportunity for housewives to start household food business and avail everyone with their homemade healthy dishes.',
#  'Droni Tech manufacture UAVs and develop software to service a range of industry requirements.',
#  "Welcome to India's most convenient pharmacy!",
#  'Provides a range of male grooming products',
#  'A learning platform that provides topic-based journey, animated videos, quizzes, infographic and mock tests to students',
#  'It aims to make learning fun via games.',
#  'Provides interior designing solutions',
#  'It is a seed company engaged in production, processing and marketing of seeds',
#  'A drone automation platform',
#  'It builds software products that makes work simpler, pleasant, and productive',
#  'It is a product-based cybersecurity solutions provider',
#  'It is an AI and big data services company providing business solutions.',
#  'It is a eyewear company',
#  'A B2C\xa0\xa0brand that focusses on premium and comfortable merchandise for Generation Alpha – kids',
#  'It is a self-healing enterprise, the IT operations software detects, predicts and prevents problems before they happen',
#  'Platform that provides complete financial solutions for excluded individuals and households',
#  'Technology-based platform that is connecting suitable applicants to the right recruiters',
#  'It produces and sells top quality snacks',
#  'Grants small business loans, supply chain finance and working capital loans to small and medium enterprises',
#  'Provides online learning classes',
#  'Uses AI to do risk profiling of e-commerce consumers who opt for EMI',
#  'Offers a range of robotics learning tools',
#  'Aims to solve some problems in the feminine hygiene sector',
#  'A platform that promotes financial well-being of employees at workplace',
#  'Delivers advanced medical care & clinical excellence aided by next-level technology',
#  'Offers online courses and extensive mentor-based learning',
#  'It uses technology to create a trust-based network of responsible citizens to ensure safety',
#  'It solves inadequacies in the healthcare delivery system through technology',
#  'Customer Experience (CX) Automation platform',
#  'Provides variety of insurance plans and policies',
#  'Developer of an artificial intelligence-powered assistant for businesses',
#  'Offers B2B tech platform to corporates, aimed at improving the operations of their cafeterias',
#  'B2B platform for agricultural commodities.',
#  'Online meat shop',
#  'A global platform for Identity and Access Management',
#  'B2B model for appliances and electrical products',
#  'Develops drones that are used by the military, paramilitary, police forces and in various industries.',
#  'It offers delivery services across India to retail, e-commerce, pharmaceutical, automobile and FMCG companies',
#  'Online flight booking',
#  'Provides facilities to get products manufactured.',
#  'Creates a voice AI platform',
#  'Online fruits and vegetables delivery company',
#  "It empowers moms to provide the best of foods to their Lil' ones",
#  'Blogging platform that enables people to create visual collections of their travel and local experiences',
#  'A short video platform',
# ...
#  'Tring is a celebrity engagement platform, for all occasions including birthday, anniversaries, get well soon messages.',
#  'Rare Planet sells handicrafts made by local artisans.',
#  "GoodGamer is India's first Daily Fantasy Sports and true Esports gaming platform.",
#  'A building a portfolio of novel medical devices designed, engineered, and priced for global Emerging Markets.',
#  'Software that uses computer vision to recognise products without barcodes',
#  'Slintel, a leader in capturing technographics-powered buying intent, helps companies uncover the 3% of active buyers in their target market.',
#  'SoOLEGAL is a global integrated directory of lawyers, legal aid organizations, and Law firms.',
#  "India's Activity Hub for Kids",
#  "Supplynote is India's leading procurement platform with a unique stack of SAAS and E-commerce to solve the procurement problem",
#  "India's largest cloud based digital discovery and services provisioning platform for the taxi rental",
#  'ShopUp provides easy access to B2B sourcing, last-mile logistics, digital credit, and business management solutions to small businesses.',
#  'Energy-efficient solutions based on the Artificial Intelligence, Machine Learning and Internet of Things technology,',
#  'Zomato is a food delivery and restaurant discovery site that provides information and reviews about restaurants.',
#  'Developer of an android application designed for businesses to sell online.',
#  'India’s Only 100% Inspected and Certified Used Bikes Marketplace.',
#  'An agritech company that provides business to business (B2B) agricultural data',
#  'RACEnergy builds and deploys battery swapping infrastructure for use in various segments of vehicles.',
#  "A homegrown fitness startup that aims to advance the 'Fit India' initiative by offering holistic and affordable workouts.",
#  'Provide quality and healthy food products',
#  "India's Finest Specialty Tea company.",
#  'Fleetx is an intelligent data platform which uses AI, machine learning, sensors and predictive analytics to help fleet owners.',
#  'Tech platform helping millions of renovation contractors, property improvement professionals and businesses manage their business digitally.',
#  'Retail Video Analytics SaaS product',
#  'AVATAAR.ME is a deep-tech 3D AR platform which delivers personalized fashion discovery experience to users on mobile devices.',
#  'Arrival is a technology company that specializes in developing electric vehicles.',
#  'Cover Genius provides an insurance distribution platform designed to protect the customers of e-commerce companies',
#  'Phononic Vibes introduces a new patented technology for vibration and noise control and isolation, with a circular economy approach.',
#  'MikeLegal is an AI powered legal associate that aims to build an ecosystem of legal tools',
#  'Clair is a social fintech that provides Instant Pay Access as a Service for human capital management and gig platforms.',
#  'Gourmet Garden is a global market leader in chilled convenient packaged herbs.',
#  'Miko is an advanced robotics startup founded by three IIT Bombay post-graduates on the pillars of robotics, AI & IoT.',
#  'Razorpay is a platform that enables businesses to accept, process, and disburse payments.',
#  'Ninjacart is a business-to-business fresh produce supply chain that connects farmers, manufactures, and brands to retailers directly.',
#  'Wow! Momo is a chain of fast-food restaurants that specializes in momos.',
#  'Pepper Content is a Content-Mediation Platform that connects talented writers to organisations that require content.',
#  'Livspace is an interior design startup that offers a platform that connects people to designers, services, and products.',
#  'Acculi Labs is a clinical grade smartphone based diagnostic tool',
#  'Your.MD is a platform committed to helping a billion people find their health by unlocking self-care with digital technology.',
#  'Developer of memory-based technology intended to solve issues of advanced computing.',
#  'A helping hand to the farming community through Artificial Intelligence',
#  'The team aims to bridge the gap for credit cards and make them more accessible for people across different regions.',
#  'CreditWise Capital is a consumer finance company.',
#  'Chargebee is a PCI Level 1 certified subscription and recurring billing system for SaaS and subscription based eCommerce businesses',
#  'Reliance Retail offers online shopping and a chain of neighborhood stores, supermarkets, and wholesale/specialty stores.',
#  'Winuall specializes in the fields of E-learning, online quizzes, and tests, study material for competitive exams.',
#  'GenRobotic specializes in powered robotic exoskeletons with RC controlled humanoid robotic systems and Artificial Intelligence.',
#  'An online platform where both owners and tenants find help in making sure their rental transaction are safe and secure.',
#  'Ergos is building an integrated supply chain by setting up micro warehouses.',
#  'Krishi-Tantra is an Agri-IoT startup building farm automation for controlled agricultural environment.',
#  'PakkaProfile bridges the gap between companies and the workforce by making better, unbiased decisions with the help of psychometric games',
#  'Monet Networks Using sentiment and non verbal cues analysis for increased engagement and real time content feedback.',
#  'Unocoin is an Indian bitcoin processor that enables users to buy, sell, store, use, and accept bitcoins.',
#  'Pesto is a career accelerator for software engineers with the mission to take opportunities to places where talent exists.',
#  'Bambrew is an online shop for reusable bamboo straws.',
#  'Omnify is a Global SaaS platform for Small Services Business',
#  'The gaming company mostly focused on fantasy football games',
#  "Treebo is India's tech-enabled, asset-light affordable accommodation brand.",
#  'To solve the urban waste problem by utilising local technologies and business models.',
#  'Video-led social app Public provides users with a platform to share and view important hyperlocal videos',
#  'Legal Salah is bringing the provision of imparting value based legal and consultancy services to the user.',
#  'FanPlay Technologies operates as a real-money gaming startup.',
#  'Eco friendly zero power zero maintenance sewage treatment plant in India.',
#  'Coralogix is a log analytics SaaS platform that improves the delivery and maintenance process for software providers.',
#  'Equiwatt is a digital platform enabling households to get paid for saving energy at peak times.',
#  'Zhangmen is an online tutoring platform provides tutoring courses to students.',
#  'Agrowave engages in transforming agriculture supply chain by connecting farms to businesses.',
#  'Sapio Analytics provides AI-powered policymaking solutions for government institutions.',
#  'Taimei Technology provides a cloud platform for clinical research collaboration.',
#  'Avanse, regulated by the Reserve Bank of India, is an education finance company that operates as a non-banking finance company (NBFC).',
#  "India's largest industrial ecommerce platform",
#  'Hopscotch provides an insider access to international brands for babies, kids, and moms.',
#  'Pristyn Care is Health Care Startup that is disrupting Day Care Procedures.',
#  'Wooden Street is a online furniture platform that provides custom made & ready to order furniture.',
#  'Acko General Insurance is a private sector general insurance company in India.',
#  'Invento Robotics specializes in developing service robots intended for customer interactions.',
#  'Infurnia Technologies is an eponymous cloud-based architecture design software platform.',
#  "SuperCric is India's first strategy Cricket Manager simulation game",
#  'Snowflake is a cloud data platform that provides a data warehouse-as-a-service designed for the cloud.',
#  'GenieTalk as a virtual assistant uses AI to bring conversation commerce with a personalised experience on the app.',
#  'Classplus offers a mobile-first SaaS platform for 3000+ tutors to offer their curriculum and operations completely online.',
#  'Mobile Premier League(MPL) is a skill based E-Sports platform where you can play your favourite mobile games',
#  'Fourth Partner Energy provides turnkey rooftop solar energy solutions for customers in India.',
#  'Flipkart is an e-commerce marketplace that offers over 30 million products cross 70+ categories.',
#  'Vivriti Capital is a marketplace for small enterprises and individuals that lack efficient access to financial services.',
#  'The funding for branding and marketing activities as well as strengthening the product and technology teams',
#  'An Intelligent Patient Relationship Management (PRM) system for hospitals and other healthcare providers in India.',
#  'An Indian educational technology and online tutoring firm',
#  'Melorra is an operator of an online jewelry store that is used to offer contemporary jewelry.',
#  'Reliance owns businesses across India engaged in energy, petrochemicals, textiles, natural resources',
#  'Experienced Venture Capital-General Partner focused on Technology investments.',
#  'A Bangalore based biotechnology company with focus on tissue engineering and regenerative medicine.',
#  'AI-enabled network of speakers and thought leaders, aka. experts',
#  'Provides News, Jobs, Information & Entertainment on WhatsApp, Absolutely free',
#  'NewsReach India offers partner publications a digital footprint',
#  'Dream11 is India’s Biggest Sports Game with 30 million+ users playing Fantasy Cricket',
#  'An AI-powered SaaS platform for corporate risk and due diligence for a comprehensive financial, legal, regulatory, and reputational risk analysis',
#  'Gaming and entertainment startup',
#  'VestaSpace Technology specialises in making small satellite platforms for commercial and scientific applications.',
#  'Dozee offers health and wellness monitoring products.',
#  'Known for its larger brands – Faasos, Behrouz Biryani, Oven story and Mandarin',
#  'Cosmetics & beauty products online',
#  'Crowdfunding, Charity, E-commerce',
#  'Banks that extends two distinct fixed deposit schemes',
#  'Venture Partners',
#  'Unacademy is an Indian online education technology company',
#  'Commercial Real Estate, Commercial Property Investment, Best Long Term Investments',
#  'Use transformative capital and a deep involvement strategy to help Indian entrepreneurs',
#  'WE HUB is the first-of-its-kind and only State-run platform for Women Entrepreneurs.',
#  'Get online food delivery from restaurants near you',
#  'A deep tech startup pioneering in motion-based interfaces and insights.',
#  'Gaana is a commercial music streaming service providing free and licensed music.',
#  'A pioneering organization in the farming-as-a service (FaaS) space',
#  'Shampoos, Conditioner & Hair Mask For Healthy, Happy Hair',
#  "India's first do-it-yourself warehouse management system.",
#  'Captures real-time data on crop growth conditions using on-farm sensors and delivers advisories to farmers in Indian languages',
#  'Transportation, logistics services & cargo services.',
#  'Check your latest Credit Score and get your Credit Report online in India for Free',
#  'A leader in crafting stylish, high-quality, eyewear at affordable prices.',
#  'Grinntech has a range of Lithium-ion batteries which sets new standards in Electrical safety, Energy density, Durability',
#  'CreditMantri is a provider of comprehensive Credit Analysis and Credit Improvement programs.',
#  'Given the rising trend in the number of tea stalls in the city',
#  'Deepsync is a revolutionary way to record your content, without you really speaking.',
#  'The company’s vision is simple – Connected Healthcare.',
#  'Retailer delivering superior value to its customers, suppliers and shareholders.',
#  'A platform that helps kids learn about life skills',
#  'Pitstop owns and operates a network of garages that provides car repair, detailing',
#  'Operates on a SaaS model by providing a hyper-personalised website to users.',
#  'Nirmata offers a complete solution for Kubernetes management and deployment for cloud-based apps',
#  'HireMeCar.com offers customers the fastest and easiest way to plan road travel.',
#  'ShipsKart platform that streamlines the way marine stores are ordered, approved and received on board with the help of technology.',
#  'Empowering consumer businesses to improve their sales conversions and funnel efficiency, using Artificial Intelligence & Data Science.',
#  'Financepeer is an AI based peer to peer lending platform.',
#  'Cashify.in is an e-commerce platform for reselling used electronic gadgets.',
#  'Etrio is an electric vehicle company in India with tata ace electric, Electric Tata ace HT',
#  'Codeyoung provides live online coding classes for kids between the age of 5 - 17.',
#  'Live online coding courses with social learning. Build coding skills, confident communication and leadership skills with your very own coach.',
#  "India's Only Business School That Offers MBA & PGDM Programs With 100% Placement Assurance.",
#  'Infilect Technologies specialises in visual content intelligence by parsing large-scale visual content such as photos and videos',
#  'An ecommerce platform for refurbished electronics.',
#  'Samunnati is a financial service provider focused on agri value chains.',
#  'Startup working dedicatedly in the area of healthcare-therapeutic solutions.',
#  'Yummy Corp is a food & beverages company that provides delicious, fresh, and creative food solutions for everyday corporate and group needs.',
#  "Smallcases are portfolios of stocks or ETFs created by India's top financial experts.",
#  'Clairvolex is an IP solutions company that manages IP assets of large corporations using an IPAM model.',
#  'Assiduus leverages its eCommerce experience to help build, grow and scale your brand on various eCommerce platforms',
#  'Brinton is one of the fastest growing Pharmaceutical Companies spreading its network worldwide.',
#  'AFK Gaming is a media and entertainment and gaming company located in Mumbai.',
#  'Infarm builds and distributes highly efficient vertical farms throughout cities to grow fresh produce right in your neighbourhood.',
#  'Zuper is a productivity suite for service businesses to mobile field workforce and automate all business operations.',
#  'The charioteer of your growth at all times.',
#  'To deliver a solution that will provide shopping convenience to every consumer in India',
#  'A technology-enabled platform that helps MSMEs to increase their business efficiency through collection of dues',
#  'Mobile Premier League is the mobile e-Sports platform based in India.',
#  'Offer various development solutions and mainly focus on helping startups',
#  'Onsitego is a customer service company for device and appliance repairs.',
#  'Precily is Artificial Intelligence platform for enterprises that increases efficiency of workforce by providing AI based solutions.',
#  'SmartClean Technologies is an AI company that offers data-driven cleaning operations designed for facilities.',
#  'AI-driven influencer marketing platform ClanConnect.ai, which helps brands make their campaigns more data and result-oriented',
#  'Servify is a self-learning platform that provides device management services and warranty solutions.',
#  'ShareChat is a social networking and regional content platform.',
#  'Rephrase.ai helps in creating high-quality videos and animations through an AI-powered visual dubbing tool.',
#  'Buy Latest Gold, Diamond & Gemstone Jewellery Designs Online Rings, Earrings, Necklace',
#  'FabHotels is a network of 3 star budget hotels in India',
#  'EkAnek Networks is a new startup that is focused on building the ecosystem for new age brands in lifestyle categories',
#  'Cub McPaws is a kids clothing brand.',
#  'Employee experience platform that empowers organizations to manage and retain great talent!',
#  'Pumpumpum is a car rental company',
#  'Burgerama is a unit of Junket Foods Private Limited',
#  'The Moms Co. creates a safe and natural formulated products for babies that are certified toxin-free',
#  'A service that promotes and facilitates the works of independent comic artists',
#  ...]

# %% [markdown]
# ##### Cleaning the Year Column

# %%
# Round all values in the 'Founded' column to the nearest whole number
df['Funding_Year'] = df['Funding_Year'].round()

# View unique values in the 'Founded' column after rounding
df['Funding_Year'].unique()
# Out:
# array([2018, 2019, 2020, 2021], dtype=int64)

# %% [markdown]
# ##### Cleaning Founded Column

# %%
# Get unique values in the Founded column
unique_Founded = df['Founded'].unique()

# Convert the unique values array to a list``
unique_Founded_list = unique_Founded.tolist()

# Print the list of unique Founded
unique_Founded_list
# Out:
# [nan,
#  2014.0,
#  2004.0,
#  2013.0,
#  2010.0,
#  2018.0,
#  2019.0,
#  2017.0,
#  2011.0,
#  2015.0,
#  2016.0,
#  2012.0,
#  2008.0,
#  2020.0,
#  1998.0,
#  2007.0,
#  1982.0,
#  2009.0,
#  1995.0,
#  2006.0,
#  1978.0,
#  1999.0,
#  1994.0,
#  2005.0,
#  1973.0,
#  2002.0,
#  2001.0,
#  2021.0,
#  1993.0,
#  1989.0,
#  2000.0,
#  2003.0,
#  1991.0,
#  1984.0,
#  1963.0]

# %%
df['Founded'].value_counts()
# Out:
# Founded
# 2019.0    285
# 2020.0    278
# 2015.0    276
# 2018.0    272
# 2016.0    228
# 2017.0    209
# 2014.0    137
# 2021.0     76
# 2012.0     73
# 2011.0     67
# 2013.0     64
# 2010.0     34
# 2008.0     34
# 2009.0     15
# 2007.0     10
# 2006.0      9
# 2000.0      6
# 2004.0      4
# 2002.0      3
# 1998.0      3
# 1999.0      3
# 1994.0      3
# 1989.0      2
# 1995.0      2
# 2005.0      2
# 1978.0      2
# 1973.0      1
# 2001.0      1
# 1993.0      1
# 1982.0      1
# 2003.0      1
# 1991.0      1
# 1984.0      1
# 1963.0      1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector          Stages
# 0   250000.0      Seed          2018  Software & Technology      Validation
# 1   584000.0      Seed          2018            Agriculture      Validation
# 2   949000.0  Series A          2018     Financial Services  Early Traction
# 3  2000000.0     Angel          2018     Financial Services      Validation
# 4        NaN      Seed          2018      Commerce & Retail      Validation

# %%
# Filter the data where the "Founded" column contains NaN values
df[df['Founded'].isna()]
# Out:
#           Company_Name  Founded   Location  \
# 0      TheCollegeFever      NaN  Bangalore
# 1      Happy Cow Dairy      NaN     Mumbai
# 2           MyLoanCare      NaN    Gurgaon
# 3          PayMe India      NaN      Noida
# 4             Eunimart      NaN  Hyderabad
# ...                ...      ...        ...
# 1043            Quicko      NaN  Ahmedabad
# 1044  Satin Creditcare      NaN    Gurgaon
# 1050      Leverage Edu      NaN      Delhi
# 1051             EpiFi      NaN  Ahmedabad
# 137      Smart Express      NaN     Mumbai
#
#                                                  Sector  \
# 0     Brand Marketing, Event Promotion, Marketing, S...
# 1                                  Agriculture, Farming
# 2      Credit, Financial Services, Lending, Marketplace
# 3                           Financial Services, FinTech
# 4                    E-Commerce Platforms, Retail, SaaS
# ...                                                 ...
# 1043                                           Taxation
# 1044                                            Fintech
# 1050                                             Edtech
# 1051                                            Fintech
# 137                                           Logistics
#
#                                            What_it_does  \
# 0     TheCollegeFever is a hub for fun, fiesta and f...
# 1     A startup which aggregates milk from dairy far...
# 2             Leading Online Loans Marketplace in India
# 3     PayMe India is an innovative FinTech organizat...
# 4     Eunimart is a one stop solution for merchants ...
# ...                                                 ...
# 1043            Online tax planning and filing platform
# 1044                            A micro finance company
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 137   India’s Most Innovative and Awarded Express Lo...
#
#                              Founders                          Investor  \
# 0                                 NaN                           Unknown
# 1                                 NaN                           Unknown
# 2                                 NaN                           Unknown
# 3                                 NaN                           Unknown
# 4                                 NaN                           Unknown
# ...                               ...                               ...
# 1043               Vishvajit Sonagara                        Rainmatter
# 1044                             None                     Austrian Bank
# 1050                Akshay Chaturvedi                    Blume Ventures
# 1051  Sujith Narayanan, Sumit Gwalani                    Ribbit Capital
# 137                    Yogesh Dhingra   Smiti Holding & Trading Company
#
#           Amount       Stage  Funding_Year            Main_Sector  \
# 0       250000.0        Seed          2018  Software & Technology
# 1       584000.0        Seed          2018            Agriculture
# 2       949000.0    Series A          2018     Financial Services
# 3      2000000.0       Angel          2018     Financial Services
# 4            NaN        Seed          2018      Commerce & Retail
# ...          ...         ...           ...                    ...
# 1043    280000.0                      2020     Financial Services
# 1044  15000000.0                      2020                   None
# 1050   1500000.0                      2020                   None
# 1051  13200000.0  Seed Round          2020                   None
# 137   10000000.0        Seed          2021              Transport
#
#               Stages
# 0         Validation
# 1         Validation
# 2     Early Traction
# 3         Validation
# 4         Validation
# ...              ...
# 1043         Unknown
# 1044         Unknown
# 1050         Unknown
# 1051      Validation
# 137       Validation
#
# [768 rows x 12 columns]

# %% [markdown]
# ##### Filling the Null sin the Value Founded cloumn.
# #####  Assumption: We made an assumption that all the values within the founded column with nulls should be replaced by   the corresponding year the company received funding.

# %%
def replace_founded_nulls(df):
    founded_column = df["Founded"]
    for i,year in enumerate(Founded):
        if pd.isnull(Funding_Year):
             # Replace null value with corresponding value in funded_year column
             df.at[i,"Founded"] = df.at[i, "Funding_Year"]
    return df

# %%
# call the function replace_founded function
# Assuming df is your DataFrame
df
# Out:
#          Company_Name  Founded   Location  \
# 0     TheCollegeFever      NaN  Bangalore
# 1     Happy Cow Dairy      NaN     Mumbai
# 2          MyLoanCare      NaN    Gurgaon
# 3         PayMe India      NaN      Noida
# 4            Eunimart      NaN  Hyderabad
# ...               ...      ...        ...
# 1204         Gigforce   2019.0   Gurugram
# 1205           Vahdam   2015.0  New Delhi
# 1206     Leap Finance   2019.0  Bangalore
# 1207     CollegeDekho   2015.0   Gurugram
# 1208           WeRize   2019.0  Bangalore
#
#                                                  Sector  \
# 0     Brand Marketing, Event Promotion, Marketing, S...
# 1                                  Agriculture, Farming
# 2      Credit, Financial Services, Lending, Marketplace
# 3                           Financial Services, FinTech
# 4                    E-Commerce Platforms, Retail, SaaS
# ...                                                 ...
# 1204                              Staffing & Recruiting
# 1205                                   Food & Beverages
# 1206                                 Financial Services
# 1207                                             EdTech
# 1208                                 Financial Services
#
#                                            What_it_does  \
# 0     TheCollegeFever is a hub for fun, fiesta and f...
# 1     A startup which aggregates milk from dairy far...
# 2             Leading Online Loans Marketplace in India
# 3     PayMe India is an innovative FinTech organizat...
# 4     Eunimart is a one stop solution for merchants ...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                            Founders          Investor      Amount  \
# 0                               NaN           Unknown    250000.0
# 1                               NaN           Unknown    584000.0
# 2                               NaN           Unknown    949000.0
# 3                               NaN           Unknown   2000000.0
# 4                               NaN           Unknown         NaN
# ...                             ...               ...         ...
# 1204    Chirag Mittal, Anirudh Syal   Endiya Partners   3000000.0
# 1205                     Bala Sarda          IIFL AMC  20000000.0
# 1206     Arnav Kumar, Vaibhav Singh      Owl Ventures  55000000.0
# 1207                   Ruchir Arora       Man Capital  26000000.0
# 1208  Vishal Chopra, Himanshu Gupta   Kalaari Capital   8000000.0
#
#              Stage  Funding_Year            Main_Sector          Stages
# 0             Seed          2018  Software & Technology      Validation
# 1             Seed          2018            Agriculture      Validation
# 2         Series A          2018     Financial Services  Early Traction
# 3            Angel          2018     Financial Services      Validation
# 4             Seed          2018      Commerce & Retail      Validation
# ...            ...           ...                    ...             ...
# 1204  Pre-series A          2021      Business Services      Validation
# 1205      Series D          2021        Food & Beverage         Scaling
# 1206      Series C          2021     Financial Services         Scaling
# 1207      Series B          2021                   None         Scaling
# 1208      Series A          2021     Financial Services  Early Traction
#
# [2873 rows x 12 columns]

# %%
#### This code efficiently categorizes startups into "Early Stage" or "Established" based on their founding year compared to the median year

# %%
df['Founded'].unique()
# Out:
# array([  nan, 2014., 2004., 2013., 2010., 2018., 2019., 2017., 2011.,
#        2015., 2016., 2012., 2008., 2020., 1998., 2007., 1982., 2009.,
#        1995., 2006., 1978., 1999., 1994., 2005., 1973., 2002., 2001.,
#        2021., 1993., 1989., 2000., 2003., 1991., 1984., 1963.])

# %%
# Round all values in the 'Founded' column to the nearest whole number
#df['Founded'] = df['Founded'].round()

# View unique values in the 'Founded' column after rounding
#df['Founded'].unique()

# %%
# Convert 'Founded' column to datetime with format '%Y'
#df['Founded'] = pd.to_datetime(df['Founded'], format='%Y').dt.year

# Assuming df is your DataFrame
#df['Founded'] = pd.to_datetime(df['Founded'], format='%Y', errors='coerce')


# Check the data type and other info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2873 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2873 non-null   object
#  7   Amount        2319 non-null   float64
#  8   Stage         2873 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
#  11  Stages        2873 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 291.8+ KB

# %% [markdown]
# ##### Cleaning the Founders Column

# %%
# Get unique values in the Founders column
unique_Founders = df['Founders'].unique()

# Convert the unique values array to a list``
unique_Founders_list = unique_Founders.tolist()

# Print the list of unique Founded
unique_Founders_list
# Out:
# [nan,
#  'Shantanu Deshpande',
#  'Adamas Belva Syah Devara, Iman Usman.',
#  'Jatin Solanki',
#  'Srikanth Iyer, Rama Harinath',
#  'Narayana Reddy Punyala',
#  'Nitin Gupta',
#  'Vivek AG, Veekshith C Rai',
#  'Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa',
#  'Renuka Ramnath',
#  'Peyush Bansal, Amit Chaudhary, Sumeet Kapahi',
#  'Abhay Bhat, Kinnar Shah',
#  'D Padmanabhan',
#  'Puneet Gupta, Sucharita Mukherjee',
#  'Ishit Jethwa',
#  'Ahana Gautam, Udit Kejriwal',
#  'Rakesh Malhotra',
#  'Byju Raveendran',
#  'Chapman, Priya Sharma, Ashish Anantharaman',
#  'Amit Modi',
#  'Mohammed, Shashwat Diesh',
#  'Renato Araujo',
#  'Harsimarbir Singh, Dr Vaibhav Kapoor, Dr Garima Sawhney',
#  'Gautam Tambay, Parul Gupta',
#  'Dhiraj Naubhar, Dheeraj Bansal',
#  'Tushar Kumar, Prashant Singh',
#  'Arihant Jain, Ajeet Kushwaha',
#  'Nishant Jain, Rohan Kumar',
#  'Sam Udotong',
#  'Sandipan Mitra, Uttam Kumar',
#  'Nukul Upadhye, Mahesh Jakhotia, Jitender Bedwal, Daya Rai, Nikhil Tripathi',
#  'Vivek Gupta, Abhay Hanjura',
#  'Babu Dayal, Pramod Uniyal, Lalit Mehta',
#  'KS Bhatia',
#  'Neel Mehta, Nihar Vartak',
#  'Deepak Garg, Gazal Kalra',
#  'Vivek Prabhakar, Boris Zha',
#  'Amit Acharya, Srinath Ramakkrushnan',
#  'Swapnil',
#  'Rajendra Lora',
#  'Pulkit Agrawal, Prashant Sachan, Arun Lodhi, Bimal Kartheek Rebba',
#  'Akshay Narvekar',
#  'Deepak Anchala',
#  'Parshavv Jain& Raju Kushwaha',
#  'Rachna Suneja',
#  'Vaibhav Gupta, Himanshu Devra, Pranav Chaudhary, Nishtha Gupta',
#  'Devendra Gupta, Prateek Singhal, Vivek Pandey',
#  'Amit Raj, Anshul Gupta',
#  'Annanya Sarthak, Gurpreet Singh, Praveen Sah',
#  'Manish Taneja, Rahul Dash',
#  'Sanjay Bhatia, Bharat Tanvi, Punit Java',
#  'Shashank Murali, Binay Krishna, Arjun Krishna',
#  'Jignesh Mehta, Shailen Mehta',
#  'Thirukumaran Nagarajanin, Vasudevan Chinnathambi',
#  'Rubianca Wadhwa, Sahil Wadhwa',
#  'Manish Kumar',
#  'Akanksha Hazari',
#  'Mayank Dhanuka, Sunoor Kaul',
#  'Sawan Kumar, Bhavya Bhambhani',
#  'Krishnan, Manju Dhawan, K Satyanarayana, Sanjeev Saxena',
#  'Sandeep Dalmia, Anindya Dutta',
#  'Visakh Sasikumar',
#  'Saurav Kumar',
#  'Malika Sadani',
#  'Dhruv Ratra, Swati Vyas',
#  'Ashish Bhatia, Himanshu Gupta',
#  'Manan Khurma',
#  'Anurag Garg, Sridhar Srinivasan',
#  'Team of Waterloo-based software developers',
#  'Amit Jain',
#  'Abhishek Bansal, Vaibhav Khandelwal',
#  'Mittal',
#  'Neeraj Aggarwala, Akhil Ramachandran',
#  'Sumit Sinha',
#  'Sarvesh Shashi',
#  'Paddy Padmanabhan',
#  'Akhil Sikri, Nikhil Sikri, Sneha Choudhry',
#  'Bhavish Aggarwal, Ankit Bhati',
#  'Greg Moran, David Back',
#  'Pavan Kushwaha',
#  'Jeevan Chowdary M, Harshit Harchani',
#  'Aaditya Sharda, Souvik Sengupta',
#  'Ritesh Agarwal',
#  'Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh Karwa',
#  'Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mohit Gupta',
#  'Rajendra Setia',
#  'Prasanna Manogaran, Bharani C L',
#  'Saurabh Dixit, Gurudutt Upadhyay',
#  'Ajinkya Dhariya',
#  'Ritesh Tiwari',
#  'Ashish Rajan Singh, Harshit Gupta, Nishant Mahatre, Tauseef Khan',
#  'Rubal Chib, Dr Srishti Batra',
#  'Ajay Sakhamuri',
#  'Shawrya Mehrotra',
#  'Amar Prabhu, Ashwin Soni, Sumit Maniyar',
#  'Aditya Shirole, Sahil Sharma',
#  'Meghana Narayan',
#  'Arjun Kumar, Arun Kumar, Sidharth Gurjar',
#  'Gayatri Jolly',
#  'Ankur Jain',
#  'Akil Sethuraman, Anup Gopinath, Rachna Rao',
#  'Deepinder Goyal, Gaurav Gupta, Pankaj Chaddah',
#  'Miran Junaidi, Saurabh Ghanekar, Sourav Sanyal',
#  'Gautam Kapoor, Saahil Goel, Vishesh Khurana',
#  'Amrish Rau',
#  'Prashant Agarwal',
#  'Parth Chadha, Rahul Singh',
#  'Vikrant Varshney',
#  'Sujit Bangar',
#  'Karanpal Singh',
#  'Neeraj Khandelwal, Sumit Gupta',
#  'Naveen Tewari',
#  'Virendra Gupta',
#  'Priyam Saraswat',
#  'Kapil Bharati, Mohit Tandon, Sahil Barua, Suraj Saharan',
#  'Chattanathan Devarajan, Prasanna Rao, Anand Chandra',
#  'Ankit Kaushik, Gaurav Mangla, Rhitiman Majumder',
#  'Burzin Engineer, Rahul Chari, Sameer Nigam',
#  'Nirmal Shah',
#  'Chetan Indap, Sunny Sharma, Deepanti Kavi',
#  'Suhail Narain',
#  'Ronak Sarda',
#  'Vinayak, Kshitij Abhishek, Apoorv Sadana',
#  'Ankit Garg, Chaitanya Ramalingegowda',
#  'Dr Prashant Soma',
#  'Tikam Jain',
#  'Sundeep Mohindru',
#  'Shivakumar Ganesan',
#  'Adarsh Kumar, Rupesh Mishra',
#  'Mihir Jha',
#  'Shivanand N',
#  'Anand Dalmia, Ramganesh Iyer, Subramanya S.V., Subramanya Venkat',
#  'Anoop Gautam',
#  'Raunak Bhinge',
#  'Ajay Tiwari, Sainadh Duvvuru',
#  'Mayank Kale, Ryan Singh',
#  'Anurag Meena, Nikunj Malpani, Pratik Lodha',
#  'Satya Chakravarthy, Pranjal Mehta',
#  'Divyanshu Damani, Mohammad Hasan',
#  'Charak Almast, Aastha Almast, Mani Dev Gyawali',
#  'Bipin Singh, Upasana Taku',
#  'Sumit Sanjay Singare',
#  'Monnappa Bayavanda, Prashant Reddy, Ravindra M.K, Ravindra M.K., Shesh Paplikar, Shesh Paplikar, Sridhar Venkataraman',
#  'KSHITIJ Puri, Shalabh Singhal',
#  'Vivek Iyer',
#  'Manjunatha T N, Shilpa Gopalaiah',
#  'Layak Singh',
#  'Puneet Singh Jaggi, Sanjay Bhasin, Ram Menon',
#  'Nandini Sankar',
#  'Tanmai Paul, Varun Saxena',
#  'Abhas Saroha, Oliver Jones, Oliver Jones',
#  'Shan Kadavil',
#  'Shivam Varshney, Alok Chawla',
#  'Manoj Meena, Sibabrata Das',
#  'Sankar Bora, Sourjyendu Medda, Vineet Rao',
#  'Anugrah Shrivastava, Rohan Gupta, Vasanth Kamath',
#  'Soham Thacker, Valay Patel, Varun Gajjar',
#  'Kalyan Sivasailam',
#  'Harsh Rajat, Richa Joshi',
#  'Biplab Chakraborty, Sandipan Chattopadhyay, Sandipan Mandal, Tapan Barman',
#  'Palani Rajan',
#  'Karthik Jayaraman, Sanjay Dasari',
#  'Sanjeev Bikhchandani',
#  'Neha Kant, Pankaj Vermani',
#  'Satyam Baranwal, Vivek Prakash',
#  'Kunal Shah',
#  'Brahmanad, Ramakrishna Nishtala',
#  'Nitesh Agrawal, Om Prakash',
#  'Rohit Pande, Shikhar Sachan',
#  'Prabhat Sahu',
#  'Ankit Ratan, Ankur Pandey, Arpit Ratan',
#  'Amit Shrivastava, Sumeet Verma',
#  'Bhavik Rathod, Tripti Ahuja',
#  'Vikas Chawla, Abhay Parnerkar, Satyajit Ram',
#  'Rahul Veerwal',
#  'Sai Srinivas Kiran G, Shubham Malhotra',
#  'Sonu Sood',
#  'NAVEED AHAMED, SYED SAQQA ABBAS',
#  'Darshan Shah, Soniya Kundnani',
#  'Akash Sinha, Reeju Datta',
#  'Anand Agrawal, Mayank Khera, Rishabh Goel',
#  'Devashish Fuloria, Tusheet Shrivastava, Ankita Thakur',
#  'Chakradhar Gade, Nitin Kaushal',
#  'Chirdeep Shetty',
#  'Mehul Agrawal, Ruchit Agarwal, Vikram Chopra',
#  None,
#  'Divij Bajaj',
#  'Advaith Vishwanath, Ankit Agrawal, Jerin Venad, Rushabh Shah, Sankalp Kelshikar, Subhash Sundaravadivelu',
#  'Pushpak Dagade, Jimmit Patel and Suraj Bathija',
#  'Rajith Nair',
#  'Amit, Rohit Sadhu, and Vikas Ranga',
#  'Dhruv Agrawal, Himanshu Gupta, Soham Chokshi',
#  'Rushabh Mehta',
#  'Rohin Y, PV Ramana',
#  'Nikhil Aggarwal, Vivek Gulati',
#  'Gaurav Munjal, Hemesh Singh, Roman Saini, Sachin Gupta',
#  'Arpit Mittal, Anshul Gupta',
#  'Abhishek Poddar, Saurabh Arora',
#  'Shashank Vaishnav, Vinay Singhal, Parveen Singhal',
#  'Falguni Nayar',
#  'Snehanshu Gandhi, Gaurav Shrishrimal',
#  'Rohit Sen, Nupur Gupta',
#  'Aditya Sharma, Jayesh Hans',
#  'Byju Raveendran, Divya Gokulnath',
#  'Anurag Saboo, Gaurav Pushkar',
#  'Govind Balachandran, Zakir Wahab, Piyush Arora',
#  'Gowtham Sundaresan, Azan Barodawala',
#  'Nikhil Bohra',
#  'Sharmin Ali, Sutanshu Raj',
#  'Yogesh, Mitesh Gangar',
#  'Aditya Sengupta, Akash Gehani, Harshad Sharma, Sampad Swain',
#  'Anand Prabhudesai, Dhirendra Mahyavanshi, Kunal Shah',
#  'Dhruv Madhok, Dhruv Bhasin',
#  'Cheolwon Lee, Jay Yi, Martin Lee',
#  'Dhruv Dewan, Krishi Fagwani',
#  'Lakshay Jain',
#  'Nived Narayanan',
#  'Sandeep Patel',
#  'Tanmaya Jain',
#  'Ashwin Lal',
#  'Khushnud Khan, Rishi Raj Rathore',
#  'Deepak Diwakar, Krishna Depura, Mohit Garg, Nishant Mungali',
#  'Deepak Malhotra, Rajan Bajaj',
#  'Kashif Mohammad, Aravind Maddireddy',
#  'Ashish Rawat',
#  'Shrishti, Prithika',
#  'Ishpreet Gandhi',
#  'Ankur Bansal',
#  'Kiran Mazumdar-Shaw',
#  'Abhishek Doshi, Anupama Panchal, Shashwat Bhatt, Yash Shah',
#  'Amitava Saha, Supam Maheshwari',
#  'Amit Kumar, Gunjeet Singh',
#  'Ashraf Biran, Gulshan Bakhtiani, Mohan Chavan',
#  'Param Singh, Aashna Singh, Abhijeet Mittal, Jitesh Arora',
#  'Gunjan Kejriwal, Utsav Tiwary',
#  'Vinamra Pandiya, Mayank Gupta, Joji George',
#  'Pallav Pandey, Ankur Pandey, Siddharth Singh',
#  'Anup Kumar',
#  'Punweet Singh, Shuchir Suri',
#  'Sujay Santra',
#  'Mikhil Raj, Shubhadit Sharma, Ishaan Preet Singh',
#  'Mukesh Ambani',
#  'Saurabh Uttam, Ravi Singhal',
#  'Arun Vinayak, Swapnil Jain, Tarun Mehta',
#  'Sriram Kannan, Surajit Das',
#  'Anjana Reddy',
#  'Vivek Bhutyani',
#  'Abhishek Negi, Aditya Singh, Pankaj Pandey, Uttam Kumar',
#  'Gireesh Rajendran, Ashish Lachhwani, Apu Sivadas, Rakesh Kumar and Alok Joshi',
#  'Kartikey Hariyani, Pavan Bakeri',
#  'Kavish Gadia, Nikhil Saraf',
#  'David Stavens, Mike Sokolsky, Sebastian Thrun',
#  'Abhijit Patil, Abhishek Tomar, Pankaj Raut',
#  'Ajay Nain, Prateek Chaturvedi',
#  'Abhishek Kabra, Aman Gour',
#  'Altaf Saiyed, Saloni Anand',
#  'Anurag Mehrotra, Krishnakant Thakur, Mohammed Bhol, Gautam Singh',
#  'Shivank Agarwal, Anish Khandelwal',
#  'Sahil Jatana',
#  'Ajay Kumar, Murari Singh',
#  'Adit Jain, Anand Prajapati, Mayank Goyal',
#  'HS Srinivasan, Krishnan Rajan, E.V. Shunmugam',
#  'Saurabh Gupta, Siddharth Swarnkar',
#  'Arun Mallavarapu, Prasanth Madavana',
#  'Adarsh Manpuria, Vaibhav Aggarwal',
#  'Chandrakanta, Rajendra Lora',
#  'Abhishek Kothari, Deepak Jain, Manish Lunia, Ritesh Jain',
#  'Nilay Pandey, Saurav Singh, Vivek Kumar',
#  'Siddharth Dialani, Sai Gole',
#  'Nirav Choksi',
#  'Rohan Dedhia, Vaibhav Saraf, Hrishabh Sanghvi',
#  'Mohit Sahney, Sunita Sahney',
#  'Mihir, Payoj Jain, Divyansh Bordia, Anshuman Kumar',
#  'Sachin Chhabra, Nidhi Ramachandran',
#  'Nilay Mehrotra',
#  'Aneesh Mathur',
#  'Aanan Khurma, Aditya Seth, Ripunjay Chachan',
#  'Ashish Jhina, Karthik Venkateswaran',
#  'Paavan Nanda, Saumya Singh Rathore',
#  'Tarun Sharma, Vikas Lachhwani',
#  'Rohan Nayak',
#  'Sagar Bhalotia, Anish Basu Roy',
#  'Advitiya Sharma, Gaurav Lahoti',
#  'Sunoor Kaul,',
#  'Amit Srivastava, Bhavik Vasa, Sachin Tagra, Sachin Tagra',
#  'Saurabh Tandan, Pravin Agarwala',
#  'Talha Shaikh',
#  'Harsh Vakharia, Pankit Chheda, Sanket Shah',
#  'Mayank Agarwal, Vaibhav Jain',
#  'Atul Monga',
#  'Meena Sankaran',
#  'Kasuhik Mukherjee, Vineeta Singh',
#  'Gomathi S, Dr Balaji Sampath',
#  'Guru Sankararaman, Jay Vijayan',
#  'David guerin',
#  'Amit mandahar, Chaitali roy',
#  'Anjan Panneer Selvam',
#  'Narayan Subramaniam, Niraj Rajmohan',
#  'Akshay Saini, Rahul Saini, Pranav Chabhadia',
#  'Ranodeep Saha, Vijay Kumar',
#  'Charles Creighton',
#  'Siraj Dhanani',
#  'Chris Sampson, Marcel Herz, Martin Karafilis',
#  'Deepak Anchala, Rahul Bhattacharya, Ranjana TN',
#  'Manish Kaul',
#  'Priya Goel Sheth, Harsh Jain',
#  'Abhishek Verma, Harshit Mittal, Kumar Kushang, Nitin Prakash',
#  'Pankaj Sharma',
#  'Afeef Zaman, Ataur Rahim Chowdhury, Siffat Sarwar',
#  'M R Srinivas',
#  'Subhash Choudhary, Suumit Shah',
#  'Nikhil Jain, Nittin Mittal, Sumit Chhazed',
#  'Sat Tomer, Yukti Gill',
#  'Arun Sreyas, Gautham Maheswaran',
#  'Dinesh Godara',
#  'Aayushi Khandelwal, Akhil Kansal, Kuldeep Parewa',
#  'Amit Dutta, Ashok Mittal',
#  'Abhay Jeet Gupta, Parveen Kataria, Udbhav Rai, Vineet Sharma, Vishal Mishra',
#  'Supratik Ghatak',
#  'Surender Gounder',
#  'Gaurav Baid',
#  'Denis Sverdlov',
#  'Angus McDonald, Chris Bayley',
#  "Andrea Boeri, Braghin Francesco, Giovanni Capellari, Luca D'Alessandro, Stefano Caverni",
#  'Tushar Bhargava, Anshul Gupta',
#  'Alex Kostecki, Erich Nussbaumer, Nico Simko',
#  'Arjun Balaji',
#  'Chintan Raikar, Prashant Iyengar, Sneh Vaswani',
#  'Harshil Mathur, Shashank Kumar',
#  'Ashutosh Vikram, Kartheeswaran K K, Sharath Loganathan, Thiru Nagarajan, Thirukumaran Nagarajan, Vasu Devan',
#  'Binod Kumar Homagai, Sagar Daryani, Shah Miftaur Rahman',
#  'Anirudh Singla, Rishabh Shekhar',
#  'Anuj Srivastava, Ramakant Sharma, Shagufta Anurag',
#  'HariPrasath M., Rupam Das',
#  'Alessandro Traverso, Birger Lie, Harald Jellum, Matteo Berlucchi',
#  'Jean Pierre Nozieres',
#  'Amit Sinha, Ashok Prasad',
#  'Kuljit Chadha, Subramanian Viswanathan',
#  'Hirak Joshi, Aalesh Avlani',
#  'KP Saravanan, Krish Subramanian, Rajaraman Santhanam, Thiyagarajan T',
#  'Ashwini Purohit, MS Chouhan',
#  'Arun George, Nikhil NP, Rashid Bin Abdulla, Vimal Govind MK',
#  'Maya Lakshman',
#  'Kishor Kumar Jha, Praveen Kumar',
#  'Sandeep Kondaji, Vishnuprasada Bhat, Anand Bellan Raman',
#  'Nagmanjunath Shivakumar, Savio Sebastian',
#  'Anurag Bist',
#  'Abhinand Kaseti, Harish B V, Sathvik Vishwanath, Sunny Ray',
#  'Andrew Linfoot, Ayush Jaiswal',
#  'Ram N Kumar',
#  'Vaibhav Anant',
#  'Kabandi Saika, Manik Mehta',
#  'Vinayak Seth',
#  'Kadam Jeet Jain, Rahul Chaudhary, Sidharth Gupta',
#  'Mainak, Sreekrishna',
#  'Azhar Iqubal',
#  'CA Abhinit Singh',
#  'Bharat Gupta, Pritesh Kumar',
#  'Simar Kohli, Tharun Kumar, Praseed KK',
#  'Ariel Assaraf, Guy Kroupp, Lior Redlus, Yoni Farin',
#  'Johnson Fernandes, Ravneet Kaur',
#  'Yi Zhang',
#  'Anu Meena',
#  'Ashwin Srivastava, Hardik Somani',
#  'Lu Zhao',
#  'Amit Gainda',
#  'Rahul Gupta, Swati Gupta',
#  'Rahul Anand',
#  'Harsimarbir (Harsh) Singh',
#  'Dinesh Pratap, Lokendra Ranawat, Vikas Baheti, Virendra Ranawat',
#  'Ruchi Deepak, Varun Dua',
#  'Pradeep PS',
#  'Balaji Viswanathan, Bharat Kumar, Mahalakshmi Radhakrishnan',
#  'Lovepreet Mann, Nikhil Kumar, Parul Jain',
#  'Suhail Chandhok, Arvind Sivdas, Dhanya Param',
#  'Benoit Dageville, Bob Muglia, Marcin Zukowski, Thierry Cruanes',
#  'Santosh Kataria, Ankit Kimtee, Vivek Jain',
#  'Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, Vatsal Rustagi',
#  'Saif Dhorajiwala, Vikas saluguti, Vivek Subramanian',
#  'Binny Bansal, Sachin Bansal',
#  'Aniket Deshpande, Gaurav Kumar, Irfan Mohammed, Soumendra Ghosh, Vineet Sukumar',
#  'Ankit Agrawal',
#  'Afsal Salu, Fayaz Bin Abdu, Soudabi',
#  'Krishna Kumar, Saroja Yeramilli',
#  'Dhirubhai Ambani',
#  'Parampara Capital, Venkat Vallabhaneni, Jatin Desai',
#  'Tuhin Bhowmick',
#  'Deepshikha Kumar',
#  'Suhas raikar',
#  'Bhavit Sheth, Harsh Jain',
#  'Govind Balachandran',
#  'Rajan Navani',
#  'Arun Kumar Sureban',
#  'Gaurav Parchani',
#  'Jaydeep Barman, Kallol Banerjee',
#  'Varun Sheth, Kunal Kapoor',
#  'R. Baskar Babu',
#  'Gaurav Munjal, ?Roman Saini?',
#  'Lodha, Priyanka Rathore',
#  'Pranav Pai, Siddarth Pai',
#  'Deepthi Ravula',
#  'Deepinder Goyal, Pankaj Chaddah',
#  'Abhishek Satish, Adarsh Warrier',
#  'Pawan Agarwal',
#  'Rohtash Mal CMD, Adwitiya',
#  'Shankar Prasad',
#  'Vijay Anand Bhagavatula',
#  'Ananda Prakash Verma, Shailendra Tiwari',
#  'Saswat Sahu, Rishi Raj',
#  'Adhil Shetty, Arjun Shetty, Rati Shetty',
#  'Pratik Shah',
#  'Nikhilesh Mishra, Puneet Jain',
#  'Ranjit Punja, R Sudarshan, Gowri Mukherjee',
#  'Vidur Maheswari',
#  'Ishan Sharma, Rishikesh Kumar',
#  'Shubham Gupta, Suresh Singh',
#  'Sachin Ravi, Raghav Chakravarthy',
#  'Mihir Mohan Mishra',
#  'Ashwin Kumar, Shoaib Mohammed',
#  'Damien Toledo, Jim Bugwadia, Ritesh Patel',
#  'Anmol Singh Jaggi',
#  'Dhruv Sawhney, Vivek Sahi, Sunny Bagla',
#  'Apurv Agrawal, Kanika Jain, Rishabh Ladha, Vikas Gulati',
#  'Debi Prasad Baral, Naveesh Reddy, Rohit Gajbhiye, Sunit Gajbhiye',
#  'Amit Sethi, Mandeep Manocha, Nakul Kumar',
#  'Deepak MV',
#  'Shailendra Dhakad, Rupika Taneja',
#  'Aanand Srinivas, Avinash Anand, Shankar Ram A',
#  'Ashish Munjal, Piyush Nangru',
#  'Anand Prabhu Subramanian, Vijay Gabale',
#  'Vaibhav Kapoor, Pulkit Kapoor',
#  'Anil Kumar',
#  'Dr Milind Choudhari, Dr Prasad Bhagat, and Dr Anupama',
#  'Mario Suntanu',
#  'Manoj Pillai',
#  'Somdutta Singh',
#  'Rahul Darda',
#  'Nishant Patel',
#  'Erez Galonska, Guy Galonska, Osnat Michaeli',
#  'Vijay Narasiman',
#  'Shrirang Tambe',
#  'Shirish Deodhar',
#  'Harish Mamtani',
#  'Shubham Malhotra, Sai Srinivas',
#  'Iyad Aldalooj, Majid Aldalooj, Mohammed Ibrahim',
#  'Kunal Mahipal',
#  'Bharath Rao',
#  'Abhishek Mishra, Kush Agarwal, Lav Agarwal, Stella Hu',
#  'Kunal Kishore Sinha, Sagar Pushp',
#  'Sreevathsa Prabhakar',
#  'Ankush Sachdeva, Bhanu Pratap Singh, Bhanu Singh, Farid Ahsan',
#  'Ashray Malhotra, Nisheeth Lahoti, Shivam Mangla',
#  'Saroja Yeramilli, R Krishnakumar',
#  'Chandranshu Sinha, Kartik Sheth',
#  'Shah, Abhay Bhat',
#  'Ajay Kadyan, Kumar Mayank',
#  'Tarun Lawadia, Sameer Kalra',
#  'Kabir Bose',
#  'Malika Datt Sadani, Mohit Sadaani',
#  'Ji Cheol Ryu',
#  'Anurag Sinha, Rupesh Kumar, Vibhav Hathi',
#  'Jitendra Chouksey, Sonal Singh, Jyoti Dabas, Bala Krishna Reddy, Rohit Chattopadhyay.',
#  'Akash Deep Singhal, Akshaya Singhal, Devashish Saxena, Gauri Dehnkar',
#  'Rohan Bhargava, Swati Bhargava',
#  'Nishant Chandra, Siddharth Maheshwari',
#  'Lalit Mangal, Manoj Singh, Vinay Kumar Jasti',
#  'Akash Singh, Sharath Keshava Narayana, Swapnil Jain',
#  'Bhupinder Singh',
#  'Zishaan Hayath, Hemanth Goteti',
#  'Vinay Sanghi',
#  'Sumeet Mehta, Smita Deorah',
#  'Sahil Sheth',
#  'Nirmit Parikh',
#  'Amit Rathore',
#  'Kabeer Biswas, Ankur Agarwal, Dalvir Suri, Mukund Jha',
#  'Ranjan Kumar',
#  'Anuj Srivastava, Ramakant Sharma',
#  'Swarup Mavanoor, Rahul Sankhe',
#  'Saurabh Pandey, Akshay Dubey',
#  'Vivek Rajkumar',
#  'Sonal Dandotia, Shantanu S, Virendra Chouhan, Vaibhav Tiwari',
#  'Rama Harinath, Srikanth Iyer',
#  'Darpan Sanghvi',
#  'Kajal Ilmi',
#  'Arunprasad Durairaj, Vijaybabu Gandhi, Shreenidhi Srirangam',
#  'Madhusudanan R, Prabhu R',
#  'Dr. R. Shivaraman, Praveen Dwarakanath',
#  'Arun Prakash',
#  'Anmol Singh Jaggi, Punit K Goyal',
#  'Nakul Kukar, Paras Kaushal, Supratim Naskar',
#  'Sai Srinivas Kiran Garimella, Shubham Malhotra',
#  'Kishan Vasani, Sai Sreenivas Kodur',
#  'Amit Dhakad, Hiral Jain',
#  'Lalit Keshre, Harsh Jain, Neeraj Singh, Ishan Bansal',
#  'Dr Mallesh Bommanahal, Varzavand Batliwala',
#  'Pratik Agarwal, Raj Desai, Varsha Bhambhani',
#  'Amit Agrawal',
#  'Karthi Mariappan',
#  'Tanmai Gopal, Rajoshi Ghosh',
#  'Ravi Ravulaparthi, Lakshman Gupta, Vamsee Mohan',
#  'Cindy Kua',
#  'Yashash Agarwal, Gaurav Agarwal',
#  'Ankit Agarwal',
#  'Vaishali Kulkarni, Arjun Singh Bajwa',
#  'Ananth Narayanan, T-ushar Kumar',
#  'Ashok Hariharan, Vineet Jawa',
#  'Charlie, Jay, Martin',
#  'Samarth Agrawal, Rohit Narang',
#  'Manoj Gupta, Monica Gupta',
#  'Arpita Kapoor, Mohit Rangaraju, Shilp Gupta',
#  'Pankaj Chaddah, Staff Pooja Khanna',
#  'Ishan Sharma, Rishikesh',
#  'Chaitanya Kalipatnapu, Ashwin Damera',
#  'Shobhit Bhatnagar',
#  'Abhishek Goyal, Neha Singh',
#  'Abhishek Agarwal',
#  'Pramod Ravindra',
#  'Saurabh Singh, Rahul Jain, Nagender Sangra',
#  'Amit Singh, Deepanshu Malviya',
#  'Aniket Shinde, Hardik Gondaliya',
#  'Siddharth Das, Dr Rahul Dave, Dr Pavlos Protopapas',
#  'Nakerikanti Harish',
#  'Peter Barcak',
#  'Arpit Rajpurohit, Jayesh Rajpurohit',
#  'Amit Bhardwaj, Nikhil Hegde.',
#  'Srinivas Madhavam, Srikanth Rajashekhar, Rahul Mehta',
#  'Sonakshi Nathani, Ashutosh Singla',
#  'Omer Basith',
#  'Devansh Jain Nawal, Ackshay Jain',
#  'Snehil Khanor',
#  'Nimish Goel, Nevaid Aggarwal, Devender Bindal',
#  'Ankush Aggarwal, Tushar Mehndiratta',
#  'Manuraj Jain, Surajit Raj',
#  'Kunaal Dudeja, Nalin Saluja, Archit Jayaswal',
#  'Manish Shara, Yash Desai',
#  'Gaurav Singh',
#  'Varun Khanna',
#  'Inderveer Singh',
#  'Sumeet Yashpal Mehta, Smita Deorah',
#  'Pulkit Agrawal, Prashant Sachan, Arun Lodhi, Bimal Kartheek Rebba, Nirav Sheth',
#  'Utham Gowda',
#  'Mihir Gupta, Payoj Jain, Divyansh Bordia, Anshuman Kumar',
#  'Kshitij Khandelwal, Awais Ahmed',
#  'Dhruv Bhushan',
#  'Rajesh Bernard, Vijay Krishna, Prateek Mehta',
#  'Ravish Agrawal, Swatantra Kumar, Siddharth Srivastav',
#  'Sanjeev Nair',
#  'Smriti Tomar',
#  'Anurag Sinha',
#  'Prateek Shukla, Nrupul Dev, Yogesh Bhat',
#  'Shivank Agarwal, Anish Khandelwal.',
#  'Prerna Kalra, Vidya Bhushan',
#  'DVL Padma Priya, Rakesh Kamal, Tarun Nirwan',
#  'Public banks, Private lenders',
#  'Kiran Ramakrishna, Subhajit Mukherjee',
#  'Pranjal Kacholia, Divyansh Mathur',
#  'Rishab Mehta',
#  'Sateesh Nukala, SachinNandwana',
#  'Vineet Toshniwala',
#  'Ananthakrishnan Gopal, Ashok Balasundaram, Sriram P H',
#  'Varun Chopra, Raheel Shah',
#  'Kshitj Puri, Shalabh Singhal',
#  'Rushabh Sheth, Bikram Dahl',
#  'Abhinav Ayan, Anirban Jyoti Chakravorty, Soumyaranjan Harichandan',
#  'Biswatma Nayak, Siddharth Gautam',
#  'Varun Saxena',
#  'Rajit Bhattacharya, Aisik Paul, Ankit Das',
#  'Adit Chhabra, Tapan Dixit,Tanay Dixit.',
#  'Viijender Reddy, Manas Ranjan Hota',
#  'Tanmaya Jain, Varun Puri',
#  'Anand Singh, Ankit Vaish',
#  'Vittal Ramakrishna',
#  'Jaydeep Barman, Kallol Bannerjee',
#  'Manish Jethani, Sourabh Agarwal',
#  'Kapil Mathrani, Rohan Bhatt, Poojan Thakkar',
#  'Sumit Ghosh',
#  'Ankush Sachdeva, Bhanu Pratap Singh, Farid Ahsan',
#  'Dhruvin Shah',
#  'Dr. Sachin Bhavsar',
#  'Sumeet Kapur, Ankur Bhatia, Aanchal Kapur',
#  'Prasanna Kumar, Mahesh Bhat, Rajasekhar, Amith S Mali',
#  'Karan Khairajani, Surojit Roy',
#  'Sachin Bhatia, Atit Jain',
#  'Zishaan Hayath',
#  'Archana Elapavuluri, Namandeep Bhatia, Siddharth Panjwani',
#  'K.L.N Sai Prasanth, Yathindra Ajay K.A, K. Prathyusha',
#  'Vivek Tiwari',
#  'Bijay Gautam, Souniya Khurana',
#  'Saif Dhorajiwala',
#  'Mohammed Hisamuddin',
#  'Deepak Grover',
#  'Sudeep Singh',
#  'Ragini Das, Anand Sinha',
#  'Tarun Mehta, Swapnil Jain',
#  'Chirag Mittal, Parag Modi, Anirudh Syal',
#  'Praneeth Kumar, Shobhit Jain, Mrudhukar Batchu, Kiran Naik',
#  'Suman Maram, Sudheer Maram',
#  'Siddharth Vij, Siddharth Rastogi, Shubham Agarwal, Chaitanya Rathi',
#  'Ashwin Ajila',
#  'Meghna Saraogi, Akhil Tolani',
#  'Silky Singh, Alkheya Boora Rpsey',
#  'Mugdha Pradhan',
#  'Saurabh Saxena, Pulkit Jain, Anand Prakash, Vamsi Krishna',
#  'Anshoo Sharma, Brij Bhushan',
#  'Gaurav Baheti, Sumit Mendiratta',
#  'Hitesh Ahuja',
#  'Rathinamurthy R, Sridher Jeyachandran',
#  'Gotama Gowda',
#  'Ashish C',
#  'Nikhil Hegde, Amit Bhardwaj',
#  'Saurabh Saxena',
#  'Prateek Garg, Vishva Sharma, Rahul Gupta, Rishabh Nagpal, Ratan Sethi',
#  'Chaitanya Nallan, Sangram Simha, Veerendra Shivhare',
#  'Sahil Sharma, Aditya Shirole',
#  'Manish Tewari',
#  'Vidur Maheshwari',
#  'Ashni Sheth, Varun Sheth',
#  'Vikram Chopra',
#  'RajanNavani',
#  'Rushi Shenghani',
#  'Sanchit Garg, Sanjeev Dadhich',
#  'Abhilasha, Kshitij Purwar',
#  'Anuj Bhuria, Himanshu Kumar, Himanshu Meena',
#  'Rohit Taneja',
#  'Ajaitha Shah',
#  'Sreeshankar S Nair, Romeo P Jerard',
#  'Vikram Jetley, Sanjay Sharma',
#  'Neeraj Kakkar, James Nutall, Suhas Misra, Neeraj Biyani',
#  'Ganesh Raju',
#  'Anuj Krishnan',
#  'Ooshma Garg',
#  'Rohit Grover, Pradeep Thangappan',
#  'Devang Shah, Gaurang Shah',
#  'Devesh Trivedi, Sanchit',
#  'Praveen Dwarkanath, Dr. Shivaraman Ramaswamy',
#  'Vijay Babu Gandhi, Shreenidhi Srirangam, Arunprasad Durairaj',
#  'Amrit Acharya, Srinath Ramakkrushnan, Vishal Chaudhary',
#  'Pavan Adipuram',
#  'Bhagaban Behera, Sriharsha Shetty, Nakul Kelkar',
#  'Swapnil Sahu',
#  'Aniruddh Singh, Riyaz Khan, Sagar Sheth',
#  'Mayank Yadav',
#  'Rajat Jadhav, Rahul Krishnan, Harsh Singh, Mohit Yadav',
#  'Amit Nanwani',
#  'Shivani Poddar, Tanvi Malik',
#  'Rajan Bajaj',
#  'Abhas Saroha, Oliver Jones',
#  'Aarti Gill, Mihir Gadani',
#  'Dhruv Agrawal, Faith Jiwakhan',
#  'Vemuri, Deepak Sharma, Pranay Gupta, Varun Chawla',
#  'Amit Gupta',
#  'Anant Goel',
#  'Hormazd Charna, Manoj Mishra',
#  'Srikumar Misra',
#  'Prasad Akella',
#  'Aditya Singhal, Nishant Sinha, Bahul Arora',
#  'Abhijit Roy, Samir Pratihar',
#  'Runal Dahiwade, Nityanand Prabhutendolkar, Miraj C. Vora',
#  'Arjun Ahluwalia, Adriel Maniego',
#  'Yash Vyas',
#  'Pushkar Singh, Sudarshan Ravi, Ankit Parasher',
#  'Niraj Raka, Poonam Gugale, Piyush Raka',
#  'Pranav Chopra, Neeraj Kumar',
#  'Dr Janani Venkatraman',
#  'Ravi Nishant',
#  'Rohan Mirchandani, Ganesh Krishnamurthy, Rahul Jain,Uday Thakkar.',
#  'Rajeev Agrawal',
#  'Babu Sivadasan',
#  'Abhijit Kane, Abhinav Asthana, Ankit Sobti',
#  'Raghav Arora, Lalit Kumar Aggarwal',
#  'Karthick Jayraman, Sanjay Dasari',
#  'Dr Gopichand Katragadda, Ganesh Suryanarayanan, Aditi Olemann.',
#  'Dr Binita Shrivastava Tunga, Dr Rashbehari Tunga',
#  'Shubhendra Vikram, Ankit Kumar',
#  'Ashish Gupta',
#  'Raghuraj Sunder Raju, Prasad Basavaraj, Sandeep Gudibanda',
#  'Shailesh Gupta, Mukul Shah',
#  'Nitesh Salvi',
#  'Purav Shah, Sandesh Reddy',
#  'Prashant Jain, Varun Khurana',
#  'Aswani Chaitanya',
#  'Lokendra Ranawat, Dinesh Pratap Singh, Virendra Ranawat, Vikas Baheti',
#  'Adhil Shetty, Arjun Shetty, Rati Shetty,',
#  'Geetansh Bamania',
#  'Rishabh Goel, Anand Agrawal, Mayank Khera',
#  'Kinner N Sacchdev, Rakhi Wadhwa',
#  'Karan Shaha, Vikas Chandrawat',
#  'Akshay Pai',
#  'Satyen Kothari, Beenext, Asuka Holding',
#  'Naresh Rao, Nikhil Rajmohan, Harinath Chakravarthy, Pravin Sethuraman',
#  'Indrajeet Roy',
#  'Bhavish Aggarwal',
#  'Amit Ramani',
#  'Kabeer Biswas,  Mukund Jha, Dalvir Suri, Ankur Aggarwal',
#  'Abhinav Agarwal, Anand Bakode',
#  'Dr Ruchir Mehra, Harsh Bansal, Richeek Arya',
#  'Mithun Srivatsa, Nikhil Shivaprasad',
#  'Vinayak Srivastav, Saket Dandotia, Alok Patil',
#  'Jatin Singh',
#  'Sumit Gupta, Neeraj Khandelwal',
#  'Lalit Menghani',
#  'Suvendu Prusty, Sorabh Bhandari, Chiranth Patil.',
#  'Sandeep Vohra',
#  'Anurba Nath',
#  'Gowri Mukherjee, Ranjit Punja, Rajasundaram Sudarshan',
#  'Mohammed Riaz',
#  'Hrishikesh Datar',
#  'Ravish Naresh',
#  'Harshvardhan Lunia, Mukul Sachan',
#  'Akash Deep Singhal, Akshaya Singhal',
#  'Uttam Kumar',
#  'Ashwini Purohit',
#  'Pritesh Asher',
#  'Amit Kharat, Ajit Patil, Aniruddha Pant',
#  'Krishnan, Shane Bilsborough',
#  'Abhisheka Kumar, Malkit Didyala',
#  'Kartikey Hariyani',
#  'Milan Sharma, Nishant Mishra, Himani Shah, Devendra Chandani',
#  'Ajay Agrawal',
#  'Venkatesh Rangachari, Vipul Gupta',
#  'Naman Sarawagi, Mohit Jain',
#  'Saahil Goel',
#  'Sanjay Kumar, Deepti Prasad',
#  'Satish Kannan',
#  'Sumit Sinha,\xa0\xa0Mukesh Bansal',
#  'Arjun Deshpande',
#  'Prajit Nanu',
#  'Raman Khanduja, Sanjay Nazareth',
#  'Rajesh Yabaji',
#  'Gupta, Akshay Deshraj, Manoj Sarda',
#  'Avinash BR, Gururaj Rao, Arvind Murali, Santhosh Narasipura',
#  'Steve Hardgrave',
#  'Prashanth Kuppur, Deepak Kalhan, Saurabh Kukreti, Richpal Gora',
#  'Amit Naik, Kewal Vargante',
#  'Piyush, Dipesh Agarwal',
#  'Suraj Saste',
#  'Dr Subhash Narayanan',
#  'Ranjeet Pratap Singh, Sankaranarayanan Devarajan, Sahradayi Modi, Rahul Ranjan, Prashant Gupta',
#  'Vishal Jindal',
#  'Nishith Chasmawala, Amit Sharma',
#  'Rajat Gupta',
#  'Harsh Bansal',
#  'Darshan Shah',
#  'Nitin Agrawal, Garima Agrawal',
#  'Archin Shah, Abhilash Sonwane, Ritesh Gandhi',
#  'Mukul Rustagi, Bhaswat Agarwal',
#  'Ishan Gupta, Aarti Gupta',
#  'Gagan Vermani, Divyanshu Sachdev, Gyan Prakash Tiwari',
#  'Amit Sharma, Apoorva Jois',
#  'Vivek Gupta, Jatin Solanki',
#  'Romesh Khaddar, Shikha Chaudhry, Sumedh Chaudhry',
#  'Raghavendra Prasad',
#  'Tarun Dhamija, Kartik Bansal',
#  'Jitendra Chouksey',
#  'Suresh Bavisetti, Paarth Dhar',
#  'Arindam Ghosh, U R Bhatt',
#  'Sagar Yarnalkar',
#  'SP Balamurugan, Arun Prakash, Sri Devi',
#  'Raghuram Talluri, Tanmoy Karmakar, Rakib Ahmed',
#  'Venkatesh Sundar, Nandini Tandon',
#  'Shivashish Chatterjee, Yuvraja Singh',
#  'Rohin Parkar, Malcolm Dsouza',
#  'Anand Anandkumar',
#  'Manas Ranjan Hota, Vijender Reddy',
#  'Madhusudanan R, Muthukumar and Prabhu',
#  'Vetrivel Palani, Paneerselvam',
#  'Megha Wadhwa, Karnesh Mahendru',
#  'Karanvir Singh, Utkarsh Bagri, Vikram Shekhawat, Deepak Choudhary',
#  'Amit Kumar Agarwal, Akhil Gupta, Saurabh Garg',
#  'Gaurav Hinduja, Sashank Rishyasringa',
#  'Mayank Kukreja, Anish Khadiya',
#  'Ashish Bhandari',
#  'Jen Horonjeff',
#  'Samarth Kholkar, Sandeep Mukherjee',
#  'Raghavendra Kumar Ravinutala',
#  'Vinayak Shrivastav, Saket Dandotia, Alok Patil',
#  'Sahil Kini, Nikhil Kumar',
#  'Abhishek Shah',
#  'Rishabh Jain, Aditi Sinha',
#  'Gaurav Srivastava, Gautam Kumar, Kushal Nahata',
#  'Pranav Goel, Uttam Digga',
#  'Rohit Paranjpe',
#  'Abhinay Choudhari, Hari Menon, Vipul Parekh, VS Sudhakar',
#  'Jitendra Gupta',
#  'Shrikrishna Bharambe, Shripad Nadkarni, Varun Khanna, Abhijit Berde',
#  'Vineet Shetty, Anushka Shetty',
#  'Malhi, Siddhant Saurabh',
#  'Shashank Kumar',
#  'Nandan Reddy, Sriharsha Majety, Rahul Jaimini',
#  'Saurabh Pandey, Mahadevan Narayanamoni',
#  'Deepinder Goyal',
#  'Karan Bhardwaj',
#  'Vimal Kumar',
#  'Tapojit Debnath, Nirman Dave',
#  'Pratyush Halen, Anuraag Agrawal',
#  'Prashant Border, Saurya Prakash Sinha',
#  'Ajith Mohan Karimpana',
#  'Suneel Kumar, Gaurav Tomar, Sucharita Redd',
#  'Anshul Bhagi, Sandeep Bhagi',
#  'Sam Santhosh',
#  'Kishor Jha, Praveen Kumar',
#  'Deepak Bhuvneshwari Uniyal, Shilpa Arora, Shailesh Kumar, Sanjay Aggarwal',
#  'Subhash Narayanan',
#  'Mukesh Bansal, Ankit Nagori',
#  'Tapesh Goyal, Rajesh Vaidhyanathan',
#  'Preet Arjun Singh',
#  'Sneha Roy',
#  'Dilip Kumar, Selvan Thamarai, Deepti Nair',
#  'Monica Gupta. Manoj Gupta',
#  'Anubhav Jain, Ankit Singh, Jawaid Iqbal',
#  'Rishi Malhotra, Akhil Gupta',
#  'Sumit Gupta',
#  'Sagar Modi, Advaith Vishwanath',
#  'Adarsh Anand, Amit Tiwari',
#  'Rajan Sharma',
#  'Prabhdeep Singh',
#  'Mihir Mohan mishra',
#  'Jaideep Gupta',
#  'Ezhilarasan Natarajan, Sabapathy Arumugam, Krishnakumar Narayanan, Thiruvalluvar NB',
#  'Gaurav Kumar, Vineet Sukumar',
#  'Srinath Ravichandran',
#  'George Mitra, Rajan Pathak',
#  'Amit Chandel, Rohit Garg, Vinay Kumar, Jayant Upadhyay',
#  'Pranesh Chaudhary, Sushant Sachan',
#  'Abhinav Jain, Aditya Gupta',
#  'Sridhar Joshi, Prashant Kulkarni',
#  'Maneet Gohil, Sanchit Govil, Albin Jose',
#  'Govind Agrawal, Arti Agrawal',
#  'Arshi Khan',
#  'Ankit Jain, Anand Shah',
#  'Pankaj Singh',
#  'Kush Taneja',
#  'Pramod Ghadge',
#  'Pei-fu Hsieh, Amit Jangir',
#  'Lalit Mangal, Vinay Jaasti, Manoj Singh',
#  'Rajesh',
#  'Rohan Mirchandani',
#  'Lathika Pai',
#  'Sriram Subramanian',
#  'Vidushi Kajaria, Aayush Goenka',
#  'Sudarshan Lodha, Priyanka Rathore',
#  'Sreeraman Vaidyanathan, Surga Thilakan',
#  'Prasanna Rao',
#  'Vaibhav Singh, Arnav Kumar',
#  'Ajai Thandi, Arman Sood, Ashwajeet Singh',
#  'Charit Bhograj, Zainul Charbiwala, Udayan Dasgupta, Abhinav Gujjar',
#  'Ajit Panda',
#  'Vivekananda Hallekere, Anil Giri Raju, Arun Agni',
#  'Taran Chhabra, Amar Preet Singh',
#  'Vipul Sharma, Rajat Kumar, Sachin Arora, Mohit Goel',
#  'Bhatia, Sneha Shah',
#  'Li Yong, Shushant Srivastava',
#  'Niraj Singh, Mohit Gupta, Ramanshu Mahuar',
#  'Pallavi Agarwal, Pankaj Parwanda',
#  'Ashutosh Sharma',
#  'Anand Ayyadurai, Padmanabhan Balakrishnan, Sanchit Mittal',
#  'Saurabh Singh',
#  'Prashant Warier, Pooja Rao',
#  'Gokul Shrinivas',
#  'Supriya Paul, Shobhit Banga',
#  'Ringaile Noq',
#  'Manish Rathi, Kapil Raizada, Sachin Saxena',
#  'Pankaj Raut, Abhishek Tomar, Abhijit Patil',
#  'Anirudh Singla and Rishabh Shekhar',
#  'Radha Basu',
#  'Ashneer Grover',
#  'Sanket Shah',
#  'Varun Mayya, Shashank Udupa, Abhinav Arora',
#  'Anubhav Sharma',
#  'Madhan Mohan , Akash Chelvam',
#  'Archit Agarwal, Harry Sehrawat',
#  'Vinay Kothari',
#  'Khadim Batti, Vara Kumar',
#  'Gaurav Munjal, Roman Saini, Hemesh Singh',
#  'Rajan Dang, Anushree Srivastava',
#  'Kabeer Biswas',
#  'Kamesh Goyal',
#  'Shailesh Gupta, Mukul Shah, Danish Chopra',
#  'Tithi Tewari, Gautam Tewari',
#  'Samarth Agrawal',
#  'Aniruddha Sharma, Prateek Bumb',
#  'Mahipal',
#  'Vishal Khatter, Dheeraj Khatter, Dipak Varshney',
#  'Maneesh Dhooper, Kunal Malik',
#  'Ajith Nayar, Umesh, Mahesh Subramanian',
#  'Amit Bagaria',
#  'Chinmoy Mishra, Gaurav Vij, and Abhishek Verma',
#  'Vijeet Pandey, Vikas Rishishwar',
#  'Yogesh Thore',
#  'Ritesh Kumar',
#  'Vijay Shekhar Sharma',
#  'Nicky Goulimis',
#  'Singla, Kannu Mittal, Dhawal Parate',
#  'Jayesh Rajpurohit, Arpit Rajpurohit',
#  'Abhishek Mohan',
#  'Raviteja Dodda, Yashwanth Kumar',
#  'Rustagi, Bhaswat Agarwal',
#  'Nitin Saluja, Raghav Verma',
#  'Apurv Patel',
#  'Shamik Guha, Sayan Tapadar, Muhammad Bilal Shakil, Anirban Datta Gupta',
#  'Ambareesh Murty, Ashish Shah',
#  'Supam Maheshwari, Amitava Saha',
#  'Karthick Jayraman and Sanjay Dasari',
#  'Kunal Patil',
#  'AR Rahman, Shekhar Kapur',
#  'Narain Karthikeyan.',
#  'Jitendra Emmani',
#  'Kapil Gupta',
#  'Shailaz Nag',
#  'Lal Chand Bisu, Vikas Goyal, Vinod Kumar Meena',
#  'Nikhil Banerjee',
#  'Sachin Chopra',
#  'Rakesh Sharma',
#  'Katie Russel and Daniel Wiegand',
#  'Vineet Sharma, Abhay Jeet Gupta, Udbhav Rai, Parveen Kataria, Vishal Misra',
#  'Aditi Avasthi',
#  'Mohammed Hisamuddin, Rahul Ramesh',
#  'Akash Deep',
#  'Tarun Khanna',
#  'Prashant Tandon, Gaurav Agarwal, Vikas Chauhan',
#  'Akaash Shankar',
#  'Tanushri Nagori, Aditya Shankar',
#  'Sandeep Bommireddi, Sravanth Gajula',
#  'Aditya Agarwalla, Sanjay Agarwalla',
#  'Vikash Jha',
#  'Guna Kakulapati, Rama Rajanna, Charu Sharma',
#  'Amit Bansal',
#  'Abhimanyu Saxena',
#  'Bala Parthasarathy, Anuj Kacker, Kunal Varma',
#  'Rohit Manghnani, Amit K Jaiswal, Iccha Manghnani',
#  'Ashish Kashyap',
#  'Sachin Agarwal, Aniket Deb, Ankit Tomar',
#  'Oren Kaniel, Reshef Mann',
#  'Bhavik Vasa',
#  'Navratn Singh, Kamal Pandey',
#  'Lokvir Kapoor, Rajul Garg, Tarun Upaday',
#  'Sharmin Ali',
#  'Neeraj Singh, Alok Arora',
#  'Dhruvil Sanghvi, Manisha Raisinghani',
#  'Shikhar Veer Singh, Nidhi Singh',
#  'Sarvesh Shrivastava, Ved Prakash Khatri, Amit Kapoor',
#  'Vivekananda Hallekere, Anil Giri Raju,Arun Agni',
#  'Amit Lakhotia',
#  'Abhay Rangan',
#  'Prithwi Dasgupta, Arnab Chatterjee',
#  'Trivedi',
#  'Snigdha Manchanda, Vikas Kumar, Aishwarya Malhi',
#  'Suneel Kumar, Sucharita Reddy, Gaurav Tomar, Akhilesh Nigam,',
#  'Shailendra Singh, Deepinder Dhingra, Pavan Palety',
#  'Asheesh Chanda, Vineeth Narasimhan',
#  'Balaji Viswanathan, Be Limitless Inc., Zingfin.com, NalandaU',
#  'Kumar Mayank, Ajay Kadyan',
#  'Anish Agarwal, Anant Jain',
#  'Nirav Patil',
#  'Bhavesh Shah, Manav Shah',
#  'Abhishek Emmanuel',
#  'Mahe Bayireddi',
#  'Kavita Dhillon',
#  'Sousthav Chakrabarty',
#  'Kartikeya Goel',
#  'Soham Thacker, Varun Gajjar',
#  'Arka Dhar',
#  'Divya Agarwal, Ketika Kapoor',
#  'Deepanshu Arora, Parita Parekh',
#  'Thirukumaran Nagarajan, Sharath Loganathan, Sachin Jose, Kartheeswaran KK, Vasudevan Chinnathambi',
#  'Akash Sharma, Abhishek Agarwal',
#  'Mahesh Gogineni, Varun MS, Manan Maheshwari',
#  'Amal PS',
#  'Anurakt Jain, Ishita Verma',
#  'Rajiv Mukherjee',
#  'Bharat Sethi',
#  'Neeraj Kumar',
#  'Pramath Raj Sinha',
#  'Gaurav Munjal',
#  'Leo Mavely',
#  'Mr. Subhashis Kar',
#  'Amit Narang',
#  'Praveen Agrawal, Yadvendar Champawat, Manoj Munna, Abhishek Sagar, Ashutosh Kumar, Narendra Agrawal',
#  'Tanvi Malik, Shivani Poddar.',
#  'Neer Sharma',
#  'Ghazal Alagh, Varun Alagh',
#  'Siddharth Gadia',
#  'Sashi Narahari',
#  'Jahabar Sadique, Balaji Sadagopan',
#  'Sonal Khandelwal, Vaibhav Tiwari',
#  'Kanav Sachdeva',
#  'Kumar Varma',
#  'Vishvajit Sonagara',
#  'Santosh Shinde, Sanjay Borkar',
#  'Himanshu Jain, Pulkit Jain',
#  'Vikram Kankaria, Priyanka Kankaria',
#  'Akshay Chaturvedi',
#  'Sujith Narayanan, Sumit Gwalani',
#  'Jayakrishnan, Abhijeet Manohar',
#  'Pramod Ghadge, Shahid Memon',
#  'Mayank Kumar, Phalgun Kompalli, Ravijot Chugh, Ronnie Screwvala',
#  'Smita Deorah, Sumeet Mehta',
#  'Aniket Deb, Ankit Tomar, Sachin Agrawal',
#  'Kapil Banwari',
#  'Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan',
#  ...]

# %% [markdown]
# ##### Cleaning the Investors Column

# %%
df['Investor'].unique()
# Out:
# array(['Unknown', ' Nexus Venture Partners', ' Tiger Global Management',
#        ..., 'Transworld Group', 'Owl Ventures', ' Man Capital'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2873 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2873 non-null   object
#  7   Amount        2319 non-null   float64
#  8   Stage         2873 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
#  11  Stages        2873 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 291.8+ KB

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector          Stages
# 0   250000.0      Seed          2018  Software & Technology      Validation
# 1   584000.0      Seed          2018            Agriculture      Validation
# 2   949000.0  Series A          2018     Financial Services  Early Traction
# 3  2000000.0     Angel          2018     Financial Services      Validation
# 4        NaN      Seed          2018      Commerce & Retail      Validation

# %% [markdown]
# #### the imputation with the mean was chosen to fill the amount column

# %%
# Calculate the median of the 'Amount' column
amount_median = df['Amount'].median()


#Calculate the median of the 'Amount' column and round it to 2 decimal places
amount_median = round(df['Amount'].median(), 2)

# Fill missing values in the 'Amount' column with the rounded median
df['Amount'].fillna(amount_median, inplace=True)

amount_median
# Out:
# 3000000.0

# %%
df['Amount'].min()
# Out:
# 876.0

# %%
df[df['Amount'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [Company_Name, Founded, Location, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year, Main_Sector, Stages]
# Index: []

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector          Stages
# 0   250000.0      Seed          2018  Software & Technology      Validation
# 1   584000.0      Seed          2018            Agriculture      Validation
# 2   949000.0  Series A          2018     Financial Services  Early Traction
# 3  2000000.0     Angel          2018     Financial Services      Validation
# 4  3000000.0      Seed          2018      Commerce & Retail      Validation

# %%
# Calculate the mean of non-zero amounts
median_amount = df[df['Amount'] != 0.0]['Amount'].median()

# Replace zero values in the 'Amount' column with the mean
df.loc[df['Amount'] == 0.0, 'Amount'] = median_amount

# %%
df[df['Amount'] == 0.0]
# Out:
# Empty DataFrame
# Columns: [Company_Name, Founded, Location, Sector, What_it_does, Founders, Investor, Amount, Stage, Funding_Year, Main_Sector, Stages]
# Index: []

# %%
df.head()
# Out:
#       Company_Name  Founded   Location  \
# 0  TheCollegeFever      NaN  Bangalore
# 1  Happy Cow Dairy      NaN     Mumbai
# 2       MyLoanCare      NaN    Gurgaon
# 3      PayMe India      NaN      Noida
# 4         Eunimart      NaN  Hyderabad
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      NaN  Unknown
# 1  A startup which aggregates milk from dairy far...      NaN  Unknown
# 2          Leading Online Loans Marketplace in India      NaN  Unknown
# 3  PayMe India is an innovative FinTech organizat...      NaN  Unknown
# 4  Eunimart is a one stop solution for merchants ...      NaN  Unknown
#
#       Amount     Stage  Funding_Year            Main_Sector          Stages
# 0   250000.0      Seed          2018  Software & Technology      Validation
# 1   584000.0      Seed          2018            Agriculture      Validation
# 2   949000.0  Series A          2018     Financial Services  Early Traction
# 3  2000000.0     Angel          2018     Financial Services      Validation
# 4  3000000.0      Seed          2018      Commerce & Retail      Validation

# %% [markdown]
# #### REMOVING NON STARTUPS

# %% [markdown]
# According to EU-startups, If we look at the more comprehensive definition of a startup, it cannot just be any ‘fledgling’ business enterprise, it has to be focused on growth and scale. You are no longer a startup if you have achieved scale, albeit the arbitrary the definition of scale. Scale is typically measured in terms of revenue, number of employees and valuation, but can also include age i.e.
# ##### categorizing companies that are more than 5 years old as no longer startups.
# https://www.eu-startups.com/2021/03/when-is-a-startup-no-longer-a-startup/#:~:text=Scale%20is%20typically%20measured%20in,old%20as%20no%20longer%20startups.

# %%
# Convert 'Funding_Year' column to datetime with format '%Y'
#df['Funding_Year'] = pd.to_datetime(df['Funding_Year'], format='%Y').dt.year

# Assuming df is your DataFrame
#df['Funding_Year'] = pd.to_datetime(df['Funding_Year'], format='%Y', errors='coerce')

# Convert 'Funding_Year' column to datetime with format '%Y'
#df['Funding_Year'] = pd.to_datetime(df['Funding_Year'], format='%Y').dt.year

# Check the data type and other info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2873 entries, 0 to 1208
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company_Name  2873 non-null   object
#  1   Founded       2105 non-null   float64
#  2   Location      2873 non-null   object
#  3   Sector        2854 non-null   object
#  4   What_it_does  2873 non-null   object
#  5   Founders      2329 non-null   object
#  6   Investor      2873 non-null   object
#  7   Amount        2873 non-null   float64
#  8   Stage         2873 non-null   object
#  9   Funding_Year  2873 non-null   int64
#  10  Main_Sector   1778 non-null   object
#  11  Stages        2873 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 291.8+ KB

# %%
# Convert 'Funding_Year' to datetime
# Assuming df is your DataFrame
#df['Funding_Year'] = pd.to_datetime(df['Funding_Year'], format='%Y', errors='coerce')

# %%
# Calculate 'Years of Existence' using the correct column names

df['Years of Existence'] = df['Funding_Year'] - df['Founded']

# %%
# Calculate 'Years of Existence' using the correct column names

# Convert 'Years of Existence' to int64 first, then to int32
df['Years of Existence'] = df['Years of Existence']

# %%
# Filter data where 'Years of Existence' is greater than 5

years_of_existence_gt_5 = df[df['Years of Existence'] > 5]
years_of_existence_gt_5
# Out:
#       Company_Name  Founded   Location                    Sector  \
# 4         Nu Genes   2004.0  Hyderabad                  AgriTech
# 7         Kratikal   2013.0      Noida                Technology
# 9         Lenskart   2010.0      Delhi                E-commerce
# 10      Cub McPaws   2010.0     Mumbai           E-commerce & AR
# 16          Byju's   2011.0  Bangalore                    Edtech
# ...            ...      ...        ...                       ...
# 1195     Delhivery   2011.0   Gurugram  Logistics & Supply Chain
# 1196    Flipspaces   2011.0     Mumbai                    Design
# 1201     TechEagle   2015.0   Gurugram      Aviation & Aerospace
# 1205        Vahdam   2015.0  New Delhi          Food & Beverages
# 1207  CollegeDekho   2015.0   Gurugram                    EdTech
#
#                                            What_it_does  \
# 4     It is a seed company engaged in production, pr...
# 7     It is a product-based cybersecurity solutions ...
# 9                               It is a eyewear company
# 10    A B2C  brand that focusses on premium and comf...
# 16                     Provides online learning classes
# ...                                                 ...
# 1195  Delhivery is a leading logistics and supply ch...
# 1196  Flipspaces is a global tech-enabled venture to...
# 1201  Safe, secure & reliable On-Demand Drone delive...
# 1205  VAHDAM is among the world’s first vertically i...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
#
#                                              Founders  \
# 4                              Narayana Reddy Punyala
# 7     Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa
# 9        Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
# 10                            Abhay Bhat, Kinnar Shah
# 16                                    Byju Raveendran
# ...                                               ...
# 1195                                      Sahil Barua
# 1196                                     Kunal Sharma
# 1201                               Vikram Singh Meena
# 1205                                       Bala Sarda
# 1207                                     Ruchir Arora
#
#                                       Investor       Amount         Stage  \
# 4     Innovation in Food and Agriculture (IFA)    6000000.0
# 7                          Rajeev Chitrabhanu.    1000000.0  Pre series A
# 9                                     SoftBank  275000000.0      Series G
# 10                           Venture Catalysts    3000000.0
# 16                    the CPP Investment Board  540000000.0
# ...                                        ...          ...           ...
# 1195                                  Addition   76000000.0      Series I
# 1196                            Prashasta Seth    2000000.0  Pre-series B
# 1201                         India Accelerator     500000.0          Seed
# 1205                                  IIFL AMC   20000000.0      Series D
# 1207                               Man Capital   26000000.0      Series B
#
#       Funding_Year            Main_Sector          Stages  Years of Existence
# 4             2019            Agriculture         Unknown                15.0
# 7             2019  Software & Technology      Validation                 6.0
# 9             2019      Commerce & Retail         Scaling                 9.0
# 10            2019      Commerce & Retail         Unknown                 9.0
# 16            2019                   None         Unknown                 8.0
# ...            ...                    ...             ...                 ...
# 1195          2021              Transport         Unknown                10.0
# 1196          2021                   None  Early Traction                10.0
# 1201          2021              Transport      Validation                 6.0
# 1205          2021        Food & Beverage         Scaling                 6.0
# 1207          2021                   None         Scaling                 6.0
#
# [602 rows x 13 columns]

# %% [markdown]
# ##### All the above rows will be dropped because at the time of collecting their data, they were more than 5 years which disqualifies them from being startups

# %%
# Drop rows where 'Years of Existence' is greater than 5
df = df[df['Years of Existence'] <= 5]

# Display the updated DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1503 entries, 1 to 1208
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Name        1503 non-null   object
#  1   Founded             1503 non-null   float64
#  2   Location            1503 non-null   object
#  3   Sector              1495 non-null   object
#  4   What_it_does        1503 non-null   object
#  5   Founders            1495 non-null   object
#  6   Investor            1503 non-null   object
#  7   Amount              1503 non-null   float64
#  8   Stage               1503 non-null   object
#  9   Funding_Year        1503 non-null   int64
#  10  Main_Sector         836 non-null    object
#  11  Stages              1503 non-null   object
#  12  Years of Existence  1503 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 164.4+ KB

# %%
# Assuming df is your DataFrame
#df['Funding_Year'] = df['Funding_Year'].astype(float)  # Convert to float first
df['Funding_Year'] = df['Funding_Year'].astype('int64').astype('int32')    # Convert to integer to remove decimal places
# Assuming df is your DataFrame
#df['Funding_Year'] = pd.to_datetime(df['Funding_Year'], format='%Y', errors='coerce')


df['Founded'] = df['Founded'].astype('int64').astype('int32')

# %%
# Display the updated DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1503 entries, 1 to 1208
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Name        1503 non-null   object
#  1   Founded             1503 non-null   int32
#  2   Location            1503 non-null   object
#  3   Sector              1495 non-null   object
#  4   What_it_does        1503 non-null   object
#  5   Founders            1495 non-null   object
#  6   Investor            1503 non-null   object
#  7   Amount              1503 non-null   float64
#  8   Stage               1503 non-null   object
#  9   Funding_Year        1503 non-null   int32
#  10  Main_Sector         836 non-null    object
#  11  Stages              1503 non-null   object
#  12  Years of Existence  1503 non-null   float64
# dtypes: float64(2), int32(2), object(9)
# memory usage: 152.6+ KB

# %%
#df['Funding_Year'] = df['Funding_Year'].round()

# %% [markdown]
# df[df['Industry'].isnull()]

# %%
df.isna().sum()
# Out:
# Company_Name            0
# Founded                 0
# Location                0
# Sector                  8
# What_it_does            0
# Founders                8
# Investor                0
# Amount                  0
# Stage                   0
# Funding_Year            0
# Main_Sector           667
# Stages                  0
# Years of Existence      0
# dtype: int64

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### Loading Data with initial statistics

# %%
# Send Data to CSV file

df.to_csv('30cleaned_data.csv', index=False)
df.head()
df.info()
df.describe()
df.describe(include='object')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1503 entries, 1 to 1208
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Name        1503 non-null   object
#  1   Founded             1503 non-null   int32
#  2   Location            1503 non-null   object
#  3   Sector              1495 non-null   object
#  4   What_it_does        1503 non-null   object
#  5   Founders            1495 non-null   object
#  6   Investor            1503 non-null   object
#  7   Amount              1503 non-null   float64
#  8   Stage               1503 non-null   object
#  9   Funding_Year        1503 non-null   int32
#  10  Main_Sector         836 non-null    object
#  11  Stages              1503 non-null   object
#  12  Years of Existence  1503 non-null   float64
# dtypes: float64(2), int32(2), object(9)
# memory usage: 152.6+ KB
#        Company_Name   Location   Sector  \
# count          1503       1503     1495
# unique         1218         88      381
# top        BharatPe  Bangalore  FinTech
# freq             10        541      133
#
#                                              What_it_does  \
# count                                                1503
# unique                                               1423
# top     Mobile Premier League is a skill-based eSports...
# freq                                                    4
#
#                                 Founders                   Investor Stage  \
# count                               1495                       1503  1503
# unique                              1322                        997    45
# top     Ashneer Grover, Shashvat Nakrani  Inflection Point Ventures
# freq                                   7                         31   522
#
#               Main_Sector      Stages
# count                 836        1503
# unique                 19           5
# top     Commerce & Retail  Validation
# freq                  157         564

# %% [markdown]
# ### Univariate Analysis and cleaning

# %%
# Check summary statistics
df.describe()
# Out:
#            Founded        Amount  Funding_Year  Years of Existence
# count  1503.000000  1.503000e+03   1503.000000         1503.000000
# mean   2017.954092  1.121979e+08   2020.545576            2.591484
# std       1.759477  3.869014e+09      0.551374            1.592085
# min    2014.000000  1.000000e+04   2019.000000            0.000000
# 25%    2016.000000  1.000000e+06   2020.000000            1.000000
# 50%    2018.000000  3.000000e+06   2021.000000            2.000000
# 75%    2019.000000  5.800000e+06   2021.000000            4.000000
# max    2021.000000  1.500000e+11   2021.000000            5.000000

# %% [markdown]
# #### Checking for duplicates

# %%
# Check for duplicates in the DataFrame
df[df.duplicated(keep= False)]
# Out:
#            Company_Name  Founded   Location  \
# 94            Curefoods     2020  Bangalore
# 106              Ruptok     2020  New Delhi
# 107           Curefoods     2020  Bangalore
# 119              Ruptok     2020  New Delhi
# 229            Trinkerr     2021  Bangalore
# 230               Zorro     2021   Gurugram
# 231       Ultraviolette     2021  Bangalore
# 233             Unremot     2020  Bangalore
# 234         FanAnywhere     2021  Bangalore
# 235          PingoLearn     2021       Pune
# 236                Spry     2021     Mumbai
# 238       ASQI Advisors     2019     Mumbai
# 239  Insurance Samadhan     2018  New Delhi
# 240     Evenflow Brands     2020     Mumbai
# 241          MasterChow     2020
# 243            Trinkerr     2021  Bangalore
# 244               Zorro     2021   Gurugram
# 245       Ultraviolette     2021  Bangalore
# 247             Unremot     2020  Bangalore
# 248         FanAnywhere     2021  Bangalore
# 249          PingoLearn     2021       Pune
# 250                Spry     2021     Mumbai
# 252       ASQI Advisors     2019     Mumbai
# 253  Insurance Samadhan     2018  New Delhi
# 254     Evenflow Brands     2020     Mumbai
# 255          MasterChow     2020
#
#                                 Sector  \
# 94                    Food & Beverages
# 106                            FinTech
# 107                   Food & Beverages
# 119                            FinTech
# 229                    Capital Markets
# 230                     Social network
# 231                         Automotive
# 233  Information Technology & Services
# 234                 Financial Services
# 235                         E-learning
# 236                              Music
# 238                 Financial Services
# 239                          Insurance
# 240                     Consumer Goods
# 241                          Hauz Khas
# 243                    Capital Markets
# 244                     Social network
# 245                         Automotive
# 247  Information Technology & Services
# 248                 Financial Services
# 249                         E-learning
# 250                              Music
# 252                 Financial Services
# 253                          Insurance
# 254                     Consumer Goods
# 255                          Hauz Khas
#
#                                           What_it_does  \
# 94   Healthy & nutritious foods and cold pressed ju...
# 106  Ruptok fintech Pvt. Ltd. is an online gold loa...
# 107  Healthy & nutritious foods and cold pressed ju...
# 119  Ruptok fintech Pvt. Ltd. is an online gold loa...
# 229  Trinkerr is India's first social trading platf...
# 230               Pseudonymous social network platform
# 231  Create and Inspire the future of sustainable u...
# 233      Unremot is a personal office for consultants!
# 234                             Celebrity NFT platform
# 235  PingoLearn offers language learning courses wi...
# 236  THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 238  Bringing Blockchain technology intro mainstrea...
# 239  The insurance industry will help in representa...
# 240  Identify and partner with the upcoming eCommer...
# 241                A ready-to-cook Asian cuisine brand
# 243  Trinkerr is India's first social trading platf...
# 244               Pseudonymous social network platform
# 245  Create and Inspire the future of sustainable u...
# 247      Unremot is a personal office for consultants!
# 248                             Celebrity NFT platform
# 249  PingoLearn offers language learning courses wi...
# 250  THE BEST ROYALTY-FREE MUSIC TO CREATE TRENDING...
# 252  Bringing Blockchain technology intro mainstrea...
# 253  The insurance industry will help in representa...
# 254  Identify and partner with the upcoming eCommer...
# 255                A ready-to-cook Asian cuisine brand
#
#                                           Founders                   Investor  \
# 94                                    Ankit Nagori               Binny Bansal
# 106                                    Ankur Gupta             Eclear Leasing
# 107                                   Ankit Nagori               Binny Bansal
# 119                                    Ankur Gupta             Eclear Leasing
# 229                Manvendra Singh, Gaurav Agarwal                Accel India
# 230  Jasveer Singh, Abhishek Asthana, Deepak Kumar                Ankiti Bose
# 231            Subramaniam Narayan, Niraj Rajmohan                       Zoho
# 233                            Shiju Radhakrishnan  Inflection Point Ventures
# 234                    Varun Chaudhary, Amit Kumar           DeltaHub Capital
# 235             Mohit Menghani, Shubham Maheshwari        AngelList Syndicate
# 236                Gaurav Dagaonkar, Meghna Mittal             Ashneer Grover
# 238                                  Swapnil Pawar      Founders Room Capital
# 239                     Deepak Bhuvenshwari Uniyal                        ZNL
# 240                  Utsav Agarwal, Pulkit Chhabra               A91 Partners
# 241                  Vidur Kataria, Sidhanth Madan               WEH Ventures
# 243                Manvendra Singh, Gaurav Agarwal                Accel India
# 244  Jasveer Singh, Abhishek Asthana, Deepak Kumar                Ankiti Bose
# 245            Subramaniam Narayan, Niraj Rajmohan                       Zoho
# 247                            Shiju Radhakrishnan  Inflection Point Ventures
# 248                    Varun Chaudhary, Amit Kumar           DeltaHub Capital
# 249             Mohit Menghani, Shubham Maheshwari        AngelList Syndicate
# 250                Gaurav Dagaonkar, Meghna Mittal             Ashneer Grover
# 252                                  Swapnil Pawar      Founders Room Capital
# 253                     Deepak Bhuvenshwari Uniyal                        ZNL
# 254                  Utsav Agarwal, Pulkit Chhabra               A91 Partners
# 255                  Vidur Kataria, Sidhanth Madan               WEH Ventures
#
#           Amount         Stage  Funding_Year              Main_Sector  \
# 94    13000000.0                        2021          Food & Beverage
# 106    1000000.0                        2021                     None
# 107   13000000.0                        2021          Food & Beverage
# 119    1000000.0                        2021                     None
# 229    6600000.0      Series A          2021       Financial Services
# 230   32000000.0          Seed          2021                     None
# 231  150000000.0      Series C          2021                Transport
# 233     700000.0          Seed          2021    Software & Technology
# 234    3000000.0          Seed          2021       Financial Services
# 235     200000.0                        2021        Commerce & Retail
# 236    1500000.0          Seed          2021  Media and Entertainment
# 238    1000000.0  Pre-series A          2021       Financial Services
# 239     725000.0  Pre-series A          2021       Financial Services
# 240     500000.0                        2021        Commerce & Retail
# 241     461000.0          Seed          2021                     None
# 243    6600000.0      Series A          2021       Financial Services
# 244   32000000.0          Seed          2021                     None
# 245  150000000.0      Series C          2021                Transport
# 247     700000.0          Seed          2021    Software & Technology
# 248    3000000.0          Seed          2021       Financial Services
# 249     200000.0                        2021        Commerce & Retail
# 250    1500000.0          Seed          2021  Media and Entertainment
# 252    1000000.0  Pre-series A          2021       Financial Services
# 253     725000.0  Pre-series A          2021       Financial Services
# 254     500000.0                        2021        Commerce & Retail
# 255     461000.0          Seed          2021                     None
#
#              Stages  Years of Existence
# 94          Unknown                 1.0
# 106         Unknown                 1.0
# 107         Unknown                 1.0
# 119         Unknown                 1.0
# 229  Early Traction                 0.0
# 230      Validation                 0.0
# 231         Scaling                 0.0
# 233      Validation                 1.0
# 234      Validation                 0.0
# 235         Unknown                 0.0
# 236      Validation                 0.0
# 238      Validation                 2.0
# 239      Validation                 3.0
# 240         Unknown                 1.0
# 241      Validation                 1.0
# 243  Early Traction                 0.0
# 244      Validation                 0.0
# 245         Scaling                 0.0
# 247      Validation                 1.0
# 248      Validation                 0.0
# 249         Unknown                 0.0
# 250      Validation                 0.0
# 252      Validation                 2.0
# 253      Validation                 3.0
# 254         Unknown                 1.0
# 255      Validation                 1.0

# %%
# Count the number of duplicate rows in the DataFrame
df.duplicated(keep= False).sum()
# Out:
# 26

# %%
# Remove duplicate rows from the DataFrame
df.drop_duplicates(keep='first', inplace=True)

# Count the number of duplicate rows in the DataFrame
df.duplicated(keep= False).sum()
# Out:
# 0

# %%
# copying datasets
backup= df
backup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1490 entries, 1 to 1208
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Company_Name        1490 non-null   object
#  1   Founded             1490 non-null   int32
#  2   Location            1490 non-null   object
#  3   Sector              1482 non-null   object
#  4   What_it_does        1490 non-null   object
#  5   Founders            1482 non-null   object
#  6   Investor            1490 non-null   object
#  7   Amount              1490 non-null   float64
#  8   Stage               1490 non-null   object
#  9   Funding_Year        1490 non-null   int32
#  10  Main_Sector         826 non-null    object
#  11  Stages              1490 non-null   object
#  12  Years of Existence  1490 non-null   float64
# dtypes: float64(2), int32(2), object(9)
# memory usage: 151.3+ KB

# %%
# Export the DataFrame to a CSV file
backup.to_csv('31df_backup.csv', index=False)

# %% [markdown]
# ##### Distribution of Numeric Columns:

# %%
# plot histogram on the numerical columns 
df.hist()
# Out:
# array([[<Axes: title={'center': 'Founded'}>,
#         <Axes: title={'center': 'Amount'}>],
#        [<Axes: title={'center': 'Funding_Year'}>,
#         <Axes: title={'center': 'Years of Existence'}>]], dtype=object)

# %%
# box plot to check for outliers and the quartiles of the dataset
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# #### Univariate analysis for categorical columns

# %%
# Create the box plot using Plotly Express
fig = px.box(df, x='Main_Sector', y='Amount', title='Amount($) Distribution Across Main_Sector',
             labels={'sector': 'Sector', 'amount($)': 'Amount($)'})
fig.update_layout(xaxis={'categoryorder': 'total descending'},
                  height=500,
                  width=900)
fig.show()

# %% [markdown]
# ##### Categoricala

# %% [markdown]
# ##### Bivaraite
#
# Numerical-Numerical relationship

# %%
# Create a scatter plot using Plotly Express
fig = px.scatter(df, x='Funding_Year', y='Amount', title='Amount($) vs. Funding_Year',
labels={'Year': 'Funding_Year', 'amount($)': 'Amount($)'})

# Customize the layout
fig.update_layout(xaxis_title='Funding_Year', yaxis_title='Amount($)', xaxis_tickangle=-45, height =500, width = 900)

# Show the plot
fig.show()

# %%
# Drop duplicate rows
df = df.drop_duplicates()

# List of categorical columns
categorical_columns = ['Stages', 'Location']

# Plotting frequency count for each categorical column
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    
    # Count occurrences of each category
    counts = df[column].value_counts().head(20)
    
    # Convert the counts series into a DataFrame for plotting
    counts_df = pd.DataFrame({column: counts.index, 'Frequency': counts.values})
    
    sns.barplot(data=counts_df, y=column, x='Frequency', orient='h')
    plt.title(f'Top 20 Frequency Counts for {column}')
    plt.xlabel('Frequency')
    plt.ylabel(column)
    plt.show()

# %%
# Univariate analysis for categorical columns
categorical_columns = [ 'Main_Sector']

for column in categorical_columns:
    plt.figure(figsize=(9, 6))
    sns.countplot(df[column])
    plt.title(f'Frequency Counts for {column}')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# ##### Categorical vs. Numerical

# %%
# Categorical vs. Numerical
plt.figure(figsize=(18, 20))

# Adjust vertical space between subplots
plt.subplots_adjust(hspace=0.5)

# Categorical: Main Sector vs. Numerical: Amount (Column Chart)
plt.subplot(4, 2, 1)
top_10_main_sector = df['Main_Sector'].value_counts().head(10).index
sns.barplot(x='Main_Sector', y='Amount', data=df[df['Main_Sector'].isin(top_10_main_sector)])
plt.title('Main_Sector vs. Amount')
plt.xticks(rotation=45, ha='right') 

# Categorical: Main Sector vs. Numerical: Years of Existence (Column Chart)
plt.subplot(4, 2, 2)
sns.barplot(x='Main_Sector', y='Years of Existence', data=df[df['Main_Sector'].isin(top_10_main_sector)])
plt.title('Main_Sector vs. Years of Existence')
plt.xticks(rotation=45, ha='right')


# Categorical: Top 10 Stage vs. Numerical: Amount (Column Chart)
plt.subplot(4, 2, 4)
top_10_stage = df['Stages'].value_counts().head(10).index
sns.barplot(x='Stages', y='Amount', data=df[df['Stages'].isin(top_10_stage)])
plt.title('Top 10 Stages vs. Amount')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Numerical vs. Numerical

# %%
# Numerical vs. Numerical
plt.figure(figsize=(15, 5))

# Founded vs. Years of Existence
plt.subplot(1, 3, 3)
sns.scatterplot(x='Founded', y='Years of Existence', data=df)
plt.title('Founded vs. Years of Existence')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Hypothesis Testing

# %% [markdown]
# ####
# Null Hypothesis(Ho): There is no significant difference in the amount of funding between startups in Bangalore.
# ####
# Alternative Hypothesis(Ha): There is a significant difference in the amount of funding between startups in Bangalore.

# %%
from scipy.stats import kruskal

# Assuming 'final_dataset' contains the startup data and 'Location' denotes the location of each startup
# Extract funding amounts for startups in Bangalore and those outside Bangalore
funding_in_bangalore = df[df['Location'] == 'Bangalore']['Amount']
funding_outside_bangalore = df[df['Location'] != 'Bangalore']['Amount']

# Perform Kruskal-Wallis H test
h_statistic, p_value = kruskal(funding_in_bangalore, funding_outside_bangalore)

# Print the test statistic and p-value
print("Kruskal-Wallis H Test:")
print("H Statistic:", h_statistic)
print("p-value:", p_value)

# Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the funding amounts between Bangalore startups and startups outside Bangalore.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in the funding amounts between Bangalore startups and startups outside Bangalore.")
# Out:
# Kruskal-Wallis H Test:
# H Statistic: 18.65299566558136
# p-value: 1.5680071144135714e-05
# Reject the null hypothesis. There is a significant difference in the funding amounts between Bangalore startups and startups outside Bangalore.

# %% [markdown]
# #### Business Questions
#
# 1.What sectors, Main_Sector and Industry have shown the highest growth in terms of funding received over the past four years?

# %%
# Group by sector and sum the funding for each year
grouped = df.groupby(['Main_Sector']).sum()[['Amount']]

# Calculate the growth rate over the four-year period
grouped['Growth_rate'] = (grouped['Amount'] - grouped['Amount'].iloc[0]) / grouped['Amount'].iloc[0] * 100

# Sort sectors by growth rate
grouped.sort_values(by='Growth_rate', ascending=False, inplace=True)

# Plot the growth rates
plt.figure(figsize=(10, 6))
plt.barh(grouped.index, grouped['Growth_rate'], color='skyblue')
plt.xlabel('Growth Rate (%)')
plt.title('Sector-wise Growth Rate of Funding (2018-2021)')
plt.gca().invert_yaxis()  # Invert y-axis to show highest growth at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate total funding received for each combination of 'Sector' and 'Funding_Year'
data = df.groupby(['Main_Sector', 'Funding_Year'])['Amount'].sum().reset_index()

# Calculate total funding received by each sector
total_funding = df.groupby('Main_Sector')['Amount'].sum()

# Get top 5 sectors by total funding
top_5_sectors = total_funding.nlargest(5).index

# Filter the DataFrame for only the top 5 sectors
top_5_growth = df[df['Main_Sector'].isin(top_5_sectors)]

# Aggregate the data to remove duplicates
pivot_table = top_5_growth.groupby(['Funding_Year', 'Main_Sector'])['Amount'].sum().unstack()

# Plot the total funding received for each sector over the years (line plot)
pivot_table.plot(kind='line', figsize=(12, 6))
plt.title('Total Growth in Funding Received by Top 5 Sectors (2018-2021)')
plt.xlabel('Year')
plt.ylabel('Total Funding Received')
plt.xticks(rotation=45, ha='right')
plt.xticks(np.arange(min(pivot_table.index), max(pivot_table.index)+1, 1))  # Set integer ticks for years
plt.legend(title='Main_Sector')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Group by sector, main sector, and industry and sum the funding for each year
grouped_industry = df.groupby(['Sector', 'Main_Sector']).sum()[['Amount']]

# Reset index for easier manipulation
grouped_industry.reset_index(inplace=True)

# Calculate the growth rate over the four-year period for each industry
industry_growth = {}
for industry in grouped_industry['Main_Sector'].unique():
    industry_data = grouped_industry[grouped_industry['Main_Sector'] == industry]
    growth_rate = (industry_data['Amount'].iloc[-1] - industry_data['Amount'].iloc[0]) / industry_data['Amount'].iloc[0] * 100
    industry_growth[industry] = growth_rate

# Sort industries by growth rate
sorted_industry_growth = sorted(industry_growth.items(), key=lambda x: x[1], reverse=True)[:10]  # Let's take the top 10 growing industries

# Plot the growth rates for industries
plt.figure(figsize=(10, 8))
industries, growth_rates = zip(*sorted_industry_growth)
plt.barh(industries, growth_rates, color='lightblue')
plt.xlabel('Growth Rate (%)')
plt.title('Industry-wise Growth Rate of Funding (2018-2021)')
plt.gca().invert_yaxis()  # Invert y-axis to show highest growth at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 2.What geographical regions within India have emerged as the primary hubs for startup activity and investment, and what factors contribute to their prominence?

# %%
import pandas as pd

# Assuming 'df' is your DataFrame containing startup data

# Grouping by City and calculating total funding
city_funding = df.groupby('Location')['Amount'].sum().sort_values(ascending=False).reset_index(name='Total_Funding')

# Grouping by City and counting the number of startups
city_startups = df.groupby('Location').size().sort_values(ascending=False).reset_index(name='Total_Startups')

# Merge the two dataframes
city_summary = pd.merge(city_funding, city_startups, on='Location')

# Calculate average funding per startup for each city
city_summary['Average_Funding_per_Startup'] = city_summary['Total_Funding'] / city_summary['Total_Startups']

# Display top 5 cities by total funding and number of startups
print("Top 5 cities by total funding and number of startups:")
print(city_summary.head())

# Display top 5 cities by average funding per startup
print("\nTop 5 cities by average funding per startup:")
print(city_summary.sort_values(by='Average_Funding_per_Startup', ascending=False).head())

# Example: Sector diversity analysis by city
sector_distribution = df.groupby(['Location', 'Main_Sector']).size().unstack(fill_value=0)
print("\nSector distribution by Location:")
print(sector_distribution)

# Example: Talent availability analysis (if data available)
# This could involve analyzing the presence of educational institutions, tech talent pools, etc.

# Example: Investor interest analysis (if data available)
# This could involve analyzing the number of funding rounds, top investors in each city, etc.
# Out:
# Top 5 cities by total funding and number of startups:
#     Location  Total_Funding  Total_Startups  Average_Funding_per_Startup
# 0     Mumbai   1.514932e+11             217                 6.981253e+08
# 1  Bangalore   9.912721e+09             536                 1.849388e+07
# 2  New Delhi   2.150534e+09             143                 1.503870e+07
# 3   Gurugram   1.184364e+09             157                 7.543718e+06
# 4       Pune   5.330440e+08              55                 9.691709e+06
#
# Top 5 cities by average funding per startup:
#                            Location  Total_Funding  Total_Startups  \
# 0                            Mumbai   1.514932e+11             217
# 13            San Ramon, California   1.500000e+08               1
# 14  London, England, United Kingdom   1.180000e+08               1
# 10                                    2.086610e+08               5
# 15                    San Francisco   7.900000e+07               2
#
#     Average_Funding_per_Startup
# 0                  6.981253e+08
# 13                 1.500000e+08
# 14                 1.180000e+08
# 10                 4.173220e+07
# 15                 3.950000e+07
#
# Sector distribution by Location:
# Main_Sector                       Agriculture  Beauty and Fashion  \
# Location
#                                             0                   0
#  Jaipur                                     1                   0
# Ahmedabad                                   0                   1
# Ambernath                                   0                   0
# Andhra Pradesh                              0                   0
# Bangaldesh                                  0                   0
# Bangalore                                  22                   6
# Belgaum                                     0                   0
# Bhilwara                                    0                   0
# Bhubaneswar                                 0                   0
# Bihar                                       1                   0
# California                                  1                   0
# Chandigarh                                  1                   1
# Chennai                                     8                   1
# Coimbatore                                  0                   0
# Delhi                                       2                   1
# Faridabad                                   0                   0
# Frisco, Texas, United States                0                   0
# Gandhinagar                                 1                   0
# Ghaziabad                                   0                   0
# Gujarat                                     0                   0
# Gurgaon                                     0                   0
# Gurugram                                    4                   7
# Hyderabad                                   1                   0
# Indore                                      2                   0
# Jaipur                                      0                   2
# Jodhpur                                     1                   0
# Kanpur                                      0                   0
# Kerala                                      1                   0
# Kochi                                       1                   0
# Kolkata                                     0                   0
# Kottayam                                    0                   0
# London                                      0                   0
# Lucknow                                     0                   0
# Mumbai                                      1                  11
# Nagpur                                      0                   0
# New Delhi                                   1                   2
# New York                                    0                   0
# Noida                                       2                   0
# Nolda                                       0                   0
# Patna                                       1                   0
# Powai                                       0                   0
# Pune                                        4                   0
# Rajsamand                                   1                   0
# Ranchi                                      2                   0
# Roorkee                                     0                   0
# Satara                                      0                   0
# Surat                                       0                   1
# Sydney                                      0                   0
# Tangerang, Jawa Barat, Indonesia            0                   0
# Thane                                       0                   0
# The Nilgiris                                1                   0
# Thiruvananthapuram                          0                   0
# Tirunelveli, Tamilnadu                      0                   0
# Trivandrum                                  0                   0
# Vadodara                                    0                   0
#
# Main_Sector                       Business Services  Commerce & Retail  \
# Location
#                                                   0                  0
#  Jaipur                                           0                  0
# Ahmedabad                                         1                  1
# Ambernath                                         0                  1
# Andhra Pradesh                                    0                  1
# Bangaldesh                                        0                  1
# Bangalore                                        11                 45
# Belgaum                                           0                  0
# Bhilwara                                          0                  0
# Bhubaneswar                                       0                  0
# Bihar                                             0                  0
# California                                        0                  0
# Chandigarh                                        0                  3
# Chennai                                           0                  2
# Coimbatore                                        0                  0
# Delhi                                             1                  2
# Faridabad                                         0                  0
# Frisco, Texas, United States                      0                  0
# Gandhinagar                                       0                  0
# Ghaziabad                                         0                  1
# Gujarat                                           0                  0
# Gurgaon                                           0                  2
# Gurugram                                          6                 25
# Hyderabad                                         2                  9
# Indore                                            0                  0
# Jaipur                                            0                  5
# Jodhpur                                           0                  0
# Kanpur                                            0                  0
# Kerala                                            0                  0
# Kochi                                             0                  0
# Kolkata                                           2                  3
# Kottayam                                          0                  0
# London                                            0                  0
# Lucknow                                           0                  0
# Mumbai                                            4                 23
# Nagpur                                            0                  0
# New Delhi                                         6                 17
# New York                                          0                  0
# Noida                                             0                  4
# Nolda                                             0                  1
# Patna                                             0                  0
# Powai                                             0                  0
# Pune                                              1                  3
# Rajsamand                                         0                  0
# Ranchi                                            0                  0
# Roorkee                                           0                  0
# Satara                                            0                  0
# Surat                                             0                  1
# Sydney                                            0                  1
# Tangerang, Jawa Barat, Indonesia                  0                  0
# Thane                                             0                  2
# The Nilgiris                                      0                  0
# Thiruvananthapuram                                1                  0
# Tirunelveli, Tamilnadu                            0                  1
# Trivandrum                                        0                  1
# Vadodara                                          0                  0
#
# Main_Sector                       Education  Energy & Renewable Resources  \
# Location
#                                           0                             0
#  Jaipur                                   0                             0
# Ahmedabad                                 0                             1
# Ambernath                                 0                             0
# Andhra Pradesh                            0                             0
# Bangaldesh                                0                             0
# Bangalore                                 1                             1
# Belgaum                                   0                             0
# Bhilwara                                  0                             0
# Bhubaneswar                               0                             0
# Bihar                                     0                             0
# California                                0                             0
# Chandigarh                                0                             0
# Chennai                                   0                             0
# Coimbatore                                0                             1
# Delhi                                     1                             0
# Faridabad                                 0                             0
# Frisco, Texas, United States              0                             0
# Gandhinagar                               0                             0
# Ghaziabad                                 0                             0
# Gujarat                                   0                             1
# Gurgaon                                   0                             0
# Gurugram                                  0                             1
# Hyderabad                                 0                             0
# Indore                                    0                             0
# Jaipur                                    0                             0
# Jodhpur                                   0                             0
# Kanpur                                    0                             1
# Kerala                                    0                             0
# Kochi                                     0                             0
# Kolkata                                   0                             0
# Kottayam                                  0                             0
# London                                    0                             0
# Lucknow                                   0                             0
# Mumbai                                    0                             1
# Nagpur                                    0                             0
# New Delhi                                 2                             4
# New York                                  0                             0
# Noida                                     1                             1
# Nolda                                     0                             0
# Patna                                     0                             0
# Powai                                     0                             0
# Pune                                      0                             1
# Rajsamand                                 0                             0
# Ranchi                                    0                             0
# Roorkee                                   0                             1
# Satara                                    0                             0
# Surat                                     0                             0
# Sydney                                    0                             0
# Tangerang, Jawa Barat, Indonesia          0                             0
# Thane                                     0                             0
# The Nilgiris                              0                             0
# Thiruvananthapuram                        0                             0
# Tirunelveli, Tamilnadu                    0                             0
# Trivandrum                                0                             0
# Vadodara                                  0                             0
#
# Main_Sector                       Financial Services  Food & Beverage  \
# Location
#                                                    0                0
#  Jaipur                                            0                0
# Ahmedabad                                          0                0
# Ambernath                                          0                0
# Andhra Pradesh                                     0                0
# Bangaldesh                                         0                0
# Bangalore                                         42               16
# Belgaum                                            0                1
# Bhilwara                                           1                0
# Bhubaneswar                                        0                0
# Bihar                                              0                0
# California                                         0                0
# Chandigarh                                         2                1
# Chennai                                            1                3
# Coimbatore                                         0                0
# Delhi                                              1                1
# Faridabad                                          0                0
# Frisco, Texas, United States                       0                0
# Gandhinagar                                        0                0
# Ghaziabad                                          0                0
# Gujarat                                            0                0
# Gurgaon                                            0                2
# Gurugram                                           5                5
# Hyderabad                                          4                2
# Indore                                             0                1
# Jaipur                                             0                0
# Jodhpur                                            0                0
# Kanpur                                             0                0
# Kerala                                             0                0
# Kochi                                              0                0
# Kolkata                                            0                0
# Kottayam                                           0                0
# London                                             1                0
# Lucknow                                            0                1
# Mumbai                                            18                9
# Nagpur                                             0                0
# New Delhi                                         16                5
# New York                                           0                0
# Noida                                              3                0
# Nolda                                              0                0
# Patna                                              0                0
# Powai                                              0                0
# Pune                                               6                1
# Rajsamand                                          0                0
# Ranchi                                             0                0
# Roorkee                                            0                0
# Satara                                             0                0
# Surat                                              0                0
# Sydney                                             0                0
# Tangerang, Jawa Barat, Indonesia                   0                1
# Thane                                              0                0
# The Nilgiris                                       0                0
# Thiruvananthapuram                                 0                0
# Tirunelveli, Tamilnadu                             0                0
# Trivandrum                                         0                0
# Vadodara                                           0                0
#
# Main_Sector                       Government   Health & Life Sciences  \
# Location
#                                             0                       0
#  Jaipur                                     0                       0
# Ahmedabad                                   0                       0
# Ambernath                                   0                       0
# Andhra Pradesh                              0                       0
# Bangaldesh                                  0                       0
# Bangalore                                   2                      26
# Belgaum                                     0                       0
# Bhilwara                                    0                       0
# Bhubaneswar                                 0                       1
# Bihar                                       0                       0
# California                                  0                       0
# Chandigarh                                  0                       1
# Chennai                                     1                       2
# Coimbatore                                  0                       0
# Delhi                                       0                       3
# Faridabad                                   0                       0
# Frisco, Texas, United States                0                       0
# Gandhinagar                                 0                       0
# Ghaziabad                                   0                       0
# Gujarat                                     0                       0
# Gurgaon                                     0                       2
# Gurugram                                    0                       7
# Hyderabad                                   0                       1
# Indore                                      0                       0
# Jaipur                                      0                       0
# Jodhpur                                     0                       2
# Kanpur                                      0                       1
# Kerala                                      0                       0
# Kochi                                       0                       1
# Kolkata                                     0                       2
# Kottayam                                    0                       0
# London                                      0                       0
# Lucknow                                     0                       0
# Mumbai                                      0                      17
# Nagpur                                      0                       1
# New Delhi                                   0                      10
# New York                                    0                       0
# Noida                                       1                       1
# Nolda                                       0                       0
# Patna                                       0                       0
# Powai                                       0                       0
# Pune                                        0                       6
# Rajsamand                                   0                       0
# Ranchi                                      0                       0
# Roorkee                                     0                       0
# Satara                                      0                       1
# Surat                                       0                       0
# Sydney                                      0                       0
# Tangerang, Jawa Barat, Indonesia            0                       0
# Thane                                       0                       0
# The Nilgiris                                0                       0
# Thiruvananthapuram                          0                       0
# Tirunelveli, Tamilnadu                      0                       0
# Trivandrum                                  0                       0
# Vadodara                                    0                       0
#
# Main_Sector                       Hospitality  Manufacturing  \
# Location
#                                             0              0
#  Jaipur                                     0              0
# Ahmedabad                                   1              0
# Ambernath                                   0              0
# Andhra Pradesh                              0              0
# Bangaldesh                                  0              0
# Bangalore                                   8              4
# Belgaum                                     0              0
# Bhilwara                                    0              0
# Bhubaneswar                                 0              0
# Bihar                                       0              0
# California                                  0              0
# Chandigarh                                  0              0
# Chennai                                     0              1
# Coimbatore                                  0              0
# Delhi                                       1              0
# Faridabad                                   0              0
# Frisco, Texas, United States                0              0
# Gandhinagar                                 0              0
# Ghaziabad                                   0              0
# Gujarat                                     0              0
# Gurgaon                                     0              0
# Gurugram                                    6              0
# Hyderabad                                   1              0
# Indore                                      0              0
# Jaipur                                      0              0
# Jodhpur                                     0              0
# Kanpur                                      0              0
# Kerala                                      0              0
# Kochi                                       0              0
# Kolkata                                     1              0
# Kottayam                                    0              0
# London                                      0              0
# Lucknow                                     0              0
# Mumbai                                      1              2
# Nagpur                                      0              0
# New Delhi                                   3              0
# New York                                    0              0
# Noida                                       2              0
# Nolda                                       0              0
# Patna                                       0              0
# Powai                                       0              1
# Pune                                        1              0
# Rajsamand                                   0              0
# Ranchi                                      0              0
# Roorkee                                     0              0
# Satara                                      0              0
# Surat                                       0              0
# Sydney                                      0              0
# Tangerang, Jawa Barat, Indonesia            0              0
# Thane                                       0              0
# The Nilgiris                                0              0
# Thiruvananthapuram                          0              0
# Tirunelveli, Tamilnadu                      0              0
# Trivandrum                                  0              0
# Vadodara                                    0              0
#
# Main_Sector                       Media and Entertainment  Others  \
# Location
#                                                         0       0
#  Jaipur                                                 0       0
# Ahmedabad                                               0       0
# Ambernath                                               0       0
# Andhra Pradesh                                          0       0
# Bangaldesh                                              0       0
# Bangalore                                               9       6
# Belgaum                                                 0       0
# Bhilwara                                                0       0
# Bhubaneswar                                             0       0
# Bihar                                                   0       0
# California                                              0       0
# Chandigarh                                              0       0
# Chennai                                                 0       0
# Coimbatore                                              0       0
# Delhi                                                   1       2
# Faridabad                                               0       0
# Frisco, Texas, United States                            1       0
# Gandhinagar                                             0       0
# Ghaziabad                                               0       0
# Gujarat                                                 1       0
# Gurgaon                                                 0       0
# Gurugram                                                1       2
# Hyderabad                                               0       0
# Indore                                                  1       0
# Jaipur                                                  0       1
# Jodhpur                                                 0       0
# Kanpur                                                  0       0
# Kerala                                                  0       0
# Kochi                                                   0       0
# Kolkata                                                 0       0
# Kottayam                                                0       0
# London                                                  0       0
# Lucknow                                                 0       0
# Mumbai                                                  5       0
# Nagpur                                                  0       0
# New Delhi                                               1       0
# New York                                                0       1
# Noida                                                   0       0
# Nolda                                                   0       0
# Patna                                                   0       0
# Powai                                                   0       0
# Pune                                                    0       0
# Rajsamand                                               0       0
# Ranchi                                                  0       0
# Roorkee                                                 0       0
# Satara                                                  0       0
# Surat                                                   0       0
# Sydney                                                  0       0
# Tangerang, Jawa Barat, Indonesia                        0       0
# Thane                                                   1       0
# The Nilgiris                                            0       0
# Thiruvananthapuram                                      0       0
# Tirunelveli, Tamilnadu                                  0       0
# Trivandrum                                              0       0
# Vadodara                                                0       0
#
# Main_Sector                       Real Estate and Property  \
# Location
#                                                          0
#  Jaipur                                                  0
# Ahmedabad                                                0
# Ambernath                                                0
# Andhra Pradesh                                           0
# Bangaldesh                                               0
# Bangalore                                                4
# Belgaum                                                  0
# Bhilwara                                                 0
# Bhubaneswar                                              0
# Bihar                                                    0
# California                                               0
# Chandigarh                                               0
# Chennai                                                  0
# Coimbatore                                               0
# Delhi                                                    0
# Faridabad                                                0
# Frisco, Texas, United States                             0
# Gandhinagar                                              0
# Ghaziabad                                                0
# Gujarat                                                  0
# Gurgaon                                                  0
# Gurugram                                                 0
# Hyderabad                                                0
# Indore                                                   0
# Jaipur                                                   0
# Jodhpur                                                  0
# Kanpur                                                   0
# Kerala                                                   0
# Kochi                                                    0
# Kolkata                                                  0
# Kottayam                                                 0
# London                                                   0
# Lucknow                                                  0
# Mumbai                                                   2
# Nagpur                                                   0
# New Delhi                                                0
# New York                                                 0
# Noida                                                    0
# Nolda                                                    0
# Patna                                                    0
# Powai                                                    0
# Pune                                                     1
# Rajsamand                                                0
# Ranchi                                                   0
# Roorkee                                                  0
# Satara                                                   0
# Surat                                                    0
# Sydney                                                   0
# Tangerang, Jawa Barat, Indonesia                         0
# Thane                                                    1
# The Nilgiris                                             0
# Thiruvananthapuram                                       0
# Tirunelveli, Tamilnadu                                   0
# Trivandrum                                               0
# Vadodara                                                 0
#
# Main_Sector                       Social and Community  Software & Technology  \
# Location
#                                                      0                      2
#  Jaipur                                              0                      0
# Ahmedabad                                            0                      1
# Ambernath                                            0                      0
# Andhra Pradesh                                       0                      0
# Bangaldesh                                           0                      0
# Bangalore                                            1                     48
# Belgaum                                              0                      0
# Bhilwara                                             0                      0
# Bhubaneswar                                          0                      0
# Bihar                                                0                      1
# California                                           0                      0
# Chandigarh                                           0                      1
# Chennai                                              0                      3
# Coimbatore                                           0                      0
# Delhi                                                0                      9
# Faridabad                                            0                      0
# Frisco, Texas, United States                         0                      0
# Gandhinagar                                          0                      0
# Ghaziabad                                            0                      0
# Gujarat                                              0                      0
# Gurgaon                                              0                      3
# Gurugram                                             0                     12
# Hyderabad                                            0                      3
# Indore                                               0                      0
# Jaipur                                               0                      1
# Jodhpur                                              0                      0
# Kanpur                                               0                      0
# Kerala                                               0                      1
# Kochi                                                0                      1
# Kolkata                                              0                      1
# Kottayam                                             0                      1
# London                                               0                      0
# Lucknow                                              0                      0
# Mumbai                                               0                     22
# Nagpur                                               0                      0
# New Delhi                                            0                      8
# New York                                             0                      0
# Noida                                                1                      0
# Nolda                                                0                      0
# Patna                                                0                      0
# Powai                                                0                      0
# Pune                                                 0                      4
# Rajsamand                                            0                      0
# Ranchi                                               0                      0
# Roorkee                                              0                      0
# Satara                                               0                      0
# Surat                                                0                      0
# Sydney                                               0                      0
# Tangerang, Jawa Barat, Indonesia                     0                      0
# Thane                                                0                      0
# The Nilgiris                                         0                      0
# Thiruvananthapuram                                   0                      0
# Tirunelveli, Tamilnadu                               0                      0
# Trivandrum                                           0                      0
# Vadodara                                             0                      0
#
# Main_Sector                       Sports & Fitness  Transport
# Location
#                                                  0          0
#  Jaipur                                          0          0
# Ahmedabad                                        0          2
# Ambernath                                        0          0
# Andhra Pradesh                                   0          0
# Bangaldesh                                       0          0
# Bangalore                                        0         29
# Belgaum                                          0          0
# Bhilwara                                         0          0
# Bhubaneswar                                      0          0
# Bihar                                            0          0
# California                                       0          0
# Chandigarh                                       0          1
# Chennai                                          0          3
# Coimbatore                                       0          0
# Delhi                                            0          3
# Faridabad                                        0          1
# Frisco, Texas, United States                     0          0
# Gandhinagar                                      0          0
# Ghaziabad                                        0          2
# Gujarat                                          0          0
# Gurgaon                                          0          2
# Gurugram                                         1         13
# Hyderabad                                        0          3
# Indore                                           0          0
# Jaipur                                           0          1
# Jodhpur                                          0          0
# Kanpur                                           0          0
# Kerala                                           0          0
# Kochi                                            0          0
# Kolkata                                          0          0
# Kottayam                                         0          0
# London                                           0          0
# Lucknow                                          0          0
# Mumbai                                           4          8
# Nagpur                                           0          0
# New Delhi                                        1          8
# New York                                         0          0
# Noida                                            1          0
# Nolda                                            0          0
# Patna                                            0          0
# Powai                                            0          0
# Pune                                             0          4
# Rajsamand                                        0          0
# Ranchi                                           0          0
# Roorkee                                          0          0
# Satara                                           0          0
# Surat                                            0          0
# Sydney                                           0          0
# Tangerang, Jawa Barat, Indonesia                 0          0
# Thane                                            0          0
# The Nilgiris                                     0          0
# Thiruvananthapuram                               0          0
# Tirunelveli, Tamilnadu                           0          0
# Trivandrum                                       0          0
# Vadodara                                         0          1

# %%
# Grouping the dataset based on the headquarters and calculating the total investment amount
top_10_locations_by_investment = df.groupby('Location')['Amount'].sum().reset_index()

# Sorting the grouped data to find the top 10 locations by investment amount
top_10_locations_by_investment = top_10_locations_by_investment.nlargest(10, 'Amount')

# Converting the investment amount into billions
top_10_locations_by_investment['growth_billions'] = top_10_locations_by_investment['Amount'] / 1e9

# Adding a column for the rank
top_10_locations_by_investment['rank'] = top_10_locations_by_investment.index + 1

# Renaming columns
top_10_locations_by_investment.columns = ['Location', 'Amount', 'growth_billions', 'rank']

# %%
# Initialize the Nominatim geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Function to retrieve coordinates for a location
def get_coordinates(location):
    try:
        location_info = geolocator.geocode(location)
        return (location_info.latitude, location_info.longitude) if location_info else (None, None)
    except Exception as e:
        print(f"Error retrieving coordinates for {location}: {str(e)}")
        return None, None

# %%
# Assuming 'df' is your DataFrame containing startup data

# Grouping by City and calculating total funding
city_funding = df.groupby('Location')['Amount'].sum().sort_values(ascending=False).reset_index(name='Total_Funding')

# Grouping by City and counting the number of startups
city_startups = df.groupby('Location').size().sort_values(ascending=False).reset_index(name='Total_Startups')

# Merge the two dataframes
city_summary = pd.merge(city_funding, city_startups, on='Location')

# Calculate average funding per startup for each city
city_summary['Average_Funding_per_Startup'] = city_summary['Total_Funding'] / city_summary['Total_Startups']

# Creating subplots for all visualizations
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Visualizing top cities by total funding
axes[0].bar(city_summary['Location'][:10], city_summary['Total_Funding'][:10], color='skyblue')
axes[0].set_title('Top 10 Cities by Total Funding')
axes[0].set_xlabel('City')
axes[0].set_ylabel('Total Funding (in Millions)')
axes[0].tick_params(axis='x', rotation=45)

# Visualizing top cities by number of startups
axes[1].bar(city_summary['Location'][:10], city_summary['Total_Startups'][:10], color='skyblue')
axes[1].set_title('Top 10 Cities by Number of Startups')
axes[1].set_xlabel('City')
axes[1].set_ylabel('Number of Startups')
axes[1].tick_params(axis='x', rotation=45)

# Visualizing top cities by average funding per startup
axes[2].barh(city_summary['Location'][:10], city_summary['Average_Funding_per_Startup'][:10], color='skyblue')
axes[2].set_title('Top 5 Cities by Average Funding per Startup')
axes[2].set_xlabel('Average Funding per Startup (in Millions)')
axes[2].set_ylabel('City')

# Adjusting layout and displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.Are there any notable differences in funding patterns between early-stage startups and more established companies?

# %%
# Assuming 'df' is your DataFrame containing startup data

# Calculate the overall median year for the 'founded' column
overall_median_per_year = df['Founded'].median()

# Assign startup stages based on the overall median year
df['Stage'] = np.where(df['Founded'] >= overall_median_per_year, 'Early Stage', 'Established')

overall_median_per_year
# Out:
# 2018.0

# %%
# Display the count of each category in the 'stage' column
stage_distribution = df['Stage'].value_counts()

# Print or visualize the distribution
print(stage_distribution)
# Out:
# Stage
# Early Stage    898
# Established    592
# Name: count, dtype: int64

# %%
early_stage_startups = df[df['Stage'] == 'Early Stage']['Amount'].describe()
established_startups = df[df['Stage'] == 'Established']['Amount'].describe()

print("Early Stage Funding Statistics:")
print(early_stage_startups)

print("\nEstablished Funding Statistics:")
print(established_startups)
# Out:
# Early Stage Funding Statistics:
# count    8.980000e+02
# mean     1.768903e+08
# std      5.005363e+09
# min      1.000000e+04
# 25%      8.000000e+05
# 50%      3.000000e+06
# 75%      4.275000e+06
# max      1.500000e+11
# Name: Amount, dtype: float64
#
# Established Funding Statistics:
# count    5.920000e+02
# mean     1.617460e+07
# std      4.791407e+07
# min      4.090000e+04
# 25%      1.399250e+06
# 50%      3.000000e+06
# 75%      9.000000e+06
# max      7.000000e+08
# Name: Amount, dtype: float64

# %% [markdown]
# The funding statistics for early-stage startups show a wide range, with a mean funding amount of approximately $91 million and a standard deviation of around $3.46 billion. The funding amounts vary significantly, from a minimum of $876 to a maximum of $150 billion, indicating a diverse investment landscape for early-stage companies.
#
# On the other hand, established startups have a lower mean funding amount of about $17.6 million, with a standard deviation of approximately $51.7 million. The range of funding is narrower compared to early-stage startups, ranging from $40,900 to $700 million. This suggests that established companies generally receive more stable and moderate funding compared to their early-stage counterparts.

# %%
# Calculate the count of companies by stage
stage_counts = df['Stage'].value_counts()

# Set up the data for the donut chart
labels = stage_counts.index
sizes = stage_counts.values

# Set up colors
colors = plt.cm.tab20c.colors

# Create a donut chart
fig, ax = plt.subplots(figsize=(8, 6))
wedges, texts, autotexts = ax.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.3))

# Draw a circle at the center of the donut to make it a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

# Add count and percentage labels
for i, (text, autotext) in enumerate(zip(texts, autotexts)):
    autotext.set_color('white') 
    autotext.set_fontweight('bold') 
    text.set_text(f'{labels[i]}: {sizes[i]}')

# Add title
plt.title('Distribution of Companies by Stage')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'final_dataset' is your DataFrame containing startup data and 'amount($)' is the funding amount column

# Calculate the total funding amounts for each stage
stage_funding = df.groupby('Stage')['Amount'].sum()

# Create a pie chart
plt.figure(figsize=(8, 6))
stage_funding.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=plt.cm.tab20c.colors)

# Add title
plt.title('Comparison of Funding Amounts between Early Stage and Established Companies')

# Show the plot
plt.show()

# %% [markdown]
# #### 4.Which sectors recieve the lowest level of funding and which sectors recieve the highest levels of funding in India and what factors contribute to this?

# %%
# Assuming 'final_dataset' is your DataFrame containing startup data

# Calculate the total funding amounts for each sector
sector_funding = df.groupby('Main_Sector')['Amount'].sum()

# Convert funding amounts to billions USD
sector_funding_in_billion = sector_funding / 1e9

# Find the sectors with the highest levels of funding
top_funded_sectors = sector_funding_in_billion.nlargest(10)  # Top 10 sectors with highest funding

# Plot the top funded sectors
plt.figure(figsize=(12, 8))
top_funded_sectors.plot(kind='bar', color='skyblue')
plt.title('Top 10 Sectors with Highest Funding in India')
plt.ylabel('Funding Amount (in Billions USD)')
plt.xlabel('Sector')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Annotate the bars with the funding amount
for index, value in enumerate(top_funded_sectors):
    plt.text(index, value, f'${value:.2f}B', ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Show the plot
plt.show()

# %%
# Assuming 'final_dataset' is your DataFrame containing startup data

# Calculate the total funding amounts for each sector
sector_funding = df.groupby('Main_Sector')['Amount'].sum()

# Convert funding amounts to billions USD
sector_funding_in_billion = sector_funding / 1e9

# Find the sectors with the lowest levels of funding
lowest_funded_sectors = sector_funding_in_billion.nsmallest(10)  # Bottom 10 sectors with lowest funding

# Plot the lowest funded sectors
plt.figure(figsize=(12, 8))
lowest_funded_sectors.plot(kind='bar', color='Skyblue')
plt.title('Bottom 10 Sectors with Lowest Funding in India')
plt.ylabel('Funding Amount (in Billions USD)')
plt.xlabel('Sector')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Annotate the bars with the funding amount
for index, value in enumerate(lowest_funded_sectors):
    plt.text(index, value, f'${value:.2f}B', ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Show the plot
plt.show()

# Print the lowest funded sectors for reference
print("Sectors with the lowest levels of funding:")
print(lowest_funded_sectors)
# Out:
# Sectors with the lowest levels of funding:
# Main_Sector
# Government                      0.005600
# Education                       0.007453
# Social and Community            0.029000
# Real Estate and Property        0.056767
# Energy & Renewable Resources    0.060100
# Sports & Fitness                0.062400
# Others                          0.098100
# Manufacturing                   0.150680
# Business Services               0.186990
# Beauty and Fashion              0.202980
# Name: Amount, dtype: float64

# %% [markdown]
# #### 5.Which investors have more impact on startups over the years

# %%
# Group 2018 data by investor and get the sum of the amount
investor_funding_2018 = df[df['Funding_Year'] == 2018].groupby(['Investor', 'Main_Sector'])['Amount'].sum()

# Reset the index to make 'Investor' a column again
investor_funding_2018_reset = investor_funding_2018.reset_index()

# Sort the data by the funding amount in descending order
investor_funding_2018_sorted = investor_funding_2018_reset.sort_values(by='Amount', ascending=False)

# Display the top investors for 2018
top_investors_2018 = investor_funding_2018_sorted.head(10)
print(top_investors_2018)
# Out:
# Empty DataFrame
# Columns: [Investor, Main_Sector, Amount]
# Index: []

# %%
# Group 2019 data by investor and get the sum of the amount
investor_funding_2019 = df[df['Funding_Year'] == 2019].groupby(['Investor', 'Main_Sector'])['Amount'].sum()

# Reset the index to make 'Investor' a column again
investor_funding_2019_reset = investor_funding_2019.reset_index()

# Sort the data by the funding amount in descending order
investor_funding_2019_sorted = investor_funding_2019_reset.sort_values(by='Amount', ascending=False)

# Display the top investors for 2019
top_investors_2019 = investor_funding_2019_sorted.head(10)
print(top_investors_2019)
# Out:
#                             Investor             Main_Sector      Amount
# 15             World Bank-backed IFC               Transport  60000000.0
# 0                     Accel Partners               Transport  50000000.0
# 6                       M&S Partners             Hospitality  49400000.0
# 1              Accel and Kae Capital           Manufacturing  32000000.0
# 28                   Vertex Ventures         Food & Beverage  25000000.0
# 11      Spring Canter Investment Ltd               Transport  20000000.0
# 29  Wilson Global Opportunities Fund  Health & Life Sciences  15500000.0
# 3                         AngelList.   Software & Technology  12000000.0
# 7                           Neoplux.   Software & Technology  12000000.0
# 26                  Trifecta Capital             Hospitality   7000000.0

# %%
# Group 2019 data by investor and get the sum of the amount
investor_funding_2020 = df[df['Funding_Year'] == 2020].groupby(['Investor', 'Main_Sector'])['Amount'].sum()

# Reset the index to make 'Investor' a column again
investor_funding_2020_reset = investor_funding_2020.reset_index()

# Sort the data by the funding amount in descending order
investor_funding_2020_sorted = investor_funding_2020_reset.sort_values(by='Amount', ascending=False)

# Display the top investors for 2019
top_investors_2020 = investor_funding_2020_sorted.head(10)
print(top_investors_2020)
# Out:
#                                        Investor              Main_Sector  \
# 31                            Freemark holdings        Commerce & Retail
# 48                                  Iron Pillar        Commerce & Retail
# 113                              Times Internet  Media and Entertainment
# 242                                     Temasek   Health & Life Sciences
# 44                              InnoVen Capital        Commerce & Retail
# 252                                     Unknown       Financial Services
# 169                              ICONIQ Capital            Manufacturing
# 32                                  GO Ventures  Media and Entertainment
# 82                               Ribbit Capital       Financial Services
# 229  Small Industries Development Bank of India       Financial Services
#
#           Amount
# 31   200000000.0
# 48   137000000.0
# 113  127000000.0
# 242  115000000.0
# 44   110500000.0
# 252  103000000.0
# 169   90000000.0
# 32    90000000.0
# 82    80000000.0
# 229   80000000.0

# %%
# Group 2019 data by investor and get the sum of the amount
investor_funding_2021 = df[df['Funding_Year'] == 2021].groupby(['Investor', 'Main_Sector'])['Amount'].sum()

# Reset the index to make 'Investor' a column again
investor_funding_2021_reset = investor_funding_2021.reset_index()

# Sort the data by the funding amount in descending order
investor_funding_2021_sorted = investor_funding_2021_reset.sort_values(by='Amount', ascending=False)

# Display the top investors for 2019
top_investors_2021 = investor_funding_2021_sorted.head(10)
print(top_investors_2021)
# Out:
#                            Investor            Main_Sector       Amount
# 425                       TradeCred            Agriculture  600000000.0
# 204                        Softbank              Transport  432300000.0
# 73                      Falcon Edge     Financial Services  300000000.0
# 142               Moonstone Capital      Commerce & Retail  280000000.0
# 24              Andreessen Horowitz     Financial Services  260000000.0
# 145                       Multiples     Financial Services  255000000.0
# 327                   Iconiq Growth     Financial Services  250000000.0
# 98    IIFL Alternate Asset Managers     Financial Services  200000000.0
# 168                 Prosus Ventures  Software & Technology  150000000.0
# 433                         Unknown            Agriculture  150000000.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to create a bar plot for top investors by year
def plot_top_investors(data, year, top_n=5):
    plt.figure(figsize=(12, 8))
    sns.barplot(x='Amount', y='Investor', hue= 'Main_Sector', data=data.head(top_n), dodge=False)
    plt.title(f'Top {top_n} Investors in {year} by Investment Amount and Main Sector')
    plt.xlabel('Investment Amount')
    plt.ylabel('Investor')
    plt.legend(title='Main Sector', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.gca().invert_yaxis()  # Highest value on top
    plt.show()

# Plot for 2019
plot_top_investors(top_investors_2019, 2019)

# Plot for 2020
plot_top_investors(top_investors_2020, 2020)

# Plot for 2021
plot_top_investors(top_investors_2021, 2021)
